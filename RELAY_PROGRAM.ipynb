# %%
# Identify athletes meeting OCTC selection rules

#1. At least 1 athlete per event per gender
#2. Except for 100m, 400m, cap at 3 athletes per event. 100m, 400m capped at 6
#3. Where top athlete is >30 yrs old (except marathon), to include next athlete as well (below 30)
#4. Where althlete qualified in 2 events, to choose the better performing one
#5. For athletes looking to do full time, to write in to SAA for special consideration
#6. Exclude SPEX carded athletes
#7. Except for marathon, age threshold cut off of 40 yrs old for top athlete
#8. No double tapping of prog - potential names in red


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import usual modules
import pandas as pd
import csv
import math
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl
import datetime
from scipy.stats import lognorm
import re
import string
from bs4 import BeautifulSoup
import requests
import unicodedata # for removing accented characters
import datetime

# %%
# Extract timed event records

import pandas_gbq
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(
    '/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json',
    
    
)

sql1="""
SELECT NAME, RESULT, AGE, RANK AS COMPETITION_RANK, DIVISION, EVENT, DOB, COUNTRY, CATEGORY_EVENT, GENDER, WIND, COMPETITION, DATE
FROM `saa-analytics.results.saa_full` 
WHERE DIVISION!='OPEN' AND DIVISION!='Open' AND RESULT!='NM' AND RESULT!='-' AND RESULT!='FOUL' AND RANK!='DNS' AND RESULT!='DNS' AND RESULT!='DNF' AND RESULT!='DNQ' AND RESULT!='DQ' AND RESULT IS NOT NULL
"""

athletes = pandas_gbq.read_gbq(sql1, project_id="saa-analytics", credentials=credentials)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
athletes.to_csv('athletes.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
athletes
# Out:
#                                NAME   RESULT   AGE COMPETITION_RANK DIVISION  \
# 0                REUBEN SEET HUIJIE  19:04.4  None             11.0        A
# 1                  PRANAV SHREEDHAR  18:58.1  None              5.0        A
# 2                         JACOB TAN  18:58.2  None              6.0        A
# 3               SAMUEL TOH JUN XIAN  19:03.8  None              8.0        A
# 4                LIEU YEA JAY ERWIN  19:04.1  None              9.0        A
# ...                             ...      ...   ...              ...      ...
# 21868  CEDAR GIRLS SECONDARY SCHOOL  00:50.1  None                1        B
# 21869         HWA CHONG INSTITUTION  00:50.1  None                1        A
# 21870  CEDAR GIRLS SECONDARY SCHOOL  04:26.2  None                1        C
# 21871       SINGAPORE SPORTS SCHOOL  04:11.7  None                1        B
# 21872         HWA CHONG INSTITUTION  04:16.5  None                1        A
#
#                 EVENT   DOB COUNTRY CATEGORY_EVENT  GENDER  WIND COMPETITION  \
# 0               5000m  None    None           Long    Male  None         NSG
# 1               5000m  None    None           Long    Male  None         NSG
# 2               5000m  None    None           Long    Male  None         NSG
# 3               5000m  None    None           Long    Male  None         NSG
# 4               5000m  None    None           Long    Male  None         NSG
# ...               ...   ...     ...            ...     ...   ...         ...
# 21868  4 X 100m relay  None    None          Relay  Female  None         NSG
# 21869  4 X 100m relay  None    None          Relay  Female  None         NSG
# 21870  4 X 400m relay  None    None          Relay  Female  None         NSG
# 21871  4 X 400m relay  None    None          Relay  Female  None         NSG
# 21872  4 X 400m relay  None    None          Relay  Female  None         NSG
#
#        DATE
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
# ...     ...
# 21868  2022
# 21869  2022
# 21870  2022
# 21871  2022
# 21872  2022
#
# [21873 rows x 13 columns]

# %%
# Create temporary mapped event column

athletes['MAPPED_EVENT']=''

# Correct javelin category

mask = athletes['EVENT'].str.contains(r'Javelin', na=True)
athletes.loc[mask, 'CATEGORY_EVENT'] = 'Throw'


# Running

mask = athletes['EVENT'].str.contains(r'50 Meter Dash', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '50m'
mask = athletes['EVENT'].str.contains(r'60 Meter Dash', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '60m'
mask = athletes['EVENT'].str.contains(r'80 Meter Dash', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '80m'
mask = athletes['EVENT'].str.contains(r'100 Meter Dash', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m'
mask = athletes['EVENT'].str.contains(r'100 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m'
mask = athletes['EVENT'].str.contains(r'100m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m'
mask = athletes['EVENT'].str.contains(r'200 Meter Dash', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '200m'
mask = athletes['EVENT'].str.contains(r'200m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '200m'
mask = athletes['EVENT'].str.contains(r'300 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '300m'
mask = athletes['EVENT'].str.contains(r'400 Meter Dash', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '400m'
mask = athletes['EVENT'].str.contains(r'400m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '400m'
mask = athletes['EVENT'].str.contains(r'600 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '600m'
mask = athletes['EVENT'].str.contains(r'800 Meter Dash', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '800m'
mask = athletes['EVENT'].str.contains(r'800 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '800m'
mask = athletes['EVENT'].str.contains(r'800m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '800m'
mask = athletes['EVENT'].str.contains(r'1500 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '1500m'
mask = athletes['EVENT'].str.contains(r'1500m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '1500m'
mask = athletes['EVENT'].str.contains(r'3000 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m'
mask = athletes['EVENT'].str.contains(r'3000m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m'
mask = athletes['EVENT'].str.contains(r'5000 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '5000m'
mask = athletes['EVENT'].str.contains(r'5000m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '5000m'
mask = athletes['EVENT'].str.contains(r'10000 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '10000m'
mask = athletes['EVENT'].str.contains(r'10000m', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '10000m'
mask = athletes['EVENT'].str.contains(r'1 Mile Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '1 mile'


# Hurdles

mask = athletes['EVENT'].str.contains(r'80m Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '80m hurdles'
mask = athletes['EVENT'].str.contains(r'80m hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '80m hurdles'
mask = athletes['EVENT'].str.contains(r'80 Meter Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '80m hurdles'
mask = athletes['EVENT'].str.contains(r'100m Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m hurdles'
mask = athletes['EVENT'].str.contains(r'100m hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m hurdles'
mask = athletes['EVENT'].str.contains(r'100 Meter Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m hurdles'
mask = athletes['EVENT'].str.contains(r'110m Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '110m hurdles'
mask = athletes['EVENT'].str.contains(r'110 Meter Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '110m hurdles'
mask = athletes['EVENT'].str.contains(r'200m Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '200m hurdles'
mask = athletes['EVENT'].str.contains(r'200m hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '200m hurdles'
mask = athletes['EVENT'].str.contains(r'200 Meter Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '200m hurdles'
mask = athletes['EVENT'].str.contains(r'400m Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '400m hurdles'
mask = athletes['EVENT'].str.contains(r'400m hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '400m hurdles'
mask = athletes['EVENT'].str.contains(r'400 Meter Hurdles', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '400m hurdles'


# Throws

mask = athletes['EVENT'].str.contains(r'Javelin', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Javelin throw'
mask = athletes['EVENT'].str.contains(r'Shot', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Shot put'
mask = athletes['EVENT'].str.contains(r'Hammer', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Hammer throw'
mask = athletes['EVENT'].str.contains(r'Discus', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Discus throw'

# Jumps

mask = athletes['EVENT'].str.contains(r'High Jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'High jump'
mask = athletes['EVENT'].str.contains(r'Long Jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Long jump'
mask = athletes['EVENT'].str.contains(r'Triple Jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Triple jump'
mask = athletes['EVENT'].str.contains(r'Pole Vault', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Pole vault'
mask = athletes['EVENT'].str.contains(r'High jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'High jump'
mask = athletes['EVENT'].str.contains(r'Long jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Long jump'
mask = athletes['EVENT'].str.contains(r'Triple jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Triple jump'
mask = athletes['EVENT'].str.contains(r'Pole vault', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Pole vault'

# Steeplechase

mask = athletes['EVENT'].str.contains(r'2000m S/C', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '2000m steeplechase'
mask = athletes['EVENT'].str.contains(r'2000m steeplechase', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '2000m steeplechase'
mask = athletes['EVENT'].str.contains(r'2000 Meter Steeplechase', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '2000m steeplechase'
mask = athletes['EVENT'].str.contains(r'3000m S/C', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m steeplechase'
mask = athletes['EVENT'].str.contains(r'3000 Meter Steeplechase', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m steeplechase'


# Walk

mask = athletes['EVENT'].str.contains(r'1500 Meter Race Walk', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '1500m race walk'
mask = athletes['EVENT'].str.contains(r'3000m Race Walk', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m race walk'
mask = athletes['EVENT'].str.contains(r'3000 Meter Race Walk', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m race walk'
mask = athletes['EVENT'].str.contains(r'5000 Meter Race Walk', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '5000m race walk'
mask = athletes['EVENT'].str.contains(r'5000m Race Walk', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '5000m race walk'
mask = athletes['EVENT'].str.contains(r'10000 Meter Race Walk', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '10000m race walk'

# Relay

mask = athletes['EVENT'].str.contains(r'4x100m Relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m relay'
mask = athletes['EVENT'].str.contains(r'4 X 100m Relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m relay'
mask = athletes['EVENT'].str.contains(r'4 X 100m relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m relay'
mask = athletes['EVENT'].str.contains(r'4x400m Relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m relay'
mask = athletes['EVENT'].str.contains(r'4 X 400m Relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m relay'
mask = athletes['EVENT'].str.contains(r'4 X 400m relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m relay'
mask = athletes['EVENT'].str.contains(r'4x100 Meter Relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m relay'
mask = athletes['EVENT'].str.contains(r'4x400 Meter Relay', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m relay'

# %%
athletes['MAPPED_AGE']=athletes['AGE']

# Map NSG divisions to age bracket. A=17-20, B=15-17, C=13-14

mask = athletes['DIVISION'].str.contains(r'A', na=True)
athletes.loc[mask, 'MAPPED_AGE'] = '18.5'
mask = athletes['DIVISION'].str.contains(r'B', na=True)
athletes.loc[mask, 'MAPPED_AGE'] = '16'
mask = athletes['DIVISION'].str.contains(r'C', na=True)
athletes.loc[mask, 'MAPPED_AGE'] = '13.5'

# %%
athletes
# Out:
#                                NAME   RESULT   AGE COMPETITION_RANK DIVISION  \
# 0                REUBEN SEET HUIJIE  19:04.4  None             11.0        A
# 1                  PRANAV SHREEDHAR  18:58.1  None              5.0        A
# 2                         JACOB TAN  18:58.2  None              6.0        A
# 3               SAMUEL TOH JUN XIAN  19:03.8  None              8.0        A
# 4                LIEU YEA JAY ERWIN  19:04.1  None              9.0        A
# ...                             ...      ...   ...              ...      ...
# 21868  CEDAR GIRLS SECONDARY SCHOOL  00:50.1  None                1        B
# 21869         HWA CHONG INSTITUTION  00:50.1  None                1        A
# 21870  CEDAR GIRLS SECONDARY SCHOOL  04:26.2  None                1        C
# 21871       SINGAPORE SPORTS SCHOOL  04:11.7  None                1        B
# 21872         HWA CHONG INSTITUTION  04:16.5  None                1        A
#
#                 EVENT   DOB COUNTRY CATEGORY_EVENT  GENDER  WIND COMPETITION  \
# 0               5000m  None    None           Long    Male  None         NSG
# 1               5000m  None    None           Long    Male  None         NSG
# 2               5000m  None    None           Long    Male  None         NSG
# 3               5000m  None    None           Long    Male  None         NSG
# 4               5000m  None    None           Long    Male  None         NSG
# ...               ...   ...     ...            ...     ...   ...         ...
# 21868  4 X 100m relay  None    None          Relay  Female  None         NSG
# 21869  4 X 100m relay  None    None          Relay  Female  None         NSG
# 21870  4 X 400m relay  None    None          Relay  Female  None         NSG
# 21871  4 X 400m relay  None    None          Relay  Female  None         NSG
# 21872  4 X 400m relay  None    None          Relay  Female  None         NSG
#
#        DATE    MAPPED_EVENT MAPPED_AGE
# 0      2023           5000m       18.5
# 1      2023           5000m       18.5
# 2      2023           5000m       18.5
# 3      2023           5000m       18.5
# 4      2023           5000m       18.5
# ...     ...             ...        ...
# 21868  2022  4 x 100m relay         16
# 21869  2022  4 x 100m relay       18.5
# 21870  2022  4 x 400m relay       13.5
# 21871  2022  4 x 400m relay         16
# 21872  2022  4 x 400m relay       18.5
#
# [21873 rows x 15 columns]

# %%
athletes.to_csv('athletes2_relay.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
credentials = service_account.Credentials.from_service_account_file(
    '/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json',
)

sql="""
SELECT NAME, RESULT, RANK, EVENT, CATEGORY_EVENT, GENDER, COMPETITION, STAGE
FROM `saa-analytics.results.saa_full`
WHERE STAGE='Final' AND COMPETITION='SEA Games' AND RANK='3'
"""

benchmarks = pandas_gbq.read_gbq(sql, project_id="saa-analytics", credentials=credentials)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
benchmarks
# Out:
#                                                  NAME    RESULT RANK  \
# 0                              Muhammad Haiqal Hanafi    10.443    3
# 1                                 Lalu Muhammad Zohri     21.02    3
# 2                                   Frederick Ramirez     46.63    3
# 3                       Wan Muhammad Fazri Wan Zahari   1:53.86    3
# 4                                      Robi Syianturi  14:43.45    3
# 5                                       Tan Htike Soe  31:25.55    3
# 6                                         John Cabang    13.855    3
# 7                                         Calvin Quek     50.75    3
# 8                                       Pandu Sukarya   8:55.05    3
# 9     Jonathan Nyepa, Khairul Hafiz Jantan, Mohama...     39.36    3
# 10    Muhammad Firdaus Zemi, Ruslem Zikry Putra Ro...   3:08.82    3
# 11                                 Nguyen Thanh Hoang   2:35:49    3
# 12                                     Pyae Phyo Htun   1:49:39    3
# 13                            Farell Glen Felix Jerus    2.15 m    3
# 14                                Patsapong Amsam-ang    5.20 m    3
# 15                      Sapwaturrahman Sapwaturrahman      7.62    3
# 16                                  Mark Harry Diones      15.7    3
# 17                            Muhammad Ziyad Zolkefli      17.3    3
# 18                               Bandit Singhatongkul     50.02    3
# 19                               Sadat Marzuqi Ajisan     59.76    3
# 20                             Agustinus Abadi Ndiken      66.2    3
# 21                                   Trần Thị Nhi Yến     11.75    3
# 22                          Zaidatul Husniah Zulkifli      23.6    3
# 23                                    Nguyễn Thị Hằng     53.84    3
# 24                                      Goh Chui Ling   2:09.15    3
# 25                                      Goh Chui Ling   4:26.33    3
# 26                              Odekta Elvina Naibaho  17:13.63    3
# 27                              Odekta Elvina Naibaho  35:31.03    3
# 28                                         Dina Aulia     13.59    3
# 29                                    Nguyễn Thị Ngọc     59.09    3
# 30                                   Nguyễn Thị Huong  11:00.85    3
# 31    Azreen Nabila Alias, Nur Afrina Batrisyia, N...     44.58    3
# 32    Sukanya Janchaona, Benny Nontanam, Sasipim S...   3:39.29    3
# 33                        Christine Organiza Hallasgo   2:50:27    3
# 34                             Kotchaphon Tangsrivong   1:57:11    3
# 35                               Michelle Sng Suat Li      1.73    3
# 36                                         Natalie Uy      4.00    3
# 37                                       Bùi Thị Loan      6.02    3
# 38                                   Nguyễn Thị Hương     13.46    3
# 39                               Nani Sahirah Maryata     14.44    3
# 40                                    Lê Thị Cẩm Dung     45.08    3
# 41                               Nurul Hidayah Lukman     49.61    3
# 42                                   Evalyn Palabrica     48.31    3
# 43                               Sunisa Khotseemueang      None    3
# 44                                 Aries Bañez Toledo      None    3
#
#                  EVENT CATEGORY_EVENT  GENDER COMPETITION  STAGE
# 0                 100m         Sprint    Male   SEA Games  Final
# 1                 200m         Sprint    Male   SEA Games  Final
# 2                 400m         Sprint    Male   SEA Games  Final
# 3                 800m            Mid    Male   SEA Games  Final
# 4                5000m           Long    Male   SEA Games  Final
# 5               10000m         Sprint    Male   SEA Games  Final
# 6         110m hurdles        Hurdles    Male   SEA Games  Final
# 7         400m hurdles        Hurdles    Male   SEA Games  Final
# 8   3000m steeplechase        Steeple    Male   SEA Games  Final
# 9       4 x 100m relay          Relay    Male   SEA Games  Final
# 10      4 x 400m relay          Relay    Male   SEA Games  Final
# 11            Marathon       Marathon    Male   SEA Games  Final
# 12      20km race walk           Walk    Male   SEA Games  Final
# 13           High jump           Jump    Male   SEA Games  Final
# 14          Pole vault           Jump    Male   SEA Games  Final
# 15           Long jump           Jump    Male   SEA Games  Final
# 16         Triple jump           Jump    Male   SEA Games  Final
# 17            Shot put          Throw    Male   SEA Games  Final
# 18        Discus throw          Throw    Male   SEA Games  Final
# 19        Hammer throw          Throw    Male   SEA Games  Final
# 20       Javelin throw          Throw    Male   SEA Games  Final
# 21                100m         Sprint  Female   SEA Games  Final
# 22                200m         Sprint  Female   SEA Games  Final
# 23                400m         Sprint  Female   SEA Games  Final
# 24                800m            Mid  Female   SEA Games  Final
# 25               1500m            Mid  Female   SEA Games  Final
# 26               5000m           Long  Female   SEA Games  Final
# 27              10000m         Sprint  Female   SEA Games  Final
# 28        100m hurdles        Hurdles  Female   SEA Games  Final
# 29        400m hurdles        Hurdles  Female   SEA Games  Final
# 30  3000m steeplechase        Steeple  Female   SEA Games  Final
# 31      4 x 100m relay          Relay  Female   SEA Games  Final
# 32      4 x 400m relay          Relay  Female   SEA Games  Final
# 33            Marathon       Marathon  Female   SEA Games  Final
# 34      20km race walk           Walk  Female   SEA Games  Final
# 35           High jump           Jump  Female   SEA Games  Final
# 36          Pole vault           Jump  Female   SEA Games  Final
# 37           Long jump           Jump  Female   SEA Games  Final
# 38         Triple jump           Jump  Female   SEA Games  Final
# 39            Shot put          Throw  Female   SEA Games  Final
# 40        Discus throw          Throw  Female   SEA Games  Final
# 41        Hammer throw          Throw  Female   SEA Games  Final
# 42       Javelin throw          Throw  Female   SEA Games  Final
# 43          Heptathlon     Heptathlon  Female   SEA Games  Final
# 44           Decathlon      Decathlon    Male   SEA Games  Final

# %%
# rename RESULT column name

benchmarks.rename(columns = {'RESULT':'BENCHMARK'}, inplace = True)

# %%
# drop columns

benchmarks.drop(['NAME', 'RANK', 'CATEGORY_EVENT', 'COMPETITION', 'STAGE'], axis=1, inplace=True)

# %%
benchmarks
# Out:
#    BENCHMARK               EVENT  GENDER
# 0     10.443                100m    Male
# 1      21.02                200m    Male
# 2      46.63                400m    Male
# 3    1:53.86                800m    Male
# 4   14:43.45               5000m    Male
# 5   31:25.55              10000m    Male
# 6     13.855        110m hurdles    Male
# 7      50.75        400m hurdles    Male
# 8    8:55.05  3000m steeplechase    Male
# 9      39.36      4 x 100m relay    Male
# 10   3:08.82      4 x 400m relay    Male
# 11   2:35:49            Marathon    Male
# 12   1:49:39      20km race walk    Male
# 13    2.15 m           High jump    Male
# 14    5.20 m          Pole vault    Male
# 15      7.62           Long jump    Male
# 16      15.7         Triple jump    Male
# 17      17.3            Shot put    Male
# 18     50.02        Discus throw    Male
# 19     59.76        Hammer throw    Male
# 20      66.2       Javelin throw    Male
# 21     11.75                100m  Female
# 22      23.6                200m  Female
# 23     53.84                400m  Female
# 24   2:09.15                800m  Female
# 25   4:26.33               1500m  Female
# 26  17:13.63               5000m  Female
# 27  35:31.03              10000m  Female
# 28     13.59        100m hurdles  Female
# 29     59.09        400m hurdles  Female
# 30  11:00.85  3000m steeplechase  Female
# 31     44.58      4 x 100m relay  Female
# 32   3:39.29      4 x 400m relay  Female
# 33   2:50:27            Marathon  Female
# 34   1:57:11      20km race walk  Female
# 35      1.73           High jump  Female
# 36      4.00          Pole vault  Female
# 37      6.02           Long jump  Female
# 38     13.46         Triple jump  Female
# 39     14.44            Shot put  Female
# 40     45.08        Discus throw  Female
# 41     49.61        Hammer throw  Female
# 42     48.31       Javelin throw  Female
# 43      None          Heptathlon  Female
# 44      None           Decathlon    Male

# %%
# Converts any time format into seconds

def convert_time(i, string, metric):

    global output
    
    l=['discus', 'throw', 'jump', 'vault', 'shot']
        
    string=string.lower()    
    
    if any(s in string for s in l)==True:
        
        if 'm' in metric:
            
            metric=metric.replace('m', '')
            output=float(str(metric))
            
        elif 'GR' in metric:
            
            metric=metric.replace('GR', '')
            output=float(str(metric))


        else:
    
            output=float(str(metric))
        
    else:
        
        searchstring = ":"
        searchstring2 = "."
        substring=str(metric)
        count = substring.count(searchstring)
        count2 = substring.count(searchstring2)
            
        if count==0:
            output=float(substring)
                        
             
        elif (type(metric)==datetime.time or type(metric)==datetime.datetime):
                                                
            time=str(metric)
            h, m ,s = time.split(':')
            output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
            
                                
        elif (count==1 and count2==1):
            
            m,s = metric.split(':')
            output = float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds())
            
            if output==229.90:
                print(metric, m, s, output, 'here')

                     
        elif (count==1 and count2==2):
            
            metric = metric.replace(".", ":", 1)
            
            h,m,s = metric.split(':')            
            output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
                
        
        elif (count==2 and count2==0):
            
            h,m,s = metric.split(':')
            output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
            
                
    return output

# %%
for i in range(len(benchmarks)):
        
    rowIndex = benchmarks.index[i]

    input_string=benchmarks.iloc[rowIndex,1]
    
    metric=benchmarks.iloc[rowIndex,0]
    
    if metric==None:
        continue
        
    out = convert_time(i, input_string, metric)
     
    benchmarks.loc[rowIndex, 'Metric'] = out

# %%
benchmarks
# Out:
#    BENCHMARK               EVENT  GENDER     Metric
# 0     10.443                100m    Male     10.443
# 1      21.02                200m    Male     21.020
# 2      46.63                400m    Male     46.630
# 3    1:53.86                800m    Male    113.860
# 4   14:43.45               5000m    Male    883.450
# 5   31:25.55              10000m    Male   1885.550
# 6     13.855        110m hurdles    Male     13.855
# 7      50.75        400m hurdles    Male     50.750
# 8    8:55.05  3000m steeplechase    Male    535.050
# 9      39.36      4 x 100m relay    Male     39.360
# 10   3:08.82      4 x 400m relay    Male    188.820
# 11   2:35:49            Marathon    Male   9349.000
# 12   1:49:39      20km race walk    Male   6579.000
# 13    2.15 m           High jump    Male      2.150
# 14    5.20 m          Pole vault    Male      5.200
# 15      7.62           Long jump    Male      7.620
# 16      15.7         Triple jump    Male     15.700
# 17      17.3            Shot put    Male     17.300
# 18     50.02        Discus throw    Male     50.020
# 19     59.76        Hammer throw    Male     59.760
# 20      66.2       Javelin throw    Male     66.200
# 21     11.75                100m  Female     11.750
# 22      23.6                200m  Female     23.600
# 23     53.84                400m  Female     53.840
# 24   2:09.15                800m  Female    129.150
# 25   4:26.33               1500m  Female    266.330
# 26  17:13.63               5000m  Female   1033.630
# 27  35:31.03              10000m  Female   2131.030
# 28     13.59        100m hurdles  Female     13.590
# 29     59.09        400m hurdles  Female     59.090
# 30  11:00.85  3000m steeplechase  Female    660.850
# 31     44.58      4 x 100m relay  Female     44.580
# 32   3:39.29      4 x 400m relay  Female    219.290
# 33   2:50:27            Marathon  Female  10227.000
# 34   1:57:11      20km race walk  Female   7031.000
# 35      1.73           High jump  Female      1.730
# 36      4.00          Pole vault  Female      4.000
# 37      6.02           Long jump  Female      6.020
# 38     13.46         Triple jump  Female     13.460
# 39     14.44            Shot put  Female     14.440
# 40     45.08        Discus throw  Female     45.080
# 41     49.61        Hammer throw  Female     49.610
# 42     48.31       Javelin throw  Female     48.310
# 43      None          Heptathlon  Female        NaN
# 44      None           Decathlon    Male        NaN

# %%
# Calculate performance windows
# Jump, throw, pole vault and shotput events are +ve distance, whereas the others are -ve timing

mask = benchmarks['EVENT'].str.contains(r'jump|throw|Pole|put', na=True)

benchmarks.loc[mask, '2pc']=benchmarks['Metric']*0.98
benchmarks.loc[mask, '35pc']=benchmarks['Metric']*0.965
benchmarks.loc[mask, '5pc']=benchmarks['Metric']*0.95

benchmarks.loc[~mask, '2pc']=benchmarks['Metric']*1.02
benchmarks.loc[~mask, '35pc']=benchmarks['Metric']*1.035
benchmarks.loc[~mask, '5pc']=benchmarks['Metric']*1.05


#benchmarks.iloc[5, [1]]='10000m run'
#benchmarks.iloc[28, [1]]='10000m run'
#benchmarks.iloc[26, [1]]='1500m'

# %%
benchmarks['MAPPED_EVENT']=benchmarks['EVENT']

# %%
benchmarks
# Out:
#    BENCHMARK               EVENT  GENDER     Metric          2pc  \
# 0     10.443                100m    Male     10.443     10.65186
# 1      21.02                200m    Male     21.020     21.44040
# 2      46.63                400m    Male     46.630     47.56260
# 3    1:53.86                800m    Male    113.860    116.13720
# 4   14:43.45               5000m    Male    883.450    901.11900
# 5   31:25.55              10000m    Male   1885.550   1923.26100
# 6     13.855        110m hurdles    Male     13.855     14.13210
# 7      50.75        400m hurdles    Male     50.750     51.76500
# 8    8:55.05  3000m steeplechase    Male    535.050    545.75100
# 9      39.36      4 x 100m relay    Male     39.360     40.14720
# 10   3:08.82      4 x 400m relay    Male    188.820    192.59640
# 11   2:35:49            Marathon    Male   9349.000   9535.98000
# 12   1:49:39      20km race walk    Male   6579.000   6710.58000
# 13    2.15 m           High jump    Male      2.150      2.10700
# 14    5.20 m          Pole vault    Male      5.200      5.09600
# 15      7.62           Long jump    Male      7.620      7.46760
# 16      15.7         Triple jump    Male     15.700     15.38600
# 17      17.3            Shot put    Male     17.300     16.95400
# 18     50.02        Discus throw    Male     50.020     49.01960
# 19     59.76        Hammer throw    Male     59.760     58.56480
# 20      66.2       Javelin throw    Male     66.200     64.87600
# 21     11.75                100m  Female     11.750     11.98500
# 22      23.6                200m  Female     23.600     24.07200
# 23     53.84                400m  Female     53.840     54.91680
# 24   2:09.15                800m  Female    129.150    131.73300
# 25   4:26.33               1500m  Female    266.330    271.65660
# 26  17:13.63               5000m  Female   1033.630   1054.30260
# 27  35:31.03              10000m  Female   2131.030   2173.65060
# 28     13.59        100m hurdles  Female     13.590     13.86180
# 29     59.09        400m hurdles  Female     59.090     60.27180
# 30  11:00.85  3000m steeplechase  Female    660.850    674.06700
# 31     44.58      4 x 100m relay  Female     44.580     45.47160
# 32   3:39.29      4 x 400m relay  Female    219.290    223.67580
# 33   2:50:27            Marathon  Female  10227.000  10431.54000
# 34   1:57:11      20km race walk  Female   7031.000   7171.62000
# 35      1.73           High jump  Female      1.730      1.69540
# 36      4.00          Pole vault  Female      4.000      3.92000
# 37      6.02           Long jump  Female      6.020      5.89960
# 38     13.46         Triple jump  Female     13.460     13.19080
# 39     14.44            Shot put  Female     14.440     14.15120
# 40     45.08        Discus throw  Female     45.080     44.17840
# 41     49.61        Hammer throw  Female     49.610     48.61780
# 42     48.31       Javelin throw  Female     48.310     47.34380
# 43      None          Heptathlon  Female        NaN          NaN
# 44      None           Decathlon    Male        NaN          NaN
#
#             35pc          5pc        MAPPED_EVENT
# 0      10.808505     10.96515                100m
# 1      21.755700     22.07100                200m
# 2      48.262050     48.96150                400m
# 3     117.845100    119.55300                800m
# 4     914.370750    927.62250               5000m
# 5    1951.544250   1979.82750              10000m
# 6      14.339925     14.54775        110m hurdles
# 7      52.526250     53.28750        400m hurdles
# 8     553.776750    561.80250  3000m steeplechase
# 9      40.737600     41.32800      4 x 100m relay
# 10    195.428700    198.26100      4 x 400m relay
# 11   9676.215000   9816.45000            Marathon
# 12   6809.265000   6907.95000      20km race walk
# 13      2.074750      2.04250           High jump
# 14      5.018000      4.94000          Pole vault
# 15      7.353300      7.23900           Long jump
# 16     15.150500     14.91500         Triple jump
# 17     16.694500     16.43500            Shot put
# 18     48.269300     47.51900        Discus throw
# 19     57.668400     56.77200        Hammer throw
# 20     63.883000     62.89000       Javelin throw
# 21     12.161250     12.33750                100m
# 22     24.426000     24.78000                200m
# 23     55.724400     56.53200                400m
# 24    133.670250    135.60750                800m
# 25    275.651550    279.64650               1500m
# 26   1069.807050   1085.31150               5000m
# 27   2205.616050   2237.58150              10000m
# 28     14.065650     14.26950        100m hurdles
# 29     61.158150     62.04450        400m hurdles
# 30    683.979750    693.89250  3000m steeplechase
# 31     46.140300     46.80900      4 x 100m relay
# 32    226.965150    230.25450      4 x 400m relay
# 33  10584.945000  10738.35000            Marathon
# 34   7277.085000   7382.55000      20km race walk
# 35      1.669450      1.64350           High jump
# 36      3.860000      3.80000          Pole vault
# 37      5.809300      5.71900           Long jump
# 38     12.988900     12.78700         Triple jump
# 39     13.934600     13.71800            Shot put
# 40     43.502200     42.82600        Discus throw
# 41     47.873650     47.12950        Hammer throw
# 42     46.619150     45.89450       Javelin throw
# 43           NaN          NaN          Heptathlon
# 44           NaN          NaN           Decathlon

# %%
athletes
# Out:
#                                NAME   RESULT   AGE COMPETITION_RANK DIVISION  \
# 0                REUBEN SEET HUIJIE  19:04.4  None             11.0        A
# 1                  PRANAV SHREEDHAR  18:58.1  None              5.0        A
# 2                         JACOB TAN  18:58.2  None              6.0        A
# 3               SAMUEL TOH JUN XIAN  19:03.8  None              8.0        A
# 4                LIEU YEA JAY ERWIN  19:04.1  None              9.0        A
# ...                             ...      ...   ...              ...      ...
# 21868  CEDAR GIRLS SECONDARY SCHOOL  00:50.1  None                1        B
# 21869         HWA CHONG INSTITUTION  00:50.1  None                1        A
# 21870  CEDAR GIRLS SECONDARY SCHOOL  04:26.2  None                1        C
# 21871       SINGAPORE SPORTS SCHOOL  04:11.7  None                1        B
# 21872         HWA CHONG INSTITUTION  04:16.5  None                1        A
#
#                 EVENT   DOB COUNTRY CATEGORY_EVENT  GENDER  WIND COMPETITION  \
# 0               5000m  None    None           Long    Male  None         NSG
# 1               5000m  None    None           Long    Male  None         NSG
# 2               5000m  None    None           Long    Male  None         NSG
# 3               5000m  None    None           Long    Male  None         NSG
# 4               5000m  None    None           Long    Male  None         NSG
# ...               ...   ...     ...            ...     ...   ...         ...
# 21868  4 X 100m relay  None    None          Relay  Female  None         NSG
# 21869  4 X 100m relay  None    None          Relay  Female  None         NSG
# 21870  4 X 400m relay  None    None          Relay  Female  None         NSG
# 21871  4 X 400m relay  None    None          Relay  Female  None         NSG
# 21872  4 X 400m relay  None    None          Relay  Female  None         NSG
#
#        DATE    MAPPED_EVENT MAPPED_AGE
# 0      2023           5000m       18.5
# 1      2023           5000m       18.5
# 2      2023           5000m       18.5
# 3      2023           5000m       18.5
# 4      2023           5000m       18.5
# ...     ...             ...        ...
# 21868  2022  4 x 100m relay         16
# 21869  2022  4 x 100m relay       18.5
# 21870  2022  4 x 400m relay       13.5
# 21871  2022  4 x 400m relay         16
# 21872  2022  4 x 400m relay       18.5
#
# [21873 rows x 15 columns]

# %%
# Left join benchmarks table to athletes table

df = athletes.reset_index().merge(benchmarks.reset_index(), on=['MAPPED_EVENT','GENDER'], how='left')
#df = athletes.merge(benchmarks, on=['EVENT','GENDER'], how='left')

# %%
df
# Out:
#        index_x                          NAME   RESULT   AGE COMPETITION_RANK  \
# 0            0            REUBEN SEET HUIJIE  19:04.4  None             11.0
# 1            1              PRANAV SHREEDHAR  18:58.1  None              5.0
# 2            2                     JACOB TAN  18:58.2  None              6.0
# 3            3           SAMUEL TOH JUN XIAN  19:03.8  None              8.0
# 4            4            LIEU YEA JAY ERWIN  19:04.1  None              9.0
# ...        ...                           ...      ...   ...              ...
# 21868    21868  CEDAR GIRLS SECONDARY SCHOOL  00:50.1  None                1
# 21869    21869         HWA CHONG INSTITUTION  00:50.1  None                1
# 21870    21870  CEDAR GIRLS SECONDARY SCHOOL  04:26.2  None                1
# 21871    21871       SINGAPORE SPORTS SCHOOL  04:11.7  None                1
# 21872    21872         HWA CHONG INSTITUTION  04:16.5  None                1
#
#       DIVISION         EVENT_x   DOB COUNTRY CATEGORY_EVENT  ...  DATE  \
# 0            A           5000m  None    None           Long  ...  2023
# 1            A           5000m  None    None           Long  ...  2023
# 2            A           5000m  None    None           Long  ...  2023
# 3            A           5000m  None    None           Long  ...  2023
# 4            A           5000m  None    None           Long  ...  2023
# ...        ...             ...   ...     ...            ...  ...   ...
# 21868        B  4 X 100m relay  None    None          Relay  ...  2022
# 21869        A  4 X 100m relay  None    None          Relay  ...  2022
# 21870        C  4 X 400m relay  None    None          Relay  ...  2022
# 21871        B  4 X 400m relay  None    None          Relay  ...  2022
# 21872        A  4 X 400m relay  None    None          Relay  ...  2022
#
#          MAPPED_EVENT MAPPED_AGE index_y BENCHMARK         EVENT_y  Metric  \
# 0               5000m       18.5     4.0  14:43.45           5000m  883.45
# 1               5000m       18.5     4.0  14:43.45           5000m  883.45
# 2               5000m       18.5     4.0  14:43.45           5000m  883.45
# 3               5000m       18.5     4.0  14:43.45           5000m  883.45
# 4               5000m       18.5     4.0  14:43.45           5000m  883.45
# ...               ...        ...     ...       ...             ...     ...
# 21868  4 x 100m relay         16    31.0     44.58  4 x 100m relay   44.58
# 21869  4 x 100m relay       18.5    31.0     44.58  4 x 100m relay   44.58
# 21870  4 x 400m relay       13.5    32.0   3:39.29  4 x 400m relay  219.29
# 21871  4 x 400m relay         16    32.0   3:39.29  4 x 400m relay  219.29
# 21872  4 x 400m relay       18.5    32.0   3:39.29  4 x 400m relay  219.29
#
#             2pc       35pc       5pc
# 0      901.1190  914.37075  927.6225
# 1      901.1190  914.37075  927.6225
# 2      901.1190  914.37075  927.6225
# 3      901.1190  914.37075  927.6225
# 4      901.1190  914.37075  927.6225
# ...         ...        ...       ...
# 21868   45.4716   46.14030   46.8090
# 21869   45.4716   46.14030   46.8090
# 21870  223.6758  226.96515  230.2545
# 21871  223.6758  226.96515  230.2545
# 21872  223.6758  226.96515  230.2545
#
# [21873 rows x 23 columns]

# %%
# Choose 100m,200m and 400m event

relay_df = df.loc[(df['MAPPED_EVENT'] == '100m') | (df['MAPPED_EVENT'] == '200m') | (df['MAPPED_EVENT']=='400m')]

# %%
relay_df
# Out:
#        index_x                                    NAME   RESULT   AGE  \
# 65          65                           CHUA CHEE HON  00:20.5  None
# 66          66                          O'NEAL TERENCE  00:33.3  None
# 67          67                     MARCUS ANG GEE HONG  00:15.7  None
# 68          68                          DHYAN JEEVANTH  00:17.4  None
# 69          69  MOHAMMAD ZULKHAIRI LUTFI BIN MOHD AZAM  00:13.9  None
# ...        ...                                     ...      ...   ...
# 21829    21829                     ELIZABETH LEE SHYIN  00:27.9  None
# 21830    21830                        GOH EN YA ELEANA  00:26.2  None
# 21831    21831                            TONG YAN YEE  01:02.4  None
# 21832    21832                   LAAVINIA D/O JAIGANTH  01:00.3  None
# 21833    21833                             CHOO JIA YI  01:03.9  None
#
#       COMPETITION_RANK DIVISION    EVENT_x   DOB COUNTRY CATEGORY_EVENT  ...  \
# 65                 4.0        A  Para 100m  None    None         Sprint  ...
# 66                 5.0        A  Para 100m  None    None         Sprint  ...
# 67                 2.0        A  Para 100m  None    None         Sprint  ...
# 68                 3.0        A  Para 100m  None    None         Sprint  ...
# 69                 1.0        A  Para 100m  None    None         Sprint  ...
# ...                ...      ...        ...   ...     ...            ...  ...
# 21829                1        C       200m  None    None         Sprint  ...
# 21830                1        A       200m  None    None         Sprint  ...
# 21831                1        A       400m  None    None         Sprint  ...
# 21832                1        B       400m  None    None         Sprint  ...
# 21833                1        C       400m  None    None         Sprint  ...
#
#        DATE MAPPED_EVENT MAPPED_AGE index_y BENCHMARK EVENT_y  Metric  \
# 65     2023         100m       18.5     0.0    10.443    100m  10.443
# 66     2023         100m       18.5     0.0    10.443    100m  10.443
# 67     2023         100m       18.5     0.0    10.443    100m  10.443
# 68     2023         100m       18.5     0.0    10.443    100m  10.443
# 69     2023         100m       18.5     0.0    10.443    100m  10.443
# ...     ...          ...        ...     ...       ...     ...     ...
# 21829  2022         200m       13.5    22.0      23.6    200m  23.600
# 21830  2022         200m       18.5    22.0      23.6    200m  23.600
# 21831  2022         400m       18.5    23.0     53.84    400m  53.840
# 21832  2022         400m         16    23.0     53.84    400m  53.840
# 21833  2022         400m       13.5    23.0     53.84    400m  53.840
#
#             2pc       35pc       5pc
# 65     10.65186  10.808505  10.96515
# 66     10.65186  10.808505  10.96515
# 67     10.65186  10.808505  10.96515
# 68     10.65186  10.808505  10.96515
# 69     10.65186  10.808505  10.96515
# ...         ...        ...       ...
# 21829  24.07200  24.426000  24.78000
# 21830  24.07200  24.426000  24.78000
# 21831  54.91680  55.724400  56.53200
# 21832  54.91680  55.724400  56.53200
# 21833  54.91680  55.724400  56.53200
#
# [9013 rows x 23 columns]

# %%
# Fill in '-' with np.NaN

relay_df['RESULT'] = relay_df['RESULT'].replace(regex=r'–', value=np.NaN)
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_45688/3629637655.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relay_df['RESULT'] = relay_df['RESULT'].replace(regex=r'–', value=np.NaN)

# %%
# Reset index for index iteration below

relay_df=relay_df.reset_index(drop=True)

relay_df['index_x']=relay_df.index

relay_df
# Out:
#       index_x                                    NAME   RESULT   AGE  \
# 0           0                           CHUA CHEE HON  00:20.5  None
# 1           1                          O'NEAL TERENCE  00:33.3  None
# 2           2                     MARCUS ANG GEE HONG  00:15.7  None
# 3           3                          DHYAN JEEVANTH  00:17.4  None
# 4           4  MOHAMMAD ZULKHAIRI LUTFI BIN MOHD AZAM  00:13.9  None
# ...       ...                                     ...      ...   ...
# 9008     9008                     ELIZABETH LEE SHYIN  00:27.9  None
# 9009     9009                        GOH EN YA ELEANA  00:26.2  None
# 9010     9010                            TONG YAN YEE  01:02.4  None
# 9011     9011                   LAAVINIA D/O JAIGANTH  01:00.3  None
# 9012     9012                             CHOO JIA YI  01:03.9  None
#
#      COMPETITION_RANK DIVISION    EVENT_x   DOB COUNTRY CATEGORY_EVENT  ...  \
# 0                 4.0        A  Para 100m  None    None         Sprint  ...
# 1                 5.0        A  Para 100m  None    None         Sprint  ...
# 2                 2.0        A  Para 100m  None    None         Sprint  ...
# 3                 3.0        A  Para 100m  None    None         Sprint  ...
# 4                 1.0        A  Para 100m  None    None         Sprint  ...
# ...               ...      ...        ...   ...     ...            ...  ...
# 9008                1        C       200m  None    None         Sprint  ...
# 9009                1        A       200m  None    None         Sprint  ...
# 9010                1        A       400m  None    None         Sprint  ...
# 9011                1        B       400m  None    None         Sprint  ...
# 9012                1        C       400m  None    None         Sprint  ...
#
#       DATE MAPPED_EVENT MAPPED_AGE index_y BENCHMARK EVENT_y  Metric  \
# 0     2023         100m       18.5     0.0    10.443    100m  10.443
# 1     2023         100m       18.5     0.0    10.443    100m  10.443
# 2     2023         100m       18.5     0.0    10.443    100m  10.443
# 3     2023         100m       18.5     0.0    10.443    100m  10.443
# 4     2023         100m       18.5     0.0    10.443    100m  10.443
# ...    ...          ...        ...     ...       ...     ...     ...
# 9008  2022         200m       13.5    22.0      23.6    200m  23.600
# 9009  2022         200m       18.5    22.0      23.6    200m  23.600
# 9010  2022         400m       18.5    23.0     53.84    400m  53.840
# 9011  2022         400m         16    23.0     53.84    400m  53.840
# 9012  2022         400m       13.5    23.0     53.84    400m  53.840
#
#            2pc       35pc       5pc
# 0     10.65186  10.808505  10.96515
# 1     10.65186  10.808505  10.96515
# 2     10.65186  10.808505  10.96515
# 3     10.65186  10.808505  10.96515
# 4     10.65186  10.808505  10.96515
# ...        ...        ...       ...
# 9008  24.07200  24.426000  24.78000
# 9009  24.07200  24.426000  24.78000
# 9010  54.91680  55.724400  56.53200
# 9011  54.91680  55.724400  56.53200
# 9012  54.91680  55.724400  56.53200
#
# [9013 rows x 23 columns]

# %%
#df = df.drop(['index', 'index_x'], axis=1)

# %%
relay_df.to_csv('df_relay.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
# Convert results into seconds format

for i in range(len(relay_df)):
    
        
    rowIndex = relay_df.index[i]
    
        
    input_string=relay_df.iloc[rowIndex,14]    
    
    metric=relay_df.iloc[rowIndex,2]
        
    if metric=='—' or metric=='DQ' or metric=='SCR' or metric=='FS' or metric=='DNQ' or metric==' DNS' or metric=='NH':
        continue
    
    print(i, input_string, metric)
        
    out = convert_time(i, input_string, metric)
         
    relay_df.loc[rowIndex, 'RESULT_CONV'] = out
# Out:
# 0 100m 00:20.5
# 1 100m 00:33.3
# 2 100m 00:15.7
# 3 100m 00:17.4
# 4 100m 00:13.9
# 716 200m 00:25.1
# 717 200m 00:25.8
# 718 200m 00:25.5
# 719 200m 00:23.7
# 720 200m 00:25.8
# 721 200m 00:23.8
# 722 200m 00:28.4
# 723 200m 00:24.0
# 724 200m 00:26.8
# 725 200m 00:26.9
# 726 200m 00:24.2
# 727 200m 00:25.2
# 728 200m 00:24.3
# 729 200m 00:27.5
# 730 200m 00:24.8
# 731 200m 00:24.7
# 732 200m 00:23.4
# 733 200m 00:25.9
# 734 200m 00:23.9
# 735 200m 00:23.7
# 736 200m 00:24.7
# 737 200m 00:25.1
# 738 200m 00:23.1
# 739 200m 00:24.2
# 740 200m 00:25.7
# 741 200m 00:23.8
# 742 200m 00:24.7
# 743 200m 00:25.8
# 744 200m 00:25.4
# 745 200m 00:24.3
# 746 200m 00:25.0
# 747 200m 00:22.5
# 748 200m 00:24.2
# 749 200m 00:23.7
# 750 200m 00:24.4
# 751 200m 00:25.1
# 752 200m 00:23.6
# 753 200m 00:23.8
# 754 200m 00:24.1
# 755 200m 00:24.6
# 756 200m 00:23.1
# 757 200m 00:23.3
# 758 200m 00:23.6
# 759 200m 00:24.0
# 760 200m 00:22.7
# 761 200m 00:21.9
# 762 200m 00:23.0
# 763 200m 00:24.1
# 764 200m 00:23.4
# 765 200m 00:22.5
# 766 200m 00:28.5
# 767 200m 00:25.4
# 768 200m 00:25.8
# 769 200m 00:24.7
# 770 200m 00:29.9
# 771 200m 00:25.7
# 772 200m 00:30.4
# 773 200m 00:25.0
# 774 200m 00:23.4
# 775 200m 00:27.3
# 776 200m 00:26.5
# 777 200m 00:25.9
# 778 200m 00:23.5
# 779 200m 00:26.5
# 780 200m 00:24.7
# 781 200m 00:30.1
# 782 200m 00:24.8
# 783 200m 00:28.7
# 784 200m 00:31.1
# 785 200m 00:24.3
# 786 200m 00:31.2
# 787 200m 00:30.0
# 788 200m 00:25.6
# 789 200m 00:29.6
# 790 200m 00:24.4
# 791 200m 00:31.5
# 792 200m 00:24.4
# 793 200m 00:29.9
# 794 200m 00:30.6
# 795 200m 00:25.0
# 796 200m 00:26.1
# 797 200m 00:28.2
# 798 200m 00:27.2
# 799 200m 00:25.8
# 800 200m 00:26.0
# 801 200m 00:24.6
# 802 200m 00:25.8
# 803 200m 00:25.4
# 804 200m 00:26.2
# 805 200m 00:27.3
# 806 200m 00:26.9
# 807 200m 00:24.2
# 808 200m 00:24.7
# 809 200m 00:28.4
# 810 200m 00:26.6
# 811 200m 00:29.5
# 812 200m 00:27.3
# 813 200m 00:24.3
# 814 200m 00:28.2
# 815 200m 00:25.9
# 816 200m 00:24.4
# 817 200m 00:26.6
# 818 200m 00:27.4
# 819 200m 00:29.8
# 820 200m 00:23.7
# 821 200m 00:24.2
# 822 200m 00:24.7
# 823 200m 00:28.4
# 824 200m 00:27.6
# 825 200m 00:26.7
# 826 200m 00:26.6
# 827 200m 00:29.1
# 828 200m 00:27.8
# 829 200m 00:23.8
# 830 200m 00:24.8
# 831 200m 00:26.4
# 832 200m 00:25.3
# 833 200m 00:24.5
# 1           1                          O'NEAL TERENCE  00:33.3  None
# 2           2                     MARCUS ANG GEE HONG  00:15.7  None
# 3           3                          DHYAN JEEVANTH  00:17.4  None
# 4           4  MOHAMMAD ZULKHAIRI LUTFI BIN MOHD AZAM  00:13.9  None
# ...       ...                                     ...      ...   ...
# 9008     9008                     ELIZABETH LEE SHYIN  00:27.9  None
# 9009     9009                        GOH EN YA ELEANA  00:26.2  None
# 9010     9010                            TONG YAN YEE  01:02.4  None
# 9011     9011                   LAAVINIA D/O JAIGANTH  01:00.3  None
# 9012     9012                             CHOO JIA YI  01:03.9  None
#
#      COMPETITION_RANK DIVISION    EVENT_x   DOB COUNTRY CATEGORY_EVENT  ...  \
# 0                 4.0        A  Para 100m  None    None         Sprint  ...
# 1                 5.0        A  Para 100m  None    None         Sprint  ...
# 2                 2.0        A  Para 100m  None    None         Sprint  ...
# 3                 3.0        A  Para 100m  None    None         Sprint  ...
# 4                 1.0        A  Para 100m  None    None         Sprint  ...
# ...               ...      ...        ...   ...     ...            ...  ...
# 9008                1        C       200m  None    None         Sprint  ...
# 9009                1        A       200m  None    None         Sprint  ...
# 9010                1        A       400m  None    None         Sprint  ...
# 9011                1        B       400m  None    None         Sprint  ...
# 9012                1        C       400m  None    None         Sprint  ...
#
#      MAPPED_EVENT MAPPED_AGE index_y BENCHMARK EVENT_y  Metric       2pc  \
# 0            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 1            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 2            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 3            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 4            100m       18.5     0.0    10.443    100m  10.443  10.65186
# ...           ...        ...     ...       ...     ...     ...       ...
# 9008         200m       13.5    22.0      23.6    200m  23.600  24.07200
# 9009         200m       18.5    22.0      23.6    200m  23.600  24.07200
# 9010         400m       18.5    23.0     53.84    400m  53.840  54.91680
# 9011         400m         16    23.0     53.84    400m  53.840  54.91680
# 9012         400m       13.5    23.0     53.84    400m  53.840  54.91680
#
#            35pc       5pc  RESULT_CONV
# 0     10.808505  10.96515         20.5
# 1     10.808505  10.96515         33.3
# 2     10.808505  10.96515         15.7
# 3     10.808505  10.96515         17.4
# 4     10.808505  10.96515         13.9
# ...         ...       ...          ...
# 9008  24.426000  24.78000         27.9
# 9009  24.426000  24.78000         26.2
# 9010  55.724400  56.53200         62.4
# 9011  55.724400  56.53200         60.3
# 9012  55.724400  56.53200         63.9
#
# [9013 rows x 24 columns]

# %%
# Fill in any empty age fields

relay_df["AGE"].fillna(0, inplace=True)
relay_df['AGE'] = relay_df['AGE'].astype('float')
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_45688/4200550883.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   relay_df["AGE"].fillna(0, inplace=True)

# %%
#rslt_df = df.loc[(df['RESULT_CONV'] < df['2pc']) & (df['AGE']<40) & (df['EVENT']!='Marathon')]

# %%
#rslt_df = df.loc[(((df['CATEGORY_EVENT']=='Jump')|(df['CATEGORY_EVENT']=='Throw'))&(df['RESULT_CONV'] >= df['5pc']) & (df['AGE']<40) & ((df['EVENT']!='Marathon')|(df['AGE']<60) & (df['EVENT']=='Marathon')))]

# %%
#rslt_df = df.loc[(((df['CATEGORY_EVENT']=='Mid')|(df['CATEGORY_EVENT']=='Sprint')|(df['CATEGORY_EVENT']=='Long')|(df['CATEGORY_EVENT']=='Hurdles')|(df['CATEGORY_EVENT']=='Walk')|(df['CATEGORY_EVENT']=='Relay')|(df['CATEGORY_EVENT']=='Marathon')|(df['CATEGORY_EVENT']=='Steeple')|(df['CATEGORY_EVENT']=='Pentathlon')|(df['CATEGORY_EVENT']=='Heptathlon')|(df['CATEGORY_EVENT']=='Triathlon'))&(df['RESULT_CONV'] <= df['5pc']) & (df['AGE']<40) & ((df['MAPPED_EVENT']!='Marathon')|(df['AGE']<60) & (df['MAPPED_EVENT']=='Marathon')))|(((df['CATEGORY_EVENT']=='Jump')|(df['CATEGORY_EVENT']=='Throw'))&(df['RESULT_CONV'] >= df['5pc']) & (df['AGE']<40) & ((df['MAPPED_EVENT']!='Marathon')|(df['AGE']<60) & (df['MAPPED_EVENT']=='Marathon')))]

# %%
relay_df
# Out:
#       index_x                                    NAME   RESULT  AGE  \
# 0           0                           CHUA CHEE HON  00:20.5  0.0
# 1           1                          O'NEAL TERENCE  00:33.3  0.0
# 2           2                     MARCUS ANG GEE HONG  00:15.7  0.0
# 3           3                          DHYAN JEEVANTH  00:17.4  0.0
# 4           4  MOHAMMAD ZULKHAIRI LUTFI BIN MOHD AZAM  00:13.9  0.0
# ...       ...                                     ...      ...  ...
# 9008     9008                     ELIZABETH LEE SHYIN  00:27.9  0.0
# 9009     9009                        GOH EN YA ELEANA  00:26.2  0.0
# 9010     9010                            TONG YAN YEE  01:02.4  0.0
# 9011     9011                   LAAVINIA D/O JAIGANTH  01:00.3  0.0
# 9012     9012                             CHOO JIA YI  01:03.9  0.0
#
#      COMPETITION_RANK DIVISION    EVENT_x   DOB COUNTRY CATEGORY_EVENT  ...  \
# 0                 4.0        A  Para 100m  None    None         Sprint  ...
# 1                 5.0        A  Para 100m  None    None         Sprint  ...
# 2                 2.0        A  Para 100m  None    None         Sprint  ...
# 3                 3.0        A  Para 100m  None    None         Sprint  ...
# 4                 1.0        A  Para 100m  None    None         Sprint  ...
# ...               ...      ...        ...   ...     ...            ...  ...
# 9008                1        C       200m  None    None         Sprint  ...
# 9009                1        A       200m  None    None         Sprint  ...
# 9010                1        A       400m  None    None         Sprint  ...
# 9011                1        B       400m  None    None         Sprint  ...
# 9012                1        C       400m  None    None         Sprint  ...
#
#      MAPPED_EVENT MAPPED_AGE index_y BENCHMARK EVENT_y  Metric       2pc  \
# 0            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 1            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 2            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 3            100m       18.5     0.0    10.443    100m  10.443  10.65186
# 4            100m       18.5     0.0    10.443    100m  10.443  10.65186
# ...           ...        ...     ...       ...     ...     ...       ...
# 9008         200m       13.5    22.0      23.6    200m  23.600  24.07200
# 9009         200m       18.5    22.0      23.6    200m  23.600  24.07200
# 9010         400m       18.5    23.0     53.84    400m  53.840  54.91680
# 9011         400m         16    23.0     53.84    400m  53.840  54.91680
# 9012         400m       13.5    23.0     53.84    400m  53.840  54.91680
#
#            35pc       5pc  RESULT_CONV
# 0     10.808505  10.96515         20.5
# 1     10.808505  10.96515         33.3
# 2     10.808505  10.96515         15.7
# 3     10.808505  10.96515         17.4
# 4     10.808505  10.96515         13.9
# ...         ...       ...          ...
# 9008  24.426000  24.78000         27.9
# 9009  24.426000  24.78000         26.2
# 9010  55.724400  56.53200         62.4
# 9011  55.724400  56.53200         60.3
# 9012  55.724400  56.53200         63.9
#
# [9013 rows x 24 columns]

# %%
# Calculate performance deltas

mask = relay_df['CATEGORY_EVENT'].str.contains(r'Jump|Throw', na=True)
relay_df.loc[mask, 'Delta2'] = relay_df['RESULT_CONV']-relay_df['2pc']
relay_df.loc[mask, 'Delta35'] = relay_df['RESULT_CONV']-relay_df['35pc']
relay_df.loc[mask, 'Delta5'] = relay_df['RESULT_CONV']-relay_df['5pc']

relay_df.loc[~mask, 'Delta2'] =  relay_df['2pc'] - relay_df['RESULT_CONV']
relay_df.loc[~mask, 'Delta35'] = relay_df['35pc'] - relay_df['RESULT_CONV']
relay_df.loc[~mask, 'Delta5'] = relay_df['5pc'] - relay_df['RESULT_CONV']



#rslt_df['Delta2']=rslt_df['2pc']-rslt_df['RESULT_CONV']
#rslt_df['Delta35']=rslt_df['35pc']-rslt_df['RESULT_CONV']
#rslt_df['Delta5']=rslt_df['5pc']-rslt_df['RESULT_CONV']
relay_df=relay_df.loc[relay_df['COMPETITION']!='SEA Games']

# %%
relay_df
# Out:
#       index_x                                    NAME   RESULT  AGE  \
# 0           0                           CHUA CHEE HON  00:20.5  0.0
# 1           1                          O'NEAL TERENCE  00:33.3  0.0
# 2           2                     MARCUS ANG GEE HONG  00:15.7  0.0
# 3           3                          DHYAN JEEVANTH  00:17.4  0.0
# 4           4  MOHAMMAD ZULKHAIRI LUTFI BIN MOHD AZAM  00:13.9  0.0
# ...       ...                                     ...      ...  ...
# 9008     9008                     ELIZABETH LEE SHYIN  00:27.9  0.0
# 9009     9009                        GOH EN YA ELEANA  00:26.2  0.0
# 9010     9010                            TONG YAN YEE  01:02.4  0.0
# 9011     9011                   LAAVINIA D/O JAIGANTH  01:00.3  0.0
# 9012     9012                             CHOO JIA YI  01:03.9  0.0
#
#      COMPETITION_RANK DIVISION    EVENT_x   DOB COUNTRY CATEGORY_EVENT  ...  \
# 0                 4.0        A  Para 100m  None    None         Sprint  ...
# 1                 5.0        A  Para 100m  None    None         Sprint  ...
# 2                 2.0        A  Para 100m  None    None         Sprint  ...
# 3                 3.0        A  Para 100m  None    None         Sprint  ...
# 4                 1.0        A  Para 100m  None    None         Sprint  ...
# ...               ...      ...        ...   ...     ...            ...  ...
# 9008                1        C       200m  None    None         Sprint  ...
# 9009                1        A       200m  None    None         Sprint  ...
# 9010                1        A       400m  None    None         Sprint  ...
# 9011                1        B       400m  None    None         Sprint  ...
# 9012                1        C       400m  None    None         Sprint  ...
#
#      BENCHMARK EVENT_y  Metric       2pc       35pc       5pc  RESULT_CONV  \
# 0       10.443    100m  10.443  10.65186  10.808505  10.96515         20.5
# 1       10.443    100m  10.443  10.65186  10.808505  10.96515         33.3
# 2       10.443    100m  10.443  10.65186  10.808505  10.96515         15.7
# 3       10.443    100m  10.443  10.65186  10.808505  10.96515         17.4
# 4       10.443    100m  10.443  10.65186  10.808505  10.96515         13.9
# ...        ...     ...     ...       ...        ...       ...          ...
# 9008      23.6    200m  23.600  24.07200  24.426000  24.78000         27.9
# 9009      23.6    200m  23.600  24.07200  24.426000  24.78000         26.2
# 9010     53.84    400m  53.840  54.91680  55.724400  56.53200         62.4
# 9011     53.84    400m  53.840  54.91680  55.724400  56.53200         60.3
# 9012     53.84    400m  53.840  54.91680  55.724400  56.53200         63.9
#
#         Delta2    Delta35    Delta5
# 0     -9.84814  -9.691495  -9.53485
# 1    -22.64814 -22.491495 -22.33485
# 2     -5.04814  -4.891495  -4.73485
# 3     -6.74814  -6.591495  -6.43485
# 4     -3.24814  -3.091495  -2.93485
# ...        ...        ...       ...
# 9008  -3.82800  -3.474000  -3.12000
# 9009  -2.12800  -1.774000  -1.42000
# 9010  -7.48320  -6.675600  -5.86800
# 9011  -5.38320  -4.575600  -3.76800
# 9012  -8.98320  -8.175600  -7.36800
#
# [9013 rows x 27 columns]

# %%
# Correct some known names

relay_df['NAME'] = relay_df['NAME'].replace(regex=r'PRAHARSH, RYAN', value='S/O SUBASH SOMAN, PRAHARSH RYAN')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'Ryan, Praharsh', value='S/O SUBASH SOMAN, PRAHARSH RYAN')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'TAN, ELIZABETH ANN SHEE R', value='TAN, ELIZABETH-ANN')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'Tan, Elizabeth Ann', value='TAN, ELIZABETH-ANN')

relay_df['NAME'] = relay_df['NAME'].replace(regex=r'LOUIS, MARC BRIAN', value='Louis, Marc Brian')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'Louis, Marc', value='Louis, Marc Brian')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'TAN JUN JIE', value='Tan Jun Jie')

relay_df['NAME'] = relay_df['NAME'].replace(regex=r'SNG, MICHELLE', value='Sng, Michelle')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'SNG, SUAT LI, MICHELLE', value='Sng, Michelle')

relay_df['NAME'] = relay_df['NAME'].replace(regex=r'MUN, IVAN', value='Mun, Ivan')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'LOW, JUN YU', value='Low, Jun Yu')

relay_df['NAME'] = relay_df['NAME'].replace(regex=r'ANG, CHEN XIANG', value='Ang, Chen Xiang')
relay_df['NAME'] = relay_df['NAME'].replace(regex=r'LIM, OLIVER', value='Lim, Oliver')

# %%
# Create a perf_scalar variable to measure proximity to 5% window

relay_df['PERF_SCALAR']=relay_df['Delta5']/relay_df['Metric']*100

# %%
relay_df.to_csv('checkpoint.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
#rslt_df['Rank'] = (rslt_df.sort_values(by=['EVENT', 'GENDER', 'Delta35'], ascending=[False, False, True])['Delta35']
#                .rank(method='first', ascending=False)
#             )

# %%
spex_list=pd.read_csv('/Users/veesheenyuen/Desktop/DataScience/SAA/SPEX_CARDED_LIST.csv', encoding='latin-1')

# %%
spex_list
# Out:
#                             V1                           V2  \
# 0                Goh Chui Ling               Goh, Chui Ling
# 1                 Michelle Sng                Sng, Michelle
# 2          Quek Jun Jie Calvin         Quek, Jun Jie Calvin
# 3      SOH RUI YONG, GUILLAUME      Soh Rui Yong, Guillaume
# 4     Aaron Justin tan wen jie    Tan Wen Jie, Aaron Justin
# 5         DANIEL LEOW SOON YEE        Yee, Daniel Leow Soon
# 6                  Joshua Chua                 Chua, Joshua
# 7     NG ZHI RONG RYAN RAPHAEL    Ng Zhi Rong, Ryan Raphael
# 8                 Wenli Rachel                Wenli, Rachel
# 9           Wong YaoHan Melvin          Wong YaoHan, Melvin
# 10          XANDER HO ANN HENG         Ho Ann Heng,  Xander
# 11     Veronica Shanti Pereira     Pereira, Veronica Shanti
# 12              Ang Chen Xiang              Ang, Chen Xiang
# 13                 KAMPTON KAM                 Kam, Kampton
# 14            MARC BRIAN LOUIS             MARC BRIAN LOUIS
# 15                Mark Lee Ren                 Mark Lee Ren
# 16  Reuben Rainer Lee Siong En  Lee Siong En, Reuben Rainer
# 17   ELIZABETH-ANN TAN SHEE RU   Tan Shee Ru, Elizabeth-Ann
# 18        Thiruben Thana Rajan         Thiruben Thana Rajan
# 19          Bhavna Gopikrishna           Bhavna Gopikrishna
# 20            Chloe Chee En-Ya            Chee En-Ya, Chloe
# 21         Conrad Kangli Emery          Conrad Kangli Emery
# 22          Harry Irfan Curran           Harry Irfan Curran
# 23                Huang weijun                Huang, WeiJun
# 24                  Jayden tan                  Tan, Jayden
# 25          Koh Shun Yi Audrey          Koh Shun Yi, Audrey
# 26       LAAVINIA D/O JAIGANTH        LAAVINIA D/O JAIGANTH
# 27         Lim Yee Chern Clara         Lim Yee Chern, Clara
# 28         LOH DING RONG ANSON         Loh Ding Rong, Anson
# 29                ONG YING TAT                Ong, Ying Tat
# 30           SONG EN XU REAGAN           Song En Xu, Reagan
# 31             Subaraghav hari              Subaraghav hari
# 32               Teh Ying Shan               Teh, Ying Shan
# 33                     YAN TEO                     Teo, Yan
# 34                ZHONG CHUHAN                Zhong, ChuHan
# 35         ESTHER TAY SHEE WEI         Tay Shee Wei, Esther
# 36                  Faith Ford                  Ford, Faith
# 37          Garrett Chua Je-An          Chua Je-An, Garrett
# 38                   Lucas Fun                   Fun, Lucas
#
#                       V3                         V4 Level
# 0                    NaN                        NaN    E3
# 1                    NaN                        NaN    E3
# 2                    NaN                        NaN    E3
# 3                    NaN                        NaN    E3
# 4                    NaN                        NaN   E3P
# 5                    NaN                        NaN   E3P
# 6                    NaN                        NaN   E3P
# 7          Raphael, Ryan                        NaN   E3P
# 8                    NaN                        NaN   E3P
# 9                    NaN                        NaN   E3P
# 10  HO, XANDER, ANN HENG                        NaN   E3P
# 11                   NaN                        NaN   S1P
# 12                   NaN                        NaN   S2P
# 13                   NaN                        NaN    S3
# 14     Louis, Marc Brian                Louis, Marc    S3
# 15         Lee, Mark Ren                        NaN    S3
# 16    LEE, REUBEN RAINER                        NaN    S3
# 17    TAN, ELIZABETH-ANN  TAN, ELIZABETH ANN SHEE R  SP3P
# 18                   NaN                        NaN  SP3P
# 19                   NaN                        NaN     Y
# 20                   NaN                        NaN     Y
# 21                   NaN                        NaN     Y
# 22   Irfan Curran, Harry                        NaN     Y
# 23        Huang, Wei Jun              Huang Wei Jun     Y
# 24                   NaN                        NaN     Y
# 25                   NaN                        NaN     Y
# 26                   NaN                        NaN     Y
# 27   Clara Lim Yee Chern                        NaN     Y
# 28                   NaN                        NaN     Y
# 29                   NaN                        NaN     Y
# 30    Song, Reagan En Xu                        NaN     Y
# 31                   NaN                        NaN     Y
# 32                   NaN                        NaN     Y
# 33                   NaN                        NaN     Y
# 34         Zhong Chu Han             Zhong, Chu Han     Y
# 35                   NaN                        NaN    Y+
# 36                   NaN                        NaN    Y+
# 37                   NaN                        NaN    Y+
# 38                   NaN                        NaN    Y+

# %%
spex1 = spex_list['V1'].dropna().tolist()
spex2 = spex_list['V2'].dropna().tolist()
spex3 = spex_list['V3'].dropna().tolist()
spex4 = spex_list['V4'].dropna().tolist()

# %%
# Put all spex carded names into one single list 

spex_athletes=spex1+spex2+spex3+spex4

# %%
spex_athletes
# Out:
# ['Goh Chui Ling',
#  'Michelle Sng',
#  'Quek Jun Jie Calvin',
#  'SOH RUI YONG, GUILLAUME',
#  'Aaron Justin tan wen jie',
#  'DANIEL LEOW SOON YEE',
#  'Joshua Chua',
#  'NG ZHI RONG RYAN RAPHAEL',
#  'Wenli Rachel',
#  'Wong YaoHan Melvin',
#  'XANDER HO ANN HENG',
#  'Veronica Shanti Pereira',
#  'Ang Chen Xiang',
#  'KAMPTON KAM',
#  'MARC BRIAN LOUIS',
#  'Mark Lee Ren',
#  'Reuben Rainer Lee Siong En',
#  'ELIZABETH-ANN TAN SHEE RU',
#  'Thiruben Thana Rajan',
#  'Bhavna Gopikrishna',
#  'Chloe Chee En-Ya',
#  'Conrad Kangli Emery',
#  'Harry Irfan Curran',
#  'Huang weijun',
#  'Jayden tan',
#  'Koh Shun Yi Audrey',
#  'LAAVINIA D/O JAIGANTH',
#  'Lim Yee Chern Clara',
#  'LOH DING RONG ANSON',
#  'ONG YING TAT',
#  'SONG EN XU REAGAN',
#  'Subaraghav hari',
#  'Teh Ying Shan',
#  'YAN TEO',
#  'ZHONG CHUHAN',
#  'ESTHER TAY SHEE WEI',
#  'Faith Ford',
#  'Garrett Chua Je-An',
#  'Lucas Fun',
#  'Goh, Chui Ling',
#  'Sng, Michelle',
#  'Quek, Jun Jie Calvin',
#  'Soh Rui Yong, Guillaume',
#  'Tan Wen Jie, Aaron Justin',
#  'Yee, Daniel Leow Soon',
#  'Chua, Joshua',
#  'Ng Zhi Rong, Ryan Raphael',
#  'Wenli, Rachel',
#  'Wong YaoHan, Melvin',
#  'Ho Ann Heng,  Xander',
#  'Pereira, Veronica Shanti',
#  'Ang, Chen Xiang',
#  'Kam, Kampton',
#  'MARC BRIAN LOUIS',
#  'Mark Lee Ren',
#  'Lee Siong En, Reuben Rainer',
#  ' Tan Shee Ru, Elizabeth-Ann',
#  'Thiruben Thana Rajan',
#  'Bhavna Gopikrishna',
#  'Chee En-Ya, Chloe',
#  'Conrad Kangli Emery',
#  'Harry Irfan Curran',
#  'Huang, WeiJun',
#  'Tan, Jayden',
#  'Koh Shun Yi, Audrey',
#  'LAAVINIA D/O JAIGANTH',
#  'Lim Yee Chern, Clara',
#  'Loh Ding Rong, Anson',
#  'Ong, Ying Tat',
#  'Song En Xu, Reagan',
#  'Subaraghav hari',
#  'Teh, Ying Shan',
#  'Teo, Yan',
#  'Zhong, ChuHan',
#  'Tay Shee Wei, Esther',
#  'Ford, Faith',
#  'Chua Je-An, Garrett',
#  'Fun, Lucas',
#  'Raphael, Ryan',
#  'HO, XANDER, ANN HENG',
#  'Louis, Marc Brian',
#  'Lee, Mark Ren',
#  'LEE, REUBEN RAINER',
#  'TAN, ELIZABETH-ANN',
#  'Irfan Curran, Harry',
#  'Huang, Wei Jun',
#  'Clara Lim Yee Chern',
#  'Song, Reagan En Xu',
#  'Zhong Chu Han',
#  'Louis, Marc',
#  'TAN, ELIZABETH ANN SHEE R',
#  'Huang Wei Jun',
#  'Zhong, Chu Han']

# %%
# Convert names to lower case for easy compare

spex_athletes_casefold=[s.casefold() for s in spex_athletes]

# %%
spex_athletes_casefold
# Out:
# ['goh chui ling',
#  'michelle sng',
#  'quek jun jie calvin',
#  'soh rui yong, guillaume',
#  'aaron justin tan wen jie',
#  'daniel leow soon yee',
#  'joshua chua',
#  'ng zhi rong ryan raphael',
#  'wenli rachel',
#  'wong yaohan melvin',
#  'xander ho ann heng',
#  'veronica shanti pereira',
#  'ang chen xiang',
#  'kampton kam',
#  'marc brian louis',
#  'mark lee ren',
#  'reuben rainer lee siong en',
#  'elizabeth-ann tan shee ru',
#  'thiruben thana rajan',
#  'bhavna gopikrishna',
#  'chloe chee en-ya',
#  'conrad kangli emery',
#  'harry irfan curran',
#  'huang weijun',
#  'jayden tan',
#  'koh shun yi audrey',
#  'laavinia d/o jaiganth',
#  'lim yee chern clara',
#  'loh ding rong anson',
#  'ong ying tat',
#  'song en xu reagan',
#  'subaraghav hari',
#  'teh ying shan',
#  'yan teo',
#  'zhong chuhan',
#  'esther tay shee wei',
#  'faith ford',
#  'garrett chua je-an',
#  'lucas fun',
#  'goh, chui ling',
#  'sng, michelle',
#  'quek, jun jie calvin',
#  'soh rui yong, guillaume',
#  'tan wen jie, aaron justin',
#  'yee, daniel leow soon',
#  'chua, joshua',
#  'ng zhi rong, ryan raphael',
#  'wenli, rachel',
#  'wong yaohan, melvin',
#  'ho ann heng,  xander',
#  'pereira, veronica shanti',
#  'ang, chen xiang',
#  'kam, kampton',
#  'marc brian louis',
#  'mark lee ren',
#  'lee siong en, reuben rainer',
#  ' tan shee ru, elizabeth-ann',
#  'thiruben thana rajan',
#  'bhavna gopikrishna',
#  'chee en-ya, chloe',
#  'conrad kangli emery',
#  'harry irfan curran',
#  'huang, weijun',
#  'tan, jayden',
#  'koh shun yi, audrey',
#  'laavinia d/o jaiganth',
#  'lim yee chern, clara',
#  'loh ding rong, anson',
#  'ong, ying tat',
#  'song en xu, reagan',
#  'subaraghav hari',
#  'teh, ying shan',
#  'teo, yan',
#  'zhong, chuhan',
#  'tay shee wei, esther',
#  'ford, faith',
#  'chua je-an, garrett',
#  'fun, lucas',
#  'raphael, ryan',
#  'ho, xander, ann heng',
#  'louis, marc brian',
#  'lee, mark ren',
#  'lee, reuben rainer',
#  'tan, elizabeth-ann',
#  'irfan curran, harry',
#  'huang, wei jun',
#  'clara lim yee chern',
#  'song, reagan en xu',
#  'zhong chu han',
#  'louis, marc',
#  'tan, elizabeth ann shee r',
#  'huang wei jun',
#  'zhong, chu han']

# %%
# If athlete appears in more than one event, choose the best performing one

top_performers=relay_df.sort_values(['NAME','PERF_SCALAR'],ascending=False).groupby('NAME').head(1) # Choose top performing event per NAME

# %%
top_performers
# Out:
#       index_x                  NAME   RESULT   AGE COMPETITION_RANK  \
# 6811     6811           yeo, janice  1:16.22  18.0               14
# 7267     7267            yeo, jalea    14.69  13.0               18
# 6945     6945            toh, chloe    13.94  15.0               10
# 2013     2013              teo, yan    11.53  18.0                3
# 2120     2120   tay hong yan, jeryl    13.66  13.0               48
# ...       ...                   ...      ...   ...              ...
# 921       921     AARON LUCAS WHALL  00:26.9   0.0             28.0
# 4569     4569  AARON KEITH IMMANUEL  00:24.1   0.0                8
# 5585     5585  A A Ayu Teja Gayatri  00:18.0   0.0             86.0
# 7686     7686          ., Kaarthika  1:59.53  27.0                9
# 3731     3731       ., Cheung Zheng  1:12.67  14.0               20
#
#           DIVISION                            EVENT_x          DOB COUNTRY  \
# 6811           U20           Women 400 Meter Dash U20  2006-08-20     None
# 7267           U15           Women 100 Meter Dash U15  2011-01-28     None
# 6945           U18           Women 100 Meter Dash U18  2009-01-13     None
# 2013         A Div           Men 100 Meter Dash A Div  2005-06-18     None
# 2120           U15             Men 100 Meter Dash U15  2011-02-15     None
# ...            ...                                ...          ...     ...
# 921              C                               200m         None    None
# 4569             B                               200m         None    None
# 5585             B                               100m         None    None
# 7686  Women Junior  Women 400 Meter Dash Women Junior  1996-06-13     None
# 3731           U15      Boys 11-14 400 Meter Dash U15  2009-02-19     None
#
#      CATEGORY_EVENT  ... EVENT_y  Metric       2pc       35pc       5pc  \
# 6811         Sprint  ...    400m  53.840  54.91680  55.724400  56.53200
# 7267         Sprint  ...    100m  11.750  11.98500  12.161250  12.33750
# 6945         Sprint  ...    100m  11.750  11.98500  12.161250  12.33750
# 2013         Sprint  ...    100m  10.443  10.65186  10.808505  10.96515
# 2120         Sprint  ...    100m  10.443  10.65186  10.808505  10.96515
# ...             ...  ...     ...     ...       ...        ...       ...
# 921          Sprint  ...    200m  21.020  21.44040  21.755700  22.07100
# 4569         Sprint  ...    200m  21.020  21.44040  21.755700  22.07100
# 5585         Sprint  ...    100m  11.750  11.98500  12.161250  12.33750
# 7686         Sprint  ...    400m  53.840  54.91680  55.724400  56.53200
# 3731         Sprint  ...    400m  46.630  47.56260  48.262050  48.96150
#
#      RESULT_CONV    Delta2    Delta35    Delta5  PERF_SCALAR
# 6811       76.22 -21.30320 -20.495600 -19.68800   -36.567608
# 7267       14.69  -2.70500  -2.528750  -2.35250   -20.021277
# 6945       13.94  -1.95500  -1.778750  -1.60250   -13.638298
# 2013       11.53  -0.87814  -0.721495  -0.56485    -5.408886
# 2120       13.66  -3.00814  -2.851495  -2.69485   -25.805324
# ...          ...       ...        ...       ...          ...
# 921        26.90  -5.45960  -5.144300  -4.82900   -22.973359
# 4569       24.10  -2.65960  -2.344300  -2.02900    -9.652712
# 5585       18.00  -6.01500  -5.838750  -5.66250   -48.191489
# 7686      119.53 -64.61320 -63.805600 -62.99800  -117.009658
# 3731       72.67 -25.10740 -24.407950 -23.70850   -50.843877
#
# [4477 rows x 28 columns]

# %%
top_performers.to_csv('top_checkpoint.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
# Filter out SPEX carded athletes from list

spexed_list = top_performers.loc[~relay_df['NAME'].str.casefold().isin(spex_athletes_casefold)]  # ~ means NOT IN. DROP spex carded athletes

# %%
# Filter 100m, 200m and 400m, age between 20 and 35

spexed_list['MAPPED_AGE'] = spexed_list['MAPPED_AGE'].astype(float)

ranked_df = spexed_list.loc[(spexed_list['MAPPED_AGE'] >= 20) & (spexed_list['MAPPED_AGE']<=35) & ((spexed_list['DATE']=='2023'))]
#ranked_df = spexed_list.loc[(spexed_list['MAPPED_AGE'] >= 18) & (spexed_list['MAPPED_AGE']<=19) & ((spexed_list['MAPPED_EVENT']=='100m')|(spexed_list['MAPPED_EVENT']=='200m')|(spexed_list['MAPPED_EVENT']=='400m'))]
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_45688/1797569186.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spexed_list['MAPPED_AGE'] = spexed_list['MAPPED_AGE'].astype(float)

# %%
ranked_df
# Out:
#       index_x                      NAME   RESULT   AGE COMPETITION_RANK  \
# 3609     3609          Zhen Yong, Chang  1:05.81  25.0               11
# 3270     3270      Yeo, Jeremy, Zhi Hui    16.84  20.0                2
# 2001     2001               Yeo, Jeremy    17.74  21.0                1
# 7731     7731              Wong, Jannah    14.49  27.0                1
# 3617     3617           Wan Hong, Chong    13.15  24.0               11
# ...       ...                       ...      ...   ...              ...
# 7683     7683               Aw, Vanessa  1:13.92  28.0                1
# 3403     3403           Ariiq, Muhammad    13.45  22.0               14
# 7751     7751            Ang, Shermaine    17.72  23.0                9
# 3509     3509  Alexander Greaves, James    27.26  21.0               10
# 7686     7686              ., Kaarthika  1:59.53  27.0                9
#
#           DIVISION                            EVENT_x          DOB COUNTRY  \
# 3609    Men Junior      Men 400 Meter Dash Men Junior  1998-09-22     None
# 3270          Para            Men 100 Meter Dash Para  2002-11-14     None
# 2001          Para            Men 100 Meter Dash Para  2002-11-14     None
# 7731  Women Junior  Women 100 Meter Dash Women Junior  1996-08-09     None
# 3617    Men Junior      Men 100 Meter Dash Men Junior  1999-12-23     None
# ...            ...                                ...          ...     ...
# 7683  Women Junior  Women 400 Meter Dash Women Junior  1995-09-11     None
# 3403    Men Junior      Men 100 Meter Dash Men Junior  2001-09-08     None
# 7751  Women Junior  Women 100 Meter Dash Women Junior  2000-01-14     None
# 3509    Men Junior      Men 200 Meter Dash Men Junior  2002-02-17     None
# 7686  Women Junior  Women 400 Meter Dash Women Junior  1996-06-13     None
#
#      CATEGORY_EVENT  ... EVENT_y  Metric       2pc       35pc       5pc  \
# 3609         Sprint  ...    400m  46.630  47.56260  48.262050  48.96150
# 3270         Sprint  ...    100m  10.443  10.65186  10.808505  10.96515
# 2001         Sprint  ...    100m  10.443  10.65186  10.808505  10.96515
# 7731         Sprint  ...    100m  11.750  11.98500  12.161250  12.33750
# 3617         Sprint  ...    100m  10.443  10.65186  10.808505  10.96515
# ...             ...  ...     ...     ...       ...        ...       ...
# 7683         Sprint  ...    400m  53.840  54.91680  55.724400  56.53200
# 3403         Sprint  ...    100m  10.443  10.65186  10.808505  10.96515
# 7751         Sprint  ...    100m  11.750  11.98500  12.161250  12.33750
# 3509         Sprint  ...    200m  21.020  21.44040  21.755700  22.07100
# 7686         Sprint  ...    400m  53.840  54.91680  55.724400  56.53200
#
#       RESULT_CONV    Delta2    Delta35    Delta5  PERF_SCALAR
# 3609        65.81 -18.24740 -17.547950 -16.84850   -36.132318
# 3270        16.84  -6.18814  -6.031495  -5.87485   -56.256344
# 2001        17.74  -7.08814  -6.931495  -6.77485   -64.874557
# 7731        14.49  -2.50500  -2.328750  -2.15250   -18.319149
# 3617        13.15  -2.49814  -2.341495  -2.18485   -20.921670
# ...           ...       ...        ...       ...          ...
# 7683        73.92 -19.00320 -18.195600 -17.38800   -32.295691
# 3403        13.45  -2.79814  -2.641495  -2.48485   -23.794408
# 7751        17.72  -5.73500  -5.558750  -5.38250   -45.808511
# 3509        27.26  -5.81960  -5.504300  -5.18900   -24.686013
# 7686       119.53 -64.61320 -63.805600 -62.99800  -117.009658
#
# [85 rows x 28 columns]

# %%
# Rank and sort results

ranked_df.sort_values(['GENDER', 'MAPPED_EVENT', 'PERF_SCALAR'], ascending=[True, True, False], inplace=True)
ranked_df['overall_rank'] = 1
ranked_df['overall_rank'] = ranked_df.groupby(['GENDER', 'MAPPED_EVENT'])['overall_rank'].cumsum()
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_45688/4071210366.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranked_df.sort_values(['GENDER', 'MAPPED_EVENT', 'PERF_SCALAR'], ascending=[True, True, False], inplace=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_45688/4071210366.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranked_df['overall_rank'] = 1
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_45688/4071210366.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranked_df['overall_rank'] = ranked_df.groupby(['GENDER', 'MAPPED_EVENT'])['overall_rank'].cumsum()

# %%
ranked_df
# Out:
#       index_x                         NAME   RESULT   AGE COMPETITION_RANK  \
# 7731     7731                 Wong, Jannah    14.49  27.0                1
# 7654     7654               Hui Ting, Liow    15.59  29.0                2
# 7685     7685                 Chua, Joelle    15.72  25.0                2
# 7671     7671        Mualim, Nurul Natasha    16.03  25.0                4
# 7752     7752          Vasudevan, Pushpaja    16.57  23.0                6
# ...       ...                          ...      ...   ...              ...
# 3505     3505       BIN FARED, AQMAL FIQRI  1:13.95  21.0               17
# 3575     3575  Bin Md Akip, Muhammad Hilal  1:16.01  23.0               18
# 3390     3390                  Lim, Berton  1:16.62  29.0               19
# 3520     3520                 Azlyman, Mus  1:19.80  23.0               20
# 3517     3517                   Tan, Bryan  1:27.90  23.0               21
#
#           DIVISION                            EVENT_x          DOB COUNTRY  \
# 7731  Women Junior  Women 100 Meter Dash Women Junior  1996-08-09     None
# 7654  Women Junior  Women 100 Meter Dash Women Junior  1994-11-04     None
# 7685  Women Junior  Women 100 Meter Dash Women Junior  1998-04-28     None
# 7671  Women Junior  Women 100 Meter Dash Women Junior  1998-05-24     None
# 7752  Women Junior  Women 100 Meter Dash Women Junior  2000-11-29     None
# ...            ...                                ...          ...     ...
# 3505    Men Junior      Men 400 Meter Dash Men Junior  2002-01-18     None
# 3575    Men Junior      Men 400 Meter Dash Men Junior  2000-03-09     None
# 3390    Men Junior      Men 400 Meter Dash Men Junior  1994-06-07     None
# 3520    Men Junior      Men 400 Meter Dash Men Junior  2000-02-23     None
# 3517    Men Junior      Men 400 Meter Dash Men Junior  2000-02-20     None
#
#      CATEGORY_EVENT  ... Metric      2pc      35pc      5pc RESULT_CONV  \
# 7731         Sprint  ...  11.75  11.9850  12.16125  12.3375       14.49
# 7654         Sprint  ...  11.75  11.9850  12.16125  12.3375       15.59
# 7685         Sprint  ...  11.75  11.9850  12.16125  12.3375       15.72
# 7671         Sprint  ...  11.75  11.9850  12.16125  12.3375       16.03
# 7752         Sprint  ...  11.75  11.9850  12.16125  12.3375       16.57
# ...             ...  ...    ...      ...       ...      ...         ...
# 3505         Sprint  ...  46.63  47.5626  48.26205  48.9615       73.95
# 3575         Sprint  ...  46.63  47.5626  48.26205  48.9615       76.01
# 3390         Sprint  ...  46.63  47.5626  48.26205  48.9615       76.62
# 3520         Sprint  ...  46.63  47.5626  48.26205  48.9615       79.80
# 3517         Sprint  ...  46.63  47.5626  48.26205  48.9615       87.90
#
#        Delta2   Delta35   Delta5 PERF_SCALAR  overall_rank
# 7731  -2.5050  -2.32875  -2.1525  -18.319149             1
# 7654  -3.6050  -3.42875  -3.2525  -27.680851             2
# 7685  -3.7350  -3.55875  -3.3825  -28.787234             3
# 7671  -4.0450  -3.86875  -3.6925  -31.425532             4
# 7752  -4.5850  -4.40875  -4.2325  -36.021277             5
# ...       ...       ...      ...         ...           ...
# 3505 -26.3874 -25.68795 -24.9885  -53.588891            15
# 3575 -28.4474 -27.74795 -27.0485  -58.006648            16
# 3390 -29.0574 -28.35795 -27.6585  -59.314819            17
# 3520 -32.2374 -31.53795 -30.8385  -66.134463            18
# 3517 -40.3374 -39.63795 -38.9385  -83.505254            19
#
# [85 rows x 29 columns]

# %%
# Filter top 20

top_20_20_to_35=ranked_df[ranked_df['overall_rank']<21]

# %%
top_20_20_to_35
# Out:
#       index_x                         NAME   RESULT   AGE COMPETITION_RANK  \
# 7731     7731                 Wong, Jannah    14.49  27.0                1
# 7654     7654               Hui Ting, Liow    15.59  29.0                2
# 7685     7685                 Chua, Joelle    15.72  25.0                2
# 7671     7671        Mualim, Nurul Natasha    16.03  25.0                4
# 7752     7752          Vasudevan, Pushpaja    16.57  23.0                6
# ...       ...                          ...      ...   ...              ...
# 3505     3505       BIN FARED, AQMAL FIQRI  1:13.95  21.0               17
# 3575     3575  Bin Md Akip, Muhammad Hilal  1:16.01  23.0               18
# 3390     3390                  Lim, Berton  1:16.62  29.0               19
# 3520     3520                 Azlyman, Mus  1:19.80  23.0               20
# 3517     3517                   Tan, Bryan  1:27.90  23.0               21
#
#           DIVISION                            EVENT_x          DOB COUNTRY  \
# 7731  Women Junior  Women 100 Meter Dash Women Junior  1996-08-09     None
# 7654  Women Junior  Women 100 Meter Dash Women Junior  1994-11-04     None
# 7685  Women Junior  Women 100 Meter Dash Women Junior  1998-04-28     None
# 7671  Women Junior  Women 100 Meter Dash Women Junior  1998-05-24     None
# 7752  Women Junior  Women 100 Meter Dash Women Junior  2000-11-29     None
# ...            ...                                ...          ...     ...
# 3505    Men Junior      Men 400 Meter Dash Men Junior  2002-01-18     None
# 3575    Men Junior      Men 400 Meter Dash Men Junior  2000-03-09     None
# 3390    Men Junior      Men 400 Meter Dash Men Junior  1994-06-07     None
# 3520    Men Junior      Men 400 Meter Dash Men Junior  2000-02-23     None
# 3517    Men Junior      Men 400 Meter Dash Men Junior  2000-02-20     None
#
#      CATEGORY_EVENT  ... Metric      2pc      35pc      5pc RESULT_CONV  \
# 7731         Sprint  ...  11.75  11.9850  12.16125  12.3375       14.49
# 7654         Sprint  ...  11.75  11.9850  12.16125  12.3375       15.59
# 7685         Sprint  ...  11.75  11.9850  12.16125  12.3375       15.72
# 7671         Sprint  ...  11.75  11.9850  12.16125  12.3375       16.03
# 7752         Sprint  ...  11.75  11.9850  12.16125  12.3375       16.57
# ...             ...  ...    ...      ...       ...      ...         ...
# 3505         Sprint  ...  46.63  47.5626  48.26205  48.9615       73.95
# 3575         Sprint  ...  46.63  47.5626  48.26205  48.9615       76.01
# 3390         Sprint  ...  46.63  47.5626  48.26205  48.9615       76.62
# 3520         Sprint  ...  46.63  47.5626  48.26205  48.9615       79.80
# 3517         Sprint  ...  46.63  47.5626  48.26205  48.9615       87.90
#
#        Delta2   Delta35   Delta5 PERF_SCALAR  overall_rank
# 7731  -2.5050  -2.32875  -2.1525  -18.319149             1
# 7654  -3.6050  -3.42875  -3.2525  -27.680851             2
# 7685  -3.7350  -3.55875  -3.3825  -28.787234             3
# 7671  -4.0450  -3.86875  -3.6925  -31.425532             4
# 7752  -4.5850  -4.40875  -4.2325  -36.021277             5
# ...       ...       ...      ...         ...           ...
# 3505 -26.3874 -25.68795 -24.9885  -53.588891            15
# 3575 -28.4474 -27.74795 -27.0485  -58.006648            16
# 3390 -29.0574 -28.35795 -27.6585  -59.314819            17
# 3520 -32.2374 -31.53795 -30.8385  -66.134463            18
# 3517 -40.3374 -39.63795 -38.9385  -83.505254            19
#
# [75 rows x 29 columns]

# %%
top_20_20_to_35.to_csv('top_20_20_to_35.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
#spexed_list=spexed_list[(((spexed_list['EVENT']=='400m')&(spexed_list['overall_rank']<7)))|(((spexed_list['EVENT']=='100m')&(spexed_list['overall_rank']<7)))]

# %%
#spexed_list=spexed_list[(((spexed_list['MAPPED_EVENT']=='400m')|(spexed_list['MAPPED_EVENT']=='100m'))&(spexed_list['overall_rank']<7))|(~((spexed_list['MAPPED_EVENT']=='400m')|(spexed_list['MAPPED_EVENT']=='100m'))&(spexed_list['overall_rank']<4))]

# %%
#spexed_list.to_csv('ranked_all_events.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
# 1. If top athlete>30 (and the only one >30), there are already 6 in list, and next one is already <30 then it means do nothing? 
# 2. If top athlete>30 and is the sole pick.  Next athlete is far beyond 5% band.  Do we add?
# 3. If top athlete>30 and there are less than 6 within 5% band of SEAG benchmark. Do we add that one more who is beyond 5%?
# 4. At least one per gender.  The only pick is far beyond 5%.  Do we add?
