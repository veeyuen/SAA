# %%
# 17th SEA Youth U20

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import usual modules
import pandas as pd
import csv
import math
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl
import datetime
from scipy.stats import lognorm
import re
import string
from bs4 import BeautifulSoup
import requests
import unicodedata # for removing accented characters
import datetime
import icecream as ic
import dateutil.parser as parser 
import datacompy
import pytz

from itertools import permutations



from google.cloud import storage

# %%
'''
# PRODUCTION ENVIRONMENT
# Extract timed event records

import pandas_gbq
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(
    '/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json',
    
    
)

sql1="""
SELECT NAME, RESULT, TEAM, AGE, RANK AS COMPETITION_RANK, DIVISION, EVENT, DISTANCE, EVENT_CLASS, UNIQUE_ID, DOB, NATIONALITY, WIND, CATEGORY_EVENT, GENDER, COMPETITION, DATE, YEAR, REGION, TIMESTAMP
FROM `saa-analytics.results.athlete_results_prod` 
WHERE RESULT!='NM' AND RESULT!='-' AND RESULT!='DNS' AND RESULT!='DNF' AND RESULT!='DNQ' AND RESULT!='DQ' AND RESULT IS NOT NULL

"""

competitors = pandas_gbq.read_gbq(sql1, project_id="saa-analytics", credentials=credentials)


'''
# Out:
# '\n# PRODUCTION ENVIRONMENT\n# Extract timed event records\n\nimport pandas_gbq\nfrom google.oauth2 import service_account\n\ncredentials = service_account.Credentials.from_service_account_file(\n    \'/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json\',\n    \n    \n)\n\nsql1="""\nSELECT NAME, RESULT, TEAM, AGE, RANK AS COMPETITION_RANK, DIVISION, EVENT, DISTANCE, EVENT_CLASS, UNIQUE_ID, DOB, NATIONALITY, WIND, CATEGORY_EVENT, GENDER, COMPETITION, DATE, YEAR, REGION, TIMESTAMP\nFROM `saa-analytics.results.athlete_results_prod` \nWHERE RESULT!=\'NM\' AND RESULT!=\'-\' AND RESULT!=\'DNS\' AND RESULT!=\'DNF\' AND RESULT!=\'DNQ\' AND RESULT!=\'DQ\' AND RESULT IS NOT NULL\n\n"""\n\ncompetitors = pandas_gbq.read_gbq(sql1, project_id="saa-analytics", credentials=credentials)\n\n\n'

# %%
# PRODUCTION ENVIRONMENT
# Extract timed event records

import pandas_gbq
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(
    '/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json',
    
    
)

sql1="""
SELECT NAME, RESULT, TEAM, AGE, RANK AS COMPETITION_RANK, DIVISION, EVENT, DISTANCE, EVENT_CLASS, UNIQUE_ID, DOB, NATIONALITY, WIND, CATEGORY_EVENT, GENDER, COMPETITION, DATE, YEAR, REGION, TIMESTAMP
FROM `saa-analytics.results.PRODUCTION` 
WHERE RESULT!='NM' AND RESULT!='-' AND RESULT!='DNS' AND RESULT!='DNF' AND RESULT!='DNQ' AND RESULT!='DQ' AND RESULT IS NOT NULL

"""

competitors = pandas_gbq.read_gbq(sql1, project_id="saa-analytics", credentials=credentials)
# Out:
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
competitors
# Out:
#                           NAME    RESULT                     TEAM   AGE  \
# 0          NG Caitlin Shan Wen     12.42                     <NA>  <NA>
# 1        TAN Ying Tong Shannon     12.53                     <NA>  <NA>
# 2          NG Caitlin Shan Wen     12.36                     <NA>  <NA>
# 3        TAN Ying Tong Shannon     12.33                     <NA>  <NA>
# 4             TAY Sean Russell     49.89                     <NA>  <NA>
# ...                        ...       ...                      ...   ...
# 168782              LAU, REINA      9.52  Singapore Sports School    16
# 168783      LOW, MING DAO JASE     11.97  Singapore Sports School    15
# 168784  CHAN CHENG ERN JENNICA      9.83  Singapore Sports School    15
# 168785             Vanessa Lee  17:11.36                     <NA>  <NA>
# 168786              Nicole Low  17:16.72                     <NA>  <NA>
#
#        COMPETITION_RANK DIVISION        EVENT DISTANCE EVENT_CLASS UNIQUE_ID  \
# 0                     5     <NA>         100m     <NA>         nan      <NA>
# 1                     2     <NA>         100m     <NA>         nan      <NA>
# 2                     6     <NA>         100m     <NA>         nan      <NA>
# 3                     7     <NA>         100m     <NA>         nan      <NA>
# 4                     6     <NA>         400m     <NA>         nan      <NA>
# ...                 ...      ...          ...      ...         ...       ...
# 168782              4.0           Triple Jump
# 168783              7.0           Triple Jump
# 168784              2.0           Triple Jump
# 168785              nan     <NA>        5000m     <NA>        <NA>      <NA>
# 168786              nan     <NA>        5000m     <NA>        <NA>      <NA>
#
#                               DOB NATIONALITY  WIND CATEGORY_EVENT  GENDER  \
# 0       2010-11-24 00:00:00+00:00         SGP  -0.3         Sprint  Female
# 1       2009-11-20 00:00:00+00:00         SGP  -0.7         Sprint  Female
# 2       2010-11-24 00:00:00+00:00         SGP   0.4         Sprint  Female
# 3       2009-11-20 00:00:00+00:00         SGP   0.8         Sprint  Female
# 4       2009-12-25 00:00:00+00:00         SGP  <NA>         Sprint    Male
# ...                           ...         ...   ...            ...     ...
# 168782                       2007                 0           Jump  Female
# 168783                       2008                 0           Jump    Male
# 168784                       2008                 0           Jump  Female
# 168785                       <NA>         SGP  <NA>           Long  Female
# 168786                       <NA>         SGP  <NA>           Long  Female
#
#                                               COMPETITION  \
# 0                                   3rd Asian Youth Games
# 1                                   3rd Asian Youth Games
# 2                                   3rd Asian Youth Games
# 3                                   3rd Asian Youth Games
# 4                                   3rd Asian Youth Games
# ...                                                   ...
# 168782                                       Melacca Open
# 168783                       Thailand Sports School Games
# 168784                                       Melacca Open
# 168785  4J Studios scottishathletics National Senior &...
# 168786  4J Studios scottishathletics National Senior &...
#
#                              DATE  YEAR         REGION  \
# 0       2025-10-23 00:00:00+00:00  2025  International
# 1       2025-10-23 00:00:00+00:00  2025  International
# 2       2025-10-23 00:00:00+00:00  2025  International
# 3       2025-10-23 00:00:00+00:00  2025  International
# 4       2025-10-24 00:00:00+00:00  2025  International
# ...                           ...   ...            ...
# 168782  2023-11-19 00:00:00+00:00  2023  International
# 168783  2023-07-29 00:00:00+00:00  2023  International
# 168784  2023-11-19 00:00:00+00:00  2023  International
# 168785  2025-08-23 00:00:00+00:00  2025  International
# 168786  2025-08-23 00:00:00+00:00  2025  International
#
#                         TIMESTAMP
# 0       2025-10-27 21:31:00+00:00
# 1       2025-10-27 21:31:00+00:00
# 2       2025-10-27 21:31:00+00:00
# 3       2025-10-27 21:31:00+00:00
# 4       2025-10-27 21:31:00+00:00
# ...                           ...
# 168782  2025-08-10 17:19:00+00:00
# 168783  2025-08-10 17:19:00+00:00
# 168784  2025-08-10 17:19:00+00:00
# 168785  2025-08-31 18:46:00+00:00
# 168786  2025-08-31 18:46:00+00:00
#
# [168787 rows x 20 columns]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')


competitors.to_csv('athletes_all_prod.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
competitors
# Out:
#                           NAME    RESULT                     TEAM   AGE  \
# 0          NG Caitlin Shan Wen     12.42                     <NA>  <NA>
# 1        TAN Ying Tong Shannon     12.53                     <NA>  <NA>
# 2          NG Caitlin Shan Wen     12.36                     <NA>  <NA>
# 3        TAN Ying Tong Shannon     12.33                     <NA>  <NA>
# 4             TAY Sean Russell     49.89                     <NA>  <NA>
# ...                        ...       ...                      ...   ...
# 168782              LAU, REINA      9.52  Singapore Sports School    16
# 168783      LOW, MING DAO JASE     11.97  Singapore Sports School    15
# 168784  CHAN CHENG ERN JENNICA      9.83  Singapore Sports School    15
# 168785             Vanessa Lee  17:11.36                     <NA>  <NA>
# 168786              Nicole Low  17:16.72                     <NA>  <NA>
#
#        COMPETITION_RANK DIVISION        EVENT DISTANCE EVENT_CLASS UNIQUE_ID  \
# 0                     5     <NA>         100m     <NA>         nan      <NA>
# 1                     2     <NA>         100m     <NA>         nan      <NA>
# 2                     6     <NA>         100m     <NA>         nan      <NA>
# 3                     7     <NA>         100m     <NA>         nan      <NA>
# 4                     6     <NA>         400m     <NA>         nan      <NA>
# ...                 ...      ...          ...      ...         ...       ...
# 168782              4.0           Triple Jump
# 168783              7.0           Triple Jump
# 168784              2.0           Triple Jump
# 168785              nan     <NA>        5000m     <NA>        <NA>      <NA>
# 168786              nan     <NA>        5000m     <NA>        <NA>      <NA>
#
#                               DOB NATIONALITY  WIND CATEGORY_EVENT  GENDER  \
# 0       2010-11-24 00:00:00+00:00         SGP  -0.3         Sprint  Female
# 1       2009-11-20 00:00:00+00:00         SGP  -0.7         Sprint  Female
# 2       2010-11-24 00:00:00+00:00         SGP   0.4         Sprint  Female
# 3       2009-11-20 00:00:00+00:00         SGP   0.8         Sprint  Female
# 4       2009-12-25 00:00:00+00:00         SGP  <NA>         Sprint    Male
# ...                           ...         ...   ...            ...     ...
# 168782                       2007                 0           Jump  Female
# 168783                       2008                 0           Jump    Male
# 168784                       2008                 0           Jump  Female
# 168785                       <NA>         SGP  <NA>           Long  Female
# 168786                       <NA>         SGP  <NA>           Long  Female
#
#                                               COMPETITION  \
# 0                                   3rd Asian Youth Games
# 1                                   3rd Asian Youth Games
# 2                                   3rd Asian Youth Games
# 3                                   3rd Asian Youth Games
# 4                                   3rd Asian Youth Games
# ...                                                   ...
# 168782                                       Melacca Open
# 168783                       Thailand Sports School Games
# 168784                                       Melacca Open
# 168785  4J Studios scottishathletics National Senior &...
# 168786  4J Studios scottishathletics National Senior &...
#
#                              DATE  YEAR         REGION  \
# 0       2025-10-23 00:00:00+00:00  2025  International
# 1       2025-10-23 00:00:00+00:00  2025  International
# 2       2025-10-23 00:00:00+00:00  2025  International
# 3       2025-10-23 00:00:00+00:00  2025  International
# 4       2025-10-24 00:00:00+00:00  2025  International
# ...                           ...   ...            ...
# 168782  2023-11-19 00:00:00+00:00  2023  International
# 168783  2023-07-29 00:00:00+00:00  2023  International
# 168784  2023-11-19 00:00:00+00:00  2023  International
# 168785  2025-08-23 00:00:00+00:00  2025  International
# 168786  2025-08-23 00:00:00+00:00  2025  International
#
#                         TIMESTAMP
# 0       2025-10-27 21:31:00+00:00
# 1       2025-10-27 21:31:00+00:00
# 2       2025-10-27 21:31:00+00:00
# 3       2025-10-27 21:31:00+00:00
# 4       2025-10-27 21:31:00+00:00
# ...                           ...
# 168782  2025-08-10 17:19:00+00:00
# 168783  2025-08-10 17:19:00+00:00
# 168784  2025-08-10 17:19:00+00:00
# 168785  2025-08-31 18:46:00+00:00
# 168786  2025-08-31 18:46:00+00:00
#
# [168787 rows x 20 columns]

# %%
competitors[competitors['COMPETITION']=='Box Hill Burn']
# Out:
#                          NAME   RESULT  TEAM   AGE COMPETITION_RANK DIVISION  \
# 1677              Romaine Soh  02:56.0  None  None                7     None
# 1678               Jayden Tan  02:31.1  None  None                5     None
# 9095                Shaun Goh  14:57.4  None  None                3     None
# 9096  Vanessa Lee Ying Zhuang  17:06.7  None  None               11     None
# 9097               Nicole Low  17:21.3  None  None               13     None
#
#       EVENT DISTANCE EVENT_CLASS UNIQUE_ID        DOB NATIONALITY  WIND  \
# 1677  1000m     None        None      None  26-Nov-94         SGP  None
# 1678  1000m     None        None      None  24-Jun-06         SGP  None
# 9095  5000m     None        None      None  12-Jan-97         SGP  None
# 9096  5000m     None        None      None  23-Feb-98         SGP  None
# 9097  5000m     None        None      None  19-Jun-98         SGP  None
#
#      CATEGORY_EVENT  GENDER    COMPETITION                       DATE  YEAR  \
# 1677            Mid  Female  Box Hill Burn  2025-03-06 00:00:00+00:00  2025
# 1678            Mid    Male  Box Hill Burn  2025-03-06 00:00:00+00:00  2025
# 9095           Long    Male  Box Hill Burn  2025-03-06 00:00:00+00:00  2025
# 9096           Long  Female  Box Hill Burn  2025-03-06 00:00:00+00:00  2025
# 9097           Long  Female  Box Hill Burn  2025-03-06 00:00:00+00:00  2025
#
#              REGION TIMESTAMP
# 1677  International      None
# 1678  International      None
# 9095  International      None
# 9096  International      None
# 9097  International      None

# %%
#assert competitors['event_date'].all()!='nan' # make sure the conversion to datetime format is valid
#assert str(competitors['event_date'].all())!='NaT' # make sure the conversion to datetime format is valid

# %%
# DATE column to contain timezone - tz aware mode

competitors['DATE'] = pd.to_datetime(competitors['DATE'], format='mixed', dayfirst=False, utc=True)

# %%
# datetime to contain UTC (timezone)

competitors['NOW'] = datetime.datetime.now()

timezone = pytz.timezone('UTC')

competitors['NOW'] = datetime.datetime.now().replace(tzinfo=timezone)

# %%
competitors['NOW']
# Out:
# 0        2025-10-27 21:34:16.886000+00:00
# 1        2025-10-27 21:34:16.886000+00:00
# 2        2025-10-27 21:34:16.886000+00:00
# 3        2025-10-27 21:34:16.886000+00:00
# 4        2025-10-27 21:34:16.886000+00:00
#                        ...
# 168782   2025-10-27 21:34:16.886000+00:00
# 168783   2025-10-27 21:34:16.886000+00:00
# 168784   2025-10-27 21:34:16.886000+00:00
# 168785   2025-10-27 21:34:16.886000+00:00
# 168786   2025-10-27 21:34:16.886000+00:00
# Name: NOW, Length: 168787, dtype: datetime64[us, UTC]

# %%
# Calculate number of days from today to event date

#competitors['DATE'] = pd.to_datetime(competitors['DATE'], format='mixed', dayfirst=False, utc=False)

competitors['delta_time'] = competitors['NOW'] - competitors['DATE']


#competitors['delta_time'] = datetime.datetime.now() - competitors['DATE']


competitors['delta_time_conv'] = pd.to_numeric(competitors['delta_time'].dt.days, downcast='integer')

competitors['event_month'] = competitors['DATE'].dt.month

# %%
competitors['delta_time']
# Out:
# 0          4 days 21:34:16.886000
# 1          4 days 21:34:16.886000
# 2          4 days 21:34:16.886000
# 3          4 days 21:34:16.886000
# 4          3 days 21:34:16.886000
#                    ...
# 168782   708 days 21:34:16.886000
# 168783   821 days 21:34:16.886000
# 168784   708 days 21:34:16.886000
# 168785    65 days 21:34:16.886000
# 168786    65 days 21:34:16.886000
# Name: delta_time, Length: 168787, dtype: timedelta64[ns]

# %%
# Make sure date conversion is is valid for all rows

assert not competitors['delta_time'].isna().any()

# %%
# These results have not had their event dates converted properly

competitors[competitors['DATE'].isna()]
# Out:
# Empty DataFrame
# Columns: [NAME, RESULT, TEAM, AGE, COMPETITION_RANK, DIVISION, EVENT, DISTANCE, EVENT_CLASS, UNIQUE_ID, DOB, NATIONALITY, WIND, CATEGORY_EVENT, GENDER, COMPETITION, DATE, YEAR, REGION, TIMESTAMP, NOW, delta_time, delta_time_conv, event_month]
# Index: []
#
# [0 rows x 24 columns]

# %%
competitors
# Out:
#                           NAME    RESULT                     TEAM   AGE  \
# 0          NG Caitlin Shan Wen     12.42                     <NA>  <NA>
# 1        TAN Ying Tong Shannon     12.53                     <NA>  <NA>
# 2          NG Caitlin Shan Wen     12.36                     <NA>  <NA>
# 3        TAN Ying Tong Shannon     12.33                     <NA>  <NA>
# 4             TAY Sean Russell     49.89                     <NA>  <NA>
# ...                        ...       ...                      ...   ...
# 168782              LAU, REINA      9.52  Singapore Sports School    16
# 168783      LOW, MING DAO JASE     11.97  Singapore Sports School    15
# 168784  CHAN CHENG ERN JENNICA      9.83  Singapore Sports School    15
# 168785             Vanessa Lee  17:11.36                     <NA>  <NA>
# 168786              Nicole Low  17:16.72                     <NA>  <NA>
#
#        COMPETITION_RANK DIVISION        EVENT DISTANCE EVENT_CLASS UNIQUE_ID  \
# 0                     5     <NA>         100m     <NA>         nan      <NA>
# 1                     2     <NA>         100m     <NA>         nan      <NA>
# 2                     6     <NA>         100m     <NA>         nan      <NA>
# 3                     7     <NA>         100m     <NA>         nan      <NA>
# 4                     6     <NA>         400m     <NA>         nan      <NA>
# ...                 ...      ...          ...      ...         ...       ...
# 168782              4.0           Triple Jump
# 168783              7.0           Triple Jump
# 168784              2.0           Triple Jump
# 168785              nan     <NA>        5000m     <NA>        <NA>      <NA>
# 168786              nan     <NA>        5000m     <NA>        <NA>      <NA>
#
#         ...  GENDER                                        COMPETITION  \
# 0       ...  Female                              3rd Asian Youth Games
# 1       ...  Female                              3rd Asian Youth Games
# 2       ...  Female                              3rd Asian Youth Games
# 3       ...  Female                              3rd Asian Youth Games
# 4       ...    Male                              3rd Asian Youth Games
# ...     ...     ...                                                ...
# 168782  ...  Female                                       Melacca Open
# 168783  ...    Male                       Thailand Sports School Games
# 168784  ...  Female                                       Melacca Open
# 168785  ...  Female  4J Studios scottishathletics National Senior &...
# 168786  ...  Female  4J Studios scottishathletics National Senior &...
#
#                             DATE  YEAR         REGION  \
# 0      2025-10-23 00:00:00+00:00  2025  International
# 1      2025-10-23 00:00:00+00:00  2025  International
# 2      2025-10-23 00:00:00+00:00  2025  International
# 3      2025-10-23 00:00:00+00:00  2025  International
# 4      2025-10-24 00:00:00+00:00  2025  International
# ...                          ...   ...            ...
# 168782 2023-11-19 00:00:00+00:00  2023  International
# 168783 2023-07-29 00:00:00+00:00  2023  International
# 168784 2023-11-19 00:00:00+00:00  2023  International
# 168785 2025-08-23 00:00:00+00:00  2025  International
# 168786 2025-08-23 00:00:00+00:00  2025  International
#
#                         TIMESTAMP                              NOW  \
# 0       2025-10-27 21:31:00+00:00 2025-10-27 21:34:16.886000+00:00
# 1       2025-10-27 21:31:00+00:00 2025-10-27 21:34:16.886000+00:00
# 2       2025-10-27 21:31:00+00:00 2025-10-27 21:34:16.886000+00:00
# 3       2025-10-27 21:31:00+00:00 2025-10-27 21:34:16.886000+00:00
# 4       2025-10-27 21:31:00+00:00 2025-10-27 21:34:16.886000+00:00
# ...                           ...                              ...
# 168782  2025-08-10 17:19:00+00:00 2025-10-27 21:34:16.886000+00:00
# 168783  2025-08-10 17:19:00+00:00 2025-10-27 21:34:16.886000+00:00
# 168784  2025-08-10 17:19:00+00:00 2025-10-27 21:34:16.886000+00:00
# 168785  2025-08-31 18:46:00+00:00 2025-10-27 21:34:16.886000+00:00
# 168786  2025-08-31 18:46:00+00:00 2025-10-27 21:34:16.886000+00:00
#
#                      delta_time delta_time_conv event_month
# 0        4 days 21:34:16.886000               4          10
# 1        4 days 21:34:16.886000               4          10
# 2        4 days 21:34:16.886000               4          10
# 3        4 days 21:34:16.886000               4          10
# 4        3 days 21:34:16.886000               3          10
# ...                         ...             ...         ...
# 168782 708 days 21:34:16.886000             708          11
# 168783 821 days 21:34:16.886000             821           7
# 168784 708 days 21:34:16.886000             708          11
# 168785  65 days 21:34:16.886000              65           8
# 168786  65 days 21:34:16.886000              65           8
#
# [168787 rows x 24 columns]

# %%
# Choose date range for SEAG qualification window from Oct 22 to current


competitors['DATE']=competitors['DATE'].dt.tz_localize(None)  # switch off timezone for compatibility with np.datetime64

start = datetime.datetime(2024, 10, 26)
#start = datetime.datetime(2025, 10, 26)


end = datetime.datetime(2025, 10, 26)

start_date = np.datetime64(start)
end_date = np.datetime64(end)


mask = (competitors['DATE'] >= start_date) & (competitors['DATE'] <= end_date)
athletes_selected = competitors.loc[mask]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')

athletes_selected.to_csv('athletes_selected.csv', encoding='utf-8')

# %%
# Select all of 2024/25 for OCTC

#athletes_selected = competitors[(competitors['YEAR']=='2024')|(competitors['YEAR']=='2025')]

#athletes_selected = competitors[(competitors['YEAR']=='2025')]

# %%
athletes_selected
# Out:
#                          NAME    RESULT  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0         NG Caitlin Shan Wen     12.42  <NA>  <NA>                5     <NA>
# 1       TAN Ying Tong Shannon     12.53  <NA>  <NA>                2     <NA>
# 2         NG Caitlin Shan Wen     12.36  <NA>  <NA>                6     <NA>
# 3       TAN Ying Tong Shannon     12.33  <NA>  <NA>                7     <NA>
# 4            TAY Sean Russell     49.89  <NA>  <NA>                6     <NA>
# ...                       ...       ...   ...   ...              ...      ...
# 167900       Marc Brian Louis     20.89                            1
# 167922      Harry Irfan Curra     34.57                            3
# 168210           Rui Yong Soh  14:46.81                            4
# 168785            Vanessa Lee  17:11.36  <NA>  <NA>              nan     <NA>
# 168786             Nicole Low  17:16.72  <NA>  <NA>              nan     <NA>
#
#         EVENT DISTANCE EVENT_CLASS UNIQUE_ID  ...  GENDER  \
# 0        100m     <NA>         nan      <NA>  ...  Female
# 1        100m     <NA>         nan      <NA>  ...  Female
# 2        100m     <NA>         nan      <NA>  ...  Female
# 3        100m     <NA>         nan      <NA>  ...  Female
# 4        400m     <NA>         nan      <NA>  ...    Male
# ...       ...      ...         ...       ...  ...     ...
# 167900   200m                                 ...    Male
# 167922   300m                                 ...    Male
# 168210  5000m                                 ...    Male
# 168785  5000m     <NA>        <NA>      <NA>  ...  Female
# 168786  5000m     <NA>        <NA>      <NA>  ...  Female
#
#                                               COMPETITION       DATE  YEAR  \
# 0                                   3rd Asian Youth Games 2025-10-23  2025
# 1                                   3rd Asian Youth Games 2025-10-23  2025
# 2                                   3rd Asian Youth Games 2025-10-23  2025
# 3                                   3rd Asian Youth Games 2025-10-23  2025
# 4                                   3rd Asian Youth Games 2025-10-24  2025
# ...                                                   ...        ...   ...
# 167900                                    2nd SANO Sprint 2025-08-11  2025
# 167922                             Summer Games In Hikone 2025-08-09  2025
# 168210          Hercules Wimbledon 5000m Festival Evening 2025-08-09  2025
# 168785  4J Studios scottishathletics National Senior &... 2025-08-23  2025
# 168786  4J Studios scottishathletics National Senior &... 2025-08-23  2025
#
#                REGION                  TIMESTAMP  \
# 0       International  2025-10-27 21:31:00+00:00
# 1       International  2025-10-27 21:31:00+00:00
# 2       International  2025-10-27 21:31:00+00:00
# 3       International  2025-10-27 21:31:00+00:00
# 4       International  2025-10-27 21:31:00+00:00
# ...               ...                        ...
# 167900  International  2025-08-14 12:50:00+00:00
# 167922  International  2025-08-14 12:50:00+00:00
# 168210  International  2025-08-14 12:50:00+00:00
# 168785  International  2025-08-31 18:46:00+00:00
# 168786  International  2025-08-31 18:46:00+00:00
#
#                                     NOW              delta_time  \
# 0      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 1      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 2      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 3      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 4      2025-10-27 21:34:16.886000+00:00  3 days 21:34:16.886000
# ...                                 ...                     ...
# 167900 2025-10-27 21:34:16.886000+00:00 77 days 21:34:16.886000
# 167922 2025-10-27 21:34:16.886000+00:00 79 days 21:34:16.886000
# 168210 2025-10-27 21:34:16.886000+00:00 79 days 21:34:16.886000
# 168785 2025-10-27 21:34:16.886000+00:00 65 days 21:34:16.886000
# 168786 2025-10-27 21:34:16.886000+00:00 65 days 21:34:16.886000
#
#        delta_time_conv event_month
# 0                    4          10
# 1                    4          10
# 2                    4          10
# 3                    4          10
# 4                    3          10
# ...                ...         ...
# 167900              77           8
# 167922              79           8
# 168210              79           8
# 168785              65           8
# 168786              65           8
#
# [19396 rows x 24 columns]

# %%
athletes_selected[athletes_selected['NAME']=='Hia, Caleb']
# Out:
#              NAME    RESULT  TEAM   AGE COMPETITION_RANK DIVISION     EVENT  \
# 25306  Hia, Caleb  02:37:15  None  None              482     None  Marathon
#
#       DISTANCE EVENT_CLASS UNIQUE_ID  ... GENDER           COMPETITION  \
# 25306     None        None      None  ...   Male  London Marathon 2025
#
#             DATE  YEAR         REGION TIMESTAMP  \
# 25306 2025-04-27  2025  International      None
#
#                                    NOW               delta_time  \
# 25306 2025-10-27 21:34:16.886000+00:00 183 days 21:34:16.886000
#
#       delta_time_conv event_month
# 25306             183           4
#
# [1 rows x 24 columns]

# %%
# Choose 2024/25 only

athletes = athletes_selected

# %%
athletes
# Out:
#                          NAME    RESULT  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0         NG Caitlin Shan Wen     12.42  <NA>  <NA>                5     <NA>
# 1       TAN Ying Tong Shannon     12.53  <NA>  <NA>                2     <NA>
# 2         NG Caitlin Shan Wen     12.36  <NA>  <NA>                6     <NA>
# 3       TAN Ying Tong Shannon     12.33  <NA>  <NA>                7     <NA>
# 4            TAY Sean Russell     49.89  <NA>  <NA>                6     <NA>
# ...                       ...       ...   ...   ...              ...      ...
# 167900       Marc Brian Louis     20.89                            1
# 167922      Harry Irfan Curra     34.57                            3
# 168210           Rui Yong Soh  14:46.81                            4
# 168785            Vanessa Lee  17:11.36  <NA>  <NA>              nan     <NA>
# 168786             Nicole Low  17:16.72  <NA>  <NA>              nan     <NA>
#
#         EVENT DISTANCE EVENT_CLASS UNIQUE_ID  ...  GENDER  \
# 0        100m     <NA>         nan      <NA>  ...  Female
# 1        100m     <NA>         nan      <NA>  ...  Female
# 2        100m     <NA>         nan      <NA>  ...  Female
# 3        100m     <NA>         nan      <NA>  ...  Female
# 4        400m     <NA>         nan      <NA>  ...    Male
# ...       ...      ...         ...       ...  ...     ...
# 167900   200m                                 ...    Male
# 167922   300m                                 ...    Male
# 168210  5000m                                 ...    Male
# 168785  5000m     <NA>        <NA>      <NA>  ...  Female
# 168786  5000m     <NA>        <NA>      <NA>  ...  Female
#
#                                               COMPETITION       DATE  YEAR  \
# 0                                   3rd Asian Youth Games 2025-10-23  2025
# 1                                   3rd Asian Youth Games 2025-10-23  2025
# 2                                   3rd Asian Youth Games 2025-10-23  2025
# 3                                   3rd Asian Youth Games 2025-10-23  2025
# 4                                   3rd Asian Youth Games 2025-10-24  2025
# ...                                                   ...        ...   ...
# 167900                                    2nd SANO Sprint 2025-08-11  2025
# 167922                             Summer Games In Hikone 2025-08-09  2025
# 168210          Hercules Wimbledon 5000m Festival Evening 2025-08-09  2025
# 168785  4J Studios scottishathletics National Senior &... 2025-08-23  2025
# 168786  4J Studios scottishathletics National Senior &... 2025-08-23  2025
#
#                REGION                  TIMESTAMP  \
# 0       International  2025-10-27 21:31:00+00:00
# 1       International  2025-10-27 21:31:00+00:00
# 2       International  2025-10-27 21:31:00+00:00
# 3       International  2025-10-27 21:31:00+00:00
# 4       International  2025-10-27 21:31:00+00:00
# ...               ...                        ...
# 167900  International  2025-08-14 12:50:00+00:00
# 167922  International  2025-08-14 12:50:00+00:00
# 168210  International  2025-08-14 12:50:00+00:00
# 168785  International  2025-08-31 18:46:00+00:00
# 168786  International  2025-08-31 18:46:00+00:00
#
#                                     NOW              delta_time  \
# 0      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 1      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 2      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 3      2025-10-27 21:34:16.886000+00:00  4 days 21:34:16.886000
# 4      2025-10-27 21:34:16.886000+00:00  3 days 21:34:16.886000
# ...                                 ...                     ...
# 167900 2025-10-27 21:34:16.886000+00:00 77 days 21:34:16.886000
# 167922 2025-10-27 21:34:16.886000+00:00 79 days 21:34:16.886000
# 168210 2025-10-27 21:34:16.886000+00:00 79 days 21:34:16.886000
# 168785 2025-10-27 21:34:16.886000+00:00 65 days 21:34:16.886000
# 168786 2025-10-27 21:34:16.886000+00:00 65 days 21:34:16.886000
#
#        delta_time_conv event_month
# 0                    4          10
# 1                    4          10
# 2                    4          10
# 3                    4          10
# 4                    3          10
# ...                ...         ...
# 167900              77           8
# 167922              79           8
# 168210              79           8
# 168785              65           8
# 168786              65           8
#
# [19396 rows x 24 columns]

# %%
athletes[athletes['NAME']=='Jun Jie Calvin Quek']
# Out:
#                       NAME  RESULT  TEAM   AGE COMPETITION_RANK DIVISION  \
# 328    Jun Jie Calvin Quek   50.17  <NA>  <NA>              9.0     <NA>
# 1616   Jun Jie Calvin Quek   49.75   nan   nan              1.0      nan
# 1621   Jun Jie Calvin Quek   50.82   nan   nan              1.0      nan
# 1622   Jun Jie Calvin Quek   50.80   nan   nan              1.0      nan
# 1651   Jun Jie Calvin Quek   51.56   nan   nan              1.0      nan
# 2917   Jun Jie Calvin Quek   10.86  None  None                2     None
# 8042   Jun Jie Calvin Quek   52.62  None  None                9     None
# 8112   Jun Jie Calvin Quek   50.77  None  None                1     None
# 8142   Jun Jie Calvin Quek   51.64  None  None              6.0     None
# 8143   Jun Jie Calvin Quek   50.58  None  None                2     None
# 8144   Jun Jie Calvin Quek   50.94  None  None                8     None
# 56695  Jun Jie Calvin Quek  10.963     -                      2
# 56763  Jun Jie Calvin Quek  11.080     -                      3
# 57216  Jun Jie Calvin Quek  47.384     -                      1
# 57254  Jun Jie Calvin Quek  47.756     -                      1
#
#               EVENT DISTANCE EVENT_CLASS UNIQUE_ID  ... GENDER  \
# 328    400m Hurdles     <NA>        <NA>      <NA>  ...   Male
# 1616   400m Hurdles      nan         nan       nan  ...   Male
# 1621   400m Hurdles      nan         nan       nan  ...   Male
# 1622   400m Hurdles      nan         nan       nan  ...   Male
# 1651   400m Hurdles      nan         nan       nan  ...   Male
# 2917           100m     None        None      None  ...   Male
# 8042   400m Hurdles     None        None      None  ...   Male
# 8112   400m Hurdles     None        None      None  ...   Male
# 8142   400m Hurdles     None        None      None  ...   Male
# 8143   400m Hurdles     None        None      None  ...   Male
# 8144   400m Hurdles     None        None      None  ...   Male
# 56695          100m                  nan            ...   Male
# 56763          100m                  nan            ...   Male
# 57216          400m                  nan            ...   Male
# 57254          400m                  nan            ...   Male
#
#                                              COMPETITION                DATE  \
# 328                   20th World Athletics Championships 2025-09-21 00:00:00
# 1616                             The 20th Twilight Games 2025-08-20 00:00:00
# 1621   National Track and Field Regional Invitational... 2025-07-20 00:00:00
# 1622   National Track and Field Regional Invitational... 2025-07-20 00:00:00
# 1651                        Hong Kong Athletics Series 4 2025-06-29 00:00:00
# 2917                             Potch Invitational Meet 2025-04-16 00:00:00
# 8042                                Sydney Track Classic 2025-03-15 00:00:00
# 8112                             Potch Invitational Meet 2025-04-16 00:00:00
# 8142       12th Kinami Michitaka Memorial Athletics Meet 2025-05-11 00:00:00
# 8143                  26th Asian Athletics Championships 2025-05-31 00:00:00
# 8144                  26th Asian Athletics Championships 2025-05-31 00:00:00
# 56695                         Pesta Sukan Athletics 2025 2025-07-26 17:45:00
# 56763                         Pesta Sukan Athletics 2025 2025-08-02 11:55:00
# 57216                         Pesta Sukan Athletics 2025 2025-07-27 16:40:00
# 57254                         Pesta Sukan Athletics 2025 2025-08-02 14:05:00
#
#        YEAR         REGION                   TIMESTAMP  \
# 328    2025  International   2025-09-20 11:19:00+00:00
# 1616   2025  International   2025-08-22 16:54:00+00:00
# 1621   2025  International   2025-08-22 16:54:00+00:00
# 1622   2025  International   2025-08-22 16:54:00+00:00
# 1651   2025  International                     56:28.5
# 2917   2025  International                        None
# 8042   2025  International                        None
# 8112   2025  International                        None
# 8142   2025  International  2025-05-16 15:18:11.207945
# 8143   2025  International  2025-06-01 16:49:06.835826
# 8144   2025  International                     36:03.8
# 56695  2025          Local   2025-08-15 14:46:00+00:00
# 56763  2025          Local   2025-08-15 14:46:00+00:00
# 57216  2025          Local   2025-08-15 14:46:00+00:00
# 57254  2025          Local   2025-08-15 14:46:00+00:00
#
#                                    NOW               delta_time  \
# 328   2025-10-27 21:34:16.886000+00:00  36 days 21:34:16.886000
# 1616  2025-10-27 21:34:16.886000+00:00  68 days 21:34:16.886000
# 1621  2025-10-27 21:34:16.886000+00:00  99 days 21:34:16.886000
# 1622  2025-10-27 21:34:16.886000+00:00  99 days 21:34:16.886000
# 1651  2025-10-27 21:34:16.886000+00:00 120 days 21:34:16.886000
# 2917  2025-10-27 21:34:16.886000+00:00 194 days 21:34:16.886000
# 8042  2025-10-27 21:34:16.886000+00:00 226 days 21:34:16.886000
# 8112  2025-10-27 21:34:16.886000+00:00 194 days 21:34:16.886000
# 8142  2025-10-27 21:34:16.886000+00:00 169 days 21:34:16.886000
# 8143  2025-10-27 21:34:16.886000+00:00 149 days 21:34:16.886000
# 8144  2025-10-27 21:34:16.886000+00:00 149 days 21:34:16.886000
# 56695 2025-10-27 21:34:16.886000+00:00  93 days 03:49:16.886000
# 56763 2025-10-27 21:34:16.886000+00:00  86 days 09:39:16.886000
# 57216 2025-10-27 21:34:16.886000+00:00  92 days 04:54:16.886000
# 57254 2025-10-27 21:34:16.886000+00:00  86 days 07:29:16.886000
#
#       delta_time_conv event_month
# 328                36           9
# 1616               68           8
# 1621               99           7
# 1622               99           7
# 1651              120           6
# 2917              194           4
# 8042              226           3
# 8112              194           4
# 8142              169           5
# 8143              149           5
# 8144              149           5
# 56695              93           7
# 56763              86           8
# 57216              92           7
# 57254              86           8
#
# [15 rows x 24 columns]

# %%
# Process dates to extract age

# Map NSG divisions into age

mask = (athletes['DIVISION'].str.contains(r'A', na=False))
athletes.loc[mask, 'AGE'] = '18.5'

mask = (athletes['DIVISION'].str.contains(r'B', na=False))
athletes.loc[mask, 'AGE'] = '16'

mask = (athletes['DIVISION'].str.contains(r'C', na=False))
athletes.loc[mask, 'AGE'] = '13.5'

mask = (athletes['DIVISION'].str.contains(r'O', na=False))
athletes.loc[mask, 'AGE'] = '12'

# %%
def length(string):

    B = ''
    year = ''

    try:

        length = len(string)

        if length == 2:

            string = '19' + string

        elif length == 1:

            string = ''

        else:

            pass

        if string is not None or len(string) != 1:

            B = parser.parse(string, dayfirst=True)
                        
    except:

        pass

    return B


athletes['DOB_dt'] = athletes['DOB'].apply(length)
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/1704523743.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes['DOB_dt'] = athletes['DOB'].apply(length)

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')


athletes.to_csv('U20_age_post_map_oct27.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
# Create temporary mapped event column
# Junior Category Only

athletes['MAPPED_EVENT']=''

for col in athletes.columns:
    athletes[col] = athletes[col].astype(str)
    athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
    athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
    athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
    athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
    athletes[col] = athletes[col].str.strip()


# Correct javelin category

mask = athletes['EVENT'].str.contains(r'Javelin', na=True)
athletes.loc[mask, 'CATEGORY_EVENT'] = 'Throw'


# Running

mask = (athletes['EVENT'].str.contains(r'Dash', na=True) & athletes['DISTANCE'].str.contains(r'100', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '100m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'100', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '100m'
mask = athletes['EVENT'].str.contains(r'100 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m'
mask = athletes['EVENT'].str.contains(r'^100m$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '100m'

mask = (athletes['EVENT'].str.contains(r'Dash', na=True) & athletes['DISTANCE'].str.contains(r'200', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '200m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'200', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '200m'
mask = athletes['EVENT'].str.contains(r'^200m$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '200m'
mask = athletes['EVENT'].str.contains(r'200\sMeter', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '200m'

mask = (athletes['EVENT'].str.contains(r'Dash', na=True) & athletes['DISTANCE'].str.contains(r'400', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '400m'
mask = athletes['EVENT'].str.contains(r'^400m$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '400m'
mask = athletes['EVENT'].str.contains(r'^400\sMeter$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '400m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'400', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '400m'


mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'800', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '800m'
mask = athletes['EVENT'].str.contains(r'800 Meter Run', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '800m'
mask = athletes['EVENT'].str.contains(r'^800m$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '800m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'1000', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '1000m'


mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'1500', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '1500m'
mask = athletes['EVENT'].str.contains(r'^1500m$', na=True, regex=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '1500m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'3000', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m'
#mask = athletes['EVENT'].str.contains(r'3000m', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '3000m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'5000', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '5000m'
mask = athletes['EVENT'].str.contains(r'^5000m$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '5000m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'10000', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '10,000m'
mask = athletes['EVENT'].str.contains(r'^10000m$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '10,000m'
mask = athletes['EVENT'].str.contains(r'^10\,000m$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '10,000m'
mask = (athletes['EVENT'].str.contains(r'Run', na=True) & athletes['DISTANCE'].str.contains(r'Mile', na=True))
athletes.loc[mask, 'MAPPED_EVENT'] = '1 Mile'

#mask = athletes['EVENT'].str.contains(r'10\,000m', na=True, regex=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '10000m'



# Hurdles


mask = athletes['EVENT'].str.contains(r'110m\sHurdles\s\(0\.991m\)', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = '110m hurdles'


mask = (athletes['EVENT'].str.contains(r'100m Hurdles|100m hurdles', na=False) & athletes['EVENT_CLASS'].str.contains('0.838|0.84', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))  # this is the correct syntax
athletes.loc[mask, 'MAPPED_EVENT'] = '100m Hurdles'
#mask = (athletes['EVENT'].str.contains(r'100m Hurdles|100m hurdles', na=False) & athletes['DIVISION'].str.contains('None', na=False) & athletes['GENDER'].str.contains(r'Female', na=False) & athletes['REGION'].str.contains(r'International', na=False))  # this is the correct syntax
#athletes.loc[mask, 'MAPPED_EVENT'] = '100m Hurdles'
mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'100', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.838|0.84', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '100m Hurdles'
mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'100', na=False) & athletes['DIVISION'].str.contains(r'Open|OPEN', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '100m Hurdles' # NEW


#mask = (athletes['EVENT'].str.contains(r'100m Hurdles|100m hurdles', na=False) & athletes['REGION'].str.contains(r'International', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '100m Hurdles'





# Using np.where instead

#athletes['MAPPED_EVENT'] = np.where(((athletes['EVENT']=='110m hurdles|110m Hurdles') & ((athletes['EVENT_CLASS']=='')|athletes['EVENT_CLASS']=='None') & (athletes['REGION']=='International')), '110m Hurdles', ' ')   
                                
mask = (athletes['EVENT'].str.contains(r'110m Hurdles|110m hurdles', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.991|99.1', na=False) & athletes['GENDER'].str.contains(r'Male', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '110m Hurdles'


mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'110', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.991', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '110m Hurdles'
mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'110', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.838', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '110m Hurdles'
mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'110', na=False) & athletes['DIVISION'].str.contains(r'U20', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '110m Hurdles'








#mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'400', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.762|76.2cm', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '400m Hurdles'
#mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'400', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.84|84|0.838', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '400m Hurdles'
#mask = (athletes['EVENT'].str.contains(r'^Hurdles$', na=False) & athletes['DISTANCE'].str.contains(r'400', na=False) & athletes['DIVISION'].str.contains(r'U18', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '400m Hurdles'
#mask = (athletes['EVENT'].str.contains(r'400m Hurdles', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.84|84|0.838', na=False)  & athletes['GENDER'].str.contains(r'Male', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '400m Hurdles'
#mask = (athletes['EVENT'].str.contains(r'Hurdles', na=False) & athletes['DISTANCE'].str.contains(r'400', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.762', na=False)& athletes['GENDER'].str.contains(r'Female', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '400m Hurdles'
#mask = (athletes['EVENT'].str.contains(r'400m Hurdles', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.762m', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '400m Hurdles'
#mask = (athletes['EVENT'].str.contains(r'400m Hurdles|400m hurdles', na=False) & athletes['EVENT_CLASS'].str.contains('0.762|0.84|0.838', na=False) & athletes['REGION'].str.contains(r'International', na=False))  # this is the correct syntax
#athletes.loc[mask, 'MAPPED_EVENT'] = '400m Hurdles'



# Throws


mask = (athletes['EVENT'].str.contains(r'Javelin Throw|Javelin throw|Javelin', na=False) & athletes['EVENT_CLASS'].str.contains(r'600g', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = 'Javelin Throw'
mask = (athletes['EVENT'].str.contains(r'Javelin Throw|Javelin throw|Javelin', na=False) & athletes['DIVISION'].str.contains(r'Open|OPEN', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = 'Javelin Throw' # NEW MEN and WOMEN


mask = (athletes['EVENT'].str.contains(r'Javelin Throw|Javelin throw|Javelin', na=False) & athletes['EVENT_CLASS'].str.contains(r'800g', na=False) & athletes['GENDER'].str.contains(r'Male', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = 'Javelin Throw'

#mask = (athletes['EVENT'].str.contains(r'Shot Put|Shot put', na=False, regex=True) & (athletes['GENDER']=='Female') & (athletes['EVENT_CLASS']=='3kg'))# there are some additional characters after Put
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Shot Put'


#mask = (athletes['EVENT'].str.contains(r'Shot Put|Shot put', na=False) & (athletes['GENDER']=='Male') & (athletes['EVENT_CLASS'].str.contains(r'5', na=False)))# there are some additional characters after Put
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Shot Put'
#mask = (athletes['EVENT'].str.contains(r'Shot Put|Shot put', na=False) & (athletes['GENDER']=='Female') & (athletes['EVENT_CLASS'].str.contains(r'3', na=False)))# there are some additional characters after Put
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Shot Put'



#mask = (athletes['EVENT'].str.contains(r'Hammer Throw|Hammer throw', na=False) & athletes['EVENT_CLASS'].str.contains(r'5kg', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Hammer Throw'
#mask = (athletes['EVENT'].str.contains(r'Hammer Throw|Hammer throw', na=False) & athletes['EVENT_CLASS'].str.contains(r'3.00kg', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Hammer Throw'

mask = (athletes['EVENT'].str.contains(r'Discus Throw|Discus|Discus throw', na=False) & athletes['EVENT_CLASS'].str.contains(r'1.75kg', na=False) & athletes['GENDER'].str.contains(r'Male', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = 'Discus Throw'
mask = (athletes['EVENT'].str.contains(r'Discus Throw|Discus|Discus throw', na=False) & athletes['EVENT_CLASS'].str.contains(r'1kg|1.00kg', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = 'Discus Throw'
mask = (athletes['EVENT'].str.contains(r'Discus Throw|Discus|Discus throw', na=False) & athletes['DIVISION'].str.contains(r'Open|OPEN', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = 'Discus Throw' # NEW

mask = (athletes['EVENT'].str.contains(r'Discus Throw|Discus throw', na=False) & athletes['DIVISION'].str.contains(r'U20', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = 'Discus Throw'


# Jumps

mask = athletes['EVENT'].str.contains(r'High Jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'High Jump'

mask = athletes['EVENT'].str.contains(r'^Long\sJump$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Long Jump'
mask = athletes['EVENT'].str.contains(r'Long Jump Open', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Long Jump'
mask = athletes['EVENT'].str.contains(r'Long Jump Trial', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Long Jump'


mask = athletes['EVENT'].str.contains(r'Triple Jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Triple Jump'
mask = athletes['EVENT'].str.contains(r'Pole Vault', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Pole Vault'
mask = athletes['EVENT'].str.contains(r'High jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'High Jump'
mask = athletes['EVENT'].str.contains(r'Long jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Long Jump'
mask = athletes['EVENT'].str.contains(r'Triple jump', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Triple Jump'
mask = athletes['EVENT'].str.contains(r'^Pole\svault$', na=True)
athletes.loc[mask, 'MAPPED_EVENT'] = 'Pole Vault'

# Steeplechase

mask = (athletes['EVENT'].str.contains(r'Steeplechase|steeplechase|S\/C', na=False) & athletes['DISTANCE'].str.contains(r'3000', na=False)  & athletes['EVENT_CLASS'].str.contains(r'0.914', na=False)  & athletes['GENDER'].str.contains(r'Male', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m Steeplechase'
mask = (athletes['EVENT'].str.contains(r'Steeplechase|steeplechase|S\/C', na=False) & athletes['DISTANCE'].str.contains(r'3000', na=False)  & athletes['EVENT_CLASS'].str.contains(r'0.762', na=False)  & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m Steeplechase'
mask = (athletes['EVENT'].str.contains(r'Steeplechase|steeplechase|S\/C', na=False) & athletes['DISTANCE'].str.contains(r'3000', na=False)  & athletes['DIVISION'].str.contains(r'OPEN|Open', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m Steeplechase' # NEW. Apply to both MEN and WOMEN



mask = (athletes['EVENT'].str.contains(r'3000m Steeplechase|3000m steeplechase|3000m S\/C', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.914', na=False) & athletes['GENDER'].str.contains(r'Male', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m Steeplechase'
mask = (athletes['EVENT'].str.contains(r'3000m Steeplechase|3000m steeplechase|3000m S\/C', na=False) & athletes['EVENT_CLASS'].str.contains(r'0.762', na=False) & athletes['GENDER'].str.contains(r'Female', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m Steeplechase'
mask = (athletes['EVENT'].str.contains(r'3000m Steeplechase|3000m steeplechase|3000m S\/C', na=False) & athletes['DIVISION'].str.contains(r'OPEN|Open', na=False))
athletes.loc[mask, 'MAPPED_EVENT'] = '3000m Steeplechase' # NEW. Apply to both MEN and WOMEN




# Marathon

#mask = athletes['EVENT'].str.contains(r'^Marathon$', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Marathon'
#mask = athletes['EVENT'].str.contains(r'^Half\sMarathon$', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Half Marathon'
#mask = athletes['EVENT'].str.contains(r'^Half\smarathon$', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Half Marathon'


# Walk

#mask = (athletes['EVENT'].str.contains(r'Race Walk', na=False) & athletes['DISTANCE'].str.contains(r'5000', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '5000m Racewalk'

#mask = (athletes['EVENT'].str.contains(r'Race Walk', na=False) & athletes['DISTANCE'].str.contains(r'10000', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '10000m Racewalk'



# Relay

#mask = athletes['EVENT'].str.contains(r'4x80m Relay', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 80m'
#mask = athletes['EVENT'].str.contains(r'^4\sx\s100m$', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m'
#mask = athletes['EVENT'].str.contains(r'4x100m Relay', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m'
#mask = athletes['EVENT'].str.contains(r'4 X 100m Relay', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m'
#mask = (athletes['EVENT'].str.contains(r'Relay', na=False) & athletes['DISTANCE'].str.contains(r'400', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m'

#mask = athletes['EVENT'].str.contains(r'4x400m Relay', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m'
#mask = athletes['EVENT'].str.contains(r'4 X 400m Relay', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m'
#mask = athletes['EVENT'].str.contains(r'4x100 Meter Relay', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 100m'
#mask = (athletes['EVENT'].str.contains(r'Relay', na=False) & athletes['DISTANCE'].str.contains(r'1600', na=False))
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m'
#mask = athletes['EVENT'].str.contains(r'^4\sx\s400m$', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = '4 x 400m'

# Decathlon/Heptathlon

#mask = athletes['EVENT'].str.contains(r'^Heptathlon$', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Heptathlon'
#mask = athletes['EVENT'].str.contains(r'^Decathlon$', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Decathlon'
#mask = athletes['EVENT'].str.contains(r'Heptathlon', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Heptathlon'
#mask = athletes['EVENT'].str.contains(r'Decathlon', na=True)
#athletes.loc[mask, 'MAPPED_EVENT'] = 'Decathlon'
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes['MAPPED_EVENT']=''
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4144613628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/3513542181.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()

# %%
for col in athletes.columns:
    athletes[col] = athletes[col].astype(str)
    athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
    athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
    athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
    athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
    athletes[col] = athletes[col].str.strip()
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].astype(str)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\xa0', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\r', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.replace('\n', ' ', regex=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_8419/2203170124.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athletes[col] = athletes[col].str.strip()

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')


athletes.to_csv('U20_post_map_oct27.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
# Load Asian Youth Benchmarks

os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/Benchmarks/')

all_benchmark = pd.read_csv("All_Benchmarks.csv")

# %%
all_benchmark
# Out:
#                 BENCHMARK          EVENT  GENDER RESULT
# 0    26th Asian Athletics           100m    Male  10.33
# 1    26th Asian Athletics           100m  Female  11.66
# 2    26th Asian Athletics           200m    Male  21.01
# 3    26th Asian Athletics           200m  Female  23.66
# 4    26th Asian Athletics           400m    Male  46.29
# ..                    ...            ...     ...    ...
# 215    17th SEA Youth U20    Triple Jump  Female  12.57
# 216    17th SEA Youth U20   Discus Throw    Male  48.76
# 217    17th SEA Youth U20   Discus Throw  Female  40.84
# 218    17th SEA Youth U20  Javelin Throw    Male  62.54
# 219    17th SEA Youth U20  Javelin Throw  Female  44.34
#
# [220 rows x 4 columns]

# %%
benchmark=all_benchmark[all_benchmark['BENCHMARK']=='17th SEA Youth U20']

# %%
benchmark
# Out:
#               BENCHMARK               EVENT  GENDER   RESULT
# 198  17th SEA Youth U20                100m    Male     10.6
# 199  17th SEA Youth U20                100m  Female    12.13
# 200  17th SEA Youth U20                200m    Male    21.45
# 201  17th SEA Youth U20                200m  Female    24.65
# 202  17th SEA Youth U20                400m    Male    47.77
# 203  17th SEA Youth U20                400m  Female    55.95
# 204  17th SEA Youth U20               1500m    Male  04:11.3
# 205  17th SEA Youth U20               1500m  Female  04:54.2
# 206  17th SEA Youth U20  3000m Steeplechase    Male  10:23.9
# 207  17th SEA Youth U20  3000m Steeplechase  Female  12:26.3
# 208  17th SEA Youth U20        110m Hurdles    Male    13.88
# 209  17th SEA Youth U20        100m Hurdles  Female    14.36
# 210  17th SEA Youth U20           High Jump    Male     2.04
# 211  17th SEA Youth U20           High Jump  Female     1.64
# 212  17th SEA Youth U20           Long Jump    Male     7.19
# 213  17th SEA Youth U20           Long Jump  Female     5.74
# 214  17th SEA Youth U20         Triple Jump    Male    14.99
# 215  17th SEA Youth U20         Triple Jump  Female    12.57
# 216  17th SEA Youth U20        Discus Throw    Male    48.76
# 217  17th SEA Youth U20        Discus Throw  Female    40.84
# 218  17th SEA Youth U20       Javelin Throw    Male    62.54
# 219  17th SEA Youth U20       Javelin Throw  Female    44.34

# %%
benchmark=benchmark.reset_index(drop=True)

# %%
# Converts any time format into seconds

def convert_time(i, string, metric):

    global output
    
    l=['discus', 'throw', 'jump', 'vault', 'shot']
        
    string=string.lower()
    
   # print('metric', metric)
    
    try:
        
        if 'w' in metric:  # skip marks with illegal wind speeds
            
        #    print('W', metric)
            
            output=''
            
        else:
            
    
            if any(s in string for s in l)==True:
            
                if 'm' in metric:
            
                    metric=metric.replace('m', '')
                    output=float(str(metric))
            
                elif 'GR' in metric:
            
                    metric=metric.replace('GR', '')
                    output=float(str(metric))
                
                
                else:
    
                    output=float(str(metric))
        
            elif string=='':   # no event description at all!
                
                output='' # return nothing
            
                
        
            else:
        
                searchstring = ":"
                searchstring2 = "."
                substring=str(metric)
                count = substring.count(searchstring)
                count2 = substring.count(searchstring2)
            
                if count==0:
                
                    output=float(substring)
            
            
                elif '10,000m' in string and count==2:  # fix erroneous timing format from XX:XX:XX to XX:XX.XX
                
                
                    idx = 5 # 6th character position
                    replacement = "."
                    metric = metric[:idx] + replacement + metric[idx+1:]                
                
                    m,s = metric.split(':')            

                    output = float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds())

                elif '5000m' in string and count==2:  # fix erroneous timing format from XX:XX:XX to XX:XX.XX
                
                
                    idx = 5 # 6th character position
                    replacement = "."
                    metric = metric[:idx] + replacement + metric[idx+1:]                
                
                    m,s = metric.split(':')            

                    output = float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds())

                    
                    
                elif '1500m' in string and count==2:  # fix erroneous timing format from XX:XX:XX to XX:XX.XX
                    
                    if len(substring)==7:  # format is X:XX:XX and not XX:XX:XX 
                        
                        idx = 4 # 5th character position
                        replacement = "."
                        metric = '0' + metric[:idx] + replacement + metric[idx+1:]                
                
                        m,s = metric.split(':')            

                        output = float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds())
                    
                        
                    else:  # format is XX:XX:XX
                        
                        idx = 5 # 5th character position
                        replacement = "."
                        metric = metric[:idx] + replacement + metric[idx+1:]                
                
                        m,s = metric.split(':')            

                        output = float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds())  
             
                elif (type(metric)==datetime.time or type(metric)==datetime.datetime):
                
                                                
                    time=str(metric)
                    h, m ,s = time.split(':')
                    output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
            
                                
                elif (count==1 and count2==1):
            
                    m,s = metric.split(':')
                    output = float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds())
                     
                elif (count==1 and count2==2):
                
            
                    metric = metric.replace(".", ":", 1)
            
                    h,m,s = metric.split(':')            
                    output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
                
        
                elif (count==2 and count2==0):
                
            
                    h,m,s = metric.split(':')
                    output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
  
            

    except:
        
        pass
                
    return output

# %%
def process_benchmarks(df):
    
    for i in range(len(df)):

        rowIndex = df.index[i]

        input_string=df.iloc[rowIndex,0]
    
        metric=df.iloc[rowIndex,3]
    
        if metric==None:
        
            continue
        
        out = convert_time(i, input_string, metric)
        
        print(rowIndex, input_string, out)

    
        df.loc[rowIndex, 'Metric'] = out
    
    return df

# %%
process_benchmarks(benchmark)
# Out:
# 0 17th SEA Youth U20 10.6
# 1 17th SEA Youth U20 12.13
# 2 17th SEA Youth U20 21.45
# 3 17th SEA Youth U20 24.65
# 4 17th SEA Youth U20 47.77
# 5 17th SEA Youth U20 55.95
# 6 17th SEA Youth U20 251.3
# 7 17th SEA Youth U20 294.2
# 8 17th SEA Youth U20 623.9
# 9 17th SEA Youth U20 746.3
# 10 17th SEA Youth U20 13.88
# 11 17th SEA Youth U20 14.36
# 12 17th SEA Youth U20 2.04
# 13 17th SEA Youth U20 1.64
# 14 17th SEA Youth U20 7.19
# 15 17th SEA Youth U20 5.74
# 16 17th SEA Youth U20 14.99
# 17 17th SEA Youth U20 12.57
# 18 17th SEA Youth U20 48.76
# 19 17th SEA Youth U20 40.84
# 20 17th SEA Youth U20 62.54
# 21 17th SEA Youth U20 44.34
#              BENCHMARK               EVENT  GENDER   RESULT  Metric
# 0   17th SEA Youth U20                100m    Male     10.6   10.60
# 1   17th SEA Youth U20                100m  Female    12.13   12.13
# 2   17th SEA Youth U20                200m    Male    21.45   21.45
# 3   17th SEA Youth U20                200m  Female    24.65   24.65
# 4   17th SEA Youth U20                400m    Male    47.77   47.77
# 5   17th SEA Youth U20                400m  Female    55.95   55.95
# 6   17th SEA Youth U20               1500m    Male  04:11.3  251.30
# 7   17th SEA Youth U20               1500m  Female  04:54.2  294.20
# 8   17th SEA Youth U20  3000m Steeplechase    Male  10:23.9  623.90
# 9   17th SEA Youth U20  3000m Steeplechase  Female  12:26.3  746.30
# 10  17th SEA Youth U20        110m Hurdles    Male    13.88   13.88
# 11  17th SEA Youth U20        100m Hurdles  Female    14.36   14.36
# 12  17th SEA Youth U20           High Jump    Male     2.04    2.04
# 13  17th SEA Youth U20           High Jump  Female     1.64    1.64
# 14  17th SEA Youth U20           Long Jump    Male     7.19    7.19
# 15  17th SEA Youth U20           Long Jump  Female     5.74    5.74
# 16  17th SEA Youth U20         Triple Jump    Male    14.99   14.99
# 17  17th SEA Youth U20         Triple Jump  Female    12.57   12.57
# 18  17th SEA Youth U20        Discus Throw    Male    48.76   48.76
# 19  17th SEA Youth U20        Discus Throw  Female    40.84   40.84
# 20  17th SEA Youth U20       Javelin Throw    Male    62.54   62.54
# 21  17th SEA Youth U20       Javelin Throw  Female    44.34   44.34

# %%
benchmark
# Out:
#              BENCHMARK               EVENT  GENDER   RESULT  Metric
# 0   17th SEA Youth U20                100m    Male     10.6   10.60
# 1   17th SEA Youth U20                100m  Female    12.13   12.13
# 2   17th SEA Youth U20                200m    Male    21.45   21.45
# 3   17th SEA Youth U20                200m  Female    24.65   24.65
# 4   17th SEA Youth U20                400m    Male    47.77   47.77
# 5   17th SEA Youth U20                400m  Female    55.95   55.95
# 6   17th SEA Youth U20               1500m    Male  04:11.3  251.30
# 7   17th SEA Youth U20               1500m  Female  04:54.2  294.20
# 8   17th SEA Youth U20  3000m Steeplechase    Male  10:23.9  623.90
# 9   17th SEA Youth U20  3000m Steeplechase  Female  12:26.3  746.30
# 10  17th SEA Youth U20        110m Hurdles    Male    13.88   13.88
# 11  17th SEA Youth U20        100m Hurdles  Female    14.36   14.36
# 12  17th SEA Youth U20           High Jump    Male     2.04    2.04
# 13  17th SEA Youth U20           High Jump  Female     1.64    1.64
# 14  17th SEA Youth U20           Long Jump    Male     7.19    7.19
# 15  17th SEA Youth U20           Long Jump  Female     5.74    5.74
# 16  17th SEA Youth U20         Triple Jump    Male    14.99   14.99
# 17  17th SEA Youth U20         Triple Jump  Female    12.57   12.57
# 18  17th SEA Youth U20        Discus Throw    Male    48.76   48.76
# 19  17th SEA Youth U20        Discus Throw  Female    40.84   40.84
# 20  17th SEA Youth U20       Javelin Throw    Male    62.54   62.54
# 21  17th SEA Youth U20       Javelin Throw  Female    44.34   44.34

# %%
mask = benchmark['EVENT'].str.lower().str.contains(r'jump|throw|put|pole|decathlon|heptathlon', na=True)

benchmark.loc[mask, '2%']=benchmark['Metric']*0.98
benchmark.loc[mask, '3.5%']=benchmark['Metric']*0.965
benchmark.loc[mask, '5%']=benchmark['Metric']*0.95

benchmark.loc[~mask, '2%']=benchmark['Metric']*1.02
benchmark.loc[~mask, '3.5%']=benchmark['Metric']*1.035
benchmark.loc[~mask, '5%']=benchmark['Metric']*1.05


#benchmarks.iloc[5, [1]]='10000m run'
#benchmarks.iloc[28, [1]]='10000m run'
#benchmarks.iloc[26, [1]]='1500m'

# %%
benchmark['MAPPED_EVENT']=benchmark['EVENT'].str.strip()

# %%
for col in benchmark.columns:
    benchmark[col] = benchmark[col].astype(str)
    benchmark[col] = benchmark[col].str.replace('\xa0', ' ', regex=True)
    benchmark[col] = benchmark[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
    benchmark[col] = benchmark[col].str.replace('\r', ' ', regex=True)
    benchmark[col] = benchmark[col].str.replace('\n', ' ', regex=True)
    benchmark[col] = benchmark[col].str.strip()

# %%
benchmark
# Out:
#              BENCHMARK               EVENT  GENDER   RESULT Metric  \
# 0   17th SEA Youth U20                100m    Male     10.6   10.6
# 1   17th SEA Youth U20                100m  Female    12.13  12.13
# 2   17th SEA Youth U20                200m    Male    21.45  21.45
# 3   17th SEA Youth U20                200m  Female    24.65  24.65
# 4   17th SEA Youth U20                400m    Male    47.77  47.77
# 5   17th SEA Youth U20                400m  Female    55.95  55.95
# 6   17th SEA Youth U20               1500m    Male  04:11.3  251.3
# 7   17th SEA Youth U20               1500m  Female  04:54.2  294.2
# 8   17th SEA Youth U20  3000m Steeplechase    Male  10:23.9  623.9
# 9   17th SEA Youth U20  3000m Steeplechase  Female  12:26.3  746.3
# 10  17th SEA Youth U20        110m Hurdles    Male    13.88  13.88
# 11  17th SEA Youth U20        100m Hurdles  Female    14.36  14.36
# 12  17th SEA Youth U20           High Jump    Male     2.04   2.04
# 13  17th SEA Youth U20           High Jump  Female     1.64   1.64
# 14  17th SEA Youth U20           Long Jump    Male     7.19   7.19
# 15  17th SEA Youth U20           Long Jump  Female     5.74   5.74
# 16  17th SEA Youth U20         Triple Jump    Male    14.99  14.99
# 17  17th SEA Youth U20         Triple Jump  Female    12.57  12.57
# 18  17th SEA Youth U20        Discus Throw    Male    48.76  48.76
# 19  17th SEA Youth U20        Discus Throw  Female    40.84  40.84
# 20  17th SEA Youth U20       Javelin Throw    Male    62.54  62.54
# 21  17th SEA Youth U20       Javelin Throw  Female    44.34  44.34
#
#                    2%                3.5%                  5%  \
# 0              10.812  10.970999999999998               11.13
# 1             12.3726  12.554549999999999  12.736500000000001
# 2              21.879            22.20075             22.5225
# 3              25.143  25.512749999999997             25.8825
# 4             48.7254            49.44195  50.158500000000004
# 5              57.069  57.908249999999995             58.7475
# 6             256.326            260.0955             263.865
# 7             300.084  304.49699999999996              308.91
# 8             636.378            645.7365             655.095
# 9             761.226            772.4205             783.615
# 10            14.1576             14.3658  14.574000000000002
# 11            14.6472  14.862599999999999              15.078
# 12             1.9992              1.9686               1.938
# 13             1.6072  1.5825999999999998  1.5579999999999998
# 14  7.046200000000001             6.93835              6.8305
# 15             5.6252              5.5391               5.453
# 16            14.6902  14.465349999999999  14.240499999999999
# 17            12.3186            12.13005             11.9415
# 18            47.7848  47.053399999999996  46.321999999999996
# 19            40.0232             39.4106              38.798
# 20            61.2892  60.351099999999995              59.413
# 21            43.4532             42.7881  42.123000000000005
#
#           MAPPED_EVENT
# 0                 100m
# 1                 100m
# 2                 200m
# 3                 200m
# 4                 400m
# 5                 400m
# 6                1500m
# 7                1500m
# 8   3000m Steeplechase
# 9   3000m Steeplechase
# 10        110m Hurdles
# 11        100m Hurdles
# 12           High Jump
# 13           High Jump
# 14           Long Jump
# 15           Long Jump
# 16         Triple Jump
# 17         Triple Jump
# 18        Discus Throw
# 19        Discus Throw
# 20       Javelin Throw
# 21       Javelin Throw

# %%
athletes
# Out:
#                          NAME    RESULT  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0         NG Caitlin Shan Wen     12.42  <NA>  18.5                5     <NA>
# 1       TAN Ying Tong Shannon     12.53  <NA>  18.5                2     <NA>
# 2         NG Caitlin Shan Wen     12.36  <NA>  18.5                6     <NA>
# 3       TAN Ying Tong Shannon     12.33  <NA>  18.5                7     <NA>
# 4            TAY Sean Russell     49.89  <NA>  18.5                6     <NA>
# ...                       ...       ...   ...   ...              ...      ...
# 167900       Marc Brian Louis     20.89                            1
# 167922      Harry Irfan Curra     34.57                            3
# 168210           Rui Yong Soh  14:46.81                            4
# 168785            Vanessa Lee  17:11.36  <NA>  18.5              nan     <NA>
# 168786             Nicole Low  17:16.72  <NA>  18.5              nan     <NA>
#
#         EVENT DISTANCE EVENT_CLASS UNIQUE_ID  ...                 DATE  YEAR  \
# 0        100m     <NA>         nan      <NA>  ...  2025-10-23 00:00:00  2025
# 1        100m     <NA>         nan      <NA>  ...  2025-10-23 00:00:00  2025
# 2        100m     <NA>         nan      <NA>  ...  2025-10-23 00:00:00  2025
# 3        100m     <NA>         nan      <NA>  ...  2025-10-23 00:00:00  2025
# 4        400m     <NA>         nan      <NA>  ...  2025-10-24 00:00:00  2025
# ...       ...      ...         ...       ...  ...                  ...   ...
# 167900   200m                                 ...  2025-08-11 00:00:00  2025
# 167922   300m                                 ...  2025-08-09 00:00:00  2025
# 168210  5000m                                 ...  2025-08-09 00:00:00  2025
# 168785  5000m     <NA>        <NA>      <NA>  ...  2025-08-23 00:00:00  2025
# 168786  5000m     <NA>        <NA>      <NA>  ...  2025-08-23 00:00:00  2025
#
#                REGION                  TIMESTAMP  \
# 0       International  2025-10-27 21:31:00+00:00
# 1       International  2025-10-27 21:31:00+00:00
# 2       International  2025-10-27 21:31:00+00:00
# 3       International  2025-10-27 21:31:00+00:00
# 4       International  2025-10-27 21:31:00+00:00
# ...               ...                        ...
# 167900  International  2025-08-14 12:50:00+00:00
# 167922  International  2025-08-14 12:50:00+00:00
# 168210  International  2025-08-14 12:50:00+00:00
# 168785  International  2025-08-31 18:46:00+00:00
# 168786  International  2025-08-31 18:46:00+00:00
#
#                                      NOW               delta_time  \
# 0       2025-10-27 21:34:16.886000+00:00   4 days 21:34:16.886000
# 1       2025-10-27 21:34:16.886000+00:00   4 days 21:34:16.886000
# 2       2025-10-27 21:34:16.886000+00:00   4 days 21:34:16.886000
# 3       2025-10-27 21:34:16.886000+00:00   4 days 21:34:16.886000
# 4       2025-10-27 21:34:16.886000+00:00   3 days 21:34:16.886000
# ...                                  ...                      ...
# 167900  2025-10-27 21:34:16.886000+00:00  77 days 21:34:16.886000
# 167922  2025-10-27 21:34:16.886000+00:00  79 days 21:34:16.886000
# 168210  2025-10-27 21:34:16.886000+00:00  79 days 21:34:16.886000
# 168785  2025-10-27 21:34:16.886000+00:00  65 days 21:34:16.886000
# 168786  2025-10-27 21:34:16.886000+00:00  65 days 21:34:16.886000
#
#        delta_time_conv event_month                     DOB_dt MAPPED_EVENT
# 0                    4          10  2010-11-24 00:00:00+00:00         100m
# 1                    4          10  2009-11-20 00:00:00+00:00         100m
# 2                    4          10  2010-11-24 00:00:00+00:00         100m
# 3                    4          10  2009-11-20 00:00:00+00:00         100m
# 4                    3          10  2009-12-25 00:00:00+00:00         400m
# ...                ...         ...                        ...          ...
# 167900              77           8        2002-08-07 00:00:00         200m
# 167922              79           8        2008-01-31 00:00:00
# 168210              79           8        1991-08-06 00:00:00        5000m
# 168785              65           8                                   5000m
# 168786              65           8                                   5000m
#
# [19396 rows x 26 columns]

# %%
# There is a problem with RESULTS column being changed after this statement

#df = athletes.reset_index().merge(benchmarks.reset_index(), on=['MAPPED_EVENT','GENDER'], how='left')
#df = athletes.merge(benchmarks, on=['EVENT','GENDER'], how='left')

# %%
# Merge benchmarks onto athletes on MAPPED_EVENT and GENDER

df = pd.merge(
    left=athletes, 
    right=benchmark,
    how='left',
    left_on=['MAPPED_EVENT', 'GENDER'],
    right_on=['MAPPED_EVENT', 'GENDER'],
)

# %%
df
# Out:
#                         NAME  RESULT_x  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0        NG Caitlin Shan Wen     12.42  <NA>  18.5                5     <NA>
# 1      TAN Ying Tong Shannon     12.53  <NA>  18.5                2     <NA>
# 2        NG Caitlin Shan Wen     12.36  <NA>  18.5                6     <NA>
# 3      TAN Ying Tong Shannon     12.33  <NA>  18.5                7     <NA>
# 4           TAY Sean Russell     49.89  <NA>  18.5                6     <NA>
# ...                      ...       ...   ...   ...              ...      ...
# 19391       Marc Brian Louis     20.89                            1
# 19392      Harry Irfan Curra     34.57                            3
# 19393           Rui Yong Soh  14:46.81                            4
# 19394            Vanessa Lee  17:11.36  <NA>  18.5              nan     <NA>
# 19395             Nicole Low  17:16.72  <NA>  18.5              nan     <NA>
#
#       EVENT_x DISTANCE EVENT_CLASS UNIQUE_ID  ... event_month  \
# 0        100m     <NA>         nan      <NA>  ...          10
# 1        100m     <NA>         nan      <NA>  ...          10
# 2        100m     <NA>         nan      <NA>  ...          10
# 3        100m     <NA>         nan      <NA>  ...          10
# 4        400m     <NA>         nan      <NA>  ...          10
# ...       ...      ...         ...       ...  ...         ...
# 19391    200m                                 ...           8
# 19392    300m                                 ...           8
# 19393   5000m                                 ...           8
# 19394   5000m     <NA>        <NA>      <NA>  ...           8
# 19395   5000m     <NA>        <NA>      <NA>  ...           8
#
#                           DOB_dt MAPPED_EVENT           BENCHMARK EVENT_y  \
# 0      2010-11-24 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 1      2009-11-20 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 2      2010-11-24 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 3      2009-11-20 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 4      2009-12-25 00:00:00+00:00         400m  17th SEA Youth U20    400m
# ...                          ...          ...                 ...     ...
# 19391        2002-08-07 00:00:00         200m  17th SEA Youth U20    200m
# 19392        2008-01-31 00:00:00                              NaN     NaN
# 19393        1991-08-06 00:00:00        5000m                 NaN     NaN
# 19394                                   5000m                 NaN     NaN
# 19395                                   5000m                 NaN     NaN
#
#       RESULT_y Metric       2%                3.5%                  5%
# 0        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 1        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 2        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 3        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 4        47.77  47.77  48.7254            49.44195  50.158500000000004
# ...        ...    ...      ...                 ...                 ...
# 19391    21.45  21.45   21.879            22.20075             22.5225
# 19392      NaN    NaN      NaN                 NaN                 NaN
# 19393      NaN    NaN      NaN                 NaN                 NaN
# 19394      NaN    NaN      NaN                 NaN                 NaN
# 19395      NaN    NaN      NaN                 NaN                 NaN
#
# [19396 rows x 33 columns]

# %%
# replace '-' with NaN

df['RESULT_x'] = df['RESULT_x'].replace(regex=r'–', value=np.NaN)
#df['SEED'] = df['SEED'].replace(regex=r'–', value=np.NaN)

# %%
df
# Out:
#                         NAME  RESULT_x  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0        NG Caitlin Shan Wen     12.42  <NA>  18.5                5     <NA>
# 1      TAN Ying Tong Shannon     12.53  <NA>  18.5                2     <NA>
# 2        NG Caitlin Shan Wen     12.36  <NA>  18.5                6     <NA>
# 3      TAN Ying Tong Shannon     12.33  <NA>  18.5                7     <NA>
# 4           TAY Sean Russell     49.89  <NA>  18.5                6     <NA>
# ...                      ...       ...   ...   ...              ...      ...
# 19391       Marc Brian Louis     20.89                            1
# 19392      Harry Irfan Curra     34.57                            3
# 19393           Rui Yong Soh  14:46.81                            4
# 19394            Vanessa Lee  17:11.36  <NA>  18.5              nan     <NA>
# 19395             Nicole Low  17:16.72  <NA>  18.5              nan     <NA>
#
#       EVENT_x DISTANCE EVENT_CLASS UNIQUE_ID  ... event_month  \
# 0        100m     <NA>         nan      <NA>  ...          10
# 1        100m     <NA>         nan      <NA>  ...          10
# 2        100m     <NA>         nan      <NA>  ...          10
# 3        100m     <NA>         nan      <NA>  ...          10
# 4        400m     <NA>         nan      <NA>  ...          10
# ...       ...      ...         ...       ...  ...         ...
# 19391    200m                                 ...           8
# 19392    300m                                 ...           8
# 19393   5000m                                 ...           8
# 19394   5000m     <NA>        <NA>      <NA>  ...           8
# 19395   5000m     <NA>        <NA>      <NA>  ...           8
#
#                           DOB_dt MAPPED_EVENT           BENCHMARK EVENT_y  \
# 0      2010-11-24 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 1      2009-11-20 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 2      2010-11-24 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 3      2009-11-20 00:00:00+00:00         100m  17th SEA Youth U20    100m
# 4      2009-12-25 00:00:00+00:00         400m  17th SEA Youth U20    400m
# ...                          ...          ...                 ...     ...
# 19391        2002-08-07 00:00:00         200m  17th SEA Youth U20    200m
# 19392        2008-01-31 00:00:00                              NaN     NaN
# 19393        1991-08-06 00:00:00        5000m                 NaN     NaN
# 19394                                   5000m                 NaN     NaN
# 19395                                   5000m                 NaN     NaN
#
#       RESULT_y Metric       2%                3.5%                  5%
# 0        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 1        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 2        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 3        12.13  12.13  12.3726  12.554549999999999  12.736500000000001
# 4        47.77  47.77  48.7254            49.44195  50.158500000000004
# ...        ...    ...      ...                 ...                 ...
# 19391    21.45  21.45   21.879            22.20075             22.5225
# 19392      NaN    NaN      NaN                 NaN                 NaN
# 19393      NaN    NaN      NaN                 NaN                 NaN
# 19394      NaN    NaN      NaN                 NaN                 NaN
# 19395      NaN    NaN      NaN                 NaN                 NaN
#
# [19396 rows x 33 columns]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')


df.to_csv('U20_postmap_oct27.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
# Convert results and seed into seconds format

df.reset_index(drop=True, inplace=True)

for col in df.columns:
    
    df[col] = df[col].astype(str)
    df[col] = df[col].str.replace('\xa0', ' ', regex=True)
    df[col] = df[col].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
    df[col] = df[col].str.replace('\r', ' ', regex=True)
    df[col] = df[col].str.replace('\n', ' ', regex=True)
    df[col] = df[col].str.strip()

for i in range(len(df)):
    
    result_out=''
    
        
    rowIndex = df.index[i]

    event=df.loc[rowIndex,'MAPPED_EVENT']    # event description
    
    result=df.loc[rowIndex,'RESULT_x'] # result
    
    if result=='—' or result=='None' or result=='DQ' or result=='SCR' or result=='FS' or result=='DNQ' or result=='DNS' or result=='NH' or result=='NM' or result=='FOUL' or result=='DNF' or result=='SR' :
        continue
    
    result_out = convert_time(i, event, result)
         
    df.loc[rowIndex, 'RESULT_CONV'] = result_out
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/1944330574.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[rowIndex, 'RESULT_CONV'] = result_out

# %%
#df["AGE"].fillna(0, inplace=True)
#df['AGE'] = df['AGE'].astype('float')

# %%
df
# Out:
#                         NAME  RESULT_x  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0        NG Caitlin Shan Wen     12.42  <NA>  18.5                5     <NA>
# 1      TAN Ying Tong Shannon     12.53  <NA>  18.5                2     <NA>
# 2        NG Caitlin Shan Wen     12.36  <NA>  18.5                6     <NA>
# 3      TAN Ying Tong Shannon     12.33  <NA>  18.5                7     <NA>
# 4           TAY Sean Russell     49.89  <NA>  18.5                6     <NA>
# ...                      ...       ...   ...   ...              ...      ...
# 19391       Marc Brian Louis     20.89                            1
# 19392      Harry Irfan Curra     34.57                            3
# 19393           Rui Yong Soh  14:46.81                            4
# 19394            Vanessa Lee  17:11.36  <NA>  18.5              nan     <NA>
# 19395             Nicole Low  17:16.72  <NA>  18.5              nan     <NA>
#
#       EVENT_x DISTANCE EVENT_CLASS UNIQUE_ID  ...                     DOB_dt  \
# 0        100m     <NA>         nan      <NA>  ...  2010-11-24 00:00:00+00:00
# 1        100m     <NA>         nan      <NA>  ...  2009-11-20 00:00:00+00:00
# 2        100m     <NA>         nan      <NA>  ...  2010-11-24 00:00:00+00:00
# 3        100m     <NA>         nan      <NA>  ...  2009-11-20 00:00:00+00:00
# 4        400m     <NA>         nan      <NA>  ...  2009-12-25 00:00:00+00:00
# ...       ...      ...         ...       ...  ...                        ...
# 19391    200m                                 ...        2002-08-07 00:00:00
# 19392    300m                                 ...        2008-01-31 00:00:00
# 19393   5000m                                 ...        1991-08-06 00:00:00
# 19394   5000m     <NA>        <NA>      <NA>  ...
# 19395   5000m     <NA>        <NA>      <NA>  ...
#
#       MAPPED_EVENT           BENCHMARK EVENT_y RESULT_y Metric       2%  \
# 0             100m  17th SEA Youth U20    100m    12.13  12.13  12.3726
# 1             100m  17th SEA Youth U20    100m    12.13  12.13  12.3726
# 2             100m  17th SEA Youth U20    100m    12.13  12.13  12.3726
# 3             100m  17th SEA Youth U20    100m    12.13  12.13  12.3726
# 4             400m  17th SEA Youth U20    400m    47.77  47.77  48.7254
# ...            ...                 ...     ...      ...    ...      ...
# 19391         200m  17th SEA Youth U20    200m    21.45  21.45   21.879
# 19392                              nan     nan      nan    nan      nan
# 19393        5000m                 nan     nan      nan    nan      nan
# 19394        5000m                 nan     nan      nan    nan      nan
# 19395        5000m                 nan     nan      nan    nan      nan
#
#                      3.5%                  5% RESULT_CONV
# 0      12.554549999999999  12.736500000000001       12.42
# 1      12.554549999999999  12.736500000000001       12.53
# 2      12.554549999999999  12.736500000000001       12.36
# 3      12.554549999999999  12.736500000000001       12.33
# 4                49.44195  50.158500000000004       49.89
# ...                   ...                 ...         ...
# 19391            22.20075             22.5225       20.89
# 19392                 nan                 nan
# 19393                 nan                 nan      886.81
# 19394                 nan                 nan     1031.36
# 19395                 nan                 nan     1036.72
#
# [19396 rows x 34 columns]

# %%
# Choose SEED if better than RESULT

#condition1=df['SEED_CONV']>df['RESULT_CONV']
#condition2=((df['CATEGORY_EVENT']=='Jump')|(df['CATEGORY_EVENT']=='Throw'))
#condition3=df['SEED_CONV']<df['RESULT_CONV']
#condition4=~((df['CATEGORY_EVENT']=='Jump')|(df['CATEGORY_EVENT']=='Throw'))


#df['RESULT_BEST']=df['SEED_CONV'].where((condition1 & condition2)|(condition3 & condition4), df['RESULT_CONV'].values)

df['RESULT_BEST'] = df['RESULT_CONV']

# %%
df
# Out:
#                         NAME  RESULT_x  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0        NG Caitlin Shan Wen     12.42  <NA>  18.5                5     <NA>
# 1      TAN Ying Tong Shannon     12.53  <NA>  18.5                2     <NA>
# 2        NG Caitlin Shan Wen     12.36  <NA>  18.5                6     <NA>
# 3      TAN Ying Tong Shannon     12.33  <NA>  18.5                7     <NA>
# 4           TAY Sean Russell     49.89  <NA>  18.5                6     <NA>
# ...                      ...       ...   ...   ...              ...      ...
# 19391       Marc Brian Louis     20.89                            1
# 19392      Harry Irfan Curra     34.57                            3
# 19393           Rui Yong Soh  14:46.81                            4
# 19394            Vanessa Lee  17:11.36  <NA>  18.5              nan     <NA>
# 19395             Nicole Low  17:16.72  <NA>  18.5              nan     <NA>
#
#       EVENT_x DISTANCE EVENT_CLASS UNIQUE_ID  ... MAPPED_EVENT  \
# 0        100m     <NA>         nan      <NA>  ...         100m
# 1        100m     <NA>         nan      <NA>  ...         100m
# 2        100m     <NA>         nan      <NA>  ...         100m
# 3        100m     <NA>         nan      <NA>  ...         100m
# 4        400m     <NA>         nan      <NA>  ...         400m
# ...       ...      ...         ...       ...  ...          ...
# 19391    200m                                 ...         200m
# 19392    300m                                 ...
# 19393   5000m                                 ...        5000m
# 19394   5000m     <NA>        <NA>      <NA>  ...        5000m
# 19395   5000m     <NA>        <NA>      <NA>  ...        5000m
#
#                 BENCHMARK EVENT_y RESULT_y Metric       2%  \
# 0      17th SEA Youth U20    100m    12.13  12.13  12.3726
# 1      17th SEA Youth U20    100m    12.13  12.13  12.3726
# 2      17th SEA Youth U20    100m    12.13  12.13  12.3726
# 3      17th SEA Youth U20    100m    12.13  12.13  12.3726
# 4      17th SEA Youth U20    400m    47.77  47.77  48.7254
# ...                   ...     ...      ...    ...      ...
# 19391  17th SEA Youth U20    200m    21.45  21.45   21.879
# 19392                 nan     nan      nan    nan      nan
# 19393                 nan     nan      nan    nan      nan
# 19394                 nan     nan      nan    nan      nan
# 19395                 nan     nan      nan    nan      nan
#
#                      3.5%                  5% RESULT_CONV RESULT_BEST
# 0      12.554549999999999  12.736500000000001       12.42       12.42
# 1      12.554549999999999  12.736500000000001       12.53       12.53
# 2      12.554549999999999  12.736500000000001       12.36       12.36
# 3      12.554549999999999  12.736500000000001       12.33       12.33
# 4                49.44195  50.158500000000004       49.89       49.89
# ...                   ...                 ...         ...         ...
# 19391            22.20075             22.5225       20.89       20.89
# 19392                 nan                 nan
# 19393                 nan                 nan      886.81      886.81
# 19394                 nan                 nan     1031.36     1031.36
# 19395                 nan                 nan     1036.72     1036.72
#
# [19396 rows x 35 columns]

# %%
# Change to numeric

df[['2%', '3.5%', '5%', 'RESULT_BEST', 'Metric']] = df[['2%', '3.5%', '5%', 'RESULT_BEST', 'Metric']].apply(pd.to_numeric, errors='coerce')

# %%
mask = df['CATEGORY_EVENT'].str.lower().str.contains(r'jump|throw|decathlon|heptathlon', na=True)

df.loc[mask, 'Delta2'] = df['RESULT_BEST']-df['2%']
df.loc[mask, 'Delta3.5'] = df['RESULT_BEST']-df['3.5%']
df.loc[mask, 'Delta5'] = df['RESULT_BEST']-df['5%']
df.loc[mask, 'Delta_Benchmark'] = df['RESULT_BEST']-df['Metric']

df.loc[~mask, 'Delta2'] =  df['2%'] - df['RESULT_BEST']
df.loc[~mask, 'Delta3.5'] = df['3.5%'] - df['RESULT_BEST']
df.loc[~mask, 'Delta5'] = df['5%'] - df['RESULT_BEST']
df.loc[~mask, 'Delta_Benchmark'] = df['Metric'] - df['RESULT_BEST']

#rslt_df['Delta2']=rslt_df['2pc']-rslt_df['RESULT_CONV']
#rslt_df['Delta35']=rslt_df['35pc']-rslt_df['RESULT_CONV']
#rslt_df['Delta5']=rslt_df['5pc']-rslt_df['RESULT_CONV']
df=df.loc[df['COMPETITION']!='Southeast Asian Games'] # Do not include results from SEAG in dataset

# %%
# Performance metric to filter out athletes

df['PERF_SCALAR']=df['Delta5']/df['Metric']*100

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')


df.to_csv('U20_postmap_benchmarked_oct27.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
df[df['MAPPED_EVENT']=='10,000m']
# Out:
#                            NAME  RESULT_x                            TEAM AGE  \
# 296                   Ko, Keane  34:03.99                       Club Zoom  12
# 297               Tea, Wee Keat  39:35.86                      Lacticbuds  12
# 298               Ho, Sheng Hui  38:37.79  Singapore University of Social  12
# 299    SAVIOUR, GILBERT DOMINIC  37:32.24    Cougars Athletic Association  12
# 300               Chin, Matthew  39:55.64       Nanyang Technological Uni  12
# ...                         ...       ...                             ...  ..
# 15624              Tan, Bernice   44:25.6                      Lacticbuds  12
# 15628           Goh, Shing Ling   39:21.6                      TeamFabian  12
# 15646              Sng, Raymond   35:28.2                       Club Zoom  12
# 19381                 Shaun Goh  31:02.40
# 19382   Vanessa Lee Ying Zhuang  36:15.67
#
#       COMPETITION_RANK DIVISION  EVENT_x DISTANCE EVENT_CLASS UNIQUE_ID  ...  \
# 296                  1     Open      Run  10000.0        None   K326A01  ...
# 297                  5     Open      Run  10000.0        None   W549C02  ...
# 298                  4     Open      Run  10000.0        None   S039Z01  ...
# 299                  3     Open      Run  10000.0        None   G797C05  ...
# 300                  6     Open      Run  10000.0        None   M886G01  ...
# ...                ...      ...      ...      ...         ...       ...  ...
# 15624                3     Open      Run    10000        None   B075C00  ...
# 15628                2     Open      Run    10000        None   S268G99  ...
# 15646                2     Open      Run    10000        None   R559H98  ...
# 19381                5           10,000m                                 ...
# 19382                            10,000m                                 ...
#
#        2% 3.5%  5% RESULT_CONV RESULT_BEST Delta2 Delta3.5 Delta5  \
# 296   NaN  NaN NaN     2043.99     2043.99    NaN      NaN    NaN
# 297   NaN  NaN NaN     2375.86     2375.86    NaN      NaN    NaN
# 298   NaN  NaN NaN     2317.79     2317.79    NaN      NaN    NaN
# 299   NaN  NaN NaN     2252.24     2252.24    NaN      NaN    NaN
# 300   NaN  NaN NaN     2395.64     2395.64    NaN      NaN    NaN
# ...    ..  ...  ..         ...         ...    ...      ...    ...
# 15624 NaN  NaN NaN      2665.6     2665.60    NaN      NaN    NaN
# 15628 NaN  NaN NaN      2361.6     2361.60    NaN      NaN    NaN
# 15646 NaN  NaN NaN      2128.2     2128.20    NaN      NaN    NaN
# 19381 NaN  NaN NaN      1862.4     1862.40    NaN      NaN    NaN
# 19382 NaN  NaN NaN     2175.67     2175.67    NaN      NaN    NaN
#
#       Delta_Benchmark PERF_SCALAR
# 296               NaN         NaN
# 297               NaN         NaN
# 298               NaN         NaN
# 299               NaN         NaN
# 300               NaN         NaN
# ...               ...         ...
# 15624             NaN         NaN
# 15628             NaN         NaN
# 15646             NaN         NaN
# 19381             NaN         NaN
# 19382             NaN         NaN
#
# [91 rows x 40 columns]

# %%
# Strip out punctuation from NAME
from itertools import permutations
import string
from dateutil import parser

translator = str.maketrans('', '', string.punctuation)
df['clean_name'] = df['NAME'].str.translate(translator)
df['clean_name'] = df['clean_name'].str.casefold()


df = df.reset_index(drop=True)

translator = str.maketrans('', '', string.punctuation)

df['clean_name'] = df['NAME'].apply(lambda x: str(x).translate(translator))
df['clean_name'] = df['clean_name'].str.casefold()

# %%
def parse_dob(x):
    if pd.isna(x) or str(x).strip().lower() in ["none", "nan", "nat", ""]:
        return None
    try:
        # force dayfirst since your DOBs are in DD/MM/YY
        dt = parser.parse(str(x), dayfirst=True)
        # fix 2-digit year misinterpretation (like 1912 instead of 2012)
        if dt.year < 1950:  
            dt = dt.replace(year=dt.year + 100)
        return dt.strftime("%Y-%m-%d")
    except Exception:
        return None

df["DOB_parsed"] = df["DOB"].apply(parse_dob)

# Build dictionary without null DOBs
dictionary_dob_clean_name = {
    row["clean_name"]: row["DOB_parsed"]
    for _, row in df.iterrows()
    if row["DOB_parsed"] is not None
}

# Test Aarika Ray
print(dictionary_dob_clean_name.get("aarika ray"))
# Out:
# 2012-05-19

# %%
'''
# Read a variation name list and corrections from CSVs

os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/Name Variations/')

names = pd.read_csv("junior_names.csv")

for index, row in names.iterrows():
        
    print(names.VARIATION, names.NAME)
    df['NAME_MAPPED'] = df['NAME'].replace(regex=rf"{row['VARIATION']}", value=f"{row['NAME']}")
'''
# Out:
# '\n# Read a variation name list and corrections from CSVs\n\nos.chdir(\'/Users/veesheenyuen/Desktop/DataScience/SAA/Name Variations/\')\n\nnames = pd.read_csv("junior_names.csv")\n\nfor index, row in names.iterrows():\n        \n    print(names.VARIATION, names.NAME)\n    df[\'NAME_MAPPED\'] = df[\'NAME\'].replace(regex=rf"{row[\'VARIATION\']}", value=f"{row[\'NAME\']}")\n'

# %%
# Read name variations from GCS name lists bucket (OLD VERSION)
'''
df['NAME'] = df['NAME'].str.replace('\xa0', '', regex=True)
df['NAME'] = df['NAME'].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
df['NAME'] = df['NAME'].str.replace('\r', '', regex=True)
df['NAME'] = df['NAME'].str.replace('\n', '', regex=True)
df['NAME'] = df['NAME'].str.strip()

df['NAME'] = df['NAME'].str.casefold()  # everything lower case


# Read csv from GCS bucket

file_path = "gs://name_variations/name_variations.csv"
names = pd.read_csv(file_path,
                 sep=",",
                 storage_options={"token": '/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json'})


# Clean and apply casefold to name variations

names['NAME'] = names['NAME'].str.replace('\xa0', '', regex=True)
names['NAME'] = names['NAME'].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
names['NAME'] = names['NAME'].str.replace('\r', '', regex=True)
names['NAME'] = names['NAME'].str.replace('\n', '', regex=True)
names['NAME'] = names['NAME'].str.strip()
names['VARIATION'] = names['VARIATION'].str.replace('\xa0', '', regex=True)
names['VARIATION'] = names['VARIATION'].str.replace('[\x00-\x1f\x7f-\x9f]', '', regex=True)
names['VARIATION'] = names['VARIATION'].str.replace('\r', '', regex=True)
names['VARIATION'] = names['VARIATION'].str.replace('\n', '', regex=True)
names['VARIATION'] = names['VARIATION'].str.strip()

names['VARIATION'] = names['VARIATION'].str.casefold() # convert to lower case
names['NAME'] = names['NAME'].str.casefold()


# Iterate over dataframe and replace names

for index, row in names.iterrows():
        
    df['NAME'] = df['NAME'].replace(regex=rf"{row['VARIATION']}", value=f"{row['NAME']}")
    

    
df['NAME'] = df['NAME'].str.title()  # capitalize first letter
'''
# Out:
# '\ndf[\'NAME\'] = df[\'NAME\'].str.replace(\'\xa0\', \'\', regex=True)\ndf[\'NAME\'] = df[\'NAME\'].str.replace(\'[\x00-\x1f\x7f-\x9f]\', \'\', regex=True)\ndf[\'NAME\'] = df[\'NAME\'].str.replace(\'\r\', \'\', regex=True)\ndf[\'NAME\'] = df[\'NAME\'].str.replace(\'\n\', \'\', regex=True)\ndf[\'NAME\'] = df[\'NAME\'].str.strip()\n\ndf[\'NAME\'] = df[\'NAME\'].str.casefold()  # everything lower case\n\n\n# Read csv from GCS bucket\n\nfile_path = "gs://name_variations/name_variations.csv"\nnames = pd.read_csv(file_path,\n                 sep=",",\n                 storage_options={"token": \'/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json\'})\n\n\n# Clean and apply casefold to name variations\n\nnames[\'NAME\'] = names[\'NAME\'].str.replace(\'\xa0\', \'\', regex=True)\nnames[\'NAME\'] = names[\'NAME\'].str.replace(\'[\x00-\x1f\x7f-\x9f]\', \'\', regex=True)\nnames[\'NAME\'] = names[\'NAME\'].str.replace(\'\r\', \'\', regex=True)\nnames[\'NAME\'] = names[\'NAME\'].str.replace(\'\n\', \'\', regex=True)\nnames[\'NAME\'] = names[\'NAME\'].str.strip()\nnames[\'VARIATION\'] = names[\'VARIATION\'].str.replace(\'\xa0\', \'\', regex=True)\nnames[\'VARIATION\'] = names[\'VARIATION\'].str.replace(\'[\x00-\x1f\x7f-\x9f]\', \'\', regex=True)\nnames[\'VARIATION\'] = names[\'VARIATION\'].str.replace(\'\r\', \'\', regex=True)\nnames[\'VARIATION\'] = names[\'VARIATION\'].str.replace(\'\n\', \'\', regex=True)\nnames[\'VARIATION\'] = names[\'VARIATION\'].str.strip()\n\nnames[\'VARIATION\'] = names[\'VARIATION\'].str.casefold() # convert to lower case\nnames[\'NAME\'] = names[\'NAME\'].str.casefold()\n\n\n# Iterate over dataframe and replace names\n\nfor index, row in names.iterrows():\n        \n    df[\'NAME\'] = df[\'NAME\'].replace(regex=rf"{row[\'VARIATION\']}", value=f"{row[\'NAME\']}")\n    \n\n    \ndf[\'NAME\'] = df[\'NAME\'].str.title()  # capitalize first letter\n'

# %%
# Fastest execution speed version

# Normalize function as before
def normalize_text(s):
    return (str(s)
            .replace('\xa0', '')
            .replace('\r', '')
            .replace('\n', '')
            .strip()
            .casefold())

# Normalize dataframe
df['NAME'] = df['NAME'].apply(normalize_text)

# Load variations file and normalize
file_path = "gs://name_variations/name_variations.csv"
names = pd.read_csv(file_path,
                    sep=',',
                    storage_options={"token": '/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json'})

names['VARIATION'] = names['VARIATION'].apply(normalize_text)
names['NAME'] = names['NAME'].apply(normalize_text)

# Precompile all regex patterns safely

compiled_patterns = []
for pattern_str, replacement in zip(names['VARIATION'], names['NAME']):
    try:
        compiled_re = re.compile(pattern_str)
        compiled_patterns.append( (compiled_re, replacement) )
    except re.error as e:
        print(f"Skipping invalid regex pattern: {pattern_str} Error: {e}")

# Iterate over all patterns and apply replacements using precompiled regexes
for regex, replacement in compiled_patterns:
    df['NAME'] = df['NAME'].str.replace(regex, replacement, regex=True)

# Capitalize final standardized names
df['NAME'] = df['NAME'].str.title()

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')

df.to_csv("names_check.csv", encoding='utf-8')

# %%
# Exclude foreigners from MALAYSIA, THAILAND etc.

#df_select = df[(df['TEAM']!='Malaysia') & (df['TEAM']!='THAILAND') & (df['TEAM']!='China') & (df['TEAM']!='South Korea') & (df['TEAM']!='Laos') & (df['TEAM']!='Philippines') & (df['TEAM']!='Piboonbumpen Thailand') & (df['TEAM']!='Chinese Taipei') & (df['TEAM']!='Gurkha Contingent') & (df['TEAM']!='Australia') & (df['TEAM']!='Piboonbumpen Thailand') & (df['TEAM']!='Hong Kong') & (df['TEAM']!='PERAK')] 

df_select = df[(df['TEAM']!='Malaysia')&(df['TEAM']!='THAILAND')&(df['TEAM']!='China')&(df['TEAM']!='Thailand') 
                       &(df['TEAM']!='South Korea')&(df['TEAM']!='Laos')&(df['TEAM']!='Myanmar') 
                       &(df['TEAM']!='Philippines')&(df['TEAM']!='Piboonbumpen Thailand') 
                       &(df['TEAM']!='Chinese Taipei')&(df['TEAM']!='Gurkha Contingent') 
                       &(df['TEAM']!='Australia')&(df['TEAM']!='Piboonbumpen Thailand') 
                       &(df['TEAM']!='Hong Kong')&(df['TEAM']!='PERAK')&(df['TEAM']!='Sri Lanka') 
                       &(df['TEAM']!='Indonesia')&(df['TEAM']!='THAILAND')&(df['TEAM']!='MALAYSIA') 
                       &(df['TEAM']!='PHILIPPINES') & (df['TEAM']!='SOUTH KOREA')&(df['TEAM']!='Waseda') 
                       &(df['TEAM']!='LAOS')&(df['TEAM']!='CHINESE TAIPEI')&(df['TEAM']!='Vietnam')
                       &(df['TEAM']!='INDIA')&(df['TEAM']!='Hong Kong, China')&(df['TEAM']!='AIC JAPAN')
                       &(df['NATIONALITY']!='GBR')&(df['NATIONALITY']!='JPN')&(df['NATIONALITY']!='SRI')&(df['NATIONALITY']!='SAM')
                       &(df['NATIONALITY']!='THA')&(df['NATIONALITY']!='IND')&(df['NATIONALITY']!='PHI')&(df['NATIONALITY']!='MAS')]

# %%
df_select
# Out:
#                          NAME  RESULT_x  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0         Ng Caitlin Shan Wen     12.42  <NA>  18.5                5     <NA>
# 1       Tan Ying Tong Shannon     12.53  <NA>  18.5                2     <NA>
# 2         Ng Caitlin Shan Wen     12.36  <NA>  18.5                6     <NA>
# 3       Tan Ying Tong Shannon     12.33  <NA>  18.5                7     <NA>
# 4            Tay Sean Russell     49.89  <NA>  18.5                6     <NA>
# ...                       ...       ...   ...   ...              ...      ...
# 19391        Louis Marc Brian     20.89                            1
# 19392      Curran Harry Irfan     34.57                            3
# 19393  Soh Rui Yong Guillaume  14:46.81                            4
# 19394             Vanessa Lee  17:11.36  <NA>  18.5              nan     <NA>
# 19395     Nicole Low Sui Xuan  17:16.72  <NA>  18.5              nan     <NA>
#
#       EVENT_x DISTANCE EVENT_CLASS UNIQUE_ID  ...       5% RESULT_CONV  \
# 0        100m     <NA>         nan      <NA>  ...  12.7365       12.42
# 1        100m     <NA>         nan      <NA>  ...  12.7365       12.53
# 2        100m     <NA>         nan      <NA>  ...  12.7365       12.36
# 3        100m     <NA>         nan      <NA>  ...  12.7365       12.33
# 4        400m     <NA>         nan      <NA>  ...  50.1585       49.89
# ...       ...      ...         ...       ...  ...      ...         ...
# 19391    200m                                 ...  22.5225       20.89
# 19392    300m                                 ...      NaN
# 19393   5000m                                 ...      NaN      886.81
# 19394   5000m     <NA>        <NA>      <NA>  ...      NaN     1031.36
# 19395   5000m     <NA>        <NA>      <NA>  ...      NaN     1036.72
#
#       RESULT_BEST  Delta2 Delta3.5  Delta5 Delta_Benchmark PERF_SCALAR  \
# 0           12.42 -0.0474  0.13455  0.3165           -0.29    2.609233
# 1           12.53 -0.1574  0.02455  0.2065           -0.40    1.702391
# 2           12.36  0.0126  0.19455  0.3765           -0.23    3.103875
# 3           12.33  0.0426  0.22455  0.4065           -0.20    3.351195
# 4           49.89 -1.1646 -0.44805  0.2685           -2.12    0.562068
# ...           ...     ...      ...     ...             ...         ...
# 19391       20.89  0.9890  1.31075  1.6325            0.56    7.610723
# 19392         NaN     NaN      NaN     NaN             NaN         NaN
# 19393      886.81     NaN      NaN     NaN             NaN         NaN
# 19394     1031.36     NaN      NaN     NaN             NaN         NaN
# 19395     1036.72     NaN      NaN     NaN             NaN         NaN
#
#                   clean_name  DOB_parsed
# 0        ng caitlin shan wen  2010-11-24
# 1      tan ying tong shannon  2009-11-20
# 2        ng caitlin shan wen  2010-11-24
# 3      tan ying tong shannon  2009-11-20
# 4           tay sean russell  2009-12-25
# ...                      ...         ...
# 19391       marc brian louis  2002-08-07
# 19392      harry irfan curra  2008-01-31
# 19393           rui yong soh  1991-08-06
# 19394            vanessa lee        None
# 19395             nicole low        None
#
# [19079 rows x 42 columns]

# %%
'''
# Read list of foreigners

foreigners = pd.read_csv('/Users/veesheenyuen/Desktop/DataScience/SAA/MM/List of Foreigners.csv', encoding='latin-1')
'''
# Out:
# "\n# Read list of foreigners\n\nforeigners = pd.read_csv('/Users/veesheenyuen/Desktop/DataScience/SAA/MM/List of Foreigners.csv', encoding='latin-1')\n"

# %%
# Read list of foreigners from GCS bucket

file_path = "gs://name_lists/List of Foreigners.csv"
foreigners = pd.read_csv(file_path,
                 sep=",",
                 encoding="unicode escape",
                 storage_options={"token": '/Users/veesheenyuen/Desktop/DataScience/Keys/saa-analytics-7c8937b70609.json'})

# %%
foreigners
# Out:
#        LAST_NAME         FIRST_NAME
# 0         Aaryan  Greuter Christoph
# 1      Akahodani           Takayuki
# 2        Apondar             Audric
# 3        Brooks                Ruby
# 4        Brouwer               Cees
# ..           ...                ...
# 235      Kashama      Biwesa Daniel
# 236       ISMAIL  MUHAMMAD ZULFIQAR
# 237  Jayaganeson           Kirtisha
# 238          LIN            Yu Sian
# 239         King            Leonard
#
# [240 rows x 2 columns]

# %%
foreigners['V1'] = foreigners['LAST_NAME']+' '+foreigners['FIRST_NAME']
foreigners['V2'] = foreigners['FIRST_NAME']+' '+foreigners['LAST_NAME']
foreigners['V3'] = foreigners['LAST_NAME']+', '+foreigners['FIRST_NAME']
foreigners['V4'] = foreigners['FIRST_NAME']+' '+foreigners['LAST_NAME']

for1 = foreigners['V1'].dropna().tolist()
for2 = foreigners['V2'].dropna().tolist()
for3 = foreigners['V3'].dropna().tolist()
for4 = foreigners['V4'].dropna().tolist()

foreign_list = for1+for2+for3+for4 

foreign_list_casefold=[s.casefold() for s in foreign_list]

exclusions = foreign_list_casefold

no_foreigners_list = df_select.loc[~df['NAME'].str.casefold().isin(exclusions)]  # ~ means NOT IN. DROP spex carded athletes

# %%
no_foreigners_list
# Out:
#                          NAME  RESULT_x  TEAM   AGE COMPETITION_RANK DIVISION  \
# 0         Ng Caitlin Shan Wen     12.42  <NA>  18.5                5     <NA>
# 1       Tan Ying Tong Shannon     12.53  <NA>  18.5                2     <NA>
# 2         Ng Caitlin Shan Wen     12.36  <NA>  18.5                6     <NA>
# 3       Tan Ying Tong Shannon     12.33  <NA>  18.5                7     <NA>
# 4            Tay Sean Russell     49.89  <NA>  18.5                6     <NA>
# ...                       ...       ...   ...   ...              ...      ...
# 19391        Louis Marc Brian     20.89                            1
# 19392      Curran Harry Irfan     34.57                            3
# 19393  Soh Rui Yong Guillaume  14:46.81                            4
# 19394             Vanessa Lee  17:11.36  <NA>  18.5              nan     <NA>
# 19395     Nicole Low Sui Xuan  17:16.72  <NA>  18.5              nan     <NA>
#
#       EVENT_x DISTANCE EVENT_CLASS UNIQUE_ID  ...       5% RESULT_CONV  \
# 0        100m     <NA>         nan      <NA>  ...  12.7365       12.42
# 1        100m     <NA>         nan      <NA>  ...  12.7365       12.53
# 2        100m     <NA>         nan      <NA>  ...  12.7365       12.36
# 3        100m     <NA>         nan      <NA>  ...  12.7365       12.33
# 4        400m     <NA>         nan      <NA>  ...  50.1585       49.89
# ...       ...      ...         ...       ...  ...      ...         ...
# 19391    200m                                 ...  22.5225       20.89
# 19392    300m                                 ...      NaN
# 19393   5000m                                 ...      NaN      886.81
# 19394   5000m     <NA>        <NA>      <NA>  ...      NaN     1031.36
# 19395   5000m     <NA>        <NA>      <NA>  ...      NaN     1036.72
#
#       RESULT_BEST  Delta2 Delta3.5  Delta5 Delta_Benchmark PERF_SCALAR  \
# 0           12.42 -0.0474  0.13455  0.3165           -0.29    2.609233
# 1           12.53 -0.1574  0.02455  0.2065           -0.40    1.702391
# 2           12.36  0.0126  0.19455  0.3765           -0.23    3.103875
# 3           12.33  0.0426  0.22455  0.4065           -0.20    3.351195
# 4           49.89 -1.1646 -0.44805  0.2685           -2.12    0.562068
# ...           ...     ...      ...     ...             ...         ...
# 19391       20.89  0.9890  1.31075  1.6325            0.56    7.610723
# 19392         NaN     NaN      NaN     NaN             NaN         NaN
# 19393      886.81     NaN      NaN     NaN             NaN         NaN
# 19394     1031.36     NaN      NaN     NaN             NaN         NaN
# 19395     1036.72     NaN      NaN     NaN             NaN         NaN
#
#                   clean_name  DOB_parsed
# 0        ng caitlin shan wen  2010-11-24
# 1      tan ying tong shannon  2009-11-20
# 2        ng caitlin shan wen  2010-11-24
# 3      tan ying tong shannon  2009-11-20
# 4           tay sean russell  2009-12-25
# ...                      ...         ...
# 19391       marc brian louis  2002-08-07
# 19392      harry irfan curra  2008-01-31
# 19393           rui yong soh  1991-08-06
# 19394            vanessa lee        None
# 19395             nicole low        None
#
# [18787 rows x 42 columns]

# %%
# Choose the best result for each event participated by every athlete

top_performers_clean = no_foreigners_list.sort_values(['MAPPED_EVENT', 'NAME','PERF_SCALAR'],ascending=False).groupby(['MAPPED_EVENT', 'NAME']).head(1)

# %%
top_performers_clean.reset_index(inplace=True)

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')


top_performers_clean.to_csv('U20_top_performers_oct27.csv', encoding='utf-8')

# %%
top_performers_clean
# Out:
#        index             NAME RESULT_x                          TEAM   AGE  \
# 0      16588      Zhou Xuanyu     9.12                           DHS  13.5
# 1      16656     Zhong Chuhan    12.26                          None  None
# 2      16364  Zheng Justin De   10.47m       National Junior College    14
# 3      16497     Zhao, Daniel   11.67m         Hwa Chong Institution    14
# 4      18293      Zhao Daniel    11.98                             -
# ...      ...              ...      ...                           ...   ...
# 12350   7003     ., Shaik Isa    15.49                     Club ZOOM     8
# 12351   6660     ., Nur Elena    16.42                           UNA     6
# 12352  13258   ., Dharkshitha  08:35.6  Cedar Girls Secondary School    15
# 12353  12881        ., Cayden  06:05.1                   North Vista    12
# 12354   1519                ,  2:43.57          Republic Polytechnic    12
#
#       COMPETITION_RANK DIVISION        EVENT_x DISTANCE EVENT_CLASS  ...  \
# 0                 10.0        C    Triple Jump     None        None  ...
# 1                 None     None    Triple Jump     None        None  ...
# 2                   12      U15    Triple Jump        0        None  ...
# 3                    3      U15    Triple Jump        0        None  ...
# 4                    1             Triple Jump                  nan  ...
# ...                ...      ...            ...      ...         ...  ...
# 12350               32       U9           Dash       80              ...
# 12351                1       U7           Dash       80              ...
# 12352                1      U18      Race Walk     1500        None  ...
# 12353               54     Open       Mile Run        1              ...
# 12354                6     Open  Sprint Medley   1000.0        None  ...
#
#             5% RESULT_CONV RESULT_BEST  Delta2 Delta3.5  Delta5  \
# 0      11.9415        9.12        9.12 -3.1986 -3.01005 -2.8215
# 1      11.9415       12.26       12.26 -0.0586  0.12995  0.3185
# 2      14.2405       10.47       10.47 -4.2202 -3.99535 -3.7705
# 3      14.2405       11.67       11.67 -3.0202 -2.79535 -2.5705
# 4      14.2405       11.98       11.98 -2.7102 -2.48535 -2.2605
# ...        ...         ...         ...     ...      ...     ...
# 12350      NaN                     NaN     NaN      NaN     NaN
# 12351      NaN                     NaN     NaN      NaN     NaN
# 12352      NaN                     NaN     NaN      NaN     NaN
# 12353      NaN                     NaN     NaN      NaN     NaN
# 12354      NaN                     NaN     NaN      NaN     NaN
#
#       Delta_Benchmark PERF_SCALAR       clean_name  DOB_parsed
# 0               -3.45  -22.446301      zhou xuanyu        None
# 1               -0.31    2.533811     chuhan zhong  2005-10-18
# 2               -4.52  -25.153436  zheng justin de  2011-02-21
# 3               -3.32  -17.148099      zhao daniel  2011-07-25
# 4               -3.01  -15.080053      daniel zhao  2011-07-25
# ...               ...         ...              ...         ...
# 12350             NaN         NaN        shaik isa  2016-11-21
# 12351             NaN         NaN        nur elena  2018-12-04
# 12352             NaN         NaN      dharkshitha  2010-06-04
# 12353             NaN         NaN           cayden  2010-01-01
# 12354             NaN         NaN                   2008-10-12
#
# [12355 rows x 43 columns]

# %%
# Choose best performance for each event

#tiered_performers = top_performers_clean.sort_values(['GENDER', 'MAPPED_EVENT', 'PERF_SCALAR'],ascending=False).groupby(['MAPPED_EVENT', 'NAME']).head(1)

tiered_performers = top_performers_clean

# %%
tiered_performers
# Out:
#        index             NAME RESULT_x                          TEAM   AGE  \
# 0      16588      Zhou Xuanyu     9.12                           DHS  13.5
# 1      16656     Zhong Chuhan    12.26                          None  None
# 2      16364  Zheng Justin De   10.47m       National Junior College    14
# 3      16497     Zhao, Daniel   11.67m         Hwa Chong Institution    14
# 4      18293      Zhao Daniel    11.98                             -
# ...      ...              ...      ...                           ...   ...
# 12350   7003     ., Shaik Isa    15.49                     Club ZOOM     8
# 12351   6660     ., Nur Elena    16.42                           UNA     6
# 12352  13258   ., Dharkshitha  08:35.6  Cedar Girls Secondary School    15
# 12353  12881        ., Cayden  06:05.1                   North Vista    12
# 12354   1519                ,  2:43.57          Republic Polytechnic    12
#
#       COMPETITION_RANK DIVISION        EVENT_x DISTANCE EVENT_CLASS  ...  \
# 0                 10.0        C    Triple Jump     None        None  ...
# 1                 None     None    Triple Jump     None        None  ...
# 2                   12      U15    Triple Jump        0        None  ...
# 3                    3      U15    Triple Jump        0        None  ...
# 4                    1             Triple Jump                  nan  ...
# ...                ...      ...            ...      ...         ...  ...
# 12350               32       U9           Dash       80              ...
# 12351                1       U7           Dash       80              ...
# 12352                1      U18      Race Walk     1500        None  ...
# 12353               54     Open       Mile Run        1              ...
# 12354                6     Open  Sprint Medley   1000.0        None  ...
#
#             5% RESULT_CONV RESULT_BEST  Delta2 Delta3.5  Delta5  \
# 0      11.9415        9.12        9.12 -3.1986 -3.01005 -2.8215
# 1      11.9415       12.26       12.26 -0.0586  0.12995  0.3185
# 2      14.2405       10.47       10.47 -4.2202 -3.99535 -3.7705
# 3      14.2405       11.67       11.67 -3.0202 -2.79535 -2.5705
# 4      14.2405       11.98       11.98 -2.7102 -2.48535 -2.2605
# ...        ...         ...         ...     ...      ...     ...
# 12350      NaN                     NaN     NaN      NaN     NaN
# 12351      NaN                     NaN     NaN      NaN     NaN
# 12352      NaN                     NaN     NaN      NaN     NaN
# 12353      NaN                     NaN     NaN      NaN     NaN
# 12354      NaN                     NaN     NaN      NaN     NaN
#
#       Delta_Benchmark PERF_SCALAR       clean_name  DOB_parsed
# 0               -3.45  -22.446301      zhou xuanyu        None
# 1               -0.31    2.533811     chuhan zhong  2005-10-18
# 2               -4.52  -25.153436  zheng justin de  2011-02-21
# 3               -3.32  -17.148099      zhao daniel  2011-07-25
# 4               -3.01  -15.080053      daniel zhao  2011-07-25
# ...               ...         ...              ...         ...
# 12350             NaN         NaN        shaik isa  2016-11-21
# 12351             NaN         NaN        nur elena  2018-12-04
# 12352             NaN         NaN      dharkshitha  2010-06-04
# 12353             NaN         NaN           cayden  2010-01-01
# 12354             NaN         NaN                   2008-10-12
#
# [12355 rows x 43 columns]

# %%
# Identify Tier 1/2/3 performers

#top_performers_clean['TIER'] = np.where((top_performers_clean['Delta_Benchmark']>=0), 'Tier 1',    
#                                np.where(((top_performers_clean['Delta_Benchmark']<0) & (top_performers_clean['Delta2']>=0)), 'Tier2',
#                                np.where(((top_performers_clean['Delta2']<0) & (top_performers_clean['Delta3.5']>=0)), 'Tier3', ' ')))


tiered_performers['TIER'] = np.where((tiered_performers['Delta_Benchmark']>=0), 'Tier 1',    
                                np.where(((tiered_performers['Delta_Benchmark']<0) & (tiered_performers['Delta2']>=0)), 'Tier 2',
                                np.where(((tiered_performers['Delta2']<0) & (tiered_performers['Delta3.5']>=0)), 'Tier 3', 
                                np.where(((tiered_performers['Delta3.5']<0) & (tiered_performers['Delta5']>=0)), 'Tier 4', ' '))))

# %%
# Drop rows without a benchmark

final_df = tiered_performers[tiered_performers['BENCHMARK'].notna()]

# %%
final_df
# Out:
#        index             NAME RESULT_x                          TEAM   AGE  \
# 0      16588      Zhou Xuanyu     9.12                           DHS  13.5
# 1      16656     Zhong Chuhan    12.26                          None  None
# 2      16364  Zheng Justin De   10.47m       National Junior College    14
# 3      16497     Zhao, Daniel   11.67m         Hwa Chong Institution    14
# 4      18293      Zhao Daniel    11.98                             -
# ...      ...              ...      ...                           ...   ...
# 12350   7003     ., Shaik Isa    15.49                     Club ZOOM     8
# 12351   6660     ., Nur Elena    16.42                           UNA     6
# 12352  13258   ., Dharkshitha  08:35.6  Cedar Girls Secondary School    15
# 12353  12881        ., Cayden  06:05.1                   North Vista    12
# 12354   1519                ,  2:43.57          Republic Polytechnic    12
#
#       COMPETITION_RANK DIVISION        EVENT_x DISTANCE EVENT_CLASS  ...  \
# 0                 10.0        C    Triple Jump     None        None  ...
# 1                 None     None    Triple Jump     None        None  ...
# 2                   12      U15    Triple Jump        0        None  ...
# 3                    3      U15    Triple Jump        0        None  ...
# 4                    1             Triple Jump                  nan  ...
# ...                ...      ...            ...      ...         ...  ...
# 12350               32       U9           Dash       80              ...
# 12351                1       U7           Dash       80              ...
# 12352                1      U18      Race Walk     1500        None  ...
# 12353               54     Open       Mile Run        1              ...
# 12354                6     Open  Sprint Medley   1000.0        None  ...
#
#       RESULT_CONV RESULT_BEST  Delta2 Delta3.5  Delta5 Delta_Benchmark  \
# 0            9.12        9.12 -3.1986 -3.01005 -2.8215           -3.45
# 1           12.26       12.26 -0.0586  0.12995  0.3185           -0.31
# 2           10.47       10.47 -4.2202 -3.99535 -3.7705           -4.52
# 3           11.67       11.67 -3.0202 -2.79535 -2.5705           -3.32
# 4           11.98       11.98 -2.7102 -2.48535 -2.2605           -3.01
# ...           ...         ...     ...      ...     ...             ...
# 12350                     NaN     NaN      NaN     NaN             NaN
# 12351                     NaN     NaN      NaN     NaN             NaN
# 12352                     NaN     NaN      NaN     NaN             NaN
# 12353                     NaN     NaN      NaN     NaN             NaN
# 12354                     NaN     NaN      NaN     NaN             NaN
#
#       PERF_SCALAR       clean_name  DOB_parsed    TIER
# 0      -22.446301      zhou xuanyu        None
# 1        2.533811     chuhan zhong  2005-10-18  Tier 3
# 2      -25.153436  zheng justin de  2011-02-21
# 3      -17.148099      zhao daniel  2011-07-25
# 4      -15.080053      daniel zhao  2011-07-25
# ...           ...              ...         ...     ...
# 12350         NaN        shaik isa  2016-11-21
# 12351         NaN        nur elena  2018-12-04
# 12352         NaN      dharkshitha  2010-06-04
# 12353         NaN           cayden  2010-01-01
# 12354         NaN                   2008-10-12
#
# [12355 rows x 44 columns]

# %%
# Choose rows with mapped event

final_df=final_df[(final_df['MAPPED_EVENT']!=' ') & (final_df['TIER']!=' ')]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')


final_df.to_csv('U20_tiered_performers_oct27.csv', encoding='utf-8')

# %%
final_df
# Out:
#       index                           NAME  RESULT_x  \
# 1     16656                   Zhong Chuhan     12.26
# 78    16419                Tan Shou Yi Rei    14.99m
# 79    16613  Tan Shou Ri Yei (Chen Shouyi)     14.31
# 105   16416             Rozario Tia Louise    12.90m
# 157   16326           Medina Andrew George    14.98m
# ...     ...                            ...       ...
# 8199   1682                       Bryan Ng     10.93
# 8205   2319           Brayden Chan Wei Jie  00:10.95
# 8255   6270                  Ashok, Tharun     10.81
# 8295    455                    Amanda, Loo     12.44
# 8338   6170        Abdul Aziz, Zara Almira     12.54
#
#                                TEAM   AGE COMPETITION_RANK DIVISION  \
# 1                              None  None             None     None
# 78           Raffles Institution JC    17                1      U20
# 79                               RI  18.5              1.0        A
# 105                             FAC    12                1     Open
# 157   National University Singapore    12                1     Open
# ...                             ...   ...              ...      ...
# 8199                           None  None                2     None
# 8205                             RI  18.5              3.0        A
# 8255           Ngee Ann Polytechnic    12                4     Open
# 8295            TRACKSTAR ATHLETICS    12                2     Open
# 8338           Republic Polytechnic    12                2     Open
#
#           EVENT_x DISTANCE EVENT_CLASS  ... RESULT_CONV RESULT_BEST  Delta2  \
# 1     Triple Jump     None        None  ...       12.26       12.26 -0.0586
# 78    Triple Jump        0        None  ...       14.99       14.99  0.2998
# 79    Triple Jump     None        None  ...       14.31       14.31 -0.3802
# 105   Triple Jump        0        None  ...        12.9       12.90  0.5814
# 157   Triple Jump        0        None  ...       14.98       14.98  0.2898
# ...           ...      ...         ...  ...         ...         ...     ...
# 8199         100m     None        None  ...       10.93       10.93 -0.1180
# 8205         100m     None        None  ...       10.95       10.95 -0.1380
# 8255         Dash      100              ...       10.81       10.81  0.0020
# 8295         Dash    100.0        None  ...       12.44       12.44 -0.0674
# 8338         Dash      100              ...       12.54       12.54 -0.1674
#
#      Delta3.5  Delta5 Delta_Benchmark PERF_SCALAR  \
# 1     0.12995  0.3185           -0.31    2.533811
# 78    0.52465  0.7495            0.00    5.000000
# 79   -0.15535  0.0695           -0.68    0.463642
# 105   0.76995  0.9585            0.33    7.625298
# 157   0.51465  0.7395           -0.01    4.933289
# ...       ...     ...             ...         ...
# 8199  0.04100  0.2000           -0.33    1.886792
# 8205  0.02100  0.1800           -0.35    1.698113
# 8255  0.16100  0.3200           -0.21    3.018868
# 8295  0.11455  0.2965           -0.31    2.444353
# 8338  0.01455  0.1965           -0.41    1.619951
#
#                        clean_name  DOB_parsed    TIER
# 1                    chuhan zhong  2005-10-18  Tier 3
# 78                        tan rei  2008-12-05  Tier 1
# 79    tan shou yi rei chen shouyi        None  Tier 4
# 105            rozario tia louise  2000-10-14  Tier 1
# 157                 medina andrew  2002-03-22  Tier 2
# ...                           ...         ...     ...
# 8199                     bryan ng        None  Tier 3
# 8205         brayden chan wei jie        None  Tier 3
# 8255                 ashok tharun  2005-07-02  Tier 2
# 8295                   amanda loo  2005-12-05  Tier 3
# 8338       abdul aziz zara almira  2007-07-06  Tier 3
#
# [268 rows x 44 columns]

# %%
#os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/Asian Youth/')


#final_selection.to_csv('AY_final_selection.csv', encoding='utf-8')

# %%
# Get list of names with no DOB

mask = ((final_df['DOB']=='None')|(final_df['DOB']=='nan'))

#mask = ((final_df['DOB'].isnull()))
#mask = final_df['DOB_new']=='NaT'

missing_names = final_df.loc[mask]

name_list = missing_names['NAME'].str.casefold().to_list()

# %%
len(name_list)
# Out:
# 57

# %%
# Names with no DOB

missing_names
# Out:
#       index                                    NAME  RESULT_x  \
# 79    16613           Tan Shou Ri Yei (Chen Shouyi)     14.31
# 1196  12769                            Han Lin Feng      7.46
# 1574  10690                            Wong Jin Rou       1.6
# 1606  10595           Tan Shou Ri Yei (Chen Shouyi)      2.04
# 1827     71                              Andrew Pak     2.10m
# 3506   4160                  Mohhammad Irfan Qabeel     49.12
# 3822   4320                            Huang Weijun     49.51
# 4063   7028                   Bharadwaj Akash Vijay     49.65
# 4121   4701                Aidan Michael Soh Zi Ren  00:50.10
# 4178   4145                       Noah Ng Shen Yang  10:04.98
# 4183  16167                             Mani, Manoj   10:40.7
# 4185   4150                       Low Jit Yin Elgin  10:24.15
# 4186  16164                            Lim, Jerrell   10:32.1
# 4514   7074                                Teo, Yan      21.6
# 4584   7160                              Tan, Daryl      22.1
# 4593   3340                   Tan Ying Tong Shannon  00:25.58
# 4601   3175                               Tan Keane  00:22.36
# 4647   3234  Soh Hwei En, Rachel (Su Hui'En Rachel)  00:25.78
# 4782   3240                   Philip Hoare Jonathan  00:22.15
# 5019   3255                     Lim Yee Chern Clara  00:25.07
# 5087   3221                        Lee Joshua Shyen  00:22.48
# 5202   1637                         Jonathan Philip      22.3
# 5244   7009                        Jamie El-Red Ang     21.96
# 5273   1636                            Huang Weijun     21.95
# 5368   3198                  Emily Anne Choi Yi Siu  00:25.86
# 5549   3220                    Brayden Chan Wei Jie  00:22.32
# 5594   7070                           Ashok, Tharun     22.28
# 5649   3230                Aidan Michael Soh Zi Ren  00:22.41
# 5858   2921                             Tan Wei Yee  04:19.92
# 5884   2918                                 Su Emma  05:04.41
# 5887   2917                            Sow Philston  04:20.68
# 6012   2929                       Noah Ng Shen Yang  04:15.66
# 6014   2916                            Nitin Pranit  04:14.42
# 6110  14509                           Longue Kieran   04:21.7
# 6118   2937                              Liu Haoyue  04:21.85
# 6139   2872                         Lim Yuqi Sommer  05:01.03
# 6299   2898                     Jeevan Joshua Jerom  04:19.34
# 6346   2911                Hayagreev Jeyaseelan Sai  04:14.29
# 6373   2927                             Gerard Jofi  04:20.95
# 6404   2897                       Ethan Lee Jinxian  04:17.91
# 6474   2923                 Chong Ka Jin, Sebastian  04:20.83
# 6592   2904          Ahmad Zubayr Bin Mohamed Imran  04:23.51
# 6880   2144                           Teh Ying Shan  00:12.31
# 6959   2318                   Tan Ying Tong Shannon  00:12.27
# 6969   2331                               Tan Keane  00:10.99
# 7024   2321  Soh Hwei En, Rachel (Su Hui'En Rachel)  00:12.36
# 7188   2287                   Philip Hoare Jonathan  00:10.94
# 7394   2235                  Megan Anne Ying Ka Mun  00:12.52
# 7524   2306                     Lim Yee Chern Clara  00:12.12
# 7600   2312                        Lee Joshua Shyen  00:10.87
# 7617   2293                    Lam Sheng Jie Nathan  00:11.02
# 7850   1632                            Huang Weijun     10.91
# 7939   1631                           Fong Jun Liau     10.96
# 8065   2315                            Chua Garrett  00:10.90
# 8095   2288                        Chloe Chee En-Ya  00:12.44
# 8199   1682                                Bryan Ng     10.93
# 8205   2319                    Brayden Chan Wei Jie  00:10.95
#
#                                 TEAM   AGE COMPETITION_RANK DIVISION  \
# 79                                RI  18.5              1.0        A
# 1196                             nan   nan              nan      nan
# 1574                            None  None             None     None
# 1606                              RI  18.5              1.0        A
# 1827                             nan   nan              3.0      nan
# 3506                            None  None                2     None
# 3822                            None  None                1     None
# 4063  Singapore Management Universit    12                1     Open
# 4121                          ACS(I)  18.5              1.0        A
# 4178                             VJC  18.5              1.0        A
# 4183  Singapore Institute of Managem    12                2     Open
# 4185                             HCI  18.5              2.0        A
# 4186  Singapore Institute of Technol    12                1     Open
# 4514             Temasek Polytechnic    12                1     Open
# 4584  Singapore Institute of Technol    12                4     Open
# 4593                              CG    16              1.0        B
# 4601                          ACS(I)    16              2.0        B
# 4647                             HCI  18.5              2.0        A
# 4782                             HCI    16              1.0        B
# 5019                              RI  18.5              1.0        A
# 5087                          ACS(I)  18.5              3.0        A
# 5202                             nan   nan              3.0      nan
# 5244            Republic Polytechnic    12                2     Open
# 5273                             nan   nan              2.0      nan
# 5368                             VJC  18.5              3.0        A
# 5549                              RI  18.5              1.0        A
# 5594            Ngee Ann Polytechnic    12                8     Open
# 5649                          ACS(I)  18.5              2.0        A
# 5858                             HCI  18.5              6.0        A
# 5884                             HCI  18.5              2.0        A
# 5887                              FS    16              4.0        B
# 6012                             VJC  18.5              3.0        A
# 6014                              RI  18.5              2.0        A
# 6110             Nanyang Polytechnic    12                3     Open
# 6118                             HCI    16              6.0        B
# 6139                              CG  13.5              1.0        C
# 6299                             VJC  18.5              5.0        A
# 6346                             BTV    16              2.0        B
# 6373                             VJC  18.5              7.0        A
# 6404                              RI  18.5              4.0        A
# 6474                          ACS(I)    16              5.0        B
# 6592                              VS    16              7.0        B
# 6880                            NYJC  18.5              1.0        A
# 6959                              CG    16              1.0        B
# 6969                          ACS(I)    16              2.0        B
# 7024                             HCI  18.5              3.0        A
# 7188                             HCI    16              1.0        B
# 7394                             HCI  18.5              3.0        A
# 7524                              RI  18.5              1.0        A
# 7600                          ACS(I)  18.5              1.0        A
# 7617                             VJC  18.5              4.0        A
# 7850                             nan   nan              2.0      nan
# 7939                             nan   nan              1.0      nan
# 8065                              RI  18.5              2.0        A
# 8095                          ACS(I)  18.5              4.0        A
# 8199                            None  None                2     None
# 8205                              RI  18.5              3.0        A
#
#            EVENT_x DISTANCE EVENT_CLASS  ... RESULT_CONV RESULT_BEST   Delta2  \
# 79     Triple Jump     None        None  ...       14.31       14.31  -0.3802
# 1196     Long Jump      nan         nan  ...        7.46        7.46   0.4138
# 1574     High Jump     None        None  ...         1.6        1.60  -0.0072
# 1606     High Jump     None        None  ...        2.04        2.04   0.0408
# 1827     High Jump      nan         nan  ...         2.1        2.10   0.1008
# 3506          400m     None        None  ...       49.12       49.12  -0.3946
# 3822          400m     None        None  ...       49.51       49.51  -0.7846
# 4063          Dash      400        None  ...       49.65       49.65  -0.9246
# 4121          400m     None        None  ...        50.1       50.10  -1.3746
# 4178     3000m S/C     None      0.914m  ...      604.98      604.98  31.3980
# 4183  Steeplechase     3000        None  ...       640.7      640.70  -4.3220
# 4185     3000m S/C     None      0.914m  ...      624.15      624.15  12.2280
# 4186  Steeplechase     3000        None  ...       632.1      632.10   4.2780
# 4514          Dash      200        None  ...        21.6       21.60   0.2790
# 4584          Dash      200        None  ...        22.1       22.10  -0.2210
# 4593          200m     None        None  ...       25.58       25.58  -0.4370
# 4601          200m     None        None  ...       22.36       22.36  -0.4810
# 4647          200m     None        None  ...       25.78       25.78  -0.6370
# 4782          200m     None        None  ...       22.15       22.15  -0.2710
# 5019          200m     None        None  ...       25.07       25.07   0.0730
# 5087          200m     None        None  ...       22.48       22.48  -0.6010
# 5202          200m      nan         nan  ...        22.3       22.30  -0.4210
# 5244          Dash      200        None  ...       21.96       21.96  -0.0810
# 5273          200m      nan         nan  ...       21.95       21.95  -0.0710
# 5368          200m     None        None  ...       25.86       25.86  -0.7170
# 5549          200m     None        None  ...       22.32       22.32  -0.4410
# 5594          Dash      200        None  ...       22.28       22.28  -0.4010
# 5649          200m     None        None  ...       22.41       22.41  -0.5310
# 5858         1500m     None        None  ...      259.92      259.92  -3.5940
# 5884         1500m     None        None  ...      304.41      304.41  -4.3260
# 5887         1500m     None        None  ...      260.68      260.68  -4.3540
# 6012         1500m     None        None  ...      255.66      255.66   0.6660
# 6014         1500m     None        None  ...      254.42      254.42   1.9060
# 6110           Run     1500        None  ...       261.7      261.70  -5.3740
# 6118         1500m     None        None  ...      261.85      261.85  -5.5240
# 6139         1500m     None        None  ...      301.03      301.03  -0.9460
# 6299         1500m     None        None  ...      259.34      259.34  -3.0140
# 6346         1500m     None        None  ...      254.29      254.29   2.0360
# 6373         1500m     None        None  ...      260.95      260.95  -4.6240
# 6404         1500m     None        None  ...      257.91      257.91  -1.5840
# 6474         1500m     None        None  ...      260.83      260.83  -4.5040
# 6592         1500m     None        None  ...      263.51      263.51  -7.1840
# 6880          100m     None        None  ...       12.31       12.31   0.0626
# 6959          100m     None        None  ...       12.27       12.27   0.1026
# 6969          100m     None        None  ...       10.99       10.99  -0.1780
# 7024          100m     None        None  ...       12.36       12.36   0.0126
# 7188          100m     None        None  ...       10.94       10.94  -0.1280
# 7394          100m     None        None  ...       12.52       12.52  -0.1474
# 7524          100m     None        None  ...       12.12       12.12   0.2526
# 7600          100m     None        None  ...       10.87       10.87  -0.0580
# 7617          100m     None        None  ...       11.02       11.02  -0.2080
# 7850          100m      nan         nan  ...       10.91       10.91  -0.0980
# 7939          100m      nan         nan  ...       10.96       10.96  -0.1480
# 8065          100m     None        None  ...        10.9       10.90  -0.0880
# 8095          100m     None        None  ...       12.44       12.44  -0.0674
# 8199          100m     None        None  ...       10.93       10.93  -0.1180
# 8205          100m     None        None  ...       10.95       10.95  -0.1380
#
#       Delta3.5   Delta5 Delta_Benchmark PERF_SCALAR  \
# 79    -0.15535   0.0695           -0.68    0.463642
# 1196   0.52165   0.6295            0.27    8.755216
# 1574   0.01740   0.0420           -0.04    2.560976
# 1606   0.07140   0.1020            0.00    5.000000
# 1827   0.13140   0.1620            0.06    7.941176
# 3506   0.32195   1.0385           -1.35    2.173959
# 3822  -0.06805   0.6485           -1.74    1.357547
# 4063  -0.20805   0.5085           -1.88    1.064476
# 4121  -0.65805   0.0585           -2.33    0.122462
# 4178  40.75650  50.1150           18.92    8.032537
# 4183   5.03650  14.3950          -16.80    2.307261
# 4185  21.58650  30.9450           -0.25    4.959929
# 4186  13.63650  22.9950           -8.20    3.685687
# 4514   0.60075   0.9225           -0.15    4.300699
# 4584   0.10075   0.4225           -0.65    1.969697
# 4593  -0.06725   0.3025           -0.93    1.227181
# 4601  -0.15925   0.1625           -0.91    0.757576
# 4647  -0.26725   0.1025           -1.13    0.415822
# 4782   0.05075   0.3725           -0.70    1.736597
# 5019   0.44275   0.8125           -0.42    3.296146
# 5087  -0.27925   0.0425           -1.03    0.198135
# 5202  -0.09925   0.2225           -0.85    1.037296
# 5244   0.24075   0.5625           -0.51    2.622378
# 5273   0.25075   0.5725           -0.50    2.668998
# 5368  -0.34725   0.0225           -1.21    0.091278
# 5549  -0.11925   0.2025           -0.87    0.944056
# 5594  -0.07925   0.2425           -0.83    1.130536
# 5649  -0.20925   0.1125           -0.96    0.524476
# 5858   0.17550   3.9450           -8.62    1.569837
# 5884   0.08700   4.5000          -10.21    1.529572
# 5887  -0.58450   3.1850           -9.38    1.267409
# 6012   4.43550   8.2050           -4.36    3.265022
# 6014   5.67550   9.4450           -3.12    3.758456
# 6110  -1.60450   2.1650          -10.40    0.861520
# 6118  -1.75450   2.0150          -10.55    0.801830
# 6139   3.46700   7.8800           -6.83    2.678450
# 6299   0.75550   4.5250           -8.04    1.800637
# 6346   5.80550   9.5750           -2.99    3.810187
# 6373  -0.85450   2.9150           -9.65    1.159968
# 6404   2.18550   5.9550           -6.61    2.369678
# 6474  -0.73450   3.0350           -9.53    1.207720
# 6592  -3.41450   0.3550          -12.21    0.141265
# 6880   0.24455   0.4265           -0.18    3.516076
# 6959   0.28455   0.4665           -0.14    3.845837
# 6969  -0.01900   0.1400           -0.39    1.320755
# 7024   0.19455   0.3765           -0.23    3.103875
# 7188   0.03100   0.1900           -0.34    1.792453
# 7394   0.03455   0.2165           -0.39    1.784831
# 7524   0.43455   0.6165            0.01    5.082440
# 7600   0.10100   0.2600           -0.27    2.452830
# 7617  -0.04900   0.1100           -0.42    1.037736
# 7850   0.06100   0.2200           -0.31    2.075472
# 7939   0.01100   0.1700           -0.36    1.603774
# 8065   0.07100   0.2300           -0.30    2.169811
# 8095   0.11455   0.2965           -0.31    2.444353
# 8199   0.04100   0.2000           -0.33    1.886792
# 8205   0.02100   0.1800           -0.35    1.698113
#
#                               clean_name DOB_parsed    TIER
# 79           tan shou yi rei chen shouyi       None  Tier 4
# 1196                        han lin feng       None  Tier 1
# 1574                        jin rou wong       None  Tier 3
# 1606         tan shou yi rei chen shouyi       None  Tier 1
# 1827                          andrew pak       None  Tier 1
# 3506               irfan qabeel mohamman       None  Tier 3
# 3822                       wei jun huang       None  Tier 4
# 4063               bharadwaj akash vijay       None  Tier 4
# 4121            aidan michael soh zi ren       None  Tier 4
# 4178                   noah ng shen yang       None  Tier 1
# 4183                          mani manoj       None  Tier 3
# 4185                   low jit yin elgin       None  Tier 2
# 4186                         lim jerrell       None  Tier 2
# 4514                             teo yan       None  Tier 2
# 4584                           tan daryl       None  Tier 3
# 4593               tan ying tong shannon       None  Tier 4
# 4601                       keane tan jun       None  Tier 4
# 4647  soh hwei en rachel su huien rachel       None  Tier 4
# 4782               jonathan philip hoare       None  Tier 3
# 5019                 lim yee chern clara       None  Tier 2
# 5087                    joshua lee shyen       None  Tier 4
# 5202                     jonathan philip       None  Tier 4
# 5244                           ang jamie       None  Tier 3
# 5273                       wei jun huang       None  Tier 3
# 5368              emily anne choi yi siu       None  Tier 4
# 5549                brayden chan wei jie       None  Tier 4
# 5594                        ashok tharun       None  Tier 4
# 5649            aidan michael soh zi ren       None  Tier 4
# 5858                         tan wei yee       None  Tier 3
# 5884                      su peixin emma       None  Tier 3
# 5887                        philston sow       None  Tier 4
# 6012                   noah ng shen yang       None  Tier 2
# 6014                        pranit nitin       None  Tier 2
# 6110                       longue kieran       None  Tier 4
# 6118                          liu haoyue       None  Tier 4
# 6139                     lim yuqi sommer       None  Tier 3
# 6299                 jeevan joshua jerom       None  Tier 3
# 6346            jeyaseelan sai hayagreev       None  Tier 2
# 6373                         gerard jofi       None  Tier 4
# 6404                   ethan lee jinxian       None  Tier 3
# 6474              chong ka jin sebastian       None  Tier 4
# 6592      ahmad zubayr bin mohamed imran       None  Tier 4
# 6880                       teh ying shan       None  Tier 2
# 6959               tan ying tong shannon       None  Tier 2
# 6969                       keane tan jun       None  Tier 4
# 7024  soh hwei en rachel su huien rachel       None  Tier 2
# 7188               jonathan philip hoare       None  Tier 3
# 7394              megan anne ying ka mun       None  Tier 3
# 7524                 lim yee chern clara       None  Tier 1
# 7600                    joshua lee shyen       None  Tier 3
# 7617                lam sheng jie nathan       None  Tier 4
# 7850                       wei jun huang       None  Tier 3
# 7939                       fong jun liau       None  Tier 3
# 8065                   chua jean garrett       None  Tier 3
# 8095                     chloe chee enya       None  Tier 3
# 8199                            bryan ng       None  Tier 3
# 8205                brayden chan wei jie       None  Tier 3
#
# [57 rows x 44 columns]

# %%
final_df["DOB"] = pd.to_datetime(final_df["DOB"], errors="coerce", dayfirst=True)
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2569036124.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   final_df["DOB"] = pd.to_datetime(final_df["DOB"], errors="coerce", dayfirst=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2569036124.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   final_df["DOB"] = pd.to_datetime(final_df["DOB"], errors="coerce", dayfirst=True)
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2569036124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["DOB"] = pd.to_datetime(final_df["DOB"], errors="coerce", dayfirst=True)

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')

final_df.to_csv('check.csv', encoding='utf-8')

# %%
# Create a list of name components to seach for permutations

final_df['name_to_list'] = final_df['clean_name'].str.split(' ')

final_df
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/2979994617.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['name_to_list'] = final_df['clean_name'].str.split(' ')
#       index                           NAME  RESULT_x  \
# 1     16656                   Zhong Chuhan     12.26
# 78    16419                Tan Shou Yi Rei    14.99m
# 79    16613  Tan Shou Ri Yei (Chen Shouyi)     14.31
# 105   16416             Rozario Tia Louise    12.90m
# 157   16326           Medina Andrew George    14.98m
# ...     ...                            ...       ...
# 8199   1682                       Bryan Ng     10.93
# 8205   2319           Brayden Chan Wei Jie  00:10.95
# 8255   6270                  Ashok, Tharun     10.81
# 8295    455                    Amanda, Loo     12.44
# 8338   6170        Abdul Aziz, Zara Almira     12.54
#
#                                TEAM   AGE COMPETITION_RANK DIVISION  \
# 1                              None  None             None     None
# 78           Raffles Institution JC    17                1      U20
# 79                               RI  18.5              1.0        A
# 105                             FAC    12                1     Open
# 157   National University Singapore    12                1     Open
# ...                             ...   ...              ...      ...
# 8199                           None  None                2     None
# 8205                             RI  18.5              3.0        A
# 8255           Ngee Ann Polytechnic    12                4     Open
# 8295            TRACKSTAR ATHLETICS    12                2     Open
# 8338           Republic Polytechnic    12                2     Open
#
#           EVENT_x DISTANCE EVENT_CLASS  ... RESULT_BEST  Delta2 Delta3.5  \
# 1     Triple Jump     None        None  ...       12.26 -0.0586  0.12995
# 78    Triple Jump        0        None  ...       14.99  0.2998  0.52465
# 79    Triple Jump     None        None  ...       14.31 -0.3802 -0.15535
# 105   Triple Jump        0        None  ...       12.90  0.5814  0.76995
# 157   Triple Jump        0        None  ...       14.98  0.2898  0.51465
# ...           ...      ...         ...  ...         ...     ...      ...
# 8199         100m     None        None  ...       10.93 -0.1180  0.04100
# 8205         100m     None        None  ...       10.95 -0.1380  0.02100
# 8255         Dash      100              ...       10.81  0.0020  0.16100
# 8295         Dash    100.0        None  ...       12.44 -0.0674  0.11455
# 8338         Dash      100              ...       12.54 -0.1674  0.01455
#
#       Delta5 Delta_Benchmark PERF_SCALAR                   clean_name  \
# 1     0.3185           -0.31    2.533811                 chuhan zhong
# 78    0.7495            0.00    5.000000                      tan rei
# 79    0.0695           -0.68    0.463642  tan shou yi rei chen shouyi
# 105   0.9585            0.33    7.625298           rozario tia louise
# 157   0.7395           -0.01    4.933289                medina andrew
# ...      ...             ...         ...                          ...
# 8199  0.2000           -0.33    1.886792                     bryan ng
# 8205  0.1800           -0.35    1.698113         brayden chan wei jie
# 8255  0.3200           -0.21    3.018868                 ashok tharun
# 8295  0.2965           -0.31    2.444353                   amanda loo
# 8338  0.1965           -0.41    1.619951       abdul aziz zara almira
#
#       DOB_parsed    TIER                        name_to_list
# 1     2005-10-18  Tier 3                     [chuhan, zhong]
# 78    2008-12-05  Tier 1                          [tan, rei]
# 79          None  Tier 4  [tan, shou, yi, rei, chen, shouyi]
# 105   2000-10-14  Tier 1              [rozario, tia, louise]
# 157   2002-03-22  Tier 2                    [medina, andrew]
# ...          ...     ...                                 ...
# 8199        None  Tier 3                         [bryan, ng]
# 8205        None  Tier 3           [brayden, chan, wei, jie]
# 8255  2005-07-02  Tier 2                     [ashok, tharun]
# 8295  2005-12-05  Tier 3                       [amanda, loo]
# 8338  2007-07-06  Tier 3         [abdul, aziz, zara, almira]
#
# [268 rows x 45 columns]

# %%
# Lookup DOB from name

final_df['dob_list'] = None  


for index, row in final_df.iterrows():
         
   # if str(row['DOB_new']) == 'NaT':
   # if ((final_df['DOB']=='None') or (final_df['DOB']=='nan')):
            
    name_components = row['name_to_list']
        
    permutations_list = []
    dob_list=[]
    string=''
    
    
    for p in permutations(name_components):
        
        string = " ".join(p)
        
        permutations_list.append(string)

        dob = dictionary_dob_clean_name.get(string)
        
        if dob is not None:
            dob_list.append(dob)

    
  #  null.at[index, 'permutations'] = permutations_list
   # athletes.loc[index, 'dob_list'] = dob_list
    final_df.at[index, 'dob_list'] = [dob_list] if isinstance(dob_list, list) else dob_list
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/4220560926.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['dob_list'] = None

# %%
# Find the missing DOBs from all the possible name permutations
# Saves permuations list and has more robust handling of missing name components

from itertools import permutations

# Make sure the target columns exist
#final_df['permutations'] = None
final_df['dob_list'] = None

for index, row in final_df.iterrows():
    name_components = row['name_to_list']
    
    # If the row has no valid components, skip
    if not isinstance(name_components, (list, tuple)) or len(name_components) == 0:
        athletes.at[index, 'permutations'] = []
        athletes.at[index, 'dob_list'] = []
        continue
    
    permutations_list = []
    dob_list = []
    
    for p in permutations(name_components):
        string = " ".join(p)
        permutations_list.append(string)

        dob = dictionary_dob_clean_name.get(string)
        if dob is not None:
            dob_list.append(dob)

    # Save lists directly into cells (as Python objects)
  #  final_df.at[index, 'permutations'] = permutations_list
    final_df.at[index, 'dob_list'] = dob_list
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/3455906722.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['dob_list'] = None

# %%
final_df
# Out:
#       index                           NAME  RESULT_x  \
# 1     16656                   Zhong Chuhan     12.26
# 78    16419                Tan Shou Yi Rei    14.99m
# 79    16613  Tan Shou Ri Yei (Chen Shouyi)     14.31
# 105   16416             Rozario Tia Louise    12.90m
# 157   16326           Medina Andrew George    14.98m
# ...     ...                            ...       ...
# 8199   1682                       Bryan Ng     10.93
# 8205   2319           Brayden Chan Wei Jie  00:10.95
# 8255   6270                  Ashok, Tharun     10.81
# 8295    455                    Amanda, Loo     12.44
# 8338   6170        Abdul Aziz, Zara Almira     12.54
#
#                                TEAM   AGE COMPETITION_RANK DIVISION  \
# 1                              None  None             None     None
# 78           Raffles Institution JC    17                1      U20
# 79                               RI  18.5              1.0        A
# 105                             FAC    12                1     Open
# 157   National University Singapore    12                1     Open
# ...                             ...   ...              ...      ...
# 8199                           None  None                2     None
# 8205                             RI  18.5              3.0        A
# 8255           Ngee Ann Polytechnic    12                4     Open
# 8295            TRACKSTAR ATHLETICS    12                2     Open
# 8338           Republic Polytechnic    12                2     Open
#
#           EVENT_x DISTANCE EVENT_CLASS  ...  Delta2 Delta3.5  Delta5  \
# 1     Triple Jump     None        None  ... -0.0586  0.12995  0.3185
# 78    Triple Jump        0        None  ...  0.2998  0.52465  0.7495
# 79    Triple Jump     None        None  ... -0.3802 -0.15535  0.0695
# 105   Triple Jump        0        None  ...  0.5814  0.76995  0.9585
# 157   Triple Jump        0        None  ...  0.2898  0.51465  0.7395
# ...           ...      ...         ...  ...     ...      ...     ...
# 8199         100m     None        None  ... -0.1180  0.04100  0.2000
# 8205         100m     None        None  ... -0.1380  0.02100  0.1800
# 8255         Dash      100              ...  0.0020  0.16100  0.3200
# 8295         Dash    100.0        None  ... -0.0674  0.11455  0.2965
# 8338         Dash      100              ... -0.1674  0.01455  0.1965
#
#      Delta_Benchmark PERF_SCALAR                   clean_name  DOB_parsed  \
# 1              -0.31    2.533811                 chuhan zhong  2005-10-18
# 78              0.00    5.000000                      tan rei  2008-12-05
# 79             -0.68    0.463642  tan shou yi rei chen shouyi        None
# 105             0.33    7.625298           rozario tia louise  2000-10-14
# 157            -0.01    4.933289                medina andrew  2002-03-22
# ...              ...         ...                          ...         ...
# 8199           -0.33    1.886792                     bryan ng        None
# 8205           -0.35    1.698113         brayden chan wei jie        None
# 8255           -0.21    3.018868                 ashok tharun  2005-07-02
# 8295           -0.31    2.444353                   amanda loo  2005-12-05
# 8338           -0.41    1.619951       abdul aziz zara almira  2007-07-06
#
#         TIER                        name_to_list                  dob_list
# 1     Tier 3                     [chuhan, zhong]  [2005-10-18, 2005-10-18]
# 78    Tier 1                          [tan, rei]  [2008-12-05, 2008-04-12]
# 79    Tier 4  [tan, shou, yi, rei, chen, shouyi]                        []
# 105   Tier 1              [rozario, tia, louise]  [2000-10-15, 2000-10-14]
# 157   Tier 2                    [medina, andrew]              [2002-03-22]
# ...      ...                                 ...                       ...
# 8199  Tier 3                         [bryan, ng]              [2005-05-30]
# 8205  Tier 3           [brayden, chan, wei, jie]              [2007-08-25]
# 8255  Tier 2                     [ashok, tharun]  [2005-07-02, 2005-07-02]
# 8295  Tier 3                       [amanda, loo]  [2005-12-05, 2005-12-05]
# 8338  Tier 3         [abdul, aziz, zara, almira]              [2007-01-01]
#
# [268 rows x 46 columns]

# %%
# Create a new column with the first element of dob_list (or NaN if empty)

final_df['dob_first'] = final_df['dob_list'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/3894324010.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['dob_first'] = final_df['dob_list'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)

# %%
final_df
# Out:
#       index                           NAME  RESULT_x  \
# 1     16656                   Zhong Chuhan     12.26
# 78    16419                Tan Shou Yi Rei    14.99m
# 79    16613  Tan Shou Ri Yei (Chen Shouyi)     14.31
# 105   16416             Rozario Tia Louise    12.90m
# 157   16326           Medina Andrew George    14.98m
# ...     ...                            ...       ...
# 8199   1682                       Bryan Ng     10.93
# 8205   2319           Brayden Chan Wei Jie  00:10.95
# 8255   6270                  Ashok, Tharun     10.81
# 8295    455                    Amanda, Loo     12.44
# 8338   6170        Abdul Aziz, Zara Almira     12.54
#
#                                TEAM   AGE COMPETITION_RANK DIVISION  \
# 1                              None  None             None     None
# 78           Raffles Institution JC    17                1      U20
# 79                               RI  18.5              1.0        A
# 105                             FAC    12                1     Open
# 157   National University Singapore    12                1     Open
# ...                             ...   ...              ...      ...
# 8199                           None  None                2     None
# 8205                             RI  18.5              3.0        A
# 8255           Ngee Ann Polytechnic    12                4     Open
# 8295            TRACKSTAR ATHLETICS    12                2     Open
# 8338           Republic Polytechnic    12                2     Open
#
#           EVENT_x DISTANCE EVENT_CLASS  ... Delta3.5  Delta5 Delta_Benchmark  \
# 1     Triple Jump     None        None  ...  0.12995  0.3185           -0.31
# 78    Triple Jump        0        None  ...  0.52465  0.7495            0.00
# 79    Triple Jump     None        None  ... -0.15535  0.0695           -0.68
# 105   Triple Jump        0        None  ...  0.76995  0.9585            0.33
# 157   Triple Jump        0        None  ...  0.51465  0.7395           -0.01
# ...           ...      ...         ...  ...      ...     ...             ...
# 8199         100m     None        None  ...  0.04100  0.2000           -0.33
# 8205         100m     None        None  ...  0.02100  0.1800           -0.35
# 8255         Dash      100              ...  0.16100  0.3200           -0.21
# 8295         Dash    100.0        None  ...  0.11455  0.2965           -0.31
# 8338         Dash      100              ...  0.01455  0.1965           -0.41
#
#      PERF_SCALAR                   clean_name  DOB_parsed    TIER  \
# 1       2.533811                 chuhan zhong  2005-10-18  Tier 3
# 78      5.000000                      tan rei  2008-12-05  Tier 1
# 79      0.463642  tan shou yi rei chen shouyi        None  Tier 4
# 105     7.625298           rozario tia louise  2000-10-14  Tier 1
# 157     4.933289                medina andrew  2002-03-22  Tier 2
# ...          ...                          ...         ...     ...
# 8199    1.886792                     bryan ng        None  Tier 3
# 8205    1.698113         brayden chan wei jie        None  Tier 3
# 8255    3.018868                 ashok tharun  2005-07-02  Tier 2
# 8295    2.444353                   amanda loo  2005-12-05  Tier 3
# 8338    1.619951       abdul aziz zara almira  2007-07-06  Tier 3
#
#                             name_to_list                  dob_list   dob_first
# 1                        [chuhan, zhong]  [2005-10-18, 2005-10-18]  2005-10-18
# 78                            [tan, rei]  [2008-12-05, 2008-04-12]  2008-12-05
# 79    [tan, shou, yi, rei, chen, shouyi]                        []        None
# 105               [rozario, tia, louise]  [2000-10-15, 2000-10-14]  2000-10-15
# 157                     [medina, andrew]              [2002-03-22]  2002-03-22
# ...                                  ...                       ...         ...
# 8199                         [bryan, ng]              [2005-05-30]  2005-05-30
# 8205           [brayden, chan, wei, jie]              [2007-08-25]  2007-08-25
# 8255                     [ashok, tharun]  [2005-07-02, 2005-07-02]  2005-07-02
# 8295                       [amanda, loo]  [2005-12-05, 2005-12-05]  2005-12-05
# 8338         [abdul, aziz, zara, almira]              [2007-01-01]  2007-01-01
#
# [268 rows x 47 columns]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')

final_df.to_csv('check.csv', encoding='utf-8')

# %%
# Filter athletes born between 1 Jan 2008 to 31 Dec 2009

# First, convert to datetime
final_df['dob_first'] = pd.to_datetime(final_df['dob_first'], errors='coerce')

# Then remove timezone if it exists
if final_df['dob_first'].dt.tz is not None:
    
    final_df['dob_first'] = final_df['dob_first'].dt.tz_localize(None)

start = datetime.datetime(2006, 1, 1)

end = datetime.datetime(2007, 12, 31)

start_date = np.datetime64(start)
end_date = np.datetime64(end)


mask = ((final_df['dob_first'] >= start_date) & (final_df['dob_first'] <= end_date)|(final_df['dob_first'].isna()))
athletes_selected = final_df.loc[mask]
# Out:
# /var/folders/q5/yf8g5p896_b94gkbhqcjx3t40000gn/T/ipykernel_16903/1026149739.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['dob_first'] = pd.to_datetime(final_df['dob_first'], errors='coerce')

# %%
athletes_selected
# Out:
#       index                           NAME  RESULT_x                     TEAM  \
# 79    16613  Tan Shou Ri Yei (Chen Shouyi)     14.31                       RI
# 210   16493                   Kumar Viresh    14.36m  Victoria Junior College
# 1229  12238              Fun Le Cong Lucas     7.03m  Singapore Sports School
# 1539  18093                        Yuki Ho      1.57          Verve Fitness -
# 1574  10690                   Wong Jin Rou       1.6                     None
# ...     ...                            ...       ...                      ...
# 7850   1632                   Huang Weijun     10.91                      nan
# 7999  16886                    Donavan Yip     10.90    Temasek Polytechnic -
# 8065   2315                   Chua Garrett  00:10.90                       RI
# 8205   2319           Brayden Chan Wei Jie  00:10.95                       RI
# 8338   6170        Abdul Aziz, Zara Almira     12.54     Republic Polytechnic
#
#        AGE COMPETITION_RANK DIVISION      EVENT_x DISTANCE EVENT_CLASS  ...  \
# 79    18.5              1.0        A  Triple Jump     None        None  ...
# 210     18                1      U20  Triple Jump        0        None  ...
# 1229    12                2     Open    Long Jump        0        None  ...
# 1539                      1             High Jump                  nan  ...
# 1574  None             None     None    High Jump     None        None  ...
# ...    ...              ...      ...          ...      ...         ...  ...
# 7850   nan              2.0      nan         100m      nan         nan  ...
# 7999                      1                  100m                  nan  ...
# 8065  18.5              2.0        A         100m     None        None  ...
# 8205  18.5              3.0        A         100m     None        None  ...
# 8338    12                2     Open         Dash      100              ...
#
#      Delta3.5  Delta5 Delta_Benchmark PERF_SCALAR  \
# 79   -0.15535  0.0695           -0.68    0.463642
# 210  -0.10535  0.1195           -0.63    0.797198
# 1229  0.09165  0.1995           -0.16    2.774687
# 1539 -0.01260  0.0120           -0.07    0.731707
# 1574  0.01740  0.0420           -0.04    2.560976
# ...       ...     ...             ...         ...
# 7850  0.06100  0.2200           -0.31    2.075472
# 7999  0.07100  0.2300           -0.30    2.169811
# 8065  0.07100  0.2300           -0.30    2.169811
# 8205  0.02100  0.1800           -0.35    1.698113
# 8338  0.01455  0.1965           -0.41    1.619951
#
#                        clean_name  DOB_parsed    TIER  \
# 79    tan shou yi rei chen shouyi        None  Tier 4
# 210                  kumar viresh  2007-01-03  Tier 4
# 1229            fun le cong lucas  2006-01-11  Tier 3
# 1539                      yuki ho  2006-08-30  Tier 4
# 1574                 jin rou wong        None  Tier 3
# ...                           ...         ...     ...
# 7850                wei jun huang        None  Tier 3
# 7999                  donavan yip  2006-06-27  Tier 3
# 8065            chua jean garrett        None  Tier 3
# 8205         brayden chan wei jie        None  Tier 3
# 8338       abdul aziz zara almira  2007-07-06  Tier 3
#
#                             name_to_list  \
# 79    [tan, shou, yi, rei, chen, shouyi]
# 210                      [kumar, viresh]
# 1229              [fun, le, cong, lucas]
# 1539                          [yuki, ho]
# 1574                    [jin, rou, wong]
# ...                                  ...
# 7850                   [wei, jun, huang]
# 7999                      [donavan, yip]
# 8065               [chua, jean, garrett]
# 8205           [brayden, chan, wei, jie]
# 8338         [abdul, aziz, zara, almira]
#
#                                   dob_list  dob_first
# 79                                      []        NaT
# 210                           [2007-01-03] 2007-01-03
# 1229  [2006-01-11, 2006-01-11, 2006-01-11] 2006-01-11
# 1539              [2006-08-30, 2006-08-30] 2006-08-30
# 1574                          [2006-08-01] 2006-08-01
# ...                                    ...        ...
# 7850                          [2006-08-31] 2006-08-31
# 7999              [2006-06-27, 2006-06-27] 2006-06-27
# 8065                                    []        NaT
# 8205                          [2007-08-25] 2007-08-25
# 8338                          [2007-01-01] 2007-01-01
#
# [81 rows x 47 columns]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/17th SEA Youth/')

athletes_selected.to_csv('final_selection_U20_oct27.csv', encoding='utf-8')
