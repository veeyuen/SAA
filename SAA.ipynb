# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import usual modules
import pandas as pd
import csv
import math
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl
import datetime
from scipy.stats import lognorm
import re

# %%
os.getcwd()
#os.chdir("/Users/veesheen/Desktop")
# Out:
# '/Users/veesheenyuen/code/veeyuen/SAA'

# %%
events=pd.read_csv('all_events.csv')

events
# Out:
#     GENDER         EVENT      HEAT                    NAME BIRTH DATE NAT.  \
# 0      Men     High Jump  Combined              Janry UBAS   2-Jan-94  PHI
# 1      Men     High Jump  Combined       Suttisak SINGKHON   5-Oct-96  THA
# 2      Men     High Jump  Combined         Minh Sang LUONG  16-Feb-96  VIE
# 3      Men     High Jump  Combined            Aries TOLEDO   2-Nov-93  PHI
# 4      Men     High Jump  Combined              Van Su BUI  14-Apr-94  VIE
# ..     ...           ...       ...                     ...        ...  ...
# 216  Women  Discus Throw     Final    Queenie Ting KUNG NI  16-Nov-97  MAS
# 217  Women  Discus Throw     Final            Choo KANG NI   9-Feb-94  MAS
# 218  Women  Discus Throw     Final  Thi Hong Thuong NGUYEN  25-May-97  VIE
# 219  Women  Discus Throw     Final             Jasmin PHUA   7-Dec-01  SGP
# 220  Women  Discus Throw     Final           Kim Thi HUYEN       2003  VIE
#
#       MARK  Unnamed: 7
# 0     2.04         NaN
# 1     1.95         NaN
# 2     1.89         NaN
# 3     1.86         NaN
# 4     1.86         NaN
# ..     ...         ...
# 216  52.36         NaN
# 217  46.57         NaN
# 218  45.70         NaN
# 219  44.42         NaN
# 220  43.60         NaN
#
# [221 rows x 8 columns]

# %%
events
# Out:
#     GENDER         EVENT      HEAT                    NAME BIRTH DATE NAT.  \
# 0      Men     High Jump  Combined              Janry UBAS   2-Jan-94  PHI
# 1      Men     High Jump  Combined       Suttisak SINGKHON   5-Oct-96  THA
# 2      Men     High Jump  Combined         Minh Sang LUONG  16-Feb-96  VIE
# 3      Men     High Jump  Combined            Aries TOLEDO   2-Nov-93  PHI
# 4      Men     High Jump  Combined              Van Su BUI  14-Apr-94  VIE
# ..     ...           ...       ...                     ...        ...  ...
# 216  Women  Discus Throw     Final    Queenie Ting KUNG NI  16-Nov-97  MAS
# 217  Women  Discus Throw     Final            Choo KANG NI   9-Feb-94  MAS
# 218  Women  Discus Throw     Final  Thi Hong Thuong NGUYEN  25-May-97  VIE
# 219  Women  Discus Throw     Final             Jasmin PHUA   7-Dec-01  SGP
# 220  Women  Discus Throw     Final           Kim Thi HUYEN       2003  VIE
#
#       MARK  Unnamed: 7
# 0     2.04         NaN
# 1     1.95         NaN
# 2     1.89         NaN
# 3     1.86         NaN
# 4     1.86         NaN
# ..     ...         ...
# 216  52.36         NaN
# 217  46.57         NaN
# 218  45.70         NaN
# 219  44.42         NaN
# 220  43.60         NaN
#
# [221 rows x 8 columns]

# %%
events['MARK'] = pd.to_numeric(events['MARK'])

# %%
events['EVENT'].unique()
# Out:
# array(['High Jump', 'Long Jump', '200M', 'Hammer Throw', 'Javeln Throw',
#        '400M', 'Discus Throw', '100M', 'Triple Jump'], dtype=object)

# %%
high_jump_men=events[(events['EVENT']=='High Jump') & (events['GENDER']=='Men')].copy()
high_jump_men
# Out:
#    GENDER      EVENT      HEAT                   NAME BIRTH DATE NAT.  MARK  \
# 0     Men  High Jump  Combined             Janry UBAS   2-Jan-94  PHI  2.04
# 1     Men  High Jump  Combined      Suttisak SINGKHON   5-Oct-96  THA  1.95
# 2     Men  High Jump  Combined        Minh Sang LUONG  16-Feb-96  VIE  1.89
# 3     Men  High Jump  Combined           Aries TOLEDO   2-Nov-93  PHI  1.86
# 4     Men  High Jump  Combined             Van Su BUI  14-Apr-94  VIE  1.86
# 5     Men  High Jump     Final      Kobsit SITTHICHAI  25-Jun-99  THA  2.21
# 6     Men  High Jump     Final  Nauraj Singh RANDHAWA  27-Jan-92  MAS  2.18
# 7     Men  High Jump     Final    Moh. Eizlan DAHALAN   5-Sep-99  MAS  2.18
# 8     Men  High Jump     Final          Tawan KAEWKAM  30-Sep-99  THA  2.18
# 9     Men  High Jump     Final             Duc Anh VU   6-Feb-98  VIE  2.18
# 10    Men  High Jump     Final         Leonard GROSPE   2-Jul-01  PHI  2.04
# 11    Men  High Jump     Final             Khem NHORK   2-Feb-98  CAM  1.90
#
#     Unnamed: 7
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(high_jump_men['MARK'], kde=True, ax=ax)
ax.set_xlim(1.5, 2.5)

plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
high_jump_men['MARK'].describe()
# Out:
# count    12.000000
# mean      2.039167
# std       0.142156
# min       1.860000
# 25%       1.897500
# 50%       2.040000
# 75%       2.180000
# max       2.210000
# Name: MARK, dtype: float64

# %%
long_jump_men=events[(events['EVENT']=='Long Jump') & (events['GENDER']=='Men')].copy()
long_jump_men
# Out:
#    GENDER      EVENT      HEAT                  NAME BIRTH DATE NAT.  MARK  \
# 12    Men  Long Jump     Final     Tien Trong NGUYEN   9-Mar-97  VIE  7.80
# 13    Men  Long Jump     Final            Janry UBAS   2-Jan-94  PHI  7.73
# 14    Men  Long Jump     Final       . SAPWATURAHMAN  13-May-94  INA  7.61
# 15    Men  Long Jump     Final         Van Dien TRAN  27-Jan-98  VIE  7.46
# 16    Men  Long Jump     Final           Andre ANURA  12-Jun-99  MAS  7.24
# 17    Men  Long Jump     Final            Hoeun CHAV  20-Jan-02  CAM  6.72
# 18    Men  Long Jump     Final  Xaidavahn VONGSAVANH   8-Oct-00  LAO  6.27
# 19    Men  Long Jump  Combined            Janry UBAS   2-Jan-94  PHI  7.71
# 20    Men  Long Jump  Combined     Suttisak SINGKHON   5-Oct-96  THA  7.29
# 21    Men  Long Jump  Combined          Aries TOLEDO   2-Nov-93  PHI  7.22
# 22    Men  Long Jump  Combined       Minh Sang LUONG  16-Feb-96  VIE  6.62
# 23    Men  Long Jump  Combined            Van Su BUI  14-Apr-94  VIE  6.52
#
#     Unnamed: 7
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN

# %%
long_jump_men.sort_values('MARK', ascending=True).drop_duplicates('NAME').sort_index()
# Out:
#    GENDER      EVENT      HEAT                  NAME BIRTH DATE NAT.  MARK  \
# 12    Men  Long Jump     Final     Tien Trong NGUYEN   9-Mar-97  VIE  7.80
# 14    Men  Long Jump     Final       . SAPWATURAHMAN  13-May-94  INA  7.61
# 15    Men  Long Jump     Final         Van Dien TRAN  27-Jan-98  VIE  7.46
# 16    Men  Long Jump     Final           Andre ANURA  12-Jun-99  MAS  7.24
# 17    Men  Long Jump     Final            Hoeun CHAV  20-Jan-02  CAM  6.72
# 18    Men  Long Jump     Final  Xaidavahn VONGSAVANH   8-Oct-00  LAO  6.27
# 19    Men  Long Jump  Combined            Janry UBAS   2-Jan-94  PHI  7.71
# 20    Men  Long Jump  Combined     Suttisak SINGKHON   5-Oct-96  THA  7.29
# 21    Men  Long Jump  Combined          Aries TOLEDO   2-Nov-93  PHI  7.22
# 22    Men  Long Jump  Combined       Minh Sang LUONG  16-Feb-96  VIE  6.62
# 23    Men  Long Jump  Combined            Van Su BUI  14-Apr-94  VIE  6.52
#
#     Unnamed: 7
# 12         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN

# %%
long_jump_men.drop_duplicates(subset='NAME', keep='first')  # alternative drop logic
# Out:
#    GENDER      EVENT      HEAT                  NAME BIRTH DATE NAT.  MARK  \
# 12    Men  Long Jump     Final     Tien Trong NGUYEN   9-Mar-97  VIE  7.80
# 13    Men  Long Jump     Final            Janry UBAS   2-Jan-94  PHI  7.73
# 14    Men  Long Jump     Final       . SAPWATURAHMAN  13-May-94  INA  7.61
# 15    Men  Long Jump     Final         Van Dien TRAN  27-Jan-98  VIE  7.46
# 16    Men  Long Jump     Final           Andre ANURA  12-Jun-99  MAS  7.24
# 17    Men  Long Jump     Final            Hoeun CHAV  20-Jan-02  CAM  6.72
# 18    Men  Long Jump     Final  Xaidavahn VONGSAVANH   8-Oct-00  LAO  6.27
# 20    Men  Long Jump  Combined     Suttisak SINGKHON   5-Oct-96  THA  7.29
# 21    Men  Long Jump  Combined          Aries TOLEDO   2-Nov-93  PHI  7.22
# 22    Men  Long Jump  Combined       Minh Sang LUONG  16-Feb-96  VIE  6.62
# 23    Men  Long Jump  Combined            Van Su BUI  14-Apr-94  VIE  6.52
#
#     Unnamed: 7
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(long_jump_men['MARK'], ax=ax)
#ax.set_xlim(0, 9)
ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
long_jump_men['MARK'].describe()
# Out:
# count    12.000000
# mean      7.182500
# std       0.525463
# min       6.270000
# 25%       6.695000
# 50%       7.265000
# 75%       7.635000
# max       7.800000
# Name: MARK, dtype: float64

# %%
long_jump_men['MARK'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Full dataset

# %%
xls = pd.ExcelFile('ranking_master.xlsx')
df1 = pd.read_excel(xls, '2022')
df2 = pd.read_excel(xls, '2021')
df3 = pd.read_excel(xls, '2020')
df4 = pd.read_excel(xls, '2019')
df5 = pd.read_excel(xls, '2018')
df6 = pd.read_excel(xls, '2017')
df7 = pd.read_excel(xls, '2016')
df8 = pd.read_excel(xls, '2015')
df9 = pd.read_excel(xls, '2014')
df10 = pd.read_excel(xls, '2013')
df11 = pd.read_excel(xls, '2012')
df12 = pd.read_excel(xls, '2011')
df13 = pd.read_excel(xls, '2013')
df14 = pd.read_excel(xls, 'Before 2010')

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8542 entries, 0 to 8541
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          8542 non-null   datetime64[ns]
#  1   Event         8542 non-null   object
#  2   Name          8542 non-null   object
#  3   Age           8542 non-null   object
#  4   Team          8541 non-null   object
#  5   Result        8542 non-null   object
#  6   m/s           8542 non-null   object
#  7   Competition   8542 non-null   object
#  8   Year D.O.B.   8542 non-null   object
#  9   Info, if any  8542 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 667.5+ KB

# %%
def preprocess(i, string, metric):

    global output
    
    l=['discus', 'throw', 'jump', 'vault', 'shot']
        
    string=string.lower()    
    
    if any(s in string for s in l)==True:
    
        output=float(str(metric))
        
    else:
        
        searchstring = ":"
        searchstring2 = "."
        substring=str(metric)
        count = substring.count(searchstring)
        count2 = substring.count(searchstring2)
            
        if count==0:
            output=float(substring)
                        
             
        elif (type(metric)==datetime.time or type(metric)==datetime.datetime):
                                                
            time=str(metric)
            h, m ,s = time.split(':')
            output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
            
                                
        elif (count==1 and count2==1):
            
            m,s = metric.split(':')
            output = float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds())
            
            if output==229.90:
                print(metric, m, s, output, 'here')

                     
        elif (count==1 and count2==2):
            
            metric = metric.replace(".", ":", 1)
            
            h,m,s = metric.split(':')            
            output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
                
        
        elif (count==2 and count2==0):
            
            h,m,s = metric.split(':')
            output = float(datetime.timedelta(hours=int(h),minutes=int(m),seconds=float(s)).total_seconds())
            
                
    return output

# %%
df1
# Out:
#       Unnamed: 0       Date                                 Event  \
# 0            NaN 2022-01-22                       Women Long Jump
# 1            NaN 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 2            NaN 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 3            NaN 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 4            NaN 2022-01-15        Men 110 Meter Hurdles (0.914m)
# ...          ...        ...                                   ...
# 9134         NaN 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9135         NaN 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9136         NaN 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9137         NaN        NaT                                   NaN
# 9138         NaN 2022-12-10                   Men 10000 Meter Run
#
#                                 Name  Age                            Team  \
# 0                Rozario, Tia Louise   22                       Princeton
# 1                    ANG, Chen Xiang   28            Wings Athletics Club
# 2                    CHONG, Wei Guan   22           National University o
# 3                   AWYONG, Liang Qi   27                       Club ZOOM
# 4     MOHAMAD AFZAL, Bin Mohamad Zin   17             Singapore Sports Sc
# ...                              ...  ...                             ...
# 9134                    YEO, BRANDON   21   NATIONAL UNIVERSITY SINGAPORE
# 9135                     LEE, KELVIN   23  SINGAPORE INSTITUTE OF MANAGEM
# 9136                   EAR, HONG RAY   17                      TEAMFABIAN
# 9137                             NaN  NaN                             NaN
# 9138                   Soh, Rui Yong   31                      Individual
#
#         Result     m/s                                        Competition  \
# 0         5.62  Indoor          International - Wesley Brown invitational
# 1        14.16     0.4                                  Local - Club Zoom
# 2        14.55     0.4                                  Local - Club Zoom
# 3        14.77     0.4                                  Local - Club Zoom
# 4        14.97     1.6                                  Local - Club Zoom
# ...        ...     ...                                                ...
# 9134  12:25.52       -                                SA - 3rd All Comers
# 9135  13:38.24       -                                SA - 3rd All Comers
# 9136  14:01.31       -                                SA - 3rd All Comers
# 9137       NaN     NaN                                                NaN
# 9138  32:53.00       -  International  - Telford England 10km Champion...
#
#      Year D.O.B.        Info, if any Date of Birth (PDPA)  Unnamed: 12
# 0           2000    3pos, sanctioned                    -          NaN
# 1           1994              New NR                    -          NaN
# 2           2000                   -                    -          NaN
# 3           1995                   -                    -          NaN
# 4           2005                   -                    -          NaN
# ...          ...                 ...                  ...          ...
# 9134        2001                   -                    -          NaN
# 9135        1999                   -                    -          NaN
# 9136        2005                   -                    -          NaN
# 9137         NaN                 NaN                  NaN  NEXT UPLOAD
# 9138        1991  151pos, sanctioned                    -          NaN
#
# [9139 rows x 13 columns]

# %%
def format_result(result):
    date = datetime.datetime.utcfromtimestamp(result)
    output = datetime.datetime.strftime(date, "%M:%S:%f")
    return output

format_result(32.25)
# Out:
# '00:32:250000'

# %%
from datetime import timedelta
def format_result(result):
    seconds = int(result)
    microseconds = (result * 1000000) % 1000000
    output = timedelta(0, seconds, microseconds)
    return output

format_result(131.39)
# Out:
# datetime.timedelta(seconds=131, microseconds=390000)

# %%
t = '15:30.45'
m,s = t.split(':')
print(float(datetime.timedelta(minutes=int(m),seconds=float(s)).total_seconds()))
# Out:
# 930.45

# %%
time = "02:01:09"
date_time = datetime.datetime.strptime(time, "%H:%M:%S")
a_timedelta = date_time - datetime.datetime(1900, 1, 1)
seconds = a_timedelta.total_seconds()

print(date_time)
# Out:
# 1900-01-01 02:01:09

# %% [markdown]
# # 2022 df1

# %%
df1 = df1[df1['Event'].notna()] # take only non-empty rows
df1 = df1.reset_index() # must reset index after filtering

# %%
df1.drop(['Unnamed: 0', 'Unnamed: 12', 'Date of Birth (PDPA)'],axis=1, inplace=True)

# %%
df1
# Out:
#       index       Date                                 Event  \
# 0         0 2022-01-22                       Women Long Jump
# 1         1 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 2         2 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 3         3 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 4         4 2022-01-15        Men 110 Meter Hurdles (0.914m)
# ...     ...        ...                                   ...
# 9131   9133 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9132   9134 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9133   9135 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9134   9136 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9135   9138 2022-12-10                   Men 10000 Meter Run
#
#                                 Name  Age                            Team  \
# 0                Rozario, Tia Louise   22                       Princeton
# 1                    ANG, Chen Xiang   28            Wings Athletics Club
# 2                    CHONG, Wei Guan   22           National University o
# 3                   AWYONG, Liang Qi   27                       Club ZOOM
# 4     MOHAMAD AFZAL, Bin Mohamad Zin   17             Singapore Sports Sc
# ...                              ...  ...                             ...
# 9131                     TAN, DARREN   21  SINGAPORE INSTITUTE OF MANAGEM
# 9132                    YEO, BRANDON   21   NATIONAL UNIVERSITY SINGAPORE
# 9133                     LEE, KELVIN   23  SINGAPORE INSTITUTE OF MANAGEM
# 9134                   EAR, HONG RAY   17                      TEAMFABIAN
# 9135                   Soh, Rui Yong   31                      Individual
#
#         Result     m/s                                        Competition  \
# 0         5.62  Indoor          International - Wesley Brown invitational
# 1        14.16     0.4                                  Local - Club Zoom
# 2        14.55     0.4                                  Local - Club Zoom
# 3        14.77     0.4                                  Local - Club Zoom
# 4        14.97     1.6                                  Local - Club Zoom
# ...        ...     ...                                                ...
# 9131  11:16.54       -                                SA - 3rd All Comers
# 9132  12:25.52       -                                SA - 3rd All Comers
# 9133  13:38.24       -                                SA - 3rd All Comers
# 9134  14:01.31       -                                SA - 3rd All Comers
# 9135  32:53.00       -  International  - Telford England 10km Champion...
#
#      Year D.O.B.        Info, if any
# 0           2000    3pos, sanctioned
# 1           1994              New NR
# 2           2000                   -
# 3           1995                   -
# 4           2005                   -
# ...          ...                 ...
# 9131        2001                   -
# 9132        2001                   -
# 9133        1999                   -
# 9134        2005                   -
# 9135        1991  151pos, sanctioned
#
# [9136 rows x 11 columns]

# %%
for i in range(len(df1)):
        
    rowIndex = df1.index[i]

    input_string=df1.iloc[rowIndex,2]
    metric=df1.iloc[rowIndex,6]
        
    out = preprocess(i, input_string, metric)
     
    df1.loc[rowIndex, 'Metric'] = out

# %%
df1
# Out:
#       index       Date                                 Event  \
# 0         0 2022-01-22                       Women Long Jump
# 1         1 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 2         2 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 3         3 2022-01-15        Men 110 Meter Hurdles (1.067m)
# 4         4 2022-01-15        Men 110 Meter Hurdles (0.914m)
# ...     ...        ...                                   ...
# 9131   9133 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9132   9134 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9133   9135 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9134   9136 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9135   9138 2022-12-10                   Men 10000 Meter Run
#
#                                 Name  Age                            Team  \
# 0                Rozario, Tia Louise   22                       Princeton
# 1                    ANG, Chen Xiang   28            Wings Athletics Club
# 2                    CHONG, Wei Guan   22           National University o
# 3                   AWYONG, Liang Qi   27                       Club ZOOM
# 4     MOHAMAD AFZAL, Bin Mohamad Zin   17             Singapore Sports Sc
# ...                              ...  ...                             ...
# 9131                     TAN, DARREN   21  SINGAPORE INSTITUTE OF MANAGEM
# 9132                    YEO, BRANDON   21   NATIONAL UNIVERSITY SINGAPORE
# 9133                     LEE, KELVIN   23  SINGAPORE INSTITUTE OF MANAGEM
# 9134                   EAR, HONG RAY   17                      TEAMFABIAN
# 9135                   Soh, Rui Yong   31                      Individual
#
#         Result     m/s                                        Competition  \
# 0         5.62  Indoor          International - Wesley Brown invitational
# 1        14.16     0.4                                  Local - Club Zoom
# 2        14.55     0.4                                  Local - Club Zoom
# 3        14.77     0.4                                  Local - Club Zoom
# 4        14.97     1.6                                  Local - Club Zoom
# ...        ...     ...                                                ...
# 9131  11:16.54       -                                SA - 3rd All Comers
# 9132  12:25.52       -                                SA - 3rd All Comers
# 9133  13:38.24       -                                SA - 3rd All Comers
# 9134  14:01.31       -                                SA - 3rd All Comers
# 9135  32:53.00       -  International  - Telford England 10km Champion...
#
#      Year D.O.B.        Info, if any   Metric
# 0           2000    3pos, sanctioned     5.62
# 1           1994              New NR    14.16
# 2           2000                   -    14.55
# 3           1995                   -    14.77
# 4           2005                   -    14.97
# ...          ...                 ...      ...
# 9131        2001                   -   676.54
# 9132        2001                   -   745.52
# 9133        1999                   -   818.24
# 9134        2005                   -   841.31
# 9135        1991  151pos, sanctioned  1973.00
#
# [9136 rows x 12 columns]

# %%
women_long_jump=df1[(df1['Event']=='Women Long Jump')].copy()

# %%
# Convert to inverse log for jumps

women_long_jump['lognorm_metric']=np.log(women_long_jump['Metric'])-1

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(women_long_jump['lognorm_metric'], ax=ax)
#ax.set_xlim(0, 9)
ax.set_ylim(0, 3)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(women_long_jump['Metric'], ax=ax)
#ax.set_xlim(0, 9)
ax.set_ylim(0, 0.9)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
men_steeple_3000m=df1[(df1['Event']=='Men 3000 Meter Steeplechase (0.914m)')].copy()

# %%
men_steeple_3000m
# Out:
#       index       Date                                 Event  \
# 1345   1345 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1346   1346 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1347   1347 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1348   1348 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1349   1349 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1350   1350 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1351   1351 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1352   1352 2022-03-26  Men 3000 Meter Steeplechase (0.914m)
# 1983   1983 2022-02-20  Men 3000 Meter Steeplechase (0.914m)
# 1984   1984 2022-02-20  Men 3000 Meter Steeplechase (0.914m)
# 2648   2648 2022-03-20  Men 3000 Meter Steeplechase (0.914m)
# 2649   2649 2022-03-20  Men 3000 Meter Steeplechase (0.914m)
# 6908   6908 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6909   6909 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6910   6910 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6911   6911 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6912   6912 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6913   6913 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6914   6914 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6915   6915 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6916   6916 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6917   6917 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6918   6918 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 6919   6919 2022-10-30  Men 3000 Meter Steeplechase (0.914m)
# 7065   7065 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 7066   7066 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 7067   7067 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 7068   7068 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 7069   7069 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 7070   7070 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 7071   7071 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 7072   7072 2022-11-19  Men 3000 Meter Steeplechase (0.914m)
# 8820   8822 2022-11-29  Men 3000 Meter Steeplechase (0.914m)
# 9130   9132 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9131   9133 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9132   9134 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9133   9135 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
# 9134   9136 2022-12-11  Men 3000 Meter Steeplechase (0.914m)
#
#                                         Name  Age  \
# 1345                            ONG, Chilton    -
# 1346                           CHENG, Daniel    -
# 1347                RAMANATHAN, Rajesh Muthu    -
# 1348                               KO, Keane    -
# 1349      KULANDAIVELUDAYAR SENTHILKUMAR, Ga    -
# 1350                     AMOS SAW, Cheng You    -
# 1351                            KUMAR, Saran    -
# 1352                            ANG, Leonard    -
# 1983  SENTHILKUMAR GAUTAM, KULANDAIVELUDAYAR   18
# 1984                           WEI FENG, LIM   18
# 2648                           CHONG, JEREMY   17
# 2649                           SRIRAAM, RAJA   18
# 6908                           Tan, Chong Qi   24
# 6909            Moheden, Muhammad Shah Feroz   38
# 6910                           Tan, Jonathan   17
# 6911                         Parajuli, Nabin   29
# 6912                       Shreedhar, Pranav   17
# 6913                              Hui, Jared   28
# 6914              Kamaleshwaran, Thiruppathi   24
# 6915                               Poh, Edry   19
# 6916                              Lim, Terry   24
# 6917                             Lee, Kelvin   23
# 6918                           Ear, Hong Ray   17
# 6919                     Goh Wei An, Stephen   19
# 7065            Kulandaiveludayar Se, Gautam   18
# 7066                            Wong, Gideon   17
# 7067                            Kumar, Saran   20
# 7068                              Wee, Caleb   18
# 7069                               Poh, Edry   19
# 7070                            Leonard, Ang   18
# 7071                             Wong, Jovan   17
# 7072                            Zhi Yan, Lim   19
# 8820                           TAN, CHONG QI   24
# 9130                           TAN, JONATHAN   17
# 9131                             TAN, DARREN   21
# 9132                            YEO, BRANDON   21
# 9133                             LEE, KELVIN   23
# 9134                           EAR, HONG RAY   17
#
#                                 Team           Result m/s  \
# 1345                             NTU         10:27.41   -
# 1346                             NUS         10:48.67   -
# 1347                             NUS         11:11.19   -
# 1348                             NYP         11:19.15   -
# 1349                              NP         11:32.63   -
# 1350                             SIM         13:07.85   -
# 1351                             NYP         13:31.40   -
# 1352                              SP         13:52.31   -
# 1983             Trackstar Athletics          9:49.12   -
# 1984             Trackstar Athletics          9:50.52   -
# 2648                Oldham Athletics         13:13.69   -
# 2649                Oldham Athletics         13:55.88   -
# 6908   National University Singapore         10:32.58   -
# 6909                    Totality 360         10:58.24   -
# 6910                      TeamFabian         11:01.88   -
# 6911            Wings Athletics Club         11:17.28   -
# 6912                      TeamFabian         11:28.77   -
# 6913                       Club Zoom         11:39.62   -
# 6914       Nanyang Technological Uni         12:45.95   -
# 6915            Ngee Ann Polytechnic         12:51.88   -
# 6916   National University Singapore         13:47.12   -
# 6917  Singapore Institute of Managem         15:01.15   -
# 6918                      TeamFabian         15:39.86   -
# 6919             Temasek Polytechnic         18:04.27   -
# 7065            NGEE ANN POLYTECHNIC         11:17.99   -
# 7066            NGEE ANN POLYTECHNIC         11:23.81   -
# 7067             NANYANG POLYTECHNIC         11:35.43   -
# 7068             NANYANG POLYTECHNIC         12:00.11   -
# 7069            NGEE ANN POLYTECHNIC         12:20.42   -
# 7070           SINGAPORE POLYTECHNIC         12:25.28   -
# 7071             NANYANG POLYTECHNIC         12:38.00   -
# 7072           SINGAPORE POLYTECHNIC         12:45.47   -
# 8820                       SINGAPORE  00:10:28.280000   -
# 9130                      TEAMFABIAN         10:59.41   -
# 9131  SINGAPORE INSTITUTE OF MANAGEM         11:16.54   -
# 9132   NATIONAL UNIVERSITY SINGAPORE         12:25.52   -
# 9133  SINGAPORE INSTITUTE OF MANAGEM         13:38.24   -
# 9134                      TEAMFABIAN         14:01.31   -
#
#                         Competition Year D.O.B. Info, if any   Metric
# 1345                    Local - IVP           -            -   627.41
# 1346                    Local - IVP           -            -   648.67
# 1347                    Local - IVP           -            -   671.19
# 1348                    Local - IVP           -            -   679.15
# 1349                    Local - IVP           -            -   692.63
# 1350                    Local - IVP           -            -   787.85
# 1351                    Local - IVP           -            -   811.40
# 1352                    Local - IVP           -            -   832.31
# 1983            SA - 1st All Comers        2004            -   589.12
# 1984            SA - 1st All Comers        2004            -   590.52
# 2648            SA - 2nd All Comers        2005            -   793.69
# 2649            SA - 2nd All Comers        2004            -   835.88
# 6908                SA - Inter Club        1998            -   632.58
# 6909                SA - Inter Club        1984            -   658.24
# 6910                SA - Inter Club        2005            -   661.88
# 6911                SA - Inter Club        1993            -   677.28
# 6912                SA - Inter Club        2005            -   688.77
# 6913                SA - Inter Club        1994            -   699.62
# 6914                SA - Inter Club        1998            -   765.95
# 6915                SA - Inter Club        2003            -   771.88
# 6916                SA - Inter Club        1998            -   827.12
# 6917                SA - Inter Club        1999            -   901.15
# 6918                SA - Inter Club        2005            -   939.86
# 6919                SA - Inter Club        2003            -  1084.27
# 7065                Local - POL-ITE        2004            -   677.99
# 7066                Local - POL-ITE        2005            -   683.81
# 7067                Local - POL-ITE        2002            -   695.43
# 7068                Local - POL-ITE        2004            -   720.11
# 7069                Local - POL-ITE        2003            -   740.42
# 7070                Local - POL-ITE        2004            -   745.28
# 7071                Local - POL-ITE        2005            -   758.00
# 7072                Local - POL-ITE        2003            -   765.47
# 8820  International - Thailand Open        1998            -   628.28
# 9130            SA - 3rd All Comers        2005            -   659.41
# 9131            SA - 3rd All Comers        2001            -   676.54
# 9132            SA - 3rd All Comers        2001            -   745.52
# 9133            SA - 3rd All Comers        1999            -   818.24
# 9134            SA - 3rd All Comers        2005            -   841.31

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(men_steeple_3000m['Metric'], ax=ax)
#ax.set_xlim(0, 9)
#ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # 2021 df2

# %%
df2 = df2[df2['Event'].notna()] # take only non-empty rows
df2 = df2.reset_index() # must reset index after filtering

# %%
df2.drop(['Unnamed: 0', 'Unnamed: 12', 'Date of Birth (PDPA)'],axis=1, inplace=True)

# %%
df2
# Out:
#       index                 Date                     Event  \
# 0         0  2021-01-23 00:00:00            Men Pole Vault
# 1         1  2021-01-23 00:00:00  Women Discus Throw (1kg)
# 2         2  2021-01-23 00:00:00  Women Discus Throw (1kg)
# 3         3  2021-01-23 00:00:00    Men Discus Throw (2kg)
# 4         4  2021-01-23 00:00:00    Men Discus Throw (2kg)
# ...     ...                  ...                       ...
# 3905   3905  2021-12-11 00:00:00             Men Long Jump
# 3906   3906  2021-12-11 00:00:00             Men Long Jump
# 3907   3907  2021-12-11 00:00:00             Men Long Jump
# 3908   3908  2021-12-11 00:00:00             Men Long Jump
# 3909   3909  2021-12-11 00:00:00             Men Long Jump
#
#                       Name Age                            Team Result  m/s  \
# 0           Koh, Wei Shien  26  National University of Singapo      4    -
# 1             Phua, Jasmin  20  National University of Singapo  40.31    -
# 2            Teo, Kai Ting  20  National University of Singapo  24.79    -
# 3                Yee, Eric  22  National University of Singapo  46.41    -
# 4               See, Brian  25  National University of Singapo  45.94    -
# ...                    ...  ..                             ...    ...  ...
# 3905             Tan Daryl  20                             TCT   6.07    0
# 3906           Low Patrick  22                             NTU   5.51  0.3
# 3907          Chen Ke Yuan  21                             NTU   5.43    0
# 3908  Hussen Muhammad Aqil  24                             WAC    5.4  1.4
# 3909           Lee Donovan  23                             NTU   5.05    0
#
#                    Competition Year D.O.B.     Info, if any
# 0     SA - Performance Trial 1        1995  Event 101, Open
# 1     SA - Performance Trial 1        2001  Event 102, Open
# 2     SA - Performance Trial 1        2001  Event 102, Open
# 3     SA - Performance Trial 1        1999  Event 103, Open
# 4     SA - Performance Trial 1        1996  Event 103, Open
# ...                        ...         ...              ...
# 3905         Local - Club Zoom        2001                -
# 3906         Local - Club Zoom        1999                -
# 3907         Local - Club Zoom        2000                -
# 3908         Local - Club Zoom        1997                -
# 3909         Local - Club Zoom        1998                -
#
# [3910 rows x 11 columns]

# %%
for i in range(len(df2)):

    try:
        rowIndex = df2.index[i]

        input_string=df2.iloc[rowIndex,2]
        metric=df2.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df2.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with value", metric)
        print("Exiting operation")
        break

# %%
df2
# Out:
#       index                 Date                     Event  \
# 0         0  2021-01-23 00:00:00            Men Pole Vault
# 1         1  2021-01-23 00:00:00  Women Discus Throw (1kg)
# 2         2  2021-01-23 00:00:00  Women Discus Throw (1kg)
# 3         3  2021-01-23 00:00:00    Men Discus Throw (2kg)
# 4         4  2021-01-23 00:00:00    Men Discus Throw (2kg)
# ...     ...                  ...                       ...
# 3905   3905  2021-12-11 00:00:00             Men Long Jump
# 3906   3906  2021-12-11 00:00:00             Men Long Jump
# 3907   3907  2021-12-11 00:00:00             Men Long Jump
# 3908   3908  2021-12-11 00:00:00             Men Long Jump
# 3909   3909  2021-12-11 00:00:00             Men Long Jump
#
#                       Name Age                            Team Result  m/s  \
# 0           Koh, Wei Shien  26  National University of Singapo      4    -
# 1             Phua, Jasmin  20  National University of Singapo  40.31    -
# 2            Teo, Kai Ting  20  National University of Singapo  24.79    -
# 3                Yee, Eric  22  National University of Singapo  46.41    -
# 4               See, Brian  25  National University of Singapo  45.94    -
# ...                    ...  ..                             ...    ...  ...
# 3905             Tan Daryl  20                             TCT   6.07    0
# 3906           Low Patrick  22                             NTU   5.51  0.3
# 3907          Chen Ke Yuan  21                             NTU   5.43    0
# 3908  Hussen Muhammad Aqil  24                             WAC    5.4  1.4
# 3909           Lee Donovan  23                             NTU   5.05    0
#
#                    Competition Year D.O.B.     Info, if any  Metric
# 0     SA - Performance Trial 1        1995  Event 101, Open    4.00
# 1     SA - Performance Trial 1        2001  Event 102, Open   40.31
# 2     SA - Performance Trial 1        2001  Event 102, Open   24.79
# 3     SA - Performance Trial 1        1999  Event 103, Open   46.41
# 4     SA - Performance Trial 1        1996  Event 103, Open   45.94
# ...                        ...         ...              ...     ...
# 3905         Local - Club Zoom        2001                -    6.07
# 3906         Local - Club Zoom        1999                -    5.51
# 3907         Local - Club Zoom        2000                -    5.43
# 3908         Local - Club Zoom        1997                -    5.40
# 3909         Local - Club Zoom        1998                -    5.05
#
# [3910 rows x 12 columns]

# %%
df2.iloc[3391, :]
# Out:
# index                                            3391
# Date                              2021-11-21 00:00:00
# Event                           Women 5 Kilometer Run
# Name                                   Goh, Chui Ling
# Age                                                29
# Team                                       Individual
# Result                                       00:36:28
# m/s                                                HT
# Competition     International - 41e Foulee Venissiane
# Year D.O.B.                                      1992
# Info, if any    SB PB NB, Road Race, Sanctioned,13pos
# Metric                                         2188.0
# Name: 3391, dtype: object

# %%
women_600m_run=df2[(df2['Event']=='Women 600 Meter Run')].copy()

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(women_600m_run['Metric'], ax=ax)
#ax.set_xlim(0, 9)
#ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
women_100m_dash=df2[(df2['Event']=='Women 100 Meter Dash')].copy()

# %%
women_100m_dash.describe()
# Out:
#              index      Metric
# count   221.000000  221.000000
# mean   1413.380090   14.626652
# std    1096.928982    1.806514
# min       8.000000   12.100000
# 25%     401.000000   13.570000
# 50%     981.000000   14.330000
# 75%    1909.000000   15.120000
# max    3799.000000   25.690000

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(women_100m_dash['Metric'], ax=ax)
#ax.set_xlim(0, 9)
#ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # 2020 df3

# %%
df3
# Out:
#            Date                            Event                 Name  Age  \
# 0    2020-01-11                  Women Long Jump  Rozario, Tia Louise   20
# 1    2020-01-11               Men 400 Meter Dash      Zubin Muncherji   23
# 2    2020-01-17               Men 400 Meter Dash      Zubin Muncherji   23
# 3    2020-01-17  Women 60 Meter Hurdles (0.838m)     Nur Izlyn, Zaini   22
# 4    2020-01-18              Women 60 Meter Dash     Nur Izlyn, Zaini   22
# ...         ...                              ...                  ...  ...
# 1163 2020-12-13             Women 400 Meter Dash       Patil, Tanisha   15
# 1164 2020-12-13             Women 1500 Meter Run       Goh, Chui Ling   29
# 1165 2020-12-13             Women 1500 Meter Run       Yap, Joyceleen   20
# 1166 2020-12-13             Women 1500 Meter Run         Yuen Yu, Lee   20
# 1167 2019-01-19                     Men Marathon  Daniel Leow Soon Ye   25
#
#                                 Team   Result     m/s  \
# 0                          Princeton     5.26  Indoor
# 1                 Indiana University    49.36  Indoor
# 2                 Indiana University    49.13  Indoor
# 3                   Georgia Southern        9  Indoor
# 4                   Georgia Southern        8  Indoor
# ...                              ...      ...     ...
# 1163                         Maxform    59.37       -
# 1164            Flash Athletics Club  4:44.09       -
# 1165   National University Singapore  5:15.40       -
# 1166  Singapore Institute of Technol  5:35.51       -
# 1167                      Individual  2:39:49       -
#
#                                             Competition  Year D.O.B.  \
# 0     International - Navy v. Princeton Dual Track &...         2000
# 1            International - Indiana v Tennessee Duals          1997
# 2               International - Vanderbilt Invitational         1997
# 3                      International - Gamecock Opener          1998
# 4                      International - Gamecock Opener          1998
# ...                                                 ...          ...
# 1163                           SA - Performance Trial 2         2005
# 1164                           SA - Performance Trial 2         1991
# 1165                           SA - Performance Trial 2         2000
# 1166                           SA - Performance Trial 2         2000
# 1167                    International - Taipei Marathon         1995
#
#                                            Info, if any Date of Birth (PDPA)  \
# 0                                      5pos, sanctioned                    -
# 1                                6pos final, sanctioned                    -
# 2                               13pos final, sanctioned                    -
# 3                               24pos final, sanctioned                    -
# 4                              21pos prelim, sanctioned                    -
# ...                                                 ...                  ...
# 1163                                               2pos                    -
# 1164                                               1pos                    -
# 1165                                               2pos                    -
# 1166                                               3pos                    -
# 1167  15pos, IAAF certified course, Not Sanctioned b...                    -
#
#      Unnamed: 11
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1163         NaN
# 1164         NaN
# 1165         NaN
# 1166         NaN
# 1167           -
#
# [1168 rows x 12 columns]

# %%
df3 = df3[df3['Event'].notna()] # take only non-empty rows
df3 = df3.reset_index() # must reset index after filtering

# %%
df3.drop(['Unnamed: 11', 'Date of Birth (PDPA)'],axis=1, inplace=True)

# %%
df3
# Out:
#       index       Date                            Event                 Name  \
# 0         0 2020-01-11                  Women Long Jump  Rozario, Tia Louise
# 1         1 2020-01-11               Men 400 Meter Dash      Zubin Muncherji
# 2         2 2020-01-17               Men 400 Meter Dash      Zubin Muncherji
# 3         3 2020-01-17  Women 60 Meter Hurdles (0.838m)     Nur Izlyn, Zaini
# 4         4 2020-01-18              Women 60 Meter Dash     Nur Izlyn, Zaini
# ...     ...        ...                              ...                  ...
# 1163   1163 2020-12-13             Women 400 Meter Dash       Patil, Tanisha
# 1164   1164 2020-12-13             Women 1500 Meter Run       Goh, Chui Ling
# 1165   1165 2020-12-13             Women 1500 Meter Run       Yap, Joyceleen
# 1166   1166 2020-12-13             Women 1500 Meter Run         Yuen Yu, Lee
# 1167   1167 2019-01-19                     Men Marathon  Daniel Leow Soon Ye
#
#       Age                            Team   Result     m/s  \
# 0      20                       Princeton     5.26  Indoor
# 1      23              Indiana University    49.36  Indoor
# 2      23              Indiana University    49.13  Indoor
# 3      22                Georgia Southern        9  Indoor
# 4      22                Georgia Southern        8  Indoor
# ...   ...                             ...      ...     ...
# 1163   15                         Maxform    59.37       -
# 1164   29            Flash Athletics Club  4:44.09       -
# 1165   20   National University Singapore  5:15.40       -
# 1166   20  Singapore Institute of Technol  5:35.51       -
# 1167   25                      Individual  2:39:49       -
#
#                                             Competition  Year D.O.B.  \
# 0     International - Navy v. Princeton Dual Track &...         2000
# 1            International - Indiana v Tennessee Duals          1997
# 2               International - Vanderbilt Invitational         1997
# 3                      International - Gamecock Opener          1998
# 4                      International - Gamecock Opener          1998
# ...                                                 ...          ...
# 1163                           SA - Performance Trial 2         2005
# 1164                           SA - Performance Trial 2         1991
# 1165                           SA - Performance Trial 2         2000
# 1166                           SA - Performance Trial 2         2000
# 1167                    International - Taipei Marathon         1995
#
#                                            Info, if any
# 0                                      5pos, sanctioned
# 1                                6pos final, sanctioned
# 2                               13pos final, sanctioned
# 3                               24pos final, sanctioned
# 4                              21pos prelim, sanctioned
# ...                                                 ...
# 1163                                               2pos
# 1164                                               1pos
# 1165                                               2pos
# 1166                                               3pos
# 1167  15pos, IAAF certified course, Not Sanctioned b...
#
# [1168 rows x 11 columns]

# %%
for i in range(len(df3)):

    try:
        rowIndex = df3.index[i]

        input_string = df3.iloc[rowIndex, 2]
        metric = df3.iloc[rowIndex, 6]

        out = preprocess(i, input_string, metric)

        df3.loc[rowIndex, 'Metric'] = out

    except:

        print("Unknown input format encountered at row", i, "with value",
              metric)
        print("Exiting operation")
        break

# %%
df3
# Out:
#       index       Date                            Event                 Name  \
# 0         0 2020-01-11                  Women Long Jump  Rozario, Tia Louise
# 1         1 2020-01-11               Men 400 Meter Dash      Zubin Muncherji
# 2         2 2020-01-17               Men 400 Meter Dash      Zubin Muncherji
# 3         3 2020-01-17  Women 60 Meter Hurdles (0.838m)     Nur Izlyn, Zaini
# 4         4 2020-01-18              Women 60 Meter Dash     Nur Izlyn, Zaini
# ...     ...        ...                              ...                  ...
# 1163   1163 2020-12-13             Women 400 Meter Dash       Patil, Tanisha
# 1164   1164 2020-12-13             Women 1500 Meter Run       Goh, Chui Ling
# 1165   1165 2020-12-13             Women 1500 Meter Run       Yap, Joyceleen
# 1166   1166 2020-12-13             Women 1500 Meter Run         Yuen Yu, Lee
# 1167   1167 2019-01-19                     Men Marathon  Daniel Leow Soon Ye
#
#       Age                            Team   Result     m/s  \
# 0      20                       Princeton     5.26  Indoor
# 1      23              Indiana University    49.36  Indoor
# 2      23              Indiana University    49.13  Indoor
# 3      22                Georgia Southern        9  Indoor
# 4      22                Georgia Southern        8  Indoor
# ...   ...                             ...      ...     ...
# 1163   15                         Maxform    59.37       -
# 1164   29            Flash Athletics Club  4:44.09       -
# 1165   20   National University Singapore  5:15.40       -
# 1166   20  Singapore Institute of Technol  5:35.51       -
# 1167   25                      Individual  2:39:49       -
#
#                                             Competition  Year D.O.B.  \
# 0     International - Navy v. Princeton Dual Track &...         2000
# 1            International - Indiana v Tennessee Duals          1997
# 2               International - Vanderbilt Invitational         1997
# 3                      International - Gamecock Opener          1998
# 4                      International - Gamecock Opener          1998
# ...                                                 ...          ...
# 1163                           SA - Performance Trial 2         2005
# 1164                           SA - Performance Trial 2         1991
# 1165                           SA - Performance Trial 2         2000
# 1166                           SA - Performance Trial 2         2000
# 1167                    International - Taipei Marathon         1995
#
#                                            Info, if any   Metric
# 0                                      5pos, sanctioned     5.26
# 1                                6pos final, sanctioned    49.36
# 2                               13pos final, sanctioned    49.13
# 3                               24pos final, sanctioned     9.00
# 4                              21pos prelim, sanctioned     8.00
# ...                                                 ...      ...
# 1163                                               2pos    59.37
# 1164                                               1pos   284.09
# 1165                                               2pos   315.40
# 1166                                               3pos   335.51
# 1167  15pos, IAAF certified course, Not Sanctioned b...  9589.00
#
# [1168 rows x 12 columns]

# %% [markdown]
# # 2019 df4

# %%
df4
# Out:
#             Date                       Event                    Name Age  \
# 0     2019-01-01   Men 5 Kilometer Race Walk       Zuosheng Jean Yeo  18
# 1     2019-01-12   Men 10000 Meter Race Walk       Back, Peter James  53
# 2     2019-01-12   Men 10000 Meter Race Walk          Boon Huat, Lim  47
# 3     2019-01-12  Women 5000 Meter Race Walk           Ying, Eleanor  18
# 4     2019-01-12  Women 5000 Meter Race Walk        Whang, Chia Ning  18
# ...          ...                         ...                     ...  ..
# 15022 2019-03-29       Men 4x400 Meter Relay     ANG JUN KAI PRESTON   -
# 15023 2019-03-29       Men 4x400 Meter Relay    BRYAN CHEUNG JIA JIE   -
# 15024 2019-03-29       Men 4x400 Meter Relay   ADRIEL KUA BENG LEONG   -
# 15025 2019-03-29       Men 4x400 Meter Relay  ADAM MUKHAIR BIN AZLAN   -
# 15026 2019-03-29       Men 4x400 Meter Relay     BRENDAN KESUMA KWEE   -
#
#                         Team      Result m/s  \
# 0                 Individual    00:52:03   -
# 1       Red Hawk Sports Club  1:10:47.16   -
# 2       Red Hawk Sports Club  1:14:47.04   -
# 3      Hwa Chong Institution    32:02.40   -
# 4      Hwa Chong Institution    36:24.98   -
# ...                      ...         ...  ..
# 15022                     CH     4:00.05   -
# 15023                 ACS(I)     4:00.27   -
# 15024                    MSH     4:00.93   -
# 15025                    SJI     4:01.62   -
# 15026                     TK     4:12.70   -
#
#                                    Competition Year D.O.B.  \
# 0               International - The First Walk        2001
# 1      SA - Age-Group Race Walking Competition        1966
# 2      SA - Age-Group Race Walking Competition        1972
# 3      SA - Age-Group Race Walking Competition        2001
# 4      SA - Age-Group Race Walking Competition        2001
# ...                                        ...         ...
# 15022                 Local - National Schools           -
# 15023                 Local - National Schools           -
# 15024                 Local - National Schools           -
# 15025                 Local - National Schools           -
# 15026                 Local - National Schools           -
#
#                                     Info, if any Unnamed: 10 Unnamed: 11
# 0                                     Held in HK           -           -
# 1                                           Open           -           -
# 2                                           Open           -           -
# 3                                            U20           -           -
# 4                                            U20           -           -
# ...                                          ...         ...         ...
# 15022  Session 1519, Final, U15, C DIVISION BOYS           -           -
# 15023  Session 1519, Final, U15, C DIVISION BOYS           -           -
# 15024  Session 1519, Final, U15, C DIVISION BOYS           -           -
# 15025  Session 1519, Final, U15, C DIVISION BOYS           -           -
# 15026  Session 1519, Final, U15, C DIVISION BOYS           -           -
#
# [15027 rows x 12 columns]

# %%
df4 = df4[df4['Event'].notna()] # take only non-empty rows
df4 = df4.reset_index(drop=True) # must reset index after filtering

# %%
df4.drop(['Unnamed: 10', 'Unnamed: 11'],axis=1, inplace=True)

# %%
df4
# Out:
#             Date                       Event                    Name Age  \
# 0     2019-01-01   Men 5 Kilometer Race Walk       Zuosheng Jean Yeo  18
# 1     2019-01-12   Men 10000 Meter Race Walk       Back, Peter James  53
# 2     2019-01-12   Men 10000 Meter Race Walk          Boon Huat, Lim  47
# 3     2019-01-12  Women 5000 Meter Race Walk           Ying, Eleanor  18
# 4     2019-01-12  Women 5000 Meter Race Walk        Whang, Chia Ning  18
# ...          ...                         ...                     ...  ..
# 15022 2019-03-29       Men 4x400 Meter Relay     ANG JUN KAI PRESTON   -
# 15023 2019-03-29       Men 4x400 Meter Relay    BRYAN CHEUNG JIA JIE   -
# 15024 2019-03-29       Men 4x400 Meter Relay   ADRIEL KUA BENG LEONG   -
# 15025 2019-03-29       Men 4x400 Meter Relay  ADAM MUKHAIR BIN AZLAN   -
# 15026 2019-03-29       Men 4x400 Meter Relay     BRENDAN KESUMA KWEE   -
#
#                         Team      Result m/s  \
# 0                 Individual    00:52:03   -
# 1       Red Hawk Sports Club  1:10:47.16   -
# 2       Red Hawk Sports Club  1:14:47.04   -
# 3      Hwa Chong Institution    32:02.40   -
# 4      Hwa Chong Institution    36:24.98   -
# ...                      ...         ...  ..
# 15022                     CH     4:00.05   -
# 15023                 ACS(I)     4:00.27   -
# 15024                    MSH     4:00.93   -
# 15025                    SJI     4:01.62   -
# 15026                     TK     4:12.70   -
#
#                                    Competition Year D.O.B.  \
# 0               International - The First Walk        2001
# 1      SA - Age-Group Race Walking Competition        1966
# 2      SA - Age-Group Race Walking Competition        1972
# 3      SA - Age-Group Race Walking Competition        2001
# 4      SA - Age-Group Race Walking Competition        2001
# ...                                        ...         ...
# 15022                 Local - National Schools           -
# 15023                 Local - National Schools           -
# 15024                 Local - National Schools           -
# 15025                 Local - National Schools           -
# 15026                 Local - National Schools           -
#
#                                     Info, if any
# 0                                     Held in HK
# 1                                           Open
# 2                                           Open
# 3                                            U20
# 4                                            U20
# ...                                          ...
# 15022  Session 1519, Final, U15, C DIVISION BOYS
# 15023  Session 1519, Final, U15, C DIVISION BOYS
# 15024  Session 1519, Final, U15, C DIVISION BOYS
# 15025  Session 1519, Final, U15, C DIVISION BOYS
# 15026  Session 1519, Final, U15, C DIVISION BOYS
#
# [15027 rows x 10 columns]

# %%
for i in range(len(df4)):

    try:
        rowIndex = df4.index[i]

        input_string=df4.iloc[rowIndex,1]
        metric=df4.iloc[rowIndex,5]
        
        out = preprocess(i, input_string, metric)
                    
        df4.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with value", metric)
        print("Exiting operation")
        break
# Out:
# 3:49.90 3 49.90 229.9 here

# %%
df4
# Out:
#             Date                       Event                    Name Age  \
# 0     2019-01-01   Men 5 Kilometer Race Walk       Zuosheng Jean Yeo  18
# 1     2019-01-12   Men 10000 Meter Race Walk       Back, Peter James  53
# 2     2019-01-12   Men 10000 Meter Race Walk          Boon Huat, Lim  47
# 3     2019-01-12  Women 5000 Meter Race Walk           Ying, Eleanor  18
# 4     2019-01-12  Women 5000 Meter Race Walk        Whang, Chia Ning  18
# ...          ...                         ...                     ...  ..
# 15022 2019-03-29       Men 4x400 Meter Relay     ANG JUN KAI PRESTON   -
# 15023 2019-03-29       Men 4x400 Meter Relay    BRYAN CHEUNG JIA JIE   -
# 15024 2019-03-29       Men 4x400 Meter Relay   ADRIEL KUA BENG LEONG   -
# 15025 2019-03-29       Men 4x400 Meter Relay  ADAM MUKHAIR BIN AZLAN   -
# 15026 2019-03-29       Men 4x400 Meter Relay     BRENDAN KESUMA KWEE   -
#
#                         Team      Result m/s  \
# 0                 Individual    00:52:03   -
# 1       Red Hawk Sports Club  1:10:47.16   -
# 2       Red Hawk Sports Club  1:14:47.04   -
# 3      Hwa Chong Institution    32:02.40   -
# 4      Hwa Chong Institution    36:24.98   -
# ...                      ...         ...  ..
# 15022                     CH     4:00.05   -
# 15023                 ACS(I)     4:00.27   -
# 15024                    MSH     4:00.93   -
# 15025                    SJI     4:01.62   -
# 15026                     TK     4:12.70   -
#
#                                    Competition Year D.O.B.  \
# 0               International - The First Walk        2001
# 1      SA - Age-Group Race Walking Competition        1966
# 2      SA - Age-Group Race Walking Competition        1972
# 3      SA - Age-Group Race Walking Competition        2001
# 4      SA - Age-Group Race Walking Competition        2001
# ...                                        ...         ...
# 15022                 Local - National Schools           -
# 15023                 Local - National Schools           -
# 15024                 Local - National Schools           -
# 15025                 Local - National Schools           -
# 15026                 Local - National Schools           -
#
#                                     Info, if any   Metric
# 0                                     Held in HK  3123.00
# 1                                           Open  3123.00
# 2                                           Open  3123.00
# 3                                            U20  1922.40
# 4                                            U20  2184.98
# ...                                          ...      ...
# 15022  Session 1519, Final, U15, C DIVISION BOYS   240.05
# 15023  Session 1519, Final, U15, C DIVISION BOYS   240.27
# 15024  Session 1519, Final, U15, C DIVISION BOYS   240.93
# 15025  Session 1519, Final, U15, C DIVISION BOYS   241.62
# 15026  Session 1519, Final, U15, C DIVISION BOYS   252.70
#
# [15027 rows x 11 columns]

# %%
women_100m_dash_2019=df4[(df4['Event']=='Women 100 Meter Dash')].copy()

# %%
women_100m_dash_2019
# Out:
#             Date                 Event                         Name Age  \
# 82    2019-01-05  Women 100 Meter Dash     Ortega, Samantha Theresa  14
# 83    2019-01-05  Women 100 Meter Dash             ., Zhong Chu Han  14
# 84    2019-01-05  Women 100 Meter Dash  Alethea Gledhill, Gabrielle  14
# 85    2019-01-05  Women 100 Meter Dash          SI Teng, Laura Wong  14
# 86    2019-01-05  Women 100 Meter Dash          YI Han, Ashley, Tan  14
# ...          ...                   ...                          ...  ..
# 14872 2019-03-29  Women 100 Meter Dash           CAMILLE ALIX DAMAS  18
# 14873 2019-03-29  Women 100 Meter Dash         ASHLEIGH SONIA HAZRA  18
# 14874 2019-03-29  Women 100 Meter Dash          LIM XIN YU CLARISSA  18
# 14875 2019-03-29  Women 100 Meter Dash                   LIN PEIQIN  18
# 14876 2019-03-29  Women 100 Meter Dash    CHLOE VANESSA SEA WEN MIN   -
#
#                                Team Result  m/s                 Competition  \
# 82          SINGAPORE SPORTS SCHOOL   13.4 -2.1  SA - School Meet Episode 1
# 83        NANYANG GIRLS HIGH SCHOOL  13.94    0  SA - School Meet Episode 1
# 84     CEDAR GIRLS SECONDARY SCHOOL   14.3  0.1  SA - School Meet Episode 1
# 85         CHIJ ST. NICHOLAS GIRLS'  14.34 -0.9  SA - School Meet Episode 1
# 86     CEDAR GIRLS SECONDARY SCHOOL  14.54 -0.9  SA - School Meet Episode 1
# ...                             ...    ...  ...                         ...
# 14872                      ACS(INT)  13.12  0.2    Local - National Schools
# 14873                          SAJC  13.13  0.2    Local - National Schools
# 14874                           NJC  13.14  0.2    Local - National Schools
# 14875                           VJC  13.41  0.2    Local - National Schools
# 14876                           CJC  13.45  0.2    Local - National Schools
#
#       Year D.O.B.                                Info, if any  Metric
# 82           2005                                       C Div   13.40
# 83           2005                                       C Div   13.94
# 84           2005                                       C Div   14.30
# 85           2005                                       C Div   14.34
# 86           2005                                       C Div   14.54
# ...           ...                                         ...     ...
# 14872        2001  Session 1504, Final, U21, A DIVISION GIRLS   13.12
# 14873        2001  Session 1504, Final, U21, A DIVISION GIRLS   13.13
# 14874        2001  Session 1504, Final, U21, A DIVISION GIRLS   13.14
# 14875        2001  Session 1504, Final, U21, A DIVISION GIRLS   13.41
# 14876           -  Session 1504, Final, U21, A DIVISION GIRLS   13.45
#
# [1105 rows x 11 columns]

# %% [markdown]
# # 2018 df5

# %%
df5
# Out:
#             Date                  Event                            Name Age  \
# 0     2018-01-14        Men Triple Jump                Azhar, Arfan Bin  17
# 1     2018-01-14        Men Triple Jump           Medina, Andrew George  16
# 2     2018-01-14        Men Triple Jump               Wong, U Fai Dylan  20
# 3     2018-01-14        Men Triple Jump            Lim, Yan Hng Chervin  17
# 4     2018-01-14        Men Triple Jump           Teo, Wei Sheng Xavier  18
# ...          ...                    ...                             ...  ..
# 15223 2018-11-24  Men 4x400 Meter Relay             NANYANG POLYTECHNIC   -
# 15224 2018-11-24  Men 4x400 Meter Relay            NGEE ANN POLYTECHNIC   -
# 15225 2018-11-24  Men 4x400 Meter Relay           SINGAPORE POLYTECHNIC   -
# 15226 2018-11-24  Men 4x400 Meter Relay            REPUBLIC POLYTECHNIC   -
# 15227 2018-11-24  Men 4x400 Meter Relay  INSTITUTE OF TECHNICAL EDUCATI   -
#
#                                  Team   Result  m/s      Competition  \
# 0             SINGAPORE SPORTS SCHOOL    13.38    0    SA - Series 1
# 1             SINGAPORE SPORTS SCHOOL    13.08 -1.1    SA - Series 1
# 2             SINGAPORE SPORTS SCHOOL    12.56 -1.8    SA - Series 1
# 3             NATIONAL JUNIOR COLLEGE    11.55 -0.9    SA - Series 1
# 4                                ACSI    11.03 -2.1    SA - Series 1
# ...                               ...      ...  ...              ...
# 15223             NANYANG POLYTECHNIC  3:35.73    -  Local - POL-ITE
# 15224            NGEE ANN POLYTECHNIC  3:37.84    -  Local - POL-ITE
# 15225           SINGAPORE POLYTECHNIC  3:41.31    -  Local - POL-ITE
# 15226            REPUBLIC POLYTECHNIC  3:41.60    -  Local - POL-ITE
# 15227  INSTITUTE OF TECHNICAL EDUCATI  3:43.09    -  Local - POL-ITE
#
#       Year D.O.B. Info, if any
# 0            2001            -
# 1            2002            -
# 2            1998            -
# 3            2001            -
# 4            2000            -
# ...           ...          ...
# 15223           -            -
# 15224           -            -
# 15225           -            -
# 15226           -            -
# 15227           -            -
#
# [15228 rows x 10 columns]

# %%
df5 = df5[df5['Event'].notna()] # take only non-empty rows

# %%
df5
# Out:
#             Date                  Event                            Name Age  \
# 0     2018-01-14        Men Triple Jump                Azhar, Arfan Bin  17
# 1     2018-01-14        Men Triple Jump           Medina, Andrew George  16
# 2     2018-01-14        Men Triple Jump               Wong, U Fai Dylan  20
# 3     2018-01-14        Men Triple Jump            Lim, Yan Hng Chervin  17
# 4     2018-01-14        Men Triple Jump           Teo, Wei Sheng Xavier  18
# ...          ...                    ...                             ...  ..
# 15223 2018-11-24  Men 4x400 Meter Relay             NANYANG POLYTECHNIC   -
# 15224 2018-11-24  Men 4x400 Meter Relay            NGEE ANN POLYTECHNIC   -
# 15225 2018-11-24  Men 4x400 Meter Relay           SINGAPORE POLYTECHNIC   -
# 15226 2018-11-24  Men 4x400 Meter Relay            REPUBLIC POLYTECHNIC   -
# 15227 2018-11-24  Men 4x400 Meter Relay  INSTITUTE OF TECHNICAL EDUCATI   -
#
#                                  Team   Result  m/s      Competition  \
# 0             SINGAPORE SPORTS SCHOOL    13.38    0    SA - Series 1
# 1             SINGAPORE SPORTS SCHOOL    13.08 -1.1    SA - Series 1
# 2             SINGAPORE SPORTS SCHOOL    12.56 -1.8    SA - Series 1
# 3             NATIONAL JUNIOR COLLEGE    11.55 -0.9    SA - Series 1
# 4                                ACSI    11.03 -2.1    SA - Series 1
# ...                               ...      ...  ...              ...
# 15223             NANYANG POLYTECHNIC  3:35.73    -  Local - POL-ITE
# 15224            NGEE ANN POLYTECHNIC  3:37.84    -  Local - POL-ITE
# 15225           SINGAPORE POLYTECHNIC  3:41.31    -  Local - POL-ITE
# 15226            REPUBLIC POLYTECHNIC  3:41.60    -  Local - POL-ITE
# 15227  INSTITUTE OF TECHNICAL EDUCATI  3:43.09    -  Local - POL-ITE
#
#       Year D.O.B. Info, if any
# 0            2001            -
# 1            2002            -
# 2            1998            -
# 3            2001            -
# 4            2000            -
# ...           ...          ...
# 15223           -            -
# 15224           -            -
# 15225           -            -
# 15226           -            -
# 15227           -            -
#
# [15228 rows x 10 columns]

# %%
df5.drop(df5[df5['Result'] == 'DNS'].index, inplace = True)
df5 = df5.reset_index() # must reset index after filtering

# %%
for i in range(len(df5)):

    try:
        
        rowIndex = df5.index[i]

        input_string=df5.iloc[rowIndex,2]
        metric=df5.iloc[rowIndex,6]
                                
        out = preprocess(i, input_string, metric)
    
        df5.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df5
# Out:
#        index       Date                  Event  \
# 0          0 2018-01-14        Men Triple Jump
# 1          1 2018-01-14        Men Triple Jump
# 2          2 2018-01-14        Men Triple Jump
# 3          3 2018-01-14        Men Triple Jump
# 4          4 2018-01-14        Men Triple Jump
# ...      ...        ...                    ...
# 15222  15223 2018-11-24  Men 4x400 Meter Relay
# 15223  15224 2018-11-24  Men 4x400 Meter Relay
# 15224  15225 2018-11-24  Men 4x400 Meter Relay
# 15225  15226 2018-11-24  Men 4x400 Meter Relay
# 15226  15227 2018-11-24  Men 4x400 Meter Relay
#
#                                  Name Age                            Team  \
# 0                    Azhar, Arfan Bin  17         SINGAPORE SPORTS SCHOOL
# 1               Medina, Andrew George  16         SINGAPORE SPORTS SCHOOL
# 2                   Wong, U Fai Dylan  20         SINGAPORE SPORTS SCHOOL
# 3                Lim, Yan Hng Chervin  17         NATIONAL JUNIOR COLLEGE
# 4               Teo, Wei Sheng Xavier  18                            ACSI
# ...                               ...  ..                             ...
# 15222             NANYANG POLYTECHNIC   -             NANYANG POLYTECHNIC
# 15223            NGEE ANN POLYTECHNIC   -            NGEE ANN POLYTECHNIC
# 15224           SINGAPORE POLYTECHNIC   -           SINGAPORE POLYTECHNIC
# 15225            REPUBLIC POLYTECHNIC   -            REPUBLIC POLYTECHNIC
# 15226  INSTITUTE OF TECHNICAL EDUCATI   -  INSTITUTE OF TECHNICAL EDUCATI
#
#         Result  m/s      Competition Year D.O.B. Info, if any  Metric
# 0        13.38    0    SA - Series 1        2001            -   13.38
# 1        13.08 -1.1    SA - Series 1        2002            -   13.08
# 2        12.56 -1.8    SA - Series 1        1998            -   12.56
# 3        11.55 -0.9    SA - Series 1        2001            -   11.55
# 4        11.03 -2.1    SA - Series 1        2000            -   11.03
# ...        ...  ...              ...         ...          ...     ...
# 15222  3:35.73    -  Local - POL-ITE           -            -  215.73
# 15223  3:37.84    -  Local - POL-ITE           -            -  217.84
# 15224  3:41.31    -  Local - POL-ITE           -            -  221.31
# 15225  3:41.60    -  Local - POL-ITE           -            -  221.60
# 15226  3:43.09    -  Local - POL-ITE           -            -  223.09
#
# [15227 rows x 12 columns]

# %% [markdown]
# # 2017 df6

# %%
df6
# Out:
#             Date                         Event             Name Age  \
# 0     2017-03-19             Men 60 Meter Dash     Lawrence Wee   -
# 1     2017-03-19             Men 60 Meter Dash   Richard Mather   -
# 2     2017-03-19             Men 60 Meter Dash     Tan Yew Yong   -
# 3     2017-03-19             Men 60 Meter Dash    Radwan Jaafar   -
# 4     2017-03-19             Men 60 Meter Dash  Chin Khen Theen   -
# ...          ...                           ...              ...  ..
# 13559 2017-08-13  Women 10 Kilometer Race Walk       Wu Xin Yao   -
# 13560 2017-08-13  Women 10 Kilometer Race Walk         Chua Min   -
# 13561 2017-08-13  Women 10 Kilometer Race Walk     Chen Li Tong   -
# 13562 2017-08-13  Women 10 Kilometer Race Walk     Allison Ting   -
# 13563 2017-10-29                Women Marathon      Serena Teoh  31
#
#                                 Team   Result     m/s  \
# 0                          Singapore     7.62  Indoor
# 1                          Singapore     7.66  Indoor
# 2                          Singapore     7.77  Indoor
# 3                          Singapore     7.84  Indoor
# 4                          Singapore     7.89  Indoor
# ...                              ...      ...     ...
# 13559  Hwa Chong Institution College    58:18       -
# 13560  Hwa Chong Institution College  1:12:51       -
# 13561  Hwa Chong Institution College  1:14:00       -
# 13562  Hwa Chong Institution College  1:17:21       -
# 13563                     Individual  3:01:50       -
#
#                                              Competition Year D.O.B.  \
# 0      International - World Masters Athletics Indoor...           -
# 1      International - World Masters Athletics Indoor...           -
# 2      International - World Masters Athletics Indoor...           -
# 3      International - World Masters Athletics Indoor...           -
# 4      International - World Masters Athletics Indoor...           -
# ...                                                  ...         ...
# 13559                                  SA - Majulah Walk           -
# 13560                                  SA - Majulah Walk           -
# 13561                                  SA - Majulah Walk           -
# 13562                                  SA - Majulah Walk           -
# 13563                 International - Frankfurt Marathon        1986
#
#       Info, if any
# 0                -
# 1                -
# 2                -
# 3                -
# 4                -
# ...            ...
# 13559            -
# 13560            -
# 13561            -
# 13562            -
# 13563            -
#
# [13564 rows x 10 columns]

# %%
df6 = df6[df6['Event'].notna()] # take only non-empty rows
df6 = df6.reset_index() # must reset index after filtering

# %%
df6
# Out:
#        index       Date                         Event             Name Age  \
# 0          0 2017-03-19             Men 60 Meter Dash     Lawrence Wee   -
# 1          1 2017-03-19             Men 60 Meter Dash   Richard Mather   -
# 2          2 2017-03-19             Men 60 Meter Dash     Tan Yew Yong   -
# 3          3 2017-03-19             Men 60 Meter Dash    Radwan Jaafar   -
# 4          4 2017-03-19             Men 60 Meter Dash  Chin Khen Theen   -
# ...      ...        ...                           ...              ...  ..
# 13559  13559 2017-08-13  Women 10 Kilometer Race Walk       Wu Xin Yao   -
# 13560  13560 2017-08-13  Women 10 Kilometer Race Walk         Chua Min   -
# 13561  13561 2017-08-13  Women 10 Kilometer Race Walk     Chen Li Tong   -
# 13562  13562 2017-08-13  Women 10 Kilometer Race Walk     Allison Ting   -
# 13563  13563 2017-10-29                Women Marathon      Serena Teoh  31
#
#                                 Team   Result     m/s  \
# 0                          Singapore     7.62  Indoor
# 1                          Singapore     7.66  Indoor
# 2                          Singapore     7.77  Indoor
# 3                          Singapore     7.84  Indoor
# 4                          Singapore     7.89  Indoor
# ...                              ...      ...     ...
# 13559  Hwa Chong Institution College    58:18       -
# 13560  Hwa Chong Institution College  1:12:51       -
# 13561  Hwa Chong Institution College  1:14:00       -
# 13562  Hwa Chong Institution College  1:17:21       -
# 13563                     Individual  3:01:50       -
#
#                                              Competition Year D.O.B.  \
# 0      International - World Masters Athletics Indoor...           -
# 1      International - World Masters Athletics Indoor...           -
# 2      International - World Masters Athletics Indoor...           -
# 3      International - World Masters Athletics Indoor...           -
# 4      International - World Masters Athletics Indoor...           -
# ...                                                  ...         ...
# 13559                                  SA - Majulah Walk           -
# 13560                                  SA - Majulah Walk           -
# 13561                                  SA - Majulah Walk           -
# 13562                                  SA - Majulah Walk           -
# 13563                 International - Frankfurt Marathon        1986
#
#       Info, if any
# 0                -
# 1                -
# 2                -
# 3                -
# 4                -
# ...            ...
# 13559            -
# 13560            -
# 13561            -
# 13562            -
# 13563            -
#
# [13564 rows x 11 columns]

# %%
for i in range(len(df6)):

    try:
        rowIndex = df6.index[i]

        input_string=df6.iloc[rowIndex,2]
        metric=df6.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df6.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df6
# Out:
#        index       Date                         Event             Name Age  \
# 0          0 2017-03-19             Men 60 Meter Dash     Lawrence Wee   -
# 1          1 2017-03-19             Men 60 Meter Dash   Richard Mather   -
# 2          2 2017-03-19             Men 60 Meter Dash     Tan Yew Yong   -
# 3          3 2017-03-19             Men 60 Meter Dash    Radwan Jaafar   -
# 4          4 2017-03-19             Men 60 Meter Dash  Chin Khen Theen   -
# ...      ...        ...                           ...              ...  ..
# 13559  13559 2017-08-13  Women 10 Kilometer Race Walk       Wu Xin Yao   -
# 13560  13560 2017-08-13  Women 10 Kilometer Race Walk         Chua Min   -
# 13561  13561 2017-08-13  Women 10 Kilometer Race Walk     Chen Li Tong   -
# 13562  13562 2017-08-13  Women 10 Kilometer Race Walk     Allison Ting   -
# 13563  13563 2017-10-29                Women Marathon      Serena Teoh  31
#
#                                 Team   Result     m/s  \
# 0                          Singapore     7.62  Indoor
# 1                          Singapore     7.66  Indoor
# 2                          Singapore     7.77  Indoor
# 3                          Singapore     7.84  Indoor
# 4                          Singapore     7.89  Indoor
# ...                              ...      ...     ...
# 13559  Hwa Chong Institution College    58:18       -
# 13560  Hwa Chong Institution College  1:12:51       -
# 13561  Hwa Chong Institution College  1:14:00       -
# 13562  Hwa Chong Institution College  1:17:21       -
# 13563                     Individual  3:01:50       -
#
#                                              Competition Year D.O.B.  \
# 0      International - World Masters Athletics Indoor...           -
# 1      International - World Masters Athletics Indoor...           -
# 2      International - World Masters Athletics Indoor...           -
# 3      International - World Masters Athletics Indoor...           -
# 4      International - World Masters Athletics Indoor...           -
# ...                                                  ...         ...
# 13559                                  SA - Majulah Walk           -
# 13560                                  SA - Majulah Walk           -
# 13561                                  SA - Majulah Walk           -
# 13562                                  SA - Majulah Walk           -
# 13563                 International - Frankfurt Marathon        1986
#
#       Info, if any    Metric
# 0                -      7.62
# 1                -      7.66
# 2                -      7.77
# 3                -      7.84
# 4                -      7.89
# ...            ...       ...
# 13559            -   4768.00
# 13560            -   4371.00
# 13561            -   4440.00
# 13562            -   4641.00
# 13563            -  10910.00
#
# [13564 rows x 12 columns]

# %% [markdown]
# # 2016 df7

# %%
df7
# Out:
#             Date              Event                        Name Age  \
# 0     2016-01-30  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 1     2016-01-30  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 2     2016-02-19  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 3     2016-01-23  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 4     2016-01-23  Men 60 Meter Dash        Kang Li Loong Calvin  26
# ...          ...                ...                         ...  ..
# 13479 2016-07-06  Women Triple Jump   Bte Azman, Alya Syarafina  19
# 13480 2016-03-20  Women Triple Jump  Christy Robyn Su-Ann, Chng  13
# 13481 2016-02-20  Women Triple Jump             Koh, Boon Hsuan  16
# 13482 2016-02-20  Women Triple Jump               Chew, Rachael  15
# 13483 2016-03-20  Women Triple Jump         Ann Shyann Wai, Lee  13
#
#                              Team Result  m/s  \
# 0                      Individual   6.77  0.3
# 1                      Individual   6.77  0.5
# 2                     Tean S'pore   6.77    0
# 3                      Individual   6.78    3
# 4                      Individual   6.79  2.3
# ...                           ...    ...  ...
# 13479         Nanyang Polytechnic   8.99    3
# 13480  Nanyang Girls' High School   8.78  NWI
# 13481     National Junior College   8.77  NWI
# 13482  Nanyang Girls' High School   8.75  NWI
# 13483  Nanyang Girls' High School   8.67  NWI
#
#                               Competition Year D.O.B.          Info, if any
# 0      International - Asian Indoor Trial        1990                     -
# 1      International - Asian Indoor Trial        1990                     -
# 2            International - Asian Indoor        1990  3/8pos q Equal SB PB
# 3                           SA - Series 1        1990                     -
# 4                           SA - Series 1        1990                     -
# ...                                   ...         ...                   ...
# 13479    Local - Singapore National Games        1997                     -
# 13480                SA - U18 U20 C'ships        2003                     -
# 13481                       SA - Series 2        2000                     -
# 13482                       SA - Series 2        2001                     -
# 13483                SA - U18 U20 C'ships        2003                     -
#
# [13484 rows x 10 columns]

# %%
df7 = df7[df7['Event'].notna()] # take only non-empty rows
df7 = df7.reset_index() # must reset index after filtering

# %%
df7
# Out:
#        index       Date              Event                        Name Age  \
# 0          0 2016-01-30  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 1          1 2016-01-30  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 2          2 2016-02-19  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 3          3 2016-01-23  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 4          4 2016-01-23  Men 60 Meter Dash        Kang Li Loong Calvin  26
# ...      ...        ...                ...                         ...  ..
# 13479  13479 2016-07-06  Women Triple Jump   Bte Azman, Alya Syarafina  19
# 13480  13480 2016-03-20  Women Triple Jump  Christy Robyn Su-Ann, Chng  13
# 13481  13481 2016-02-20  Women Triple Jump             Koh, Boon Hsuan  16
# 13482  13482 2016-02-20  Women Triple Jump               Chew, Rachael  15
# 13483  13483 2016-03-20  Women Triple Jump         Ann Shyann Wai, Lee  13
#
#                              Team Result  m/s  \
# 0                      Individual   6.77  0.3
# 1                      Individual   6.77  0.5
# 2                     Tean S'pore   6.77    0
# 3                      Individual   6.78    3
# 4                      Individual   6.79  2.3
# ...                           ...    ...  ...
# 13479         Nanyang Polytechnic   8.99    3
# 13480  Nanyang Girls' High School   8.78  NWI
# 13481     National Junior College   8.77  NWI
# 13482  Nanyang Girls' High School   8.75  NWI
# 13483  Nanyang Girls' High School   8.67  NWI
#
#                               Competition Year D.O.B.          Info, if any
# 0      International - Asian Indoor Trial        1990                     -
# 1      International - Asian Indoor Trial        1990                     -
# 2            International - Asian Indoor        1990  3/8pos q Equal SB PB
# 3                           SA - Series 1        1990                     -
# 4                           SA - Series 1        1990                     -
# ...                                   ...         ...                   ...
# 13479    Local - Singapore National Games        1997                     -
# 13480                SA - U18 U20 C'ships        2003                     -
# 13481                       SA - Series 2        2000                     -
# 13482                       SA - Series 2        2001                     -
# 13483                SA - U18 U20 C'ships        2003                     -
#
# [13484 rows x 11 columns]

# %%
for i in range(len(df7)):

    try:
        rowIndex = df7.index[i]

        input_string=df7.iloc[rowIndex,2]
        metric=df7.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df7.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df7
# Out:
#        index       Date              Event                        Name Age  \
# 0          0 2016-01-30  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 1          1 2016-01-30  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 2          2 2016-02-19  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 3          3 2016-01-23  Men 60 Meter Dash        Kang Li Loong Calvin  26
# 4          4 2016-01-23  Men 60 Meter Dash        Kang Li Loong Calvin  26
# ...      ...        ...                ...                         ...  ..
# 13479  13479 2016-07-06  Women Triple Jump   Bte Azman, Alya Syarafina  19
# 13480  13480 2016-03-20  Women Triple Jump  Christy Robyn Su-Ann, Chng  13
# 13481  13481 2016-02-20  Women Triple Jump             Koh, Boon Hsuan  16
# 13482  13482 2016-02-20  Women Triple Jump               Chew, Rachael  15
# 13483  13483 2016-03-20  Women Triple Jump         Ann Shyann Wai, Lee  13
#
#                              Team Result  m/s  \
# 0                      Individual   6.77  0.3
# 1                      Individual   6.77  0.5
# 2                     Tean S'pore   6.77    0
# 3                      Individual   6.78    3
# 4                      Individual   6.79  2.3
# ...                           ...    ...  ...
# 13479         Nanyang Polytechnic   8.99    3
# 13480  Nanyang Girls' High School   8.78  NWI
# 13481     National Junior College   8.77  NWI
# 13482  Nanyang Girls' High School   8.75  NWI
# 13483  Nanyang Girls' High School   8.67  NWI
#
#                               Competition Year D.O.B.          Info, if any  \
# 0      International - Asian Indoor Trial        1990                     -
# 1      International - Asian Indoor Trial        1990                     -
# 2            International - Asian Indoor        1990  3/8pos q Equal SB PB
# 3                           SA - Series 1        1990                     -
# 4                           SA - Series 1        1990                     -
# ...                                   ...         ...                   ...
# 13479    Local - Singapore National Games        1997                     -
# 13480                SA - U18 U20 C'ships        2003                     -
# 13481                       SA - Series 2        2000                     -
# 13482                       SA - Series 2        2001                     -
# 13483                SA - U18 U20 C'ships        2003                     -
#
#        Metric
# 0        6.77
# 1        6.77
# 2        6.77
# 3        6.78
# 4        6.79
# ...       ...
# 13479    8.99
# 13480    8.78
# 13481    8.77
# 13482    8.75
# 13483    8.67
#
# [13484 rows x 12 columns]

# %% [markdown]
# # 2015 df8

# %%
df8
# Out:
#             Date               Event                   Name Age  \
# 0     2015-12-20   Men 60 Meter Dash   Kang Li Loong Calvin  25
# 1     2015-12-20   Men 60 Meter Dash          Yap, Timothee  21
# 2     2015-06-09  Men 100 Meter Dash   Kang Li Loong Calvin  25
# 3     2015-04-04  Men 100 Meter Dash   CALVIN KANG LI LOONG  25
# 4     2015-06-09  Men 100 Meter Dash           Md. Amirudin  28
# ...          ...                 ...                    ...  ..
# 9998  2015-01-25   Women Triple Jump      Lim Wan Yu, Grace  14
# 9999  2015-05-10   Women Triple Jump          Huang, Zixian  18
# 10000 2015-01-25   Women Triple Jump  Hew Yee Xuan, Adeline  14
# 10001 2015-03-22   Women Triple Jump          Chew, Rachael  15
# 10002 2015-02-15   Women Triple Jump          Chan, Wei Wen  15
#
#                                Team Result  m/s  \
# 0              Wings Athletics Club   6.86    -
# 1              Wings Athletics Club   6.99    -
# 2                         Singapore  10.47    0
# 3                         Singapore  10.48  0.2
# 4                         Singapore  10.49  0.3
# ...                             ...    ...  ...
# 9998   Cedar Girls Secondary School   8.64  0.3
# 9999                     Individual   8.58  2.3
# 10000  Cedar Girls Secondary School   8.55  0.3
# 10001    Nanyang Girls' High School   8.49    0
# 10002      Chij St. Nicholas Girls'    8.4  NWI
#
#                                         Competition Year D.O.B.  \
# 0      International - City of Manchester Open Meet        1990
# 1      International - City of Manchester Open Meet        1994
# 2                         International - SEA Games        1990
# 3                               SA - Singapore Open        1990
# 4                         International - SEA Games        1987
# ...                                             ...         ...
# 9998                                  SA - Series 1        2001
# 9999                                  SA - Series 4        1997
# 10000                                 SA - Series 1        2001
# 10001                          SA - U18 U20 C'ships        2000
# 10002                                 SA - Series 2        2000
#
#          Info, if any
# 0          1/6pos, SB
# 1       1/6pos, SB PB
# 2      4/8pos, PB, SB
# 3                   -
# 4       4/7pos, SB, q
# ...               ...
# 9998                -
# 9999                -
# 10000               -
# 10001               -
# 10002               -
#
# [10003 rows x 10 columns]

# %%
df8 = df8[df8['Event'].notna()] # take only non-empty rows
df8 = df8.reset_index() # must reset index after filtering

# %%
for i in range(len(df8)):

    try:
        rowIndex = df8.index[i]

        input_string=df8.iloc[rowIndex,2]
        metric=df8.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df8.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df8
# Out:
#        index       Date               Event                   Name Age  \
# 0          0 2015-12-20   Men 60 Meter Dash   Kang Li Loong Calvin  25
# 1          1 2015-12-20   Men 60 Meter Dash          Yap, Timothee  21
# 2          2 2015-06-09  Men 100 Meter Dash   Kang Li Loong Calvin  25
# 3          3 2015-04-04  Men 100 Meter Dash   CALVIN KANG LI LOONG  25
# 4          4 2015-06-09  Men 100 Meter Dash           Md. Amirudin  28
# ...      ...        ...                 ...                    ...  ..
# 9998    9998 2015-01-25   Women Triple Jump      Lim Wan Yu, Grace  14
# 9999    9999 2015-05-10   Women Triple Jump          Huang, Zixian  18
# 10000  10000 2015-01-25   Women Triple Jump  Hew Yee Xuan, Adeline  14
# 10001  10001 2015-03-22   Women Triple Jump          Chew, Rachael  15
# 10002  10002 2015-02-15   Women Triple Jump          Chan, Wei Wen  15
#
#                                Team Result  m/s  \
# 0              Wings Athletics Club   6.86    -
# 1              Wings Athletics Club   6.99    -
# 2                         Singapore  10.47    0
# 3                         Singapore  10.48  0.2
# 4                         Singapore  10.49  0.3
# ...                             ...    ...  ...
# 9998   Cedar Girls Secondary School   8.64  0.3
# 9999                     Individual   8.58  2.3
# 10000  Cedar Girls Secondary School   8.55  0.3
# 10001    Nanyang Girls' High School   8.49    0
# 10002      Chij St. Nicholas Girls'    8.4  NWI
#
#                                         Competition Year D.O.B.  \
# 0      International - City of Manchester Open Meet        1990
# 1      International - City of Manchester Open Meet        1994
# 2                         International - SEA Games        1990
# 3                               SA - Singapore Open        1990
# 4                         International - SEA Games        1987
# ...                                             ...         ...
# 9998                                  SA - Series 1        2001
# 9999                                  SA - Series 4        1997
# 10000                                 SA - Series 1        2001
# 10001                          SA - U18 U20 C'ships        2000
# 10002                                 SA - Series 2        2000
#
#          Info, if any  Metric
# 0          1/6pos, SB    6.86
# 1       1/6pos, SB PB    6.99
# 2      4/8pos, PB, SB   10.47
# 3                   -   10.48
# 4       4/7pos, SB, q   10.49
# ...               ...     ...
# 9998                -    8.64
# 9999                -    8.58
# 10000               -    8.55
# 10001               -    8.49
# 10002               -    8.40
#
# [10003 rows x 12 columns]

# %% [markdown]
# # 2014 df9

# %%
df9
# Out:
#             Date                     Event  \
# 0     2014-03-07         Men 60 Meter Dash
# 1     2014-01-26         Men 60 Meter Dash
# 2     2014-02-15         Men 60 Meter Dash
# 3     2014-01-26         Men 60 Meter Dash
# 4     2014-02-15         Men 60 Meter Dash
# ...          ...                       ...
# 10468 2014-12-04  Women Discus Throw (1kg)
# 10469 2014-12-04  Women Discus Throw (1kg)
# 10470 2014-12-04     Men 4x400 Meter Relay
# 10471 2014-12-04   Women 4x400 Meter Relay
# 10472 2014-12-04          Women Pole Vault
#
#                                                   Name Age  \
# 0                                          Calvin Kang  24
# 1                                         Kang, Calvin  24
# 2                                          Calvin Kang  24
# 3                                        Mustapa, Elfi  27
# 4                                          Calvin Kang  24
# ...                                                ...  ..
# 10468                                     Kek Jing Wen   -
# 10469                                   Genis Phoa Jie   -
# 10470  Calvin Quek, Joshua Lim, Wei Bin, Jonathan Wong   -
# 10471          Carys Hor, Thia Yiyi, Kugapriya, Jia Yi   -
# 10472                                      Chang An Zi   -
#
#                        Team   Result     m/s  \
# 0                 Singapore     6.75  Indoor
# 1      Wings Athletics Club     6.76     NWI
# 2                 Singapore      6.8  Indoor
# 3      Wings Athletics Club     6.82     NWI
# 4                 Singapore     6.83  Indoor
# ...                     ...      ...     ...
# 10468             Singapore    31.75       -
# 10469             Singapore    30.25       -
# 10470             Singapore  3:32.64       -
# 10471             Singapore  4:28.76       -
# 10472             Singapore      3.1       -
#
#                                      Competition Year D.O.B.  \
# 0      International - IAAF World Indoor C'ships        1990
# 1                                  SA - Series 1        1990
# 2                   International - Asian Indoor        1990
# 3                                  SA - Series 1        1987
# 4                   International - Asian Indoor        1990
# ...                                          ...         ...
# 10468         International - ASEAN School Games           -
# 10469         International - ASEAN School Games           -
# 10470         International - ASEAN School Games           -
# 10471         International - ASEAN School Games           -
# 10472         International - ASEAN School Games           -
#
#                                             Info, if any
# 0                    Heat 4 of 6, Sopot, Poland, 6/8 pos
# 1               Finals, Choa Chu Kang Stadium Stadium, -
# 2              Timed Finals, Hangzhou, China, Ranked 7th
# 3               Finals, Choa Chu Kang Stadium Stadium, -
# 4                Qualifiers, Hangzhou, China, Ranked 7th
# ...                                                  ...
# 10468  Finals, 8pos, Marikina Sports Complex, Philipp...
# 10469  Finals, 9pos, Marikina Sports Complex, Philipp...
# 10470  Finals, 5pos, Marikina Sports Complex, Philipp...
# 10471  Finals, 4pos, Marikina Sports Complex, Philipp...
# 10472  Finals, 3pos bronze, Marikina Sports Complex, ...
#
# [10473 rows x 10 columns]

# %%
df9 = df9[df9['Event'].notna()] # take only non-empty rows
df9 = df9.reset_index() # must reset index after filtering

# %%
df9
# Out:
#        index       Date                     Event  \
# 0          0 2014-03-07         Men 60 Meter Dash
# 1          1 2014-01-26         Men 60 Meter Dash
# 2          2 2014-02-15         Men 60 Meter Dash
# 3          3 2014-01-26         Men 60 Meter Dash
# 4          4 2014-02-15         Men 60 Meter Dash
# ...      ...        ...                       ...
# 10468  10468 2014-12-04  Women Discus Throw (1kg)
# 10469  10469 2014-12-04  Women Discus Throw (1kg)
# 10470  10470 2014-12-04     Men 4x400 Meter Relay
# 10471  10471 2014-12-04   Women 4x400 Meter Relay
# 10472  10472 2014-12-04          Women Pole Vault
#
#                                                   Name Age  \
# 0                                          Calvin Kang  24
# 1                                         Kang, Calvin  24
# 2                                          Calvin Kang  24
# 3                                        Mustapa, Elfi  27
# 4                                          Calvin Kang  24
# ...                                                ...  ..
# 10468                                     Kek Jing Wen   -
# 10469                                   Genis Phoa Jie   -
# 10470  Calvin Quek, Joshua Lim, Wei Bin, Jonathan Wong   -
# 10471          Carys Hor, Thia Yiyi, Kugapriya, Jia Yi   -
# 10472                                      Chang An Zi   -
#
#                        Team   Result     m/s  \
# 0                 Singapore     6.75  Indoor
# 1      Wings Athletics Club     6.76     NWI
# 2                 Singapore      6.8  Indoor
# 3      Wings Athletics Club     6.82     NWI
# 4                 Singapore     6.83  Indoor
# ...                     ...      ...     ...
# 10468             Singapore    31.75       -
# 10469             Singapore    30.25       -
# 10470             Singapore  3:32.64       -
# 10471             Singapore  4:28.76       -
# 10472             Singapore      3.1       -
#
#                                      Competition Year D.O.B.  \
# 0      International - IAAF World Indoor C'ships        1990
# 1                                  SA - Series 1        1990
# 2                   International - Asian Indoor        1990
# 3                                  SA - Series 1        1987
# 4                   International - Asian Indoor        1990
# ...                                          ...         ...
# 10468         International - ASEAN School Games           -
# 10469         International - ASEAN School Games           -
# 10470         International - ASEAN School Games           -
# 10471         International - ASEAN School Games           -
# 10472         International - ASEAN School Games           -
#
#                                             Info, if any
# 0                    Heat 4 of 6, Sopot, Poland, 6/8 pos
# 1               Finals, Choa Chu Kang Stadium Stadium, -
# 2              Timed Finals, Hangzhou, China, Ranked 7th
# 3               Finals, Choa Chu Kang Stadium Stadium, -
# 4                Qualifiers, Hangzhou, China, Ranked 7th
# ...                                                  ...
# 10468  Finals, 8pos, Marikina Sports Complex, Philipp...
# 10469  Finals, 9pos, Marikina Sports Complex, Philipp...
# 10470  Finals, 5pos, Marikina Sports Complex, Philipp...
# 10471  Finals, 4pos, Marikina Sports Complex, Philipp...
# 10472  Finals, 3pos bronze, Marikina Sports Complex, ...
#
# [10473 rows x 11 columns]

# %%
for i in range(len(df9)):

    try:
        rowIndex = df9.index[i]

        input_string=df9.iloc[rowIndex,2]
        metric=df9.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df9.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df9
# Out:
#        index       Date                     Event  \
# 0          0 2014-03-07         Men 60 Meter Dash
# 1          1 2014-01-26         Men 60 Meter Dash
# 2          2 2014-02-15         Men 60 Meter Dash
# 3          3 2014-01-26         Men 60 Meter Dash
# 4          4 2014-02-15         Men 60 Meter Dash
# ...      ...        ...                       ...
# 10468  10468 2014-12-04  Women Discus Throw (1kg)
# 10469  10469 2014-12-04  Women Discus Throw (1kg)
# 10470  10470 2014-12-04     Men 4x400 Meter Relay
# 10471  10471 2014-12-04   Women 4x400 Meter Relay
# 10472  10472 2014-12-04          Women Pole Vault
#
#                                                   Name Age  \
# 0                                          Calvin Kang  24
# 1                                         Kang, Calvin  24
# 2                                          Calvin Kang  24
# 3                                        Mustapa, Elfi  27
# 4                                          Calvin Kang  24
# ...                                                ...  ..
# 10468                                     Kek Jing Wen   -
# 10469                                   Genis Phoa Jie   -
# 10470  Calvin Quek, Joshua Lim, Wei Bin, Jonathan Wong   -
# 10471          Carys Hor, Thia Yiyi, Kugapriya, Jia Yi   -
# 10472                                      Chang An Zi   -
#
#                        Team   Result     m/s  \
# 0                 Singapore     6.75  Indoor
# 1      Wings Athletics Club     6.76     NWI
# 2                 Singapore      6.8  Indoor
# 3      Wings Athletics Club     6.82     NWI
# 4                 Singapore     6.83  Indoor
# ...                     ...      ...     ...
# 10468             Singapore    31.75       -
# 10469             Singapore    30.25       -
# 10470             Singapore  3:32.64       -
# 10471             Singapore  4:28.76       -
# 10472             Singapore      3.1       -
#
#                                      Competition Year D.O.B.  \
# 0      International - IAAF World Indoor C'ships        1990
# 1                                  SA - Series 1        1990
# 2                   International - Asian Indoor        1990
# 3                                  SA - Series 1        1987
# 4                   International - Asian Indoor        1990
# ...                                          ...         ...
# 10468         International - ASEAN School Games           -
# 10469         International - ASEAN School Games           -
# 10470         International - ASEAN School Games           -
# 10471         International - ASEAN School Games           -
# 10472         International - ASEAN School Games           -
#
#                                             Info, if any  Metric
# 0                    Heat 4 of 6, Sopot, Poland, 6/8 pos    6.75
# 1               Finals, Choa Chu Kang Stadium Stadium, -    6.76
# 2              Timed Finals, Hangzhou, China, Ranked 7th    6.80
# 3               Finals, Choa Chu Kang Stadium Stadium, -    6.82
# 4                Qualifiers, Hangzhou, China, Ranked 7th    6.83
# ...                                                  ...     ...
# 10468  Finals, 8pos, Marikina Sports Complex, Philipp...   31.75
# 10469  Finals, 9pos, Marikina Sports Complex, Philipp...   30.25
# 10470  Finals, 5pos, Marikina Sports Complex, Philipp...  212.64
# 10471  Finals, 4pos, Marikina Sports Complex, Philipp...  268.76
# 10472  Finals, 3pos bronze, Marikina Sports Complex, ...    3.10
#
# [10473 rows x 12 columns]

# %% [markdown]
# # df10 2013

# %%
df10
# Out:
#            Date               Event                       Name Age  \
# 0    2013-10-19  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 1    2013-08-10  Men 100 Meter Dash       Kang Li Loong Calvin  23
# 2    2013-12-17  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 3    2013-09-02  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 4    2013-09-06  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# ...         ...                 ...                        ...  ..
# 8037 2013-04-15   Women Triple Jump       Kwok Jean Ee Daphne    -
# 8038 2013-03-03   Women Triple Jump               Tan, Jessica  18
# 8039 2013-04-15   Women Triple Jump        Joline Aw Juan Lin    -
# 8040 2013-11-23   Women Triple Jump  Binte Ridwan, Siti Sofiah   -
# 8041 2013-01-26   Women Triple Jump        Ridwan, Siti Sofiah   -
#
#                          Team Result  m/s                         Competition  \
# 0                   Singapore  10.46  1.2       International - Malaysia Open
# 1                   Singapore  10.52 -0.4  International - IAAF World C'ships
# 2                   Singapore  10.55  0.7           International - SEA Games
# 3                   Singapore  10.58  NWI       International - Thailand Open
# 4                   Singapore  10.58 -0.1       International - Thailand Open
# ...                       ...    ...  ...                                 ...
# 8037                       CG   9.27  NWI            Local - National Schools
# 8038  Victoria Junior College   9.25    4                SA - U18 U20 C'ships
# 8039                      SNG   9.11  NWI            Local - National Schools
# 8040    Singapore Polytechnic   8.92    0                     Local - POL-ITE
# 8041    Singapore Polytechnic   8.47 -1.8                         Local - IVP
#
#      Year D.O.B.                                       Info, if any
# 0           1987  Final, UM Stadium, Kuala Lumpur, 2/7 pos, SILV...
# 1           1990  Preliminaries 4, Luzhniki Stadium, Moscow Russ...
# 2           1987  Final, Wunna Theikdi Stadium, Naypyidaw, Myanm...
# 3           1987  Semifinal, Thammasat University Sport Complex,...
# 4           1987  Final, Thammasat University Sport Complex, 3 p...
# ...          ...                                                ...
# 8037           -                    Final, Choa Chu Kang Stadium, -
# 8038        1995                   Finals, Choa Chu Kang Stadium, -
# 8039           -                    Final, Choa Chu Kang Stadium, -
# 8040           -                         Flight  1, Nanyang Poly, -
# 8041           -                 Final, ITE East College (Simei), -
#
# [8042 rows x 10 columns]

# %%
df10 = df10[df10['Event'].notna()] # take only non-empty rows
df10 = df10.reset_index() # must reset index after filtering

# %%
df10
# Out:
#       index       Date               Event                       Name Age  \
# 0         0 2013-10-19  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 1         1 2013-08-10  Men 100 Meter Dash       Kang Li Loong Calvin  23
# 2         2 2013-12-17  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 3         3 2013-09-02  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 4         4 2013-09-06  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# ...     ...        ...                 ...                        ...  ..
# 8037   8037 2013-04-15   Women Triple Jump       Kwok Jean Ee Daphne    -
# 8038   8038 2013-03-03   Women Triple Jump               Tan, Jessica  18
# 8039   8039 2013-04-15   Women Triple Jump        Joline Aw Juan Lin    -
# 8040   8040 2013-11-23   Women Triple Jump  Binte Ridwan, Siti Sofiah   -
# 8041   8041 2013-01-26   Women Triple Jump        Ridwan, Siti Sofiah   -
#
#                          Team Result  m/s                         Competition  \
# 0                   Singapore  10.46  1.2       International - Malaysia Open
# 1                   Singapore  10.52 -0.4  International - IAAF World C'ships
# 2                   Singapore  10.55  0.7           International - SEA Games
# 3                   Singapore  10.58  NWI       International - Thailand Open
# 4                   Singapore  10.58 -0.1       International - Thailand Open
# ...                       ...    ...  ...                                 ...
# 8037                       CG   9.27  NWI            Local - National Schools
# 8038  Victoria Junior College   9.25    4                SA - U18 U20 C'ships
# 8039                      SNG   9.11  NWI            Local - National Schools
# 8040    Singapore Polytechnic   8.92    0                     Local - POL-ITE
# 8041    Singapore Polytechnic   8.47 -1.8                         Local - IVP
#
#      Year D.O.B.                                       Info, if any
# 0           1987  Final, UM Stadium, Kuala Lumpur, 2/7 pos, SILV...
# 1           1990  Preliminaries 4, Luzhniki Stadium, Moscow Russ...
# 2           1987  Final, Wunna Theikdi Stadium, Naypyidaw, Myanm...
# 3           1987  Semifinal, Thammasat University Sport Complex,...
# 4           1987  Final, Thammasat University Sport Complex, 3 p...
# ...          ...                                                ...
# 8037           -                    Final, Choa Chu Kang Stadium, -
# 8038        1995                   Finals, Choa Chu Kang Stadium, -
# 8039           -                    Final, Choa Chu Kang Stadium, -
# 8040           -                         Flight  1, Nanyang Poly, -
# 8041           -                 Final, ITE East College (Simei), -
#
# [8042 rows x 11 columns]

# %%
for i in range(len(df10)):

    try:
        rowIndex = df10.index[i]

        input_string=df10.iloc[rowIndex,2]
        metric=df10.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df10.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df10
# Out:
#       index       Date               Event                       Name Age  \
# 0         0 2013-10-19  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 1         1 2013-08-10  Men 100 Meter Dash       Kang Li Loong Calvin  23
# 2         2 2013-12-17  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 3         3 2013-09-02  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 4         4 2013-09-06  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# ...     ...        ...                 ...                        ...  ..
# 8037   8037 2013-04-15   Women Triple Jump       Kwok Jean Ee Daphne    -
# 8038   8038 2013-03-03   Women Triple Jump               Tan, Jessica  18
# 8039   8039 2013-04-15   Women Triple Jump        Joline Aw Juan Lin    -
# 8040   8040 2013-11-23   Women Triple Jump  Binte Ridwan, Siti Sofiah   -
# 8041   8041 2013-01-26   Women Triple Jump        Ridwan, Siti Sofiah   -
#
#                          Team Result  m/s                         Competition  \
# 0                   Singapore  10.46  1.2       International - Malaysia Open
# 1                   Singapore  10.52 -0.4  International - IAAF World C'ships
# 2                   Singapore  10.55  0.7           International - SEA Games
# 3                   Singapore  10.58  NWI       International - Thailand Open
# 4                   Singapore  10.58 -0.1       International - Thailand Open
# ...                       ...    ...  ...                                 ...
# 8037                       CG   9.27  NWI            Local - National Schools
# 8038  Victoria Junior College   9.25    4                SA - U18 U20 C'ships
# 8039                      SNG   9.11  NWI            Local - National Schools
# 8040    Singapore Polytechnic   8.92    0                     Local - POL-ITE
# 8041    Singapore Polytechnic   8.47 -1.8                         Local - IVP
#
#      Year D.O.B.                                       Info, if any  Metric
# 0           1987  Final, UM Stadium, Kuala Lumpur, 2/7 pos, SILV...   10.46
# 1           1990  Preliminaries 4, Luzhniki Stadium, Moscow Russ...   10.52
# 2           1987  Final, Wunna Theikdi Stadium, Naypyidaw, Myanm...   10.55
# 3           1987  Semifinal, Thammasat University Sport Complex,...   10.58
# 4           1987  Final, Thammasat University Sport Complex, 3 p...   10.58
# ...          ...                                                ...     ...
# 8037           -                    Final, Choa Chu Kang Stadium, -    9.27
# 8038        1995                   Finals, Choa Chu Kang Stadium, -    9.25
# 8039           -                    Final, Choa Chu Kang Stadium, -    9.11
# 8040           -                         Flight  1, Nanyang Poly, -    8.92
# 8041           -                 Final, ITE East College (Simei), -    8.47
#
# [8042 rows x 12 columns]

# %% [markdown]
# # 2012 df11

# %%
df11
# Out:
#            Date               Event                    Name Age  \
# 0    2012-12-15  Men 100 Meter Dash         Yeo Foo Ee Gary  26
# 1    2012-12-15  Men 100 Meter Dash    Kang Li Loong Calvin  22
# 2    2012-12-15  Men 100 Meter Dash    Kang Li Loong Calvin  22
# 3    2012-12-15  Men 100 Meter Dash         Yeo Foo Ee Gary  26
# 4    2012-12-15  Men 100 Meter Dash   Mohammad, Naqib Asmin  17
# ...         ...                 ...                     ...  ..
# 8537 2012-03-30   Women Triple Jump           Andrea Chong    -
# 8538 2012-03-30   Women Triple Jump    Ng Xuanning, Nicole    -
# 8539 2012-03-30   Women Triple Jump             Ang Wei Lu    -
# 8540 2012-03-30   Women Triple Jump  Anastasia Lim Lee Lin    -
# 8541 2012-03-30   Women Triple Jump    Yandy Yee Qian Nong    -
#
#                          Team Result  m/s  \
# 0                   Singapore  10.44  1.1
# 1                   Singapore  10.57  1.1
# 2                   Singapore   10.7  NWI
# 3                   Singapore  10.89  NWI
# 4     Singapore Sports School  11.07  2.9
# ...                       ...    ...  ...
# 8537                     NYGH   4.24  NWI
# 8538                      SNG   4.24  NWI
# 8539                      SSP   4.23  NWI
# 8540                      SSP    4.2  NWI
# 8541                      SNG   4.02  NWI
#
#                                  Competition Year D.O.B.  \
# 0     International - ASEAN University Games        1986
# 1     International - ASEAN University Games        1990
# 2     International - ASEAN University Games        1990
# 3     International - ASEAN University Games        1986
# 4                              SA - Series 6        1995
# ...                                      ...         ...
# 8537                Local - National Schools           -
# 8538                Local - National Schools           -
# 8539                Local - National Schools           -
# 8540                Local - National Schools           -
# 8541                Local - National Schools           -
#
#                                         Info, if any
# 0      - Final  Main Stadium, National Sport Complex
# 1      - Final  Main Stadium, National Sport Complex
# 2     - Heat 1  Main Stadium, National Sport Complex
# 3     - Heat 2  Main Stadium, National Sport Complex
# 4                    - Final Singapore Sports School
# ...                                              ...
# 8537                   - Final Choa Chu Kang Stadium
# 8538                   - Final Choa Chu Kang Stadium
# 8539                   - Final Choa Chu Kang Stadium
# 8540                   - Final Choa Chu Kang Stadium
# 8541                   - Final Choa Chu Kang Stadium
#
# [8542 rows x 10 columns]

# %%
df11 = df11[df11['Event'].notna()] # take only non-empty rows
df11 = df11.reset_index() # must reset index after filtering

# %%
df11
# Out:
#       index       Date               Event                    Name Age  \
# 0         0 2012-12-15  Men 100 Meter Dash         Yeo Foo Ee Gary  26
# 1         1 2012-12-15  Men 100 Meter Dash    Kang Li Loong Calvin  22
# 2         2 2012-12-15  Men 100 Meter Dash    Kang Li Loong Calvin  22
# 3         3 2012-12-15  Men 100 Meter Dash         Yeo Foo Ee Gary  26
# 4         4 2012-12-15  Men 100 Meter Dash   Mohammad, Naqib Asmin  17
# ...     ...        ...                 ...                     ...  ..
# 8537   8537 2012-03-30   Women Triple Jump           Andrea Chong    -
# 8538   8538 2012-03-30   Women Triple Jump    Ng Xuanning, Nicole    -
# 8539   8539 2012-03-30   Women Triple Jump             Ang Wei Lu    -
# 8540   8540 2012-03-30   Women Triple Jump  Anastasia Lim Lee Lin    -
# 8541   8541 2012-03-30   Women Triple Jump    Yandy Yee Qian Nong    -
#
#                          Team Result  m/s  \
# 0                   Singapore  10.44  1.1
# 1                   Singapore  10.57  1.1
# 2                   Singapore   10.7  NWI
# 3                   Singapore  10.89  NWI
# 4     Singapore Sports School  11.07  2.9
# ...                       ...    ...  ...
# 8537                     NYGH   4.24  NWI
# 8538                      SNG   4.24  NWI
# 8539                      SSP   4.23  NWI
# 8540                      SSP    4.2  NWI
# 8541                      SNG   4.02  NWI
#
#                                  Competition Year D.O.B.  \
# 0     International - ASEAN University Games        1986
# 1     International - ASEAN University Games        1990
# 2     International - ASEAN University Games        1990
# 3     International - ASEAN University Games        1986
# 4                              SA - Series 6        1995
# ...                                      ...         ...
# 8537                Local - National Schools           -
# 8538                Local - National Schools           -
# 8539                Local - National Schools           -
# 8540                Local - National Schools           -
# 8541                Local - National Schools           -
#
#                                         Info, if any
# 0      - Final  Main Stadium, National Sport Complex
# 1      - Final  Main Stadium, National Sport Complex
# 2     - Heat 1  Main Stadium, National Sport Complex
# 3     - Heat 2  Main Stadium, National Sport Complex
# 4                    - Final Singapore Sports School
# ...                                              ...
# 8537                   - Final Choa Chu Kang Stadium
# 8538                   - Final Choa Chu Kang Stadium
# 8539                   - Final Choa Chu Kang Stadium
# 8540                   - Final Choa Chu Kang Stadium
# 8541                   - Final Choa Chu Kang Stadium
#
# [8542 rows x 11 columns]

# %%
for i in range(len(df11)):

    try:
        rowIndex = df11.index[i]

        input_string=df11.iloc[rowIndex,2]
        metric=df11.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df11.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df11
# Out:
#       index       Date               Event                    Name Age  \
# 0         0 2012-12-15  Men 100 Meter Dash         Yeo Foo Ee Gary  26
# 1         1 2012-12-15  Men 100 Meter Dash    Kang Li Loong Calvin  22
# 2         2 2012-12-15  Men 100 Meter Dash    Kang Li Loong Calvin  22
# 3         3 2012-12-15  Men 100 Meter Dash         Yeo Foo Ee Gary  26
# 4         4 2012-12-15  Men 100 Meter Dash   Mohammad, Naqib Asmin  17
# ...     ...        ...                 ...                     ...  ..
# 8537   8537 2012-03-30   Women Triple Jump           Andrea Chong    -
# 8538   8538 2012-03-30   Women Triple Jump    Ng Xuanning, Nicole    -
# 8539   8539 2012-03-30   Women Triple Jump             Ang Wei Lu    -
# 8540   8540 2012-03-30   Women Triple Jump  Anastasia Lim Lee Lin    -
# 8541   8541 2012-03-30   Women Triple Jump    Yandy Yee Qian Nong    -
#
#                          Team Result  m/s  \
# 0                   Singapore  10.44  1.1
# 1                   Singapore  10.57  1.1
# 2                   Singapore   10.7  NWI
# 3                   Singapore  10.89  NWI
# 4     Singapore Sports School  11.07  2.9
# ...                       ...    ...  ...
# 8537                     NYGH   4.24  NWI
# 8538                      SNG   4.24  NWI
# 8539                      SSP   4.23  NWI
# 8540                      SSP    4.2  NWI
# 8541                      SNG   4.02  NWI
#
#                                  Competition Year D.O.B.  \
# 0     International - ASEAN University Games        1986
# 1     International - ASEAN University Games        1990
# 2     International - ASEAN University Games        1990
# 3     International - ASEAN University Games        1986
# 4                              SA - Series 6        1995
# ...                                      ...         ...
# 8537                Local - National Schools           -
# 8538                Local - National Schools           -
# 8539                Local - National Schools           -
# 8540                Local - National Schools           -
# 8541                Local - National Schools           -
#
#                                         Info, if any  Metric
# 0      - Final  Main Stadium, National Sport Complex   10.44
# 1      - Final  Main Stadium, National Sport Complex   10.57
# 2     - Heat 1  Main Stadium, National Sport Complex   10.70
# 3     - Heat 2  Main Stadium, National Sport Complex   10.89
# 4                    - Final Singapore Sports School   11.07
# ...                                              ...     ...
# 8537                   - Final Choa Chu Kang Stadium    4.24
# 8538                   - Final Choa Chu Kang Stadium    4.24
# 8539                   - Final Choa Chu Kang Stadium    4.23
# 8540                   - Final Choa Chu Kang Stadium    4.20
# 8541                   - Final Choa Chu Kang Stadium    4.02
#
# [8542 rows x 12 columns]

# %% [markdown]
# # 2011 df12

# %%
df12
# Out:
#            Date                   Event                         Name Age  \
# 0    2011-11-12      Men 100 Meter Dash                     Gary Yeo  25
# 1    2011-11-14      Men 200 Meter Dash                Lee Cheng Wei  24
# 2    2011-11-12      Men 100 Meter Dash                     Gary Yeo  25
# 3    2011-11-12      Men 100 Meter Dash             Md. Elfi Mustapa  24
# 4    2011-11-14      Men 200 Meter Dash                  Calvin Kang  21
# ...         ...                     ...                          ...  ..
# 4880 2011-03-27  Men 4x100 Meter Relay   Ahmad Ibrahim Secondary Sch   -
# 4881 2011-03-27  Men 4x100 Meter Relay    Guangyang Secondary School   -
# 4882 2011-03-27  Men 4x100 Meter Relay   Bedok View Secondary School   -
# 4883 2011-03-27  Men 4x100 Meter Relay      Temasek Secondary School   -
# 4884 2011-03-27  Men 4x100 Meter Relay               Nus High School   -
#
#                              Team Result  m/s                Competition  \
# 0                       Singapore  10.46  2.1  International - SEA Games
# 1                       Singapore   21.6  1.7  International - SEA Games
# 2                       Singapore  10.64  NWI  International - SEA Games
# 3                       Singapore  11.22 -0.8  International - SEA Games
# 4                       Singapore  21.95  1.7  International - SEA Games
# ...                           ...    ...  ...                        ...
# 4880  Ahmad Ibrahim Secondary Sch  55.99    -            SA - SPH Relays
# 4881   Guangyang Secondary School  56.23    -            SA - SPH Relays
# 4882  Bedok View Secondary School  56.87    -            SA - SPH Relays
# 4883     Temasek Secondary School  57.28    -            SA - SPH Relays
# 4884              Nus High School  57.47    -            SA - SPH Relays
#
#      Year D.O.B.                                       Info, if any
# 0           1986   - Final Jakabaring Stadium, Palembang, Indonesia
# 1           1987   - Final Jakabaring Stadium, Palembang, Indonesia
# 2           1986  - Semifinal 2 Jakabaring Stadium, Palembang, I...
# 3           1987  - Semifinal 1 Jakabaring Stadium, Palembang, I...
# 4           1990   - Final Jakabaring Stadium, Palembang, Indonesia
# ...          ...                                                ...
# 4880           -                 Final 2 C Div Bukit Gombak Stadium
# 4881           -                 Final 2 C Div Bukit Gombak Stadium
# 4882           -                 Final 2 C Div Bukit Gombak Stadium
# 4883           -                 Final 3 C Div Bukit Gombak Stadium
# 4884           -                 Final 2 C Div Bukit Gombak Stadium
#
# [4885 rows x 10 columns]

# %%
df12 = df12[df12['Event'].notna()] # take only non-empty rows
df12 = df12.reset_index() # must reset index after filtering

# %%
df12
# Out:
#       index       Date                   Event                         Name  \
# 0         0 2011-11-12      Men 100 Meter Dash                     Gary Yeo
# 1         1 2011-11-14      Men 200 Meter Dash                Lee Cheng Wei
# 2         2 2011-11-12      Men 100 Meter Dash                     Gary Yeo
# 3         3 2011-11-12      Men 100 Meter Dash             Md. Elfi Mustapa
# 4         4 2011-11-14      Men 200 Meter Dash                  Calvin Kang
# ...     ...        ...                     ...                          ...
# 4880   4880 2011-03-27  Men 4x100 Meter Relay   Ahmad Ibrahim Secondary Sch
# 4881   4881 2011-03-27  Men 4x100 Meter Relay    Guangyang Secondary School
# 4882   4882 2011-03-27  Men 4x100 Meter Relay   Bedok View Secondary School
# 4883   4883 2011-03-27  Men 4x100 Meter Relay      Temasek Secondary School
# 4884   4884 2011-03-27  Men 4x100 Meter Relay               Nus High School
#
#      Age                         Team Result  m/s                Competition  \
# 0     25                    Singapore  10.46  2.1  International - SEA Games
# 1     24                    Singapore   21.6  1.7  International - SEA Games
# 2     25                    Singapore  10.64  NWI  International - SEA Games
# 3     24                    Singapore  11.22 -0.8  International - SEA Games
# 4     21                    Singapore  21.95  1.7  International - SEA Games
# ...   ..                          ...    ...  ...                        ...
# 4880   -  Ahmad Ibrahim Secondary Sch  55.99    -            SA - SPH Relays
# 4881   -   Guangyang Secondary School  56.23    -            SA - SPH Relays
# 4882   -  Bedok View Secondary School  56.87    -            SA - SPH Relays
# 4883   -     Temasek Secondary School  57.28    -            SA - SPH Relays
# 4884   -              Nus High School  57.47    -            SA - SPH Relays
#
#      Year D.O.B.                                       Info, if any
# 0           1986   - Final Jakabaring Stadium, Palembang, Indonesia
# 1           1987   - Final Jakabaring Stadium, Palembang, Indonesia
# 2           1986  - Semifinal 2 Jakabaring Stadium, Palembang, I...
# 3           1987  - Semifinal 1 Jakabaring Stadium, Palembang, I...
# 4           1990   - Final Jakabaring Stadium, Palembang, Indonesia
# ...          ...                                                ...
# 4880           -                 Final 2 C Div Bukit Gombak Stadium
# 4881           -                 Final 2 C Div Bukit Gombak Stadium
# 4882           -                 Final 2 C Div Bukit Gombak Stadium
# 4883           -                 Final 3 C Div Bukit Gombak Stadium
# 4884           -                 Final 2 C Div Bukit Gombak Stadium
#
# [4885 rows x 11 columns]

# %%
for i in range(len(df12)):

    try:
        rowIndex = df12.index[i]

        input_string=df12.iloc[rowIndex,2]
        metric=df12.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df12.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df12
# Out:
#       index       Date                   Event                         Name  \
# 0         0 2011-11-12      Men 100 Meter Dash                     Gary Yeo
# 1         1 2011-11-14      Men 200 Meter Dash                Lee Cheng Wei
# 2         2 2011-11-12      Men 100 Meter Dash                     Gary Yeo
# 3         3 2011-11-12      Men 100 Meter Dash             Md. Elfi Mustapa
# 4         4 2011-11-14      Men 200 Meter Dash                  Calvin Kang
# ...     ...        ...                     ...                          ...
# 4880   4880 2011-03-27  Men 4x100 Meter Relay   Ahmad Ibrahim Secondary Sch
# 4881   4881 2011-03-27  Men 4x100 Meter Relay    Guangyang Secondary School
# 4882   4882 2011-03-27  Men 4x100 Meter Relay   Bedok View Secondary School
# 4883   4883 2011-03-27  Men 4x100 Meter Relay      Temasek Secondary School
# 4884   4884 2011-03-27  Men 4x100 Meter Relay               Nus High School
#
#      Age                         Team Result  m/s                Competition  \
# 0     25                    Singapore  10.46  2.1  International - SEA Games
# 1     24                    Singapore   21.6  1.7  International - SEA Games
# 2     25                    Singapore  10.64  NWI  International - SEA Games
# 3     24                    Singapore  11.22 -0.8  International - SEA Games
# 4     21                    Singapore  21.95  1.7  International - SEA Games
# ...   ..                          ...    ...  ...                        ...
# 4880   -  Ahmad Ibrahim Secondary Sch  55.99    -            SA - SPH Relays
# 4881   -   Guangyang Secondary School  56.23    -            SA - SPH Relays
# 4882   -  Bedok View Secondary School  56.87    -            SA - SPH Relays
# 4883   -     Temasek Secondary School  57.28    -            SA - SPH Relays
# 4884   -              Nus High School  57.47    -            SA - SPH Relays
#
#      Year D.O.B.                                       Info, if any  Metric
# 0           1986   - Final Jakabaring Stadium, Palembang, Indonesia   10.46
# 1           1987   - Final Jakabaring Stadium, Palembang, Indonesia   21.60
# 2           1986  - Semifinal 2 Jakabaring Stadium, Palembang, I...   10.64
# 3           1987  - Semifinal 1 Jakabaring Stadium, Palembang, I...   11.22
# 4           1990   - Final Jakabaring Stadium, Palembang, Indonesia   21.95
# ...          ...                                                ...     ...
# 4880           -                 Final 2 C Div Bukit Gombak Stadium   55.99
# 4881           -                 Final 2 C Div Bukit Gombak Stadium   56.23
# 4882           -                 Final 2 C Div Bukit Gombak Stadium   56.87
# 4883           -                 Final 3 C Div Bukit Gombak Stadium   57.28
# 4884           -                 Final 2 C Div Bukit Gombak Stadium   57.47
#
# [4885 rows x 12 columns]

# %% [markdown]
# # 2010 df13

# %%
df13
# Out:
#            Date               Event                       Name Age  \
# 0    2013-10-19  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 1    2013-08-10  Men 100 Meter Dash       Kang Li Loong Calvin  23
# 2    2013-12-17  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 3    2013-09-02  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 4    2013-09-06  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# ...         ...                 ...                        ...  ..
# 8037 2013-04-15   Women Triple Jump       Kwok Jean Ee Daphne    -
# 8038 2013-03-03   Women Triple Jump               Tan, Jessica  18
# 8039 2013-04-15   Women Triple Jump        Joline Aw Juan Lin    -
# 8040 2013-11-23   Women Triple Jump  Binte Ridwan, Siti Sofiah   -
# 8041 2013-01-26   Women Triple Jump        Ridwan, Siti Sofiah   -
#
#                          Team Result  m/s                         Competition  \
# 0                   Singapore  10.46  1.2       International - Malaysia Open
# 1                   Singapore  10.52 -0.4  International - IAAF World C'ships
# 2                   Singapore  10.55  0.7           International - SEA Games
# 3                   Singapore  10.58  NWI       International - Thailand Open
# 4                   Singapore  10.58 -0.1       International - Thailand Open
# ...                       ...    ...  ...                                 ...
# 8037                       CG   9.27  NWI            Local - National Schools
# 8038  Victoria Junior College   9.25    4                SA - U18 U20 C'ships
# 8039                      SNG   9.11  NWI            Local - National Schools
# 8040    Singapore Polytechnic   8.92    0                     Local - POL-ITE
# 8041    Singapore Polytechnic   8.47 -1.8                         Local - IVP
#
#      Year D.O.B.                                       Info, if any
# 0           1987  Final, UM Stadium, Kuala Lumpur, 2/7 pos, SILV...
# 1           1990  Preliminaries 4, Luzhniki Stadium, Moscow Russ...
# 2           1987  Final, Wunna Theikdi Stadium, Naypyidaw, Myanm...
# 3           1987  Semifinal, Thammasat University Sport Complex,...
# 4           1987  Final, Thammasat University Sport Complex, 3 p...
# ...          ...                                                ...
# 8037           -                    Final, Choa Chu Kang Stadium, -
# 8038        1995                   Finals, Choa Chu Kang Stadium, -
# 8039           -                    Final, Choa Chu Kang Stadium, -
# 8040           -                         Flight  1, Nanyang Poly, -
# 8041           -                 Final, ITE East College (Simei), -
#
# [8042 rows x 10 columns]

# %%
df13 = df13[df13['Event'].notna()] # take only non-empty rows
df13 = df13.reset_index() # must reset index after filtering

# %%
for i in range(len(df13)):

    try:
        rowIndex = df13.index[i]

        input_string=df13.iloc[rowIndex,2]
        metric=df13.iloc[rowIndex,6]
        
        out = preprocess(i, input_string, metric)
    
        df13.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "with input value", metric)
        print("Exiting operation")
        break

# %%
df13
# Out:
#       index       Date               Event                       Name Age  \
# 0         0 2013-10-19  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 1         1 2013-08-10  Men 100 Meter Dash       Kang Li Loong Calvin  23
# 2         2 2013-12-17  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 3         3 2013-09-02  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# 4         4 2013-09-06  Men 100 Meter Dash    Muhammad Amirudin Jamal  26
# ...     ...        ...                 ...                        ...  ..
# 8037   8037 2013-04-15   Women Triple Jump       Kwok Jean Ee Daphne    -
# 8038   8038 2013-03-03   Women Triple Jump               Tan, Jessica  18
# 8039   8039 2013-04-15   Women Triple Jump        Joline Aw Juan Lin    -
# 8040   8040 2013-11-23   Women Triple Jump  Binte Ridwan, Siti Sofiah   -
# 8041   8041 2013-01-26   Women Triple Jump        Ridwan, Siti Sofiah   -
#
#                          Team Result  m/s                         Competition  \
# 0                   Singapore  10.46  1.2       International - Malaysia Open
# 1                   Singapore  10.52 -0.4  International - IAAF World C'ships
# 2                   Singapore  10.55  0.7           International - SEA Games
# 3                   Singapore  10.58  NWI       International - Thailand Open
# 4                   Singapore  10.58 -0.1       International - Thailand Open
# ...                       ...    ...  ...                                 ...
# 8037                       CG   9.27  NWI            Local - National Schools
# 8038  Victoria Junior College   9.25    4                SA - U18 U20 C'ships
# 8039                      SNG   9.11  NWI            Local - National Schools
# 8040    Singapore Polytechnic   8.92    0                     Local - POL-ITE
# 8041    Singapore Polytechnic   8.47 -1.8                         Local - IVP
#
#      Year D.O.B.                                       Info, if any  Metric
# 0           1987  Final, UM Stadium, Kuala Lumpur, 2/7 pos, SILV...   10.46
# 1           1990  Preliminaries 4, Luzhniki Stadium, Moscow Russ...   10.52
# 2           1987  Final, Wunna Theikdi Stadium, Naypyidaw, Myanm...   10.55
# 3           1987  Semifinal, Thammasat University Sport Complex,...   10.58
# 4           1987  Final, Thammasat University Sport Complex, 3 p...   10.58
# ...          ...                                                ...     ...
# 8037           -                    Final, Choa Chu Kang Stadium, -    9.27
# 8038        1995                   Finals, Choa Chu Kang Stadium, -    9.25
# 8039           -                    Final, Choa Chu Kang Stadium, -    9.11
# 8040           -                         Flight  1, Nanyang Poly, -    8.92
# 8041           -                 Final, ITE East College (Simei), -    8.47
#
# [8042 rows x 12 columns]

# %% [markdown]
# # Before 2010 df14

# %%
df14
# Out:
#          Date                     Event                   Name Age       Team  \
# 0  2004-12-03           Women High Jump   Suat Li Michelle Sng  17  Singapore
# 1  2004-12-02        Men 100 Meter Dash            Izwan Hanif  17  Singapore
# 2  2010-07-12            Men Pole Vault  Ng, Wei Jie, Benjamin  18  Singapore
# 3  2010-07-12        Men Shot Put (5kg)            Tan Zhi Hao  18  Singapore
# 4  2010-07-12  Men Javelin Throw (700g)     Lee Chongyi Justin   -  Singapore
# ..        ...                       ...                    ...  ..        ...
# 70 2006-07-17        Men 100 Meter Dash      Azhari Muhd Yusof  17  Singapore
# 71 2006-07-17  Women Discus Throw (1kg)           Wan, Lay Chi  18  Singapore
# 72 2006-07-17      Women 100 Meter Dash           Ann Siao Mei  19  Singapore
# 73 2006-07-17      Women 100 Meter Dash   Choo Sze-Min, Amanda  19  Singapore
# 74 2006-07-17      Women 100 Meter Dash   Choo Sze-Min, Amanda  19  Singapore
#
#    Result  m/s                               Competition Year D.O.B.  \
# 0      NH    -  International - Commonwealth Youth Games        1987
# 1      DQ -4.3  International - Commonwealth Youth Games        1987
# 2     4.4    -        International - ASEAN School Games        1992
# 3   14.92    -        International - ASEAN School Games        1992
# 4   56.74    -        International - ASEAN School Games           -
# ..    ...  ...                                       ...         ...
# 70  11.12 -0.4              International - Asian Junior        1989
# 71  44.85    -              International - Asian Junior        1988
# 72  12.93   -3              International - Asian Junior        1987
# 73  12.39  0.2              International - Asian Junior        1987
# 74  12.39 -0.8              International - Asian Junior        1987
#
#        Info, if any Date of Birth (PDPA)  \
# 0          f 7/7pos                    -
# 1         h3 6/6pos                    -
# 2   - Final, Silver                    -
# 3   - Final, Bronze                    -
# 4   - Final, Bronze                    -
# ..              ...                  ...
# 70    Semis, 7/8pos                    -
# 71   Final, 6/14pos                    -
# 72       R1, 5/7pos                    -
# 73     R1, 4/6pos q                    -
# 74    Final, 8/8pos                    -
#
#                                           Unnamed: 11
# 0   Bendigo, Australia, La Trobe University Athlet...
# 1   Bendigo, Australia, La Trobe University Athlet...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
#
# [75 rows x 12 columns]

# %%
df14 = df14[df14['Event'].notna()] # take only non-empty rows
df14 = df14.reset_index() # must reset index after filtering

# %%
df14.drop(['Unnamed: 11', 'Date of Birth (PDPA)'],axis=1, inplace=True)

# %%
df14.drop(df14[(df14['Result'] == 'DNS')|(df14['Result'] == 'NH')|(df14['Result'] == 'DQ')].index, inplace = True)

# %%
df14 = df14.reset_index() # must reset index after filtering

# %%
df14.drop(['level_0', 'index'],axis=1, inplace=True)

# %%
df14
# Out:
#          Date                     Event                   Name Age       Team  \
# 0  2010-07-12            Men Pole Vault  Ng, Wei Jie, Benjamin  18  Singapore
# 1  2010-07-12        Men Shot Put (5kg)            Tan Zhi Hao  18  Singapore
# 2  2010-07-12  Men Javelin Throw (700g)     Lee Chongyi Justin   -  Singapore
# 3  2010-07-12  Men Discus Throw (1.5kg)              Teh, Alan  17  Singapore
# 4  2010-07-12       Women 800 Meter Run      Ranjitha D/O Raja  16  Singapore
# ..        ...                       ...                    ...  ..        ...
# 68 2006-07-17        Men 100 Meter Dash      Azhari Muhd Yusof  17  Singapore
# 69 2006-07-17  Women Discus Throw (1kg)           Wan, Lay Chi  18  Singapore
# 70 2006-07-17      Women 100 Meter Dash           Ann Siao Mei  19  Singapore
# 71 2006-07-17      Women 100 Meter Dash   Choo Sze-Min, Amanda  19  Singapore
# 72 2006-07-17      Women 100 Meter Dash   Choo Sze-Min, Amanda  19  Singapore
#
#      Result  m/s                         Competition Year D.O.B.  \
# 0       4.4    -  International - ASEAN School Games        1992
# 1     14.92    -  International - ASEAN School Games        1992
# 2     56.74    -  International - ASEAN School Games           -
# 3     49.29    -  International - ASEAN School Games        1993
# 4   2:37.74    -  International - ASEAN School Games        1994
# ..      ...  ...                                 ...         ...
# 68    11.12 -0.4        International - Asian Junior        1989
# 69    44.85    -        International - Asian Junior        1988
# 70    12.93   -3        International - Asian Junior        1987
# 71    12.39  0.2        International - Asian Junior        1987
# 72    12.39 -0.8        International - Asian Junior        1987
#
#        Info, if any
# 0   - Final, Silver
# 1   - Final, Bronze
# 2   - Final, Bronze
# 3     - Final, Gold
# 4   - Final, Silver
# ..              ...
# 68    Semis, 7/8pos
# 69   Final, 6/14pos
# 70       R1, 5/7pos
# 71     R1, 4/6pos q
# 72    Final, 8/8pos
#
# [73 rows x 10 columns]

# %%
for i in range(len(df14)):

    try:
        rowIndex = df14.index[i]

        input_string=df14.iloc[rowIndex,1]
        metric=df14.iloc[rowIndex,5]
                
        out = preprocess(i, input_string, metric)
    
        df14.loc[rowIndex, 'Metric'] = out
        
    except:
        
        print("Unknown input format encountered at row", i, "input", input_string, "with input value", metric)
        print("Exiting operation")
        break
# Out:
# 18
# 18
# -
# 17
# 16
# 16
# 17
# 18
# 16
# 17
# 17
# 17
# -
# -
# 16
# 17
# -
# -
# -
# 17
# -
# 17
# 24
# 27
# 28
# 27
# 19
# 20
# 18
# 23
# 23
# 24
# 23
# 23
# -
# 28
# 25
# 25
# 25
# 22
# 27
# 22
# 22
# 23
# 23
# 19
# 19
# 19
# 25
# 28
# 27
# 27
# 19
# 21
# 24
# 24
# 27
# 30
# 30
# 19
# 19
# 19
# 16
# -
# 19
# 16
# 16
# 17
# 17
# 18
# 19
# 19
# 19

# %% [markdown]
# # Merge all the dataframes

# %%
frames=[df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13]

# %%
consolidated=pd.concat(frames)

# %%
consolidated.reset_index(drop=True)
# Out:
#          index                 Date                           Event  \
# 0          0.0  2022-01-22 00:00:00                 Women Long Jump
# 1          1.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 2          2.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 3          3.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 4          4.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (0.914m)
# ...        ...                  ...                             ...
# 121498  8037.0  2013-04-15 00:00:00               Women Triple Jump
# 121499  8038.0  2013-03-03 00:00:00               Women Triple Jump
# 121500  8039.0  2013-04-15 00:00:00               Women Triple Jump
# 121501  8040.0  2013-11-23 00:00:00               Women Triple Jump
# 121502  8041.0  2013-01-26 00:00:00               Women Triple Jump
#
#                                   Name Age                     Team Result  \
# 0                  Rozario, Tia Louise  22                Princeton   5.62
# 1                      ANG, Chen Xiang  28     Wings Athletics Club  14.16
# 2                      CHONG, Wei Guan  22    National University o  14.55
# 3                     AWYONG, Liang Qi  27                Club ZOOM  14.77
# 4       MOHAMAD AFZAL, Bin Mohamad Zin  17      Singapore Sports Sc  14.97
# ...                                ...  ..                      ...    ...
# 121498            Kwok Jean Ee Daphne    -                       CG   9.27
# 121499                    Tan, Jessica  18  Victoria Junior College   9.25
# 121500             Joline Aw Juan Lin    -                      SNG   9.11
# 121501       Binte Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.92
# 121502             Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.47
#
#            m/s                                Competition Year D.O.B.  \
# 0       Indoor  International - Wesley Brown invitational        2000
# 1          0.4                          Local - Club Zoom        1994
# 2          0.4                          Local - Club Zoom        2000
# 3          0.4                          Local - Club Zoom        1995
# 4          1.6                          Local - Club Zoom        2005
# ...        ...                                        ...         ...
# 121498     NWI                   Local - National Schools           -
# 121499       4                       SA - U18 U20 C'ships        1995
# 121500     NWI                   Local - National Schools           -
# 121501       0                            Local - POL-ITE           -
# 121502    -1.8                                Local - IVP           -
#
#                               Info, if any  Metric
# 0                         3pos, sanctioned    5.62
# 1                                   New NR   14.16
# 2                                        -   14.55
# 3                                        -   14.77
# 4                                        -   14.97
# ...                                    ...     ...
# 121498     Final, Choa Chu Kang Stadium, -    9.27
# 121499    Finals, Choa Chu Kang Stadium, -    9.25
# 121500     Final, Choa Chu Kang Stadium, -    9.11
# 121501          Flight  1, Nanyang Poly, -    8.92
# 121502  Final, ITE East College (Simei), -    8.47
#
# [121503 rows x 12 columns]

# %%
consolidated
# Out:
#        index                 Date                           Event  \
# 0        0.0  2022-01-22 00:00:00                 Women Long Jump
# 1        1.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 2        2.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 3        3.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 4        4.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (0.914m)
# ...      ...                  ...                             ...
# 8037  8037.0  2013-04-15 00:00:00               Women Triple Jump
# 8038  8038.0  2013-03-03 00:00:00               Women Triple Jump
# 8039  8039.0  2013-04-15 00:00:00               Women Triple Jump
# 8040  8040.0  2013-11-23 00:00:00               Women Triple Jump
# 8041  8041.0  2013-01-26 00:00:00               Women Triple Jump
#
#                                 Name Age                     Team Result  \
# 0                Rozario, Tia Louise  22                Princeton   5.62
# 1                    ANG, Chen Xiang  28     Wings Athletics Club  14.16
# 2                    CHONG, Wei Guan  22    National University o  14.55
# 3                   AWYONG, Liang Qi  27                Club ZOOM  14.77
# 4     MOHAMAD AFZAL, Bin Mohamad Zin  17      Singapore Sports Sc  14.97
# ...                              ...  ..                      ...    ...
# 8037            Kwok Jean Ee Daphne    -                       CG   9.27
# 8038                    Tan, Jessica  18  Victoria Junior College   9.25
# 8039             Joline Aw Juan Lin    -                      SNG   9.11
# 8040       Binte Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.92
# 8041             Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.47
#
#          m/s                                Competition Year D.O.B.  \
# 0     Indoor  International - Wesley Brown invitational        2000
# 1        0.4                          Local - Club Zoom        1994
# 2        0.4                          Local - Club Zoom        2000
# 3        0.4                          Local - Club Zoom        1995
# 4        1.6                          Local - Club Zoom        2005
# ...      ...                                        ...         ...
# 8037     NWI                   Local - National Schools           -
# 8038       4                       SA - U18 U20 C'ships        1995
# 8039     NWI                   Local - National Schools           -
# 8040       0                            Local - POL-ITE           -
# 8041    -1.8                                Local - IVP           -
#
#                             Info, if any  Metric
# 0                       3pos, sanctioned    5.62
# 1                                 New NR   14.16
# 2                                      -   14.55
# 3                                      -   14.77
# 4                                      -   14.97
# ...                                  ...     ...
# 8037     Final, Choa Chu Kang Stadium, -    9.27
# 8038    Finals, Choa Chu Kang Stadium, -    9.25
# 8039     Final, Choa Chu Kang Stadium, -    9.11
# 8040          Flight  1, Nanyang Poly, -    8.92
# 8041  Final, ITE East College (Simei), -    8.47
#
# [121503 rows x 12 columns]

# %%
#consolidated.drop(['level_0', 'index'],axis=1, inplace=True)

# %%
consolidated
# Out:
#        index                 Date                           Event  \
# 0        0.0  2022-01-22 00:00:00                 Women Long Jump
# 1        1.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 2        2.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 3        3.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 4        4.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (0.914m)
# ...      ...                  ...                             ...
# 8037  8037.0  2013-04-15 00:00:00               Women Triple Jump
# 8038  8038.0  2013-03-03 00:00:00               Women Triple Jump
# 8039  8039.0  2013-04-15 00:00:00               Women Triple Jump
# 8040  8040.0  2013-11-23 00:00:00               Women Triple Jump
# 8041  8041.0  2013-01-26 00:00:00               Women Triple Jump
#
#                                 Name Age                     Team Result  \
# 0                Rozario, Tia Louise  22                Princeton   5.62
# 1                    ANG, Chen Xiang  28     Wings Athletics Club  14.16
# 2                    CHONG, Wei Guan  22    National University o  14.55
# 3                   AWYONG, Liang Qi  27                Club ZOOM  14.77
# 4     MOHAMAD AFZAL, Bin Mohamad Zin  17      Singapore Sports Sc  14.97
# ...                              ...  ..                      ...    ...
# 8037            Kwok Jean Ee Daphne    -                       CG   9.27
# 8038                    Tan, Jessica  18  Victoria Junior College   9.25
# 8039             Joline Aw Juan Lin    -                      SNG   9.11
# 8040       Binte Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.92
# 8041             Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.47
#
#          m/s                                Competition Year D.O.B.  \
# 0     Indoor  International - Wesley Brown invitational        2000
# 1        0.4                          Local - Club Zoom        1994
# 2        0.4                          Local - Club Zoom        2000
# 3        0.4                          Local - Club Zoom        1995
# 4        1.6                          Local - Club Zoom        2005
# ...      ...                                        ...         ...
# 8037     NWI                   Local - National Schools           -
# 8038       4                       SA - U18 U20 C'ships        1995
# 8039     NWI                   Local - National Schools           -
# 8040       0                            Local - POL-ITE           -
# 8041    -1.8                                Local - IVP           -
#
#                             Info, if any  Metric
# 0                       3pos, sanctioned    5.62
# 1                                 New NR   14.16
# 2                                      -   14.55
# 3                                      -   14.77
# 4                                      -   14.97
# ...                                  ...     ...
# 8037     Final, Choa Chu Kang Stadium, -    9.27
# 8038    Finals, Choa Chu Kang Stadium, -    9.25
# 8039     Final, Choa Chu Kang Stadium, -    9.11
# 8040          Flight  1, Nanyang Poly, -    8.92
# 8041  Final, ITE East College (Simei), -    8.47
#
# [121503 rows x 12 columns]

# %%
women_100m_dash_all=consolidated[(consolidated['Event']=='Women 100 Meter Dash')].copy()

# %%
women_100m_dash_all.reset_index(drop=True)
# Out:
#        index                 Date                 Event  \
# 0       36.0  2022-01-15 00:00:00  Women 100 Meter Dash
# 1       37.0  2022-01-15 00:00:00  Women 100 Meter Dash
# 2       38.0  2022-01-15 00:00:00  Women 100 Meter Dash
# 3       43.0  2022-01-15 00:00:00  Women 100 Meter Dash
# 4       44.0  2022-01-15 00:00:00  Women 100 Meter Dash
# ...      ...                  ...                   ...
# 8553  5514.0  2013-05-18 00:00:00  Women 100 Meter Dash
# 8554  5515.0  2013-03-31 00:00:00  Women 100 Meter Dash
# 8555  5516.0  2013-01-26 00:00:00  Women 100 Meter Dash
# 8556  5517.0  2013-01-26 00:00:00  Women 100 Meter Dash
# 8557  5518.0  2013-01-05 00:00:00  Women 100 Meter Dash
#
#                          Name Age                          Team Result  m/s  \
# 0        CHANDRAN , Kugapriya  24                         Swift  12.52  0.4
# 1          ENDRIQUEZ, Roxanne  26          Wings Athletics Club  12.67  0.4
# 2                ONG, Kerstin  25                     Club ZOOM  12.97  0.4
# 3                 LUI, Zi Xun  11            Henry Park Pri Sch  15.79    1
# 4     SCHIERING, Nur Isabella  11                 Verve Fitness  17.64    1
# ...                       ...  ..                           ...    ...  ...
# 8553      Bte Nahar, Norrizan  32  SG Disability Sports Council  17.53   -1
# 8554               Shiu, Kyra  14    Chij Secondary (Toa Payoh)  17.57 -1.1
# 8555      Oh, Ern Ning, Lydia  16  Cedar Girls Secondary School  18.01  3.5
# 8556             Chu, Gillian  14  Cedar Girls Secondary School  19.06  3.7
# 8557        Tan, Naomi Louise  16    Nanyang Girls' High School  19.36  1.2
#
#             Competition Year D.O.B.                        Info, if any  \
# 0     Local - Club Zoom        1998                                   -
# 1     Local - Club Zoom        1996                                   -
# 2     Local - Club Zoom        1997                                   -
# 3     Local - Club Zoom        2011                                   -
# 4     Local - Club Zoom        2011                                   -
# ...                 ...         ...                                 ...
# 8553      SA - Series 4        1981    Finals, Choa Chu Kang Stadium, -
# 8554      SA - Series 3        1999      Final, Bukit Gombak Stadium, -
# 8555      SA - Series 2        1997  Final, ITE College East (Simei), -
# 8556      SA - Series 2        1999  Final, ITE College East (Simei), -
# 8557      SA - Series 1        1997         Final, ITE Simei College, -
#
#       Metric
# 0      12.52
# 1      12.67
# 2      12.97
# 3      15.79
# 4      17.64
# ...      ...
# 8553   17.53
# 8554   17.57
# 8555   18.01
# 8556   19.06
# 8557   19.36
#
# [8558 rows x 12 columns]

# %%
women_100m_dash_all.describe()
# Out:
#               index       Metric
# count   7453.000000  8558.000000
# mean    3494.007514    14.572123
# std     2958.994843     1.565954
# min        8.000000    11.480000
# 25%     1487.000000    13.580000
# 50%     2025.000000    14.350000
# 75%     5291.000000    15.320000
# max    14996.000000    49.980000

# %%
women_100m_dash_all.loc[women_100m_dash_all['Metric'].idxmax()]
# Out:
# index                               11670.0
# Date                    2018-05-05 00:00:00
# Event                  Women 100 Meter Dash
# Name                       Sharada, Chellam
# Age                                      93
# Team                              Team Saga
# Result                                49.98
# m/s                                    -0.9
# Competition     SA - Singapore Masters Open
# Year D.O.B.                            1925
# Info, if any                              -
# Metric                                49.98
# Name: 11670, dtype: object

# %%
# Convert to lognormal

women_100m_dash_all['lognorm_metric']=np.log(women_100m_dash_all['Metric'])

# %%
women_100m_dash_all['Metric']
# Out:
# 36      12.52
# 37      12.67
# 38      12.97
# 43      15.79
# 44      17.64
#         ...
# 5514    17.53
# 5515    17.57
# 5516    18.01
# 5517    19.06
# 5518    19.36
# Name: Metric, Length: 8558, dtype: float64

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(women_100m_dash_all['lognorm_metric'], ax=ax)
ax.set_xlim(2.3, 3)
#ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(women_100m_dash_all['Metric'], ax=ax)
ax.set_xlim(11, 19)
#ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Women_Triple_Jump_all=consolidated[(consolidated['Event']=='Women Triple Jump')].copy()

# %%
Women_Triple_Jump_all.reset_index(drop=True)
# Out:
#        index                 Date              Event  \
# 0      835.0  2022-01-23 00:00:00  Women Triple Jump
# 1      836.0  2022-01-23 00:00:00  Women Triple Jump
# 2      837.0  2022-01-23 00:00:00  Women Triple Jump
# 3      838.0  2022-01-23 00:00:00  Women Triple Jump
# 4      839.0  2022-01-23 00:00:00  Women Triple Jump
# ...      ...                  ...                ...
# 1321  8037.0  2013-04-15 00:00:00  Women Triple Jump
# 1322  8038.0  2013-03-03 00:00:00  Women Triple Jump
# 1323  8039.0  2013-04-15 00:00:00  Women Triple Jump
# 1324  8040.0  2013-11-23 00:00:00  Women Triple Jump
# 1325  8041.0  2013-01-26 00:00:00  Women Triple Jump
#
#                            Name Age                     Team Result  m/s  \
# 0                 TAN, TSE TENG  20              Nanyang Tec   11.4  1.1
# 1                   TAN, JURNUS  18            Wings Athleti   11.2    0
# 2              CHANDRU, BHAVIKA  18             Singapore Sp  10.77  1.7
# 3                   NG, JING NI  18             Singapore Sp   10.5  0.2
# 4                    TAN, CHLOE  18             Singapore Sp  10.06    0
# ...                         ...  ..                      ...    ...  ...
# 1321       Kwok Jean Ee Daphne    -                       CG   9.27  NWI
# 1322               Tan, Jessica  18  Victoria Junior College   9.25    4
# 1323        Joline Aw Juan Lin    -                      SNG   9.11  NWI
# 1324  Binte Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.92    0
# 1325        Ridwan, Siti Sofiah   -    Singapore Polytechnic   8.47 -1.8
#
#                       Competition Year D.O.B.  \
# 0     SA - National Championships        2002
# 1     SA - National Championships        2004
# 2     SA - National Championships        2004
# 3     SA - National Championships        2004
# 4     SA - National Championships        2004
# ...                           ...         ...
# 1321     Local - National Schools           -
# 1322         SA - U18 U20 C'ships        1995
# 1323     Local - National Schools           -
# 1324              Local - POL-ITE           -
# 1325                  Local - IVP           -
#
#                             Info, if any  Metric
# 0                                      -   11.40
# 1                                      -   11.20
# 2                                      -   10.77
# 3                                      -   10.50
# 4                                      -   10.06
# ...                                  ...     ...
# 1321     Final, Choa Chu Kang Stadium, -    9.27
# 1322    Finals, Choa Chu Kang Stadium, -    9.25
# 1323     Final, Choa Chu Kang Stadium, -    9.11
# 1324          Flight  1, Nanyang Poly, -    8.92
# 1325  Final, ITE East College (Simei), -    8.47
#
# [1326 rows x 12 columns]

# %%
Women_Triple_Jump_all.describe()
# Out:
#               index       Metric
# count   1172.000000  1326.000000
# mean    8984.397611     9.909306
# std     3798.331851     1.055224
# min        6.000000     4.020000
# 25%     7978.750000     9.392500
# 50%     9933.500000    10.020000
# 75%    12385.250000    10.560000
# max    14805.000000    12.540000

# %%
# Convert to inverse log for jumps

Women_Triple_Jump_all['lognorm_metric']=np.log(Women_Triple_Jump_all['Metric'])-1

# %%
Women_Triple_Jump_all['lognorm_metric']
# Out:
# 835     1.433613
# 836     1.415914
# 837     1.376764
# 838     1.351375
# 839     1.308567
#           ...
# 8037    1.226783
# 8038    1.224624
# 8039    1.209373
# 8040    1.188296
# 8041    1.136531
# Name: lognorm_metric, Length: 1326, dtype: float64

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(Women_Triple_Jump_all['Metric'], ax=ax)
#ax.set_xlim(10, 20)
#ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(Women_Triple_Jump_all['lognorm_metric'], ax=ax)
#ax.set_xlim(10, 20)
#ax.set_ylim(1, 2)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Men_110m_Hurdles_all=consolidated[(consolidated['Event']=='Men 110 Meter Hurdles (1.067m)')].copy()
Men_110m_Hurdles_all.reset_index(drop=True)
# Out:
#       index                 Date                           Event  \
# 0       1.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 1       2.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 2       3.0  2022-01-15 00:00:00  Men 110 Meter Hurdles (1.067m)
# 3     840.0  2022-01-23 00:00:00  Men 110 Meter Hurdles (1.067m)
# 4     841.0  2022-01-23 00:00:00  Men 110 Meter Hurdles (1.067m)
# ..      ...                  ...                             ...
# 487  2976.0  2013-01-26 00:00:00  Men 110 Meter Hurdles (1.067m)
# 488  2977.0  2013-01-26 00:00:00  Men 110 Meter Hurdles (1.067m)
# 489  2978.0  2013-11-30 00:00:00  Men 110 Meter Hurdles (1.067m)
# 490  2979.0  2013-10-05 00:00:00  Men 110 Meter Hurdles (1.067m)
# 491  2980.0  2013-11-30 00:00:00  Men 110 Meter Hurdles (1.067m)
#
#                      Name Age                   Team Result  m/s  \
# 0         ANG, Chen Xiang  28   Wings Athletics Club  14.16  0.4
# 1         CHONG, Wei Guan  22  National University o  14.55  0.4
# 2        AWYONG, Liang Qi  27              Club ZOOM  14.77  0.4
# 3         ANG, CHEN XIANG  28   Wings Athletics Club  13.97  1.5
# 4         CHONG, WEI GUAN  22  National University S   14.3  1.5
# ..                    ...  ..                    ...    ...  ...
# 487   Lim, Xuan Ang Angus  18   Ngee Ann Polytechnic  20.94    3
# 488   Bin Zainal, Syazwan  18    Nanyang Polytechnic  20.99  1.2
# 489   Sivakumar, Ananthan   -  Singapore Polytechnic  21.26    0
# 490   Bin Zainal, Syazwan  19    Nanyang Polytechnic  21.53  NWI
# 491  Angnus Lim, Xuan Ang   -   Ngee Ann Polytechnic  21.74    0
#
#                      Competition Year D.O.B.  \
# 0              Local - Club Zoom        1994
# 1              Local - Club Zoom        2000
# 2              Local - Club Zoom        1995
# 3    SA - National Championships        1994
# 4    SA - National Championships        2000
# ..                           ...         ...
# 487                  Local - IVP        1995
# 488                  Local - IVP        1995
# 489              Local - POL-ITE           -
# 490        SA - U23 Open C'ships        1994
# 491              Local - POL-ITE           -
#
#                           Info, if any  Metric
# 0                               New NR   14.16
# 1                                    -   14.55
# 2                                    -   14.77
# 3                               New NR   13.97
# 4                             New U23R   14.30
# ..                                 ...     ...
# 487  Heat, ITE East College (Simei), -   20.94
# 488  Heat, ITE East College (Simei), -   20.99
# 489        Section  1, Nanyang Poly, -   21.26
# 490             Finals, CCK Stadium, -   21.53
# 491        Section  1, Nanyang Poly, -   21.74
#
# [492 rows x 12 columns]

# %%
Men_110m_Hurdles_all.describe()
# Out:
#               index      Metric
# count    432.000000  492.000000
# mean    6766.527778   17.360041
# std     4167.209750    2.712015
# min        1.000000   13.940000
# 25%     2976.000000   15.075000
# 50%     6734.500000   16.725000
# 75%     9376.250000   19.037500
# max    15117.000000   30.580000

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()

sns.distplot(Men_110m_Hurdles_all['Metric'], ax=ax)
#ax.set_xlim(10, 20)
#ax.set_ylim(0, 1.5)
plt.show()
# Out:
# /Users/veesheenyuen/.pyenv/versions/3.10.6/envs/SAA/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
consolidated.to_csv("consolidated.csv")
