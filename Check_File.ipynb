# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import usual modules
import pandas as pd
import csv
import math
import os
import numpy as np
import openpyxl
import datetime
import re
import string
from bs4 import BeautifulSoup
import requests
import requests

from date_extractor import extract_dates

# %%
# Merge NSG files

os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/NSG/NSG2025/Corrected_Results/')

df = pd.read_csv("sectrack_result_01a_corrected.csv")
df2 = pd.read_csv("sectrack_result_02a_corrected.csv")
df3 = pd.read_csv("sectrack_result_03a_corrected.csv")
df4 = pd.read_csv("sectrack_result_04a_corrected.csv")
df5 = pd.read_csv("sectrack_result_05a_corrected.csv")
df6 = pd.read_csv("sectrack_result_06a_corrected.csv")
df7 = pd.read_csv("sectrack_result_07a_corrected.csv")
df8 = pd.read_csv("sectrack_result_08b_corrected.csv")
df9 = pd.read_csv("sectrack_result_09b_corrected.csv")
df10 = pd.read_csv("sectrack_result_10a_corrected.csv")
df11 = pd.read_csv("sectrack_result_11_corrected.csv")
df12 = pd.read_csv("sectrack_result_12_corrected.csv")
df13 = pd.read_csv("sectrack_result_13a_corrected.csv")
df14 = pd.read_csv("sectrack_result_14a_corrected.csv")
df15 = pd.read_csv("sectrack_result_15_corrected.csv")
df16 = pd.read_csv("sectrack_result_16_corrected.csv")
df17 = pd.read_csv("sectrack_result_17_corrected.csv")
df18 = pd.read_csv("sectrack_result_18a_corrected.csv")
df19 = pd.read_csv("sectrack_result_19a_corrected.csv")
df20 = pd.read_csv("sectrack_result_20_corrected.csv")
df21 = pd.read_csv("sectrack_result_21_corrected.csv")
df22 = pd.read_csv("sectrack_result_22a_corrected.csv")




df_merged = pd.concat([df, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22], ignore_index=True, sort=False)

# %%
df_merged
# Out:
#       FIRST_NAME  LAST_NAME  OTHER_NAME                           NAME  RANK  \
# 0            NaN        NaN         NaN           Jayden Toh Yang Jie    1.0
# 1            NaN        NaN         NaN              Dawson Oh Xu Jie    2.0
# 2            NaN        NaN         NaN             Zhao Haoze Daniel    3.0
# 3            NaN        NaN         NaN          Ong Tian Wei Gabriel    4.0
# 4            NaN        NaN         NaN             Wu Xianle Zachary    5.0
# ...          ...        ...         ...                            ...   ...
# 4930         NaN        NaN         NaN   St. Andrew's Junior College    5.0
# 4931         NaN        NaN         NaN       Catholic Junior College    6.0
# 4932         NaN        NaN         NaN  Yishun Innova Junior College    7.0
# 4933         NaN        NaN         NaN       National Junior College    8.0
# 4934         NaN        NaN         NaN            Dunman High School    9.0
#
#       TAG_ID  TEAM  SEED    RESULT QUALIFICATION  ...  \
# 0      455.0    VS   NaN     12.84           NaN  ...
# 1      525.0   HCI   NaN     12.39           NaN  ...
# 2      570.0   HCI   NaN     11.68           NaN  ...
# 3      235.0    RI   NaN     11.34           NaN  ...
# 4       74.0    CH   NaN     11.29           NaN  ...
# ...      ...   ...   ...       ...           ...  ...
# 4930     NaN  SAJC   NaN  03:43.06           NaN  ...
# 4931     NaN   CJC   NaN  03:43.67           NaN  ...
# 4932     NaN  YIJC   NaN  03:45.03           NaN  ...
# 4933     NaN   NJC   NaN  03:47.40           NaN  ...
# 4934     NaN   DHS   NaN  04:01.80           NaN  ...
#
#                                                SOURCE  REMARKS  TIMESTAMP  \
# 0     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 1     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 2     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 3     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 4     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# ...                                               ...      ...        ...
# 4930  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 4931  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 4932  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 4933  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
# 4934  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN        NaN
#
#      VENUE SUB_EVENT SESSION  EVENT_CLASS  DISTANCE  HOST_CITY  RX_TIME
# 0      NaN       NaN  S01-01          NaN       NaN  Singapore      NaN
# 1      NaN       NaN  S01-01          NaN       NaN  Singapore      NaN
# 2      NaN       NaN  S01-01          NaN       NaN  Singapore      NaN
# 3      NaN       NaN  S01-01          NaN       NaN  Singapore      NaN
# 4      NaN       NaN  S01-01          NaN       NaN  Singapore      NaN
# ...    ...       ...     ...          ...       ...        ...      ...
# 4930   NaN       NaN  S22-22          NaN       NaN  Singapore      NaN
# 4931   NaN       NaN  S22-22          NaN       NaN  Singapore      NaN
# 4932   NaN       NaN  S22-22          NaN       NaN  Singapore      NaN
# 4933   NaN       NaN  S22-22          NaN       NaN  Singapore      NaN
# 4934   NaN       NaN  S22-22          NaN       NaN  Singapore      NaN
#
# [4935 rows x 40 columns]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/NSG/NSG2025/Corrected_Results/')

df_merged.to_csv("All_results_merged.csv", index=False, encoding="utf-8")

# %%
#os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/Tilastopaja/Singapore Athletes Events/2025/May/Third')

#df = pd.read_csv("SGP_athletes_May_2025_third.csv")

df=df_merged

# %%
#today = datetime.datetime.now().strftime('%Y-%m-%d')
ct = datetime.datetime.now()
gender_pattern = 'Male|Female|Mixed'
year_pattern = '20\d\d'
df['TIMESTAMP'] = pd.to_datetime(df['TIMESTAMP'])
df['YEAR'] = df['YEAR'].astype(str)

try:

    for index, row in df.iterrows():

        assert re.search(gender_pattern, row['GENDER']) is not None   # check format of gender input
        assert row['NAME'] != None
        assert row['EVENT'] != None 
        assert row['COMPETITION'] != None 
        assert row['REGION'] != None 
        assert re.search(year_pattern, row['YEAR']) is not None   # check format of year

            # Check column locations before loading

        assert len(df.columns) == 40
        assert df.columns.get_loc('RESULT') == 8
        assert df.columns.get_loc('AGE') == 17
        assert df.columns.get_loc('WIND') == 12
        assert df.columns.get_loc('COMPETITION')==24

            # Set timestamp

        df.loc[:,'TIMESTAMP'] = ct

    print("Column position check pass")
    print("Passed data completeness check")

        
        
except:
        
        print('Problem With Input File. Upload into BigQuery Aborted')
# Out:
# Column position check pass
# Passed data completeness check

# %%
df
# Out:
#       FIRST_NAME  LAST_NAME  OTHER_NAME                           NAME  RANK  \
# 0            NaN        NaN         NaN           Jayden Toh Yang Jie    1.0
# 1            NaN        NaN         NaN              Dawson Oh Xu Jie    2.0
# 2            NaN        NaN         NaN             Zhao Haoze Daniel    3.0
# 3            NaN        NaN         NaN          Ong Tian Wei Gabriel    4.0
# 4            NaN        NaN         NaN             Wu Xianle Zachary    5.0
# ...          ...        ...         ...                            ...   ...
# 4930         NaN        NaN         NaN   St. Andrew's Junior College    5.0
# 4931         NaN        NaN         NaN       Catholic Junior College    6.0
# 4932         NaN        NaN         NaN  Yishun Innova Junior College    7.0
# 4933         NaN        NaN         NaN       National Junior College    8.0
# 4934         NaN        NaN         NaN            Dunman High School    9.0
#
#       TAG_ID  TEAM  SEED    RESULT QUALIFICATION  ...  \
# 0      455.0    VS   NaN     12.84           NaN  ...
# 1      525.0   HCI   NaN     12.39           NaN  ...
# 2      570.0   HCI   NaN     11.68           NaN  ...
# 3      235.0    RI   NaN     11.34           NaN  ...
# 4       74.0    CH   NaN     11.29           NaN  ...
# ...      ...   ...   ...       ...           ...  ...
# 4930     NaN  SAJC   NaN  03:43.06           NaN  ...
# 4931     NaN   CJC   NaN  03:43.67           NaN  ...
# 4932     NaN  YIJC   NaN  03:45.03           NaN  ...
# 4933     NaN   NJC   NaN  03:47.40           NaN  ...
# 4934     NaN   DHS   NaN  04:01.80           NaN  ...
#
#                                                SOURCE  REMARKS  \
# 0     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 1     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 2     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 3     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 4     https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# ...                                               ...      ...
# 4930  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 4931  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 4932  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 4933  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
# 4934  https://nsg.rjcat.com/sectrack_2025/ss_home.php      NaN
#
#                       TIMESTAMP VENUE SUB_EVENT SESSION  EVENT_CLASS  \
# 0    2025-06-06 15:35:30.807106   NaN       NaN  S01-01          NaN
# 1    2025-06-06 15:35:30.807106   NaN       NaN  S01-01          NaN
# 2    2025-06-06 15:35:30.807106   NaN       NaN  S01-01          NaN
# 3    2025-06-06 15:35:30.807106   NaN       NaN  S01-01          NaN
# 4    2025-06-06 15:35:30.807106   NaN       NaN  S01-01          NaN
# ...                         ...   ...       ...     ...          ...
# 4930 2025-06-06 15:35:30.807106   NaN       NaN  S22-22          NaN
# 4931 2025-06-06 15:35:30.807106   NaN       NaN  S22-22          NaN
# 4932 2025-06-06 15:35:30.807106   NaN       NaN  S22-22          NaN
# 4933 2025-06-06 15:35:30.807106   NaN       NaN  S22-22          NaN
# 4934 2025-06-06 15:35:30.807106   NaN       NaN  S22-22          NaN
#
#       DISTANCE  HOST_CITY  RX_TIME
# 0          NaN  Singapore      NaN
# 1          NaN  Singapore      NaN
# 2          NaN  Singapore      NaN
# 3          NaN  Singapore      NaN
# 4          NaN  Singapore      NaN
# ...        ...        ...      ...
# 4930       NaN  Singapore      NaN
# 4931       NaN  Singapore      NaN
# 4932       NaN  Singapore      NaN
# 4933       NaN  Singapore      NaN
# 4934       NaN  Singapore      NaN
#
# [4935 rows x 40 columns]

# %%
os.chdir('/Users/veesheenyuen/Desktop/DataScience/SAA/NSG/NSG2025/Corrected_Results/')

df_merged.to_csv("All_results_merged_checked.csv", index=False, encoding="utf-8")
